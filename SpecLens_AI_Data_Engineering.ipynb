# %% [markdown]
# <a href="https://colab.research.google.com/github/rajeshxdatascience/SpecLens-AI/blob/main/SpecLens_AI_Data_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.width',None)
pd.set_option('display.max_colwidth',None)

# %%
df = pd.read_csv('/content/24_jan_smartphones_columns_for_ml.csv')

# %%
df.head()
# Out:
#    model_id                               model  expert_rating  rating  \
# 0         1       Apple iPhone 14 (6GB + 256GB)             69     4.6
# 1         2       Apple iPhone 14 (6GB + 512GB)             69     4.6
# 2         3  Apple iPhone 14 Plus (6GB + 256GB)             72     4.6
# 3         4  Apple iPhone 14 Plus (6GB + 512GB)             72     4.6
# 4         5                Apple iPhone 14 Plus             72     4.6
#
#     rating_count market_status    launch_on  \
# 0  (321KRatings)      In Stock  07 Sep 2022
# 1  (321KRatings)  Out of Stock  07 Sep 2022
# 2   (87KRatings)  Out of Stock  07 Sep 2022
# 3   (87KRatings)  Out of Stock  07 Sep 2022
# 4   (87KRatings)      In Stock  07 Sep 2022
#
#                                              old_price    price launch_price  \
# 0    Was ₹56,999 2 day(s) ago Was ₹56,999 2 day(s) ago  ₹64,900      ₹79,900
# 1  Lowest price since launch Lowest price since launch  ₹89,900      ₹79,900
# 2  Lowest price since launch Lowest price since launch  ₹79,900      ₹89,900
# 3  Lowest price since launch Lowest price since launch  ₹99,900      ₹89,900
# 4  Lowest price since launch Lowest price since launch  ₹69,900      ₹89,900
#
#                                               display_type  \
# 0  Super Retina XDR OLED, 60 Hz Refresh Rate, Dolby Vision
# 1  Super Retina XDR OLED, 60 Hz Refresh Rate, Dolby Vision
# 2  Super Retina XDR OLED, 60 Hz Refresh Rate, Dolby Vision
# 3  Super Retina XDR OLED, 60 Hz Refresh Rate, Dolby Vision
# 4  Super Retina XDR OLED, 60 Hz Refresh Rate, Dolby Vision
#
#                                         display_size  \
# 0     6.1 inches, 90.2 cm², 86% Screen To Body Ratio
# 1     6.1 inches, 90.2 cm², 86% Screen To Body Ratio
# 2  6.7 inches, 109.8 cm², 87.4% Screen To Body Ratio
# 3  6.7 inches, 109.8 cm², 87.4% Screen To Body Ratio
# 4  6.7 inches, 109.8 cm², 87.4% Screen To Body Ratio
#
#                                                                                                                                                   display_res  \
# 0                                FHD+, 1170 x  2532 pixels, 19.5:9 (460 ppi), 8-bit colours, 82% DCI-P3, 1200 nits(Peak Brightness), 2000000:1 Contrast Ratio
# 1                                FHD+, 1170 x  2532 pixels, 19.5:9 (460 ppi), 8-bit colours, 82% DCI-P3, 1200 nits(Peak Brightness), 2000000:1 Contrast Ratio
# 2  FHD+, 1284 x  2778 pixels, 19.5:9 (458 ppi), 8-bit colours, 85% DCI-P3, 1200 nits(Peak Brightness), 800 nits(Typical Brightness), 2000000:1 Contrast Ratio
# 3  FHD+, 1284 x  2778 pixels, 19.5:9 (458 ppi), 8-bit colours, 85% DCI-P3, 1200 nits(Peak Brightness), 800 nits(Typical Brightness), 2000000:1 Contrast Ratio
# 4  FHD+, 1284 x  2778 pixels, 19.5:9 (458 ppi), 8-bit colours, 85% DCI-P3, 1200 nits(Peak Brightness), 800 nits(Typical Brightness), 2000000:1 Contrast Ratio
#
#           body_dimension     weight body_front body_back        body_side  \
# 0  146.7 x 71.5 x 7.8 mm  172 grams      Glass     Glass  Aluminium Frame
# 1  146.7 x 71.5 x 7.8 mm  172 grams      Glass     Glass  Aluminium Frame
# 2  160.8 x 78.1 x 7.8 mm  203 grams      Glass     Glass  Aluminium Frame
# 3  160.8 x 78.1 x 7.8 mm  203 grams      Glass     Glass  Aluminium Frame
# 4  160.8 x 78.1 x 7.8 mm  203 grams      Glass     Glass  Aluminium Frame
#
#         build_quality              ports                        ip_rating  \
# 0  Corning-made Glass  Lightning USB 2.0  IP68 (Dust and Water Resistant)
# 1  Corning-made Glass  Lightning USB 2.0  IP68 (Dust and Water Resistant)
# 2  Corning-made Glass  Lightning USB 2.0  IP68 (Dust and Water Resistant)
# 3  Corning-made Glass  Lightning USB 2.0  IP68 (Dust and Water Resistant)
# 4  Corning-made Glass  Lightning USB 2.0  IP68 (Dust and Water Resistant)
#
#            speaker                                        chipset  \
# 0  Stereo Speakers  Apple A15 Bionic (5 nm), 1287587 Antutu Score
# 1  Stereo Speakers  Apple A15 Bionic (5 nm), 1287587 Antutu Score
# 2  Stereo Speakers  Apple A15 Bionic (5 nm), 1287587 Antutu Score
# 3  Stereo Speakers  Apple A15 Bionic (5 nm), 1287587 Antutu Score
# 4  Stereo Speakers  Apple A15 Bionic (5 nm), 1287587 Antutu Score
#
#                                                       cpu  \
# 0  Hexa-core (2x3.23 GHz Avalanche + 4x1.82 GHz Blizzard)
# 1  Hexa-core (2x3.23 GHz Avalanche + 4x1.82 GHz Blizzard)
# 2  Hexa-core (2x3.23 GHz Avalanche + 4x1.82 GHz Blizzard)
# 3  Hexa-core (2x3.23 GHz Avalanche + 4x1.82 GHz Blizzard)
# 4  Hexa-core (2x3.23 GHz Avalanche + 4x1.82 GHz Blizzard)
#
#                            gpu  \
# 0  Apple GPU (5-core graphics)
# 1  Apple GPU (5-core graphics)
# 2  Apple GPU (5-core graphics)
# 3  Apple GPU (5-core graphics)
# 4  Apple GPU (5-core graphics)
#
#                                             main_cam  \
# 0  12 MP, f/1.5, 26mm (Wide-angle), Sensor-Shift OIS
# 1  12 MP, f/1.5, 26mm (Wide-angle), Sensor-Shift OIS
# 2  12 MP, f/1.5, 26mm (Wide-angle), Sensor-Shift OIS
# 3  12 MP, f/1.5, 26mm (Wide-angle), Sensor-Shift OIS
# 4  12 MP, f/1.5, 26mm (Wide-angle), Sensor-Shift OIS
#
#                                 main_cam2 main_cam3  \
# 0  12 MP, f/2.4, 13mm  (Ultra-wide), 120°       NaN
# 1  12 MP, f/2.4, 13mm  (Ultra-wide), 120°       NaN
# 2  12 MP, f/2.4, 13mm  (Ultra-wide), 120°       NaN
# 3  12 MP, f/2.4, 13mm  (Ultra-wide), 120°       NaN
# 4  12 MP, f/2.4, 13mm  (Ultra-wide), 120°       NaN
#
#                                                                                           main_cam_features  \
# 0  Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
# 1  Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
# 2  Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
# 3  Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
# 4  Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
#
#                                                                                                                               main_video  \
# 0  4K@24/25/30/60fps, 1080p@25/30/60/120/240fps, 720p@30fps, Cinematic mode, Dolby Vision HDR (up to 60fps), HDR, Stereo Sound Recording
# 1  4K@24/25/30/60fps, 1080p@25/30/60/120/240fps, 720p@30fps, Cinematic mode, Dolby Vision HDR (up to 60fps), HDR, Stereo Sound Recording
# 2                          4K@24/25/30/60fps, 1080p@25/30/60/120/240fps, 720p@30fps, Cinematic mode, Dolby Vision HDR (up to 60fps), HDR
# 3                          4K@24/25/30/60fps, 1080p@25/30/60/120/240fps, 720p@30fps, Cinematic mode, Dolby Vision HDR (up to 60fps), HDR
# 4                          4K@24/25/30/60fps, 1080p@25/30/60/120/240fps, 720p@30fps, Cinematic mode, Dolby Vision HDR (up to 60fps), HDR
#
#        os                            software_updates ai_features  \
# 0  iOS 16  5 year(s) of Software and Security updates         NaN
# 1  iOS 16  5 year(s) of Software and Security updates         NaN
# 2  iOS 16  5 year(s) of Software and Security updates         NaN
# 3  iOS 16  5 year(s) of Software and Security updates         NaN
# 4  iOS 16  5 year(s) of Software and Security updates         NaN
#
#                                   front_cam  \
# 0  12 MP, f/1.9, 23mm  (Wide), 1/3.6", PDAF
# 1  12 MP, f/1.9, 23mm  (Wide), 1/3.6", PDAF
# 2  12 MP, f/1.9, 23mm  (Wide), 1/3.6", PDAF
# 3  12 MP, f/1.9, 23mm  (Wide), 1/3.6", PDAF
# 4  12 MP, f/1.9, 23mm  (Wide), 1/3.6", PDAF
#
#                       front_cam_features  \
# 0  Auto Focus, Cinematic mode (4k@30fps)
# 1  Auto Focus, Cinematic mode (4k@30fps)
# 2  Auto Focus, Cinematic mode (4k@30fps)
# 3  Auto Focus, Cinematic mode (4k@30fps)
# 4  Auto Focus, Cinematic mode (4k@30fps)
#
#                                           front_video  \
# 0  1080p@25/30/60/120fps, 4K@24/25/30/60fps, gyro-EIS
# 1  1080p@25/30/60/120fps, 4K@24/25/30/60fps, gyro-EIS
# 2  1080p@25/30/60/120fps, 4K@24/25/30/60fps, gyro-EIS
# 3  1080p@25/30/60/120fps, 4K@24/25/30/60fps, gyro-EIS
# 4  1080p@25/30/60/120fps, 4K@24/25/30/60fps, gyro-EIS
#
#                                  battery  \
# 0  3279 mAh, Lithium Ion (Non-removable)
# 1  3279 mAh, Lithium Ion (Non-removable)
# 2  4323 mAh, Lithium Ion (Non-removable)
# 3  4323 mAh, Lithium Ion (Non-removable)
# 4  4323 mAh, Lithium Ion (Non-removable)
#
#                                                                     charging  \
# 0  20W (wired), Wireless Charging Supported50% in 30min (wired) (advertised)
# 1  20W (wired), Wireless Charging Supported50% in 30min (wired) (advertised)
# 2  20W (wired), Wireless Charging Supported50% in 30min (wired) (advertised)
# 3  20W (wired), Wireless Charging Supported50% in 30min (wired) (advertised)
# 4  20W (wired), Wireless Charging Supported50% in 30min (wired) (advertised)
#
#        storage           ram  \
# 0  256GB, NvMe  6GB, LPDDR4X
# 1  512GB, NvMe  6GB, LPDDR4X
# 2  256GB, NvMe  6GB, LPDDR4X
# 3  512GB, NvMe  6GB, LPDDR4X
# 4  128GB, NvMe  6GB, LPDDR4X
#
#                                                                                    sim  \
# 0                                                                    nano-SIM and eSIM
# 1                                                                    nano-SIM and eSIM
# 2  nano-SIM and eSIM (international), Dual eSIM (USA), Nano-SIM, dual stand-by (China)
# 3  nano-SIM and eSIM (international), Dual eSIM (USA), Nano-SIM, dual stand-by (China)
# 4  nano-SIM and eSIM (international), Dual eSIM (USA), Nano-SIM, dual stand-by (China)
#
#                              tech                              2g  \
# 0  5G, CDMA, EVDO, GSM, HSPA, LTE  1800, 1900, 850, 900 (4 bands)
# 1  5G, CDMA, EVDO, GSM, HSPA, LTE  1800, 1900, 850, 900 (4 bands)
# 2  5G, CDMA, EVDO, GSM, HSPA, LTE  1800, 1900, 850, 900 (4 bands)
# 3  5G, CDMA, EVDO, GSM, HSPA, LTE  1800, 1900, 850, 900 (4 bands)
# 4  5G, CDMA, EVDO, GSM, HSPA, LTE  1800, 1900, 850, 900 (4 bands)
#
#                                                                                 3g  \
# 0  UMTS/HSPA+/DC-HSDPA 850, 900, 1700(AWS), 1900, 2100, CDMA2000 1xEV-DO (6 bands)
# 1  UMTS/HSPA+/DC-HSDPA 850, 900, 1700(AWS), 1900, 2100, CDMA2000 1xEV-DO (6 bands)
# 2                    UMTS/HSPA+/DC-HSDPA 850, 900, 1700(AWS), 1900, 2100 (5 bands)
# 3                    UMTS/HSPA+/DC-HSDPA 850, 900, 1700(AWS), 1900, 2100 (5 bands)
# 4                    UMTS/HSPA+/DC-HSDPA 850, 900, 1700(AWS), 1900, 2100 (5 bands)
#
#                                                                                                                    4g  \
# 0  LTE 1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 30, 32, 34, 38, 39, 40, 41, 42, 46, 48, 66 (27 bands)
# 1  LTE 1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 30, 32, 34, 38, 39, 40, 41, 42, 46, 48, 66 (27 bands)
# 2  LTE 1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 30, 32, 34, 38, 39, 40, 41, 42, 46, 48, 66 (27 bands)
# 3  LTE 1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 30, 32, 34, 38, 39, 40, 41, 42, 46, 48, 66 (27 bands)
# 4  LTE 1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 30, 32, 34, 38, 39, 40, 41, 42, 46, 48, 66 (27 bands)
#
#                                                                                                     5g  \
# 0  SA/NSA/Sub6 1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 30, 38, 40, 41, 48, 66, 70, 77, 78, 79 (21 bands)
# 1  SA/NSA/Sub6 1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 30, 38, 40, 41, 48, 66, 70, 77, 78, 79 (21 bands)
# 2  SA/NSA/Sub6 1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 30, 38, 40, 41, 48, 66, 70, 77, 78, 79 (21 bands)
# 3  SA/NSA/Sub6 1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 30, 38, 40, 41, 48, 66, 70, 77, 78, 79 (21 bands)
# 4  SA/NSA/Sub6 1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 30, 38, 40, 41, 48, 66, 70, 77, 78, 79 (21 bands)
#
#                       speed  \
# 0  5G, GSM, HSPA, LTE, UMTS
# 1  5G, GSM, HSPA, LTE, UMTS
# 2  5G, GSM, HSPA, LTE, UMTS
# 3  5G, GSM, HSPA, LTE, UMTS
# 4  5G, GSM, HSPA, LTE, UMTS
#
#                                                              wifi  \
# 0  Wi-Fi 6 802.11 a/b/g/n/ac/ax, Hotspot, Wi-Fi Direct, Dual Band
# 1  Wi-Fi 6 802.11 a/b/g/n/ac/ax, Hotspot, Wi-Fi Direct, Dual Band
# 2  Wi-Fi 6 802.11 a/b/g/n/ac/ax, Hotspot, Wi-Fi Direct, Dual Band
# 3  Wi-Fi 6 802.11 a/b/g/n/ac/ax, Hotspot, Wi-Fi Direct, Dual Band
# 4  Wi-Fi 6 802.11 a/b/g/n/ac/ax, Hotspot, Wi-Fi Direct, Dual Band
#
#        bluetooth                positioning_system        nfc finger_print  \
# 0  5.3, A2DP, LE  BDS, GALILEO, GLONASS, GPS, QZSS  Supported          NaN
# 1  5.3, A2DP, LE  BDS, GALILEO, GLONASS, GPS, QZSS  Supported          NaN
# 2  5.3, A2DP, LE  BDS, GALILEO, GLONASS, GPS, QZSS  Supported          NaN
# 3  5.3, A2DP, LE  BDS, GALILEO, GLONASS, GPS, QZSS  Supported          NaN
# 4  5.3, A2DP, LE  BDS, GALILEO, GLONASS, GPS, QZSS  Supported          NaN
#
#                                                                                                         sensors  \
# 0  Accelerometer, Barometer Sensor, Compass, Face ID, Gyroscope, Proximity Sensor, Ultra Wideband (UWB) Support
# 1  Accelerometer, Barometer Sensor, Compass, Face ID, Gyroscope, Proximity Sensor, Ultra Wideband (UWB) Support
# 2  Accelerometer, Barometer Sensor, Compass, Face ID, Gyroscope, Proximity Sensor, Ultra Wideband (UWB) Support
# 3  Accelerometer, Barometer Sensor, Compass, Face ID, Gyroscope, Proximity Sensor, Ultra Wideband (UWB) Support
# 4  Accelerometer, Barometer Sensor, Compass, Face ID, Gyroscope, Proximity Sensor, Ultra Wideband (UWB) Support
#
#                 add_features  \
# 0  Linear Resonant Actuators
# 1  Linear Resonant Actuators
# 2  Linear Resonant Actuators
# 3  Linear Resonant Actuators
# 4  Linear Resonant Actuators
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         flipkart_buy_link  \
# 0                                                                                         https://www.flipkart.com/apple-iphone-14-starlight-256-gb/p/itmaeda15697bb79?pid=MOBGHWFHBJGZYRZC&lid=LSTMOBGHWFHBJGZYRZCUALABX&marketplace=FLIPKART&q=iphone+14+&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=d16ab4a6-25f4-4cb9-8d77-ecbd3f8a6a54.MOBGHWFHBJGZYRZC.SEARCH&ppt=pp&ppn=pp&ssid=kueh4gc0g00000001729242962911&qH=e683ba9749683369&affid=contactbe1
# 1                                                                                          https://www.flipkart.com/apple-iphone-14-midnight-512-gb/p/itm01540a8ff03de?pid=MOBGHWFHBEMUZSBY&lid=LSTMOBGHWFHBEMUZSBYWJC9VQ&marketplace=FLIPKART&q=iphone+14+&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=organic&iid=d16ab4a6-25f4-4cb9-8d77-ecbd3f8a6a54.MOBGHWFHBEMUZSBY.SEARCH&ppt=pp&ppn=pp&ssid=kueh4gc0g00000001729242962911&qH=e683ba9749683369&affid=contactbe1
# 2  https://www.flipkart.com/apple-iphone-14-plus-starlight-256-gb/p/itm8ee001dd954a2?pid=MOBGHWFHQGM9B4EU&lid=LSTMOBGHWFHQGM9B4EUGHBHUP&marketplace=FLIPKART&q=14+plus+iphone&store=tyy%2F4io&srno=s_1_4&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&fm=organic&iid=463edb55-77b0-4ae0-b1cf-07d79dcb5f45.MOBGHWFHQGM9B4EU.SEARCH&ppt=pp&ppn=pp&ssid=74yvvmat5s0000001729233498497&qH=94ddc8675cffe2b2&affid=contactbe1
# 3       https://www.flipkart.com/apple-iphone-14-plus-blue-512-gb/p/itm9b829cc08a732?pid=MOBGHWFHKHPYMQX8&lid=LSTMOBGHWFHKHPYMQX8K7QHSJ&marketplace=FLIPKART&q=14+plus+iphone&store=tyy%2F4io&srno=s_1_7&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&fm=organic&iid=463edb55-77b0-4ae0-b1cf-07d79dcb5f45.MOBGHWFHKHPYMQX8.SEARCH&ppt=pp&ppn=pp&ssid=74yvvmat5s0000001729233498497&qH=94ddc8675cffe2b2&affid=contactbe1
# 4  https://www.flipkart.com/apple-iphone-14-plus-starlight-128-gb/p/itmc922ddc8af349?pid=MOBGHWFHVCB2YZYR&lid=LSTMOBGHWFHVCB2YZYRBDOEVN&marketplace=FLIPKART&q=14+plus+iphone&store=tyy%2F4io&srno=s_1_3&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&fm=organic&iid=463edb55-77b0-4ae0-b1cf-07d79dcb5f45.MOBGHWFHVCB2YZYR.SEARCH&ppt=pp&ppn=pp&ssid=74yvvmat5s0000001729233498497&qH=94ddc8675cffe2b2&affid=contactbe1
#
#                                                                     amazon_buy_link  \
# 0  https://www.amazon.in/dp/B0BDJS3MRM?tag=beebomgadge0d-21&linkCode=ogv&th=1&psc=1
# 1  https://www.amazon.in/dp/B0BDJGX2XZ?tag=beebomgadge0d-21&linkCode=ogv&th=1&psc=1
# 2                                                                               NaN
# 3                                                                               NaN
# 4  https://www.amazon.in/dp/B0BDJFTGK6?tag=beebomgadge0d-21&linkCode=ogv&th=1&psc=1
#
#   official_store_link main_cam4 front_cam2
# 0                 NaN       NaN        NaN
# 1                 NaN       NaN        NaN
# 2                 NaN       NaN        NaN
# 3                 NaN       NaN        NaN
# 4                 NaN       NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 59 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   model_id             1268 non-null   int64
#  1   model                1268 non-null   object
#  2   expert_rating        1268 non-null   int64
#  3   rating               1268 non-null   float64
#  4   rating_count         994 non-null    object
#  5   market_status        1268 non-null   object
#  6   launch_on            1268 non-null   object
#  7   old_price            1149 non-null   object
#  8   price                1268 non-null   object
#  9   launch_price         1268 non-null   object
#  10  display_type         1268 non-null   object
#  11  display_size         1268 non-null   object
#  12  display_res          1268 non-null   object
#  13  body_dimension       1268 non-null   object
#  14  weight               1268 non-null   object
#  15  body_front           1268 non-null   object
#  16  body_back            1238 non-null   object
#  17  body_side            1251 non-null   object
#  18  build_quality        739 non-null    object
#  19  ports                1268 non-null   object
#  20  ip_rating            915 non-null    object
#  21  speaker              1265 non-null   object
#  22  chipset              1268 non-null   object
#  23  cpu                  1268 non-null   object
#  24  gpu                  1250 non-null   object
#  25  main_cam             1268 non-null   object
#  26  main_cam2            1214 non-null   object
#  27  main_cam3            631 non-null    object
#  28  main_cam_features    1268 non-null   object
#  29  main_video           1239 non-null   object
#  30  os                   1268 non-null   object
#  31  software_updates     1228 non-null   object
#  32  ai_features          780 non-null    object
#  33  front_cam            1268 non-null   object
#  34  front_cam_features   1026 non-null   object
#  35  front_video          1229 non-null   object
#  36  battery              1268 non-null   object
#  37  charging             1268 non-null   object
#  38  storage              1268 non-null   object
#  39  ram                  1268 non-null   object
#  40  sim                  1264 non-null   object
#  41  tech                 1200 non-null   object
#  42  2g                   1262 non-null   object
#  43  3g                   1264 non-null   object
#  44  4g                   1267 non-null   object
#  45  5g                   1028 non-null   object
#  46  speed                1264 non-null   object
#  47  wifi                 1268 non-null   object
#  48  bluetooth            1266 non-null   object
#  49  positioning_system   1268 non-null   object
#  50  nfc                  595 non-null    object
#  51  finger_print         1192 non-null   object
#  52  sensors              1268 non-null   object
#  53  add_features         469 non-null    object
#  54  flipkart_buy_link    1085 non-null   object
#  55  amazon_buy_link      724 non-null    object
#  56  official_store_link  610 non-null    object
#  57  main_cam4            48 non-null     object
#  58  front_cam2           9 non-null      object
# dtypes: float64(1), int64(2), object(56)
# memory usage: 584.6+ KB

# %%
df['brand'] = df['model'].str.lower().str.split(' ').str.get(0)

# %%
df['brand'].value_counts()
# Out:
# brand
# realme      231
# samsung     196
# vivo        177
# oppo        100
# redmi        93
# iqoo         74
# poco         70
# infinix      61
# oneplus      59
# apple        54
# motorola     40
# moto         38
# google       20
# nothing      18
# xiaomi       18
# honor        10
# asus          5
# cmf           4
# Name: count, dtype: int64

# %%
df.loc[df['brand'].str.contains('moto'),'brand'] = 'motorola'

# %%
df['brand'].value_counts()
# Out:
# brand
# realme      231
# samsung     196
# vivo        177
# oppo        100
# redmi        93
# motorola     78
# iqoo         74
# poco         70
# infinix      61
# oneplus      59
# apple        54
# google       20
# nothing      18
# xiaomi       18
# honor        10
# asus          5
# cmf           4
# Name: count, dtype: int64

# %%
df['brand'].count()
# Out:
# np.int64(1268)

# %%
df['brand'] = df['brand'].astype('category')

# %%
df['expert_rating'].value_counts()
# Out:
# expert_rating
# 80    57
# 73    45
# 84    41
# 74    41
# 68    37
#       ..
# 47     4
# 28     3
# 26     3
# 29     2
# 22     1
# Name: count, Length: 70, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# 4.3    299
# 4.4    271
# 4.2    236
# 4.5    134
# 4.1     92
# 4.6     70
# 4.7     46
# 4.8     29
# 4.0     29
# 2.0     16
# 3.9     15
# 1.0     12
# 3.8      5
# 3.4      5
# 3.5      2
# 3.7      2
# 3.6      2
# 5.0      1
# 4.9      1
# 3.0      1
# Name: count, dtype: int64

# %%
df['rating_count'] = df['rating_count'].str.lower().str.split('r').str.get(0)

# %%
df['rating_count'] = df['rating_count'].str.replace('(','')

# %%
df['rating_count'] = df['rating_count'].str.replace('k',"1000")

# %%
df['rating_count'] = df['rating_count'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 60 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   model_id             1268 non-null   int64
#  1   model                1268 non-null   object
#  2   expert_rating        1268 non-null   int64
#  3   rating               1268 non-null   float64
#  4   rating_count         994 non-null    float64
#  5   market_status        1268 non-null   object
#  6   launch_on            1268 non-null   object
#  7   old_price            1149 non-null   object
#  8   price                1268 non-null   object
#  9   launch_price         1268 non-null   object
#  10  display_type         1268 non-null   object
#  11  display_size         1268 non-null   object
#  12  display_res          1268 non-null   object
#  13  body_dimension       1268 non-null   object
#  14  weight               1268 non-null   object
#  15  body_front           1268 non-null   object
#  16  body_back            1238 non-null   object
#  17  body_side            1251 non-null   object
#  18  build_quality        739 non-null    object
#  19  ports                1268 non-null   object
#  20  ip_rating            915 non-null    object
#  21  speaker              1265 non-null   object
#  22  chipset              1268 non-null   object
#  23  cpu                  1268 non-null   object
#  24  gpu                  1250 non-null   object
#  25  main_cam             1268 non-null   object
#  26  main_cam2            1214 non-null   object
#  27  main_cam3            631 non-null    object
#  28  main_cam_features    1268 non-null   object
#  29  main_video           1239 non-null   object
#  30  os                   1268 non-null   object
#  31  software_updates     1228 non-null   object
#  32  ai_features          780 non-null    object
#  33  front_cam            1268 non-null   object
#  34  front_cam_features   1026 non-null   object
#  35  front_video          1229 non-null   object
#  36  battery              1268 non-null   object
#  37  charging             1268 non-null   object
#  38  storage              1268 non-null   object
#  39  ram                  1268 non-null   object
#  40  sim                  1264 non-null   object
#  41  tech                 1200 non-null   object
#  42  2g                   1262 non-null   object
#  43  3g                   1264 non-null   object
#  44  4g                   1267 non-null   object
#  45  5g                   1028 non-null   object
#  46  speed                1264 non-null   object
#  47  wifi                 1268 non-null   object
#  48  bluetooth            1266 non-null   object
#  49  positioning_system   1268 non-null   object
#  50  nfc                  595 non-null    object
#  51  finger_print         1192 non-null   object
#  52  sensors              1268 non-null   object
#  53  add_features         469 non-null    object
#  54  flipkart_buy_link    1085 non-null   object
#  55  amazon_buy_link      724 non-null    object
#  56  official_store_link  610 non-null    object
#  57  main_cam4            48 non-null     object
#  58  front_cam2           9 non-null      object
#  59  brand                1268 non-null   category
# dtypes: category(1), float64(2), int64(2), object(55)
# memory usage: 586.5+ KB

# %%
df['market_status'].value_counts()
# Out:
# market_status
# In Stock        896
# Out of Stock    372
# Name: count, dtype: int64

# %%
def market(text):

  t = text.lower()

  if t == 'in stock':
    return 1
  elif t == 'out of stock':
    return 0

df['is_available'] = df['market_status'].apply(market)

# %%
df['is_available'].value_counts()
# Out:
# is_available
# 1    896
# 0    372
# Name: count, dtype: int64

# %%
df.drop(columns='market_status',inplace=True)

# %%
df['launch_on']
# Out:
# 0       07 Sep 2022
# 1       07 Sep 2022
# 2       07 Sep 2022
# 3       07 Sep 2022
# 4       07 Sep 2022
#            ...
# 1263    07 Mar 2024
# 1264    11 Mar 2025
# 1265    11 Mar 2025
# 1266    09 May 2023
# 1267    09 May 2023
# Name: launch_on, Length: 1268, dtype: object

# %%
df['launch_on'] = pd.to_datetime(df['launch_on'])

# %%
df['launch_on']
# Out:
# 0      2022-09-07
# 1      2022-09-07
# 2      2022-09-07
# 3      2022-09-07
# 4      2022-09-07
#           ...
# 1263   2024-03-07
# 1264   2025-03-11
# 1265   2025-03-11
# 1266   2023-05-09
# 1267   2023-05-09
# Name: launch_on, Length: 1268, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 60 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   model_id             1268 non-null   int64
#  1   model                1268 non-null   object
#  2   expert_rating        1268 non-null   int64
#  3   rating               1268 non-null   float64
#  4   rating_count         994 non-null    float64
#  5   launch_on            1268 non-null   datetime64[ns]
#  6   old_price            1149 non-null   object
#  7   price                1268 non-null   object
#  8   launch_price         1268 non-null   object
#  9   display_type         1268 non-null   object
#  10  display_size         1268 non-null   object
#  11  display_res          1268 non-null   object
#  12  body_dimension       1268 non-null   object
#  13  weight               1268 non-null   object
#  14  body_front           1268 non-null   object
#  15  body_back            1238 non-null   object
#  16  body_side            1251 non-null   object
#  17  build_quality        739 non-null    object
#  18  ports                1268 non-null   object
#  19  ip_rating            915 non-null    object
#  20  speaker              1265 non-null   object
#  21  chipset              1268 non-null   object
#  22  cpu                  1268 non-null   object
#  23  gpu                  1250 non-null   object
#  24  main_cam             1268 non-null   object
#  25  main_cam2            1214 non-null   object
#  26  main_cam3            631 non-null    object
#  27  main_cam_features    1268 non-null   object
#  28  main_video           1239 non-null   object
#  29  os                   1268 non-null   object
#  30  software_updates     1228 non-null   object
#  31  ai_features          780 non-null    object
#  32  front_cam            1268 non-null   object
#  33  front_cam_features   1026 non-null   object
#  34  front_video          1229 non-null   object
#  35  battery              1268 non-null   object
#  36  charging             1268 non-null   object
#  37  storage              1268 non-null   object
#  38  ram                  1268 non-null   object
#  39  sim                  1264 non-null   object
#  40  tech                 1200 non-null   object
#  41  2g                   1262 non-null   object
#  42  3g                   1264 non-null   object
#  43  4g                   1267 non-null   object
#  44  5g                   1028 non-null   object
#  45  speed                1264 non-null   object
#  46  wifi                 1268 non-null   object
#  47  bluetooth            1266 non-null   object
#  48  positioning_system   1268 non-null   object
#  49  nfc                  595 non-null    object
#  50  finger_print         1192 non-null   object
#  51  sensors              1268 non-null   object
#  52  add_features         469 non-null    object
#  53  flipkart_buy_link    1085 non-null   object
#  54  amazon_buy_link      724 non-null    object
#  55  official_store_link  610 non-null    object
#  56  main_cam4            48 non-null     object
#  57  front_cam2           9 non-null      object
#  58  brand                1268 non-null   category
#  59  is_available         1268 non-null   int64
# dtypes: category(1), datetime64[ns](1), float64(2), int64(3), object(53)
# memory usage: 586.5+ KB

# %%
df['old_price'].value_counts()
# Out:
# old_price
# Lowest price since launch Lowest price since launch      305
# Was ₹7,999 2 month(s) ago Was ₹7,999 2 month(s) ago        8
# Was ₹15,999 2 month(s) ago Was ₹15,999 2 month(s) ago      8
# Was ₹22,999 2 month(s) ago Was ₹22,999 2 month(s) ago      7
# Was ₹13,999 2 month(s) ago Was ₹13,999 2 month(s) ago      7
#                                                         ...
# Was ₹47,839 22 day(s) ago Was ₹47,839 22 day(s) ago        1
# Was ₹25,999 2 month(s) ago Was ₹25,999 2 month(s) ago      1
# Was ₹34,999 10 day(s) ago Was ₹34,999 10 day(s) ago        1
# Was ₹23,799 5 day(s) ago Was ₹23,799 5 day(s) ago          1
# Was ₹21,300 1 month(s) ago Was ₹21,300 1 month(s) ago      1
# Name: count, Length: 667, dtype: int64

# %%
df['old_price'] = df['old_price'].str.lower().str.split(' ').str.get(1)

# %%
df.loc[df['old_price'] == 'price','old_price'] = np.nan

# %%
df['old_price'].value_counts(dropna=False)
# Out:
# old_price
# NaN        424
# ₹11,999     18
# ₹9,999      16
# ₹22,999     16
# ₹10,999     15
#           ...
# ₹13,898      1
# ₹12,754      1
# ₹11,874      1
# ₹11,450      1
# ₹22,319      1
# Name: count, Length: 448, dtype: int64

# %%
df['old_price'] = df['old_price'].str.replace('₹','')

# %%
df['old_price'] = df['old_price'].str.replace(',','')

# %%
df['old_price'] = df['old_price'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 60 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   model_id             1268 non-null   int64
#  1   model                1268 non-null   object
#  2   expert_rating        1268 non-null   int64
#  3   rating               1268 non-null   float64
#  4   rating_count         994 non-null    float64
#  5   launch_on            1268 non-null   datetime64[ns]
#  6   old_price            844 non-null    float64
#  7   price                1268 non-null   object
#  8   launch_price         1268 non-null   object
#  9   display_type         1268 non-null   object
#  10  display_size         1268 non-null   object
#  11  display_res          1268 non-null   object
#  12  body_dimension       1268 non-null   object
#  13  weight               1268 non-null   object
#  14  body_front           1268 non-null   object
#  15  body_back            1238 non-null   object
#  16  body_side            1251 non-null   object
#  17  build_quality        739 non-null    object
#  18  ports                1268 non-null   object
#  19  ip_rating            915 non-null    object
#  20  speaker              1265 non-null   object
#  21  chipset              1268 non-null   object
#  22  cpu                  1268 non-null   object
#  23  gpu                  1250 non-null   object
#  24  main_cam             1268 non-null   object
#  25  main_cam2            1214 non-null   object
#  26  main_cam3            631 non-null    object
#  27  main_cam_features    1268 non-null   object
#  28  main_video           1239 non-null   object
#  29  os                   1268 non-null   object
#  30  software_updates     1228 non-null   object
#  31  ai_features          780 non-null    object
#  32  front_cam            1268 non-null   object
#  33  front_cam_features   1026 non-null   object
#  34  front_video          1229 non-null   object
#  35  battery              1268 non-null   object
#  36  charging             1268 non-null   object
#  37  storage              1268 non-null   object
#  38  ram                  1268 non-null   object
#  39  sim                  1264 non-null   object
#  40  tech                 1200 non-null   object
#  41  2g                   1262 non-null   object
#  42  3g                   1264 non-null   object
#  43  4g                   1267 non-null   object
#  44  5g                   1028 non-null   object
#  45  speed                1264 non-null   object
#  46  wifi                 1268 non-null   object
#  47  bluetooth            1266 non-null   object
#  48  positioning_system   1268 non-null   object
#  49  nfc                  595 non-null    object
#  50  finger_print         1192 non-null   object
#  51  sensors              1268 non-null   object
#  52  add_features         469 non-null    object
#  53  flipkart_buy_link    1085 non-null   object
#  54  amazon_buy_link      724 non-null    object
#  55  official_store_link  610 non-null    object
#  56  main_cam4            48 non-null     object
#  57  front_cam2           9 non-null      object
#  58  brand                1268 non-null   category
#  59  is_available         1268 non-null   int64
# dtypes: category(1), datetime64[ns](1), float64(3), int64(3), object(52)
# memory usage: 586.5+ KB

# %%
df['price'] = df['price'].str.replace('₹','')

# %%
df['price'] = df['price'].str.replace(',','')

# %%
df['price'] = df['price'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 60 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   model_id             1268 non-null   int64
#  1   model                1268 non-null   object
#  2   expert_rating        1268 non-null   int64
#  3   rating               1268 non-null   float64
#  4   rating_count         994 non-null    float64
#  5   launch_on            1268 non-null   datetime64[ns]
#  6   old_price            844 non-null    float64
#  7   price                1268 non-null   int64
#  8   launch_price         1268 non-null   object
#  9   display_type         1268 non-null   object
#  10  display_size         1268 non-null   object
#  11  display_res          1268 non-null   object
#  12  body_dimension       1268 non-null   object
#  13  weight               1268 non-null   object
#  14  body_front           1268 non-null   object
#  15  body_back            1238 non-null   object
#  16  body_side            1251 non-null   object
#  17  build_quality        739 non-null    object
#  18  ports                1268 non-null   object
#  19  ip_rating            915 non-null    object
#  20  speaker              1265 non-null   object
#  21  chipset              1268 non-null   object
#  22  cpu                  1268 non-null   object
#  23  gpu                  1250 non-null   object
#  24  main_cam             1268 non-null   object
#  25  main_cam2            1214 non-null   object
#  26  main_cam3            631 non-null    object
#  27  main_cam_features    1268 non-null   object
#  28  main_video           1239 non-null   object
#  29  os                   1268 non-null   object
#  30  software_updates     1228 non-null   object
#  31  ai_features          780 non-null    object
#  32  front_cam            1268 non-null   object
#  33  front_cam_features   1026 non-null   object
#  34  front_video          1229 non-null   object
#  35  battery              1268 non-null   object
#  36  charging             1268 non-null   object
#  37  storage              1268 non-null   object
#  38  ram                  1268 non-null   object
#  39  sim                  1264 non-null   object
#  40  tech                 1200 non-null   object
#  41  2g                   1262 non-null   object
#  42  3g                   1264 non-null   object
#  43  4g                   1267 non-null   object
#  44  5g                   1028 non-null   object
#  45  speed                1264 non-null   object
#  46  wifi                 1268 non-null   object
#  47  bluetooth            1266 non-null   object
#  48  positioning_system   1268 non-null   object
#  49  nfc                  595 non-null    object
#  50  finger_print         1192 non-null   object
#  51  sensors              1268 non-null   object
#  52  add_features         469 non-null    object
#  53  flipkart_buy_link    1085 non-null   object
#  54  amazon_buy_link      724 non-null    object
#  55  official_store_link  610 non-null    object
#  56  main_cam4            48 non-null     object
#  57  front_cam2           9 non-null      object
#  58  brand                1268 non-null   category
#  59  is_available         1268 non-null   int64
# dtypes: category(1), datetime64[ns](1), float64(3), int64(4), object(51)
# memory usage: 586.5+ KB

# %%
df['launch_price'] = df['launch_price'].str.replace('₹','').str.replace(',','').astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 60 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   model_id             1268 non-null   int64
#  1   model                1268 non-null   object
#  2   expert_rating        1268 non-null   int64
#  3   rating               1268 non-null   float64
#  4   rating_count         994 non-null    float64
#  5   launch_on            1268 non-null   datetime64[ns]
#  6   old_price            844 non-null    float64
#  7   price                1268 non-null   int64
#  8   launch_price         1268 non-null   int64
#  9   display_type         1268 non-null   object
#  10  display_size         1268 non-null   object
#  11  display_res          1268 non-null   object
#  12  body_dimension       1268 non-null   object
#  13  weight               1268 non-null   object
#  14  body_front           1268 non-null   object
#  15  body_back            1238 non-null   object
#  16  body_side            1251 non-null   object
#  17  build_quality        739 non-null    object
#  18  ports                1268 non-null   object
#  19  ip_rating            915 non-null    object
#  20  speaker              1265 non-null   object
#  21  chipset              1268 non-null   object
#  22  cpu                  1268 non-null   object
#  23  gpu                  1250 non-null   object
#  24  main_cam             1268 non-null   object
#  25  main_cam2            1214 non-null   object
#  26  main_cam3            631 non-null    object
#  27  main_cam_features    1268 non-null   object
#  28  main_video           1239 non-null   object
#  29  os                   1268 non-null   object
#  30  software_updates     1228 non-null   object
#  31  ai_features          780 non-null    object
#  32  front_cam            1268 non-null   object
#  33  front_cam_features   1026 non-null   object
#  34  front_video          1229 non-null   object
#  35  battery              1268 non-null   object
#  36  charging             1268 non-null   object
#  37  storage              1268 non-null   object
#  38  ram                  1268 non-null   object
#  39  sim                  1264 non-null   object
#  40  tech                 1200 non-null   object
#  41  2g                   1262 non-null   object
#  42  3g                   1264 non-null   object
#  43  4g                   1267 non-null   object
#  44  5g                   1028 non-null   object
#  45  speed                1264 non-null   object
#  46  wifi                 1268 non-null   object
#  47  bluetooth            1266 non-null   object
#  48  positioning_system   1268 non-null   object
#  49  nfc                  595 non-null    object
#  50  finger_print         1192 non-null   object
#  51  sensors              1268 non-null   object
#  52  add_features         469 non-null    object
#  53  flipkart_buy_link    1085 non-null   object
#  54  amazon_buy_link      724 non-null    object
#  55  official_store_link  610 non-null    object
#  56  main_cam4            48 non-null     object
#  57  front_cam2           9 non-null      object
#  58  brand                1268 non-null   category
#  59  is_available         1268 non-null   int64
# dtypes: category(1), datetime64[ns](1), float64(3), int64(5), object(50)
# memory usage: 586.5+ KB

# %%
df['is_flipkart_available'] = df['flipkart_buy_link'].notna().astype('int')

# %%
df['is_flipkart_available'].value_counts()
# Out:
# is_flipkart_available
# 1    1085
# 0     183
# Name: count, dtype: int64

# %%
df['is_amazon_available'] = df['amazon_buy_link'].notna().astype('int')

# %%
df['is_amazon_available'].value_counts()
# Out:
# is_amazon_available
# 1    724
# 0    544
# Name: count, dtype: int64

# %%
df['is_official_available'] = df['official_store_link'].notna().astype('int')

# %%
df['is_official_available'].value_counts()
# Out:
# is_official_available
# 0    658
# 1    610
# Name: count, dtype: int64

# %%
df.drop(columns=['flipkart_buy_link','amazon_buy_link','official_store_link'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 60 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   model_id               1268 non-null   int64
#  1   model                  1268 non-null   object
#  2   expert_rating          1268 non-null   int64
#  3   rating                 1268 non-null   float64
#  4   rating_count           994 non-null    float64
#  5   launch_on              1268 non-null   datetime64[ns]
#  6   old_price              844 non-null    float64
#  7   price                  1268 non-null   int64
#  8   launch_price           1268 non-null   int64
#  9   display_type           1268 non-null   object
#  10  display_size           1268 non-null   object
#  11  display_res            1268 non-null   object
#  12  body_dimension         1268 non-null   object
#  13  weight                 1268 non-null   object
#  14  body_front             1268 non-null   object
#  15  body_back              1238 non-null   object
#  16  body_side              1251 non-null   object
#  17  build_quality          739 non-null    object
#  18  ports                  1268 non-null   object
#  19  ip_rating              915 non-null    object
#  20  speaker                1265 non-null   object
#  21  chipset                1268 non-null   object
#  22  cpu                    1268 non-null   object
#  23  gpu                    1250 non-null   object
#  24  main_cam               1268 non-null   object
#  25  main_cam2              1214 non-null   object
#  26  main_cam3              631 non-null    object
#  27  main_cam_features      1268 non-null   object
#  28  main_video             1239 non-null   object
#  29  os                     1268 non-null   object
#  30  software_updates       1228 non-null   object
#  31  ai_features            780 non-null    object
#  32  front_cam              1268 non-null   object
#  33  front_cam_features     1026 non-null   object
#  34  front_video            1229 non-null   object
#  35  battery                1268 non-null   object
#  36  charging               1268 non-null   object
#  37  storage                1268 non-null   object
#  38  ram                    1268 non-null   object
#  39  sim                    1264 non-null   object
#  40  tech                   1200 non-null   object
#  41  2g                     1262 non-null   object
#  42  3g                     1264 non-null   object
#  43  4g                     1267 non-null   object
#  44  5g                     1028 non-null   object
#  45  speed                  1264 non-null   object
#  46  wifi                   1268 non-null   object
#  47  bluetooth              1266 non-null   object
#  48  positioning_system     1268 non-null   object
#  49  nfc                    595 non-null    object
#  50  finger_print           1192 non-null   object
#  51  sensors                1268 non-null   object
#  52  add_features           469 non-null    object
#  53  main_cam4              48 non-null     object
#  54  front_cam2             9 non-null      object
#  55  brand                  1268 non-null   category
#  56  is_available           1268 non-null   int64
#  57  is_flipkart_available  1268 non-null   int64
#  58  is_amazon_available    1268 non-null   int64
#  59  is_official_available  1268 non-null   int64
# dtypes: category(1), datetime64[ns](1), float64(3), int64(8), object(47)
# memory usage: 586.5+ KB

# %%
df['display_type'].sample(10)
# Out:
# 999                  Super AMOLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 667                       IPS LCD, 120 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 494                                                Dot IPS LCD, 90 Hz Refresh Rate, SDR
# 1098                    AMOLED, 120 Hz Refresh Rate, HDR10+, 480 Hz Touch Sampling Rate
# 91                         AMOLED, 120 Hz Refresh Rate, SDR, 300 Hz Touch Sampling Rate
# 108                       IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 624                   Super AMOLED, 90 Hz Refresh Rate, SDR, 360 Hz Touch Sampling Rate
# 557     Boundless Display IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 683            E4 AMOLED, 120 Hz Refresh Rate, LTPO, HDR10+, 360 Hz Touch Sampling Rate
# 464               AMOLED, 120 Hz Refresh Rate, LTPO, HDR10+, 240 Hz Touch Sampling Rate
# Name: display_type, dtype: object

# %%
# creating column for display_panel_type

df['display_panel_type'] = df['display_type'].str.lower().str.split(',').str.get(0)

# %%
df['display_panel_type'].value_counts(dropna=False)
# Out:
# display_panel_type
# amoled                          324
# ips lcd                         310
# super amoled                    105
# lcd                              68
# dynamic 2x amoled                60
# super retina xdr oled            49
# oled                             40
# proxdr amoled                    32
# p-oled                           30
# pls lcd                          27
# dot amoled                       25
# hdr amoled                       23
# e4 amoled                        17
# dot ips lcd                      16
# fluid amoled                     10
# e5 amoled                         9
# ultra smooth display ips lcd      9
# super actua oled                  8
# smooth display amoled             8
# pro hdr amoled                    8
# turbo amoled                      7
# proxdr oled                       7
# ultra amoled                      7
# e6 amoled                         6
# flow amoled                       6
# q10+ amoled                       6
# 3d amoled amoled                  5
# super retina xdr amoled           5
# q10 amoled                        4
# tft lcd                           4
# hyperglow amoled                  3
# e7 amoled                         3
# fluid oled                        2
# tft ips                           2
# ips                               2
# led                               2
# u8 amoled                         2
# ultra smooth display amoled       2
# ultra smooth display lcd          2
# trinity engine amoled             2
# boundless display ips lcd         2
# smooth display oled               1
# true colour display amoled        1
# dynamic ips lcd                   1
# hdr oled                          1
# super actua ips lcd               1
# ips a-si                          1
# smooth display ips lcd            1
# smooth display lcd                1
# dynamic amoled                    1
# Name: count, dtype: int64

# %%
# there are more than 50+ category so we have to make new column

def display_panel_family(text):

    t = text.lower()

    if 'amoled' in t:
      return 'amoled'

    if 'oled' in t and 'amoled' not in t:
      return 'oled'

    if 'ips lcd' in t or ('ips' in t and 'tft' not in t):
      return 'ips lcd'

    if 'tft' in t:
      return 'tft'

    if 'led' in t:
      return 'led'

    if 'lcd' in t:
      return 'lcd'

    return 'unknown'

df['display_panel_family'] = df['display_panel_type'].apply(display_panel_family)

# %%
df['display_panel_family'].value_counts()
# Out:
# display_panel_family
# amoled     681
# ips lcd    343
# oled       138
# lcd         98
# tft          6
# led          2
# Name: count, dtype: int64

# %%
# convert display_panel_family from object dtypes to category

df['display_panel_family'] = df['display_panel_family'].astype('category')

# %%
df['display_type'].sample(10)
# Out:
# 1257    E5 AMOLED, 120 Hz Refresh Rate, LTPO, Dolby Vision, 480 Hz Touch Sampling Rate
# 1249                                                  IPS LCD, 60 Hz Refresh Rate, HDR
# 1207                                                  AMOLED, 120 Hz Refresh Rate, SDR
# 1246                                                  IPS LCD, 60 Hz Refresh Rate, SDR
# 929                                             Super AMOLED, 120 Hz Refresh Rate, SDR
# 1200                                                      LCD, 90 Hz Refresh Rate, SDR
# 366                                           Fluid AMOLED, 90 Hz Refresh Rate, HDR10+
# 1181         E5 AMOLED, 120 Hz Refresh Rate, LTPO, HDR10+, 1000 Hz Touch Sampling Rate
# 352                                HDR AMOLED, 165 Hz Refresh Rate, LTPO, Dolby Vision
# 188                       IPS LCD, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# Name: display_type, dtype: object

# %%
# creating new col from display_type name display_hz

df['display_hz'] = df['display_type'].str.lower().str.split(',').str.get(1)

# %%
df['display_hz'] = df['display_hz'].str.split(' ').str.get(1)

# %%
df['display_hz'].value_counts()
# Out:
# display_hz
# 120    781
# 90     274
# 60     119
# 144     81
# 165     12
# sdr      1
# Name: count, dtype: int64

# %%
df[df['display_hz'].str.contains('sdr')]
# Out:
#      model_id                   model  expert_rating  rating  rating_count  \
# 228       229  Moto E13 (8GB + 128GB)             50     4.1      371000.0
#
#      launch_on  old_price  price  launch_price  display_type  \
# 228 2023-02-08        NaN   9299          6999  IPS LCD, SDR
#
#                                         display_size  \
# 228  6.5 inches, 102 cm², 89.2% Screen To Body Ratio
#
#                                                 display_res  \
# 228  HD+, 720 x  1600 pixels, 20:9 (269 ppi), 8-bit colours
#
#                body_dimension       weight body_front body_back  \
# 228  164.19 x 74.95 x 8.47 mm  179.5 grams      Glass   Plastic
#
#          body_side     build_quality  \
# 228  Plastic Frame  Plastic Material
#
#                                          ports  \
# 228  USB Type-C 2.0, 3.5mm Headphone Jack, OTG
#
#                             ip_rating       speaker  \
# 228  IP52 (Dust and Splash Resistant)  Mono Speaker
#
#                                       chipset  \
# 228  Unisoc T606 (12 nm), 246197 Antutu Score
#
#                                                          cpu           gpu  \
# 228  Octa-core (2x1.6 GHz Cortex-A75 & 6x1.6 GHz Cortex-A55)  Mali-G57 MP1
#
#                                       main_cam main_cam2 main_cam3  \
# 228  13 MP, f/2.2, (Wide-angle), 1.12 µm, PDAF       NaN       NaN
#
#                       main_cam_features   main_video  \
# 228  HDR, LED Flash, Panorama, Pro Mode  1080p@30fps
#
#                                os software_updates  \
# 228  Android Go 13, Motorola MyUx              NaN
#
#                                   ai_features  \
# 228  AI Beauty, AI Camera, Auto Smile Capture
#
#                                     front_cam  \
# 228  5 MP, f/2.2, (Wide-angle), 1.12 µm, 1/5"
#
#                             front_cam_features  front_video  \
# 228  AI Beauty Mode, HDR Photos, Portrait Mode  1080p@30fps
#
#                                        battery     charging          storage  \
# 228  5000 mAh, Lithium Polymer (Non-removable)  10W (wired)  128GB, eMMC 5.1
#
#               ram                                        sim            tech  \
# 228  8GB, LPDDR4X  Hybrid Dual SIM (2 Nano SIMs + 1 microSD)  GSM, HSPA, LTE
#
#                     2g                 3g  \
# 228  3, 5, 8 (3 bands)  1, 5, 8 (3 bands)
#
#                                                4g   5g           speed  \
# 228  1, 3, 5, 7, 8, 20, 28, 38, 40, 41 (10 bands)  NaN  GSM, HSPA, LTE
#
#                                               wifi           bluetooth  \
# 228  Wi-Fi 5 802.11 a/b/g/n/ac, Hotspot, Dual Band  A2DP, AAC, LE, SBC
#
#                             positioning_system  nfc finger_print  \
# 228  A-GPS, GALILEO, GLONASS, GPS, LTEPP, SUPL  NaN          NaN
#
#                                                    sensors add_features  \
# 228  Accelerometer, Ambient Light Sensor, Proximity Sensor          NaN
#
#     main_cam4 front_cam2     brand  is_available  is_flipkart_available  \
# 228       NaN        NaN  motorola             0                      0
#
#      is_amazon_available  is_official_available display_panel_type  \
# 228                    1                      0            ips lcd
#
#     display_panel_family display_hz
# 228              ips lcd        sdr

# %%
# this model display_hz is not available so fill 60 as default
df.loc[228,'display_hz'] = 60

# %%
df['display_hz'].value_counts()
# Out:
# display_hz
# 120    781
# 90     274
# 60     119
# 144     81
# 165     12
# 60       1
# Name: count, dtype: int64

# %%
# converting data types of diplay_hz to numeric

df['display_hz'] = pd.to_numeric(df['display_hz'],errors='coerce')

# %%
df['display_hz'].dtypes
# Out:
# dtype('int64')

# %%
df['display_type'].sample(20)
# Out:
# 1025                                                                         Dynamic 2X AMOLED, 120 Hz Refresh Rate, HDR10+
# 179                                                        AMOLED, 120 Hz Refresh Rate, HDR10+, 1200 Hz Touch Sampling Rate
# 575                         ProXDR AMOLED, 120 Hz Refresh Rate, HDR10+, 240 Hz Touch Sampling Rate, Anti Reflection Coating
# 719                                    Ultra Smooth Display AMOLED, 120 Hz Refresh Rate, HDR10+, 180 Hz Touch Sampling Rate
# 216                                                           AMOLED, 120 Hz Refresh Rate, HDR, 1200 Hz Touch Sampling Rate
# 124                                                           IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 1201                                                                                           LCD, 90 Hz Refresh Rate, SDR
# 128                                                            AMOLED, 120 Hz Refresh Rate, SDR, 360 Hz Touch Sampling Rate
# 1125                                                            AMOLED, 60 Hz Refresh Rate, SDR, 360 Hz Touch Sampling Rate
# 766                                                           IPS LCD, 120 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 1216                                                                                           LCD, 60 Hz Refresh Rate, SDR
# 102                                                            IPS LCD, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 1168                                                  AMOLED, 120 Hz Refresh Rate, LTPO, HDR10+, 120 Hz Touch Sampling Rate
# 44                                  Super Retina XDR OLED, 120 Hz Refresh Rate, LTPO, Dolby Vision, Anti Reflection Coating
# 37      Super Retina XDR OLED, 120 Hz Refresh Rate, LTPO, Dolby Vision, 120 Hz Touch Sampling Rate, Anti Reflection Coating
# 764                                                     ProXDR AMOLED, 120 Hz Refresh Rate, HDR, 180 Hz Touch Sampling Rate
# 20                                                                  Super Retina XDR OLED, 120 Hz Refresh Rate, LTPO, HDR10
# 659                                                           IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 415                                                                LCD, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 928                                                                                  Super AMOLED, 120 Hz Refresh Rate, SDR
# Name: display_type, dtype: object

# %%
# keeping only hdr10+ , hd10 and sdr
def display_dynamic_range(text):

  t = text

  if 'Dolby Vision' in t:
    return 'Dolby Vision'
  if 'HDR10+' in t:
    return 'HDR10+'
  if 'ProXDR' in t:
    return 'ProXDR'
  if 'HDR' in t:
    return 'HDR'
  if 'HDR10' in t:
    return 'HDR10'
  if 'Pro HDR' in t:
    return 'HDR'

  return 'SDR'

df['display_dynamic_range'] = df['display_type'].apply(display_dynamic_range)

# %%
df['display_dynamic_range'].value_counts(dropna=False)
# Out:
# display_dynamic_range
# SDR             660
# HDR10+          371
# Dolby Vision    138
# HDR              87
# ProXDR           12
# Name: count, dtype: int64

# %%
df['display_dynamic_range'].count()
# Out:
# np.int64(1268)

# %%
df[df['display_dynamic_range'].str.contains('SDR')]['display_type'].sample(20)
# Out:
# 501                          IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 999                     Super AMOLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 514                        Dot AMOLED, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 626     Ultra Smooth Display IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 478                            AMOLED, 60 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 380                                                       IPS LCD, 60 Hz Refresh Rate, SDR
# 431                           AMOLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 95                            AMOLED, 144 Hz Refresh Rate, SDR, 360 Hz Touch Sampling Rate
# 588                             OLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 199                            AMOLED, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 578                          IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 1147                          AMOLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 1076                         IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 1212                                                      IPS LCD, 60 Hz Refresh Rate, SDR
# 430                           AMOLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 247                          IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 977                                                       PLS LCD, 90 Hz Refresh Rate, SDR
# 665                           IPS LCD, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 232                                                       IPS LCD, 90 Hz Refresh Rate, SDR
# 807                                                   Dot IPS LCD, 90 Hz Refresh Rate, SDR
# Name: display_type, dtype: object

# %%
# converting display_dynamic_range into category
df['display_dynamic_range'] = df['display_dynamic_range'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 64 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   model_id               1268 non-null   int64
#  1   model                  1268 non-null   object
#  2   expert_rating          1268 non-null   int64
#  3   rating                 1268 non-null   float64
#  4   rating_count           994 non-null    float64
#  5   launch_on              1268 non-null   datetime64[ns]
#  6   old_price              844 non-null    float64
#  7   price                  1268 non-null   int64
#  8   launch_price           1268 non-null   int64
#  9   display_type           1268 non-null   object
#  10  display_size           1268 non-null   object
#  11  display_res            1268 non-null   object
#  12  body_dimension         1268 non-null   object
#  13  weight                 1268 non-null   object
#  14  body_front             1268 non-null   object
#  15  body_back              1238 non-null   object
#  16  body_side              1251 non-null   object
#  17  build_quality          739 non-null    object
#  18  ports                  1268 non-null   object
#  19  ip_rating              915 non-null    object
#  20  speaker                1265 non-null   object
#  21  chipset                1268 non-null   object
#  22  cpu                    1268 non-null   object
#  23  gpu                    1250 non-null   object
#  24  main_cam               1268 non-null   object
#  25  main_cam2              1214 non-null   object
#  26  main_cam3              631 non-null    object
#  27  main_cam_features      1268 non-null   object
#  28  main_video             1239 non-null   object
#  29  os                     1268 non-null   object
#  30  software_updates       1228 non-null   object
#  31  ai_features            780 non-null    object
#  32  front_cam              1268 non-null   object
#  33  front_cam_features     1026 non-null   object
#  34  front_video            1229 non-null   object
#  35  battery                1268 non-null   object
#  36  charging               1268 non-null   object
#  37  storage                1268 non-null   object
#  38  ram                    1268 non-null   object
#  39  sim                    1264 non-null   object
#  40  tech                   1200 non-null   object
#  41  2g                     1262 non-null   object
#  42  3g                     1264 non-null   object
#  43  4g                     1267 non-null   object
#  44  5g                     1028 non-null   object
#  45  speed                  1264 non-null   object
#  46  wifi                   1268 non-null   object
#  47  bluetooth              1266 non-null   object
#  48  positioning_system     1268 non-null   object
#  49  nfc                    595 non-null    object
#  50  finger_print           1192 non-null   object
#  51  sensors                1268 non-null   object
#  52  add_features           469 non-null    object
#  53  main_cam4              48 non-null     object
#  54  front_cam2             9 non-null      object
#  55  brand                  1268 non-null   category
#  56  is_available           1268 non-null   int64
#  57  is_flipkart_available  1268 non-null   int64
#  58  is_amazon_available    1268 non-null   int64
#  59  is_official_available  1268 non-null   int64
#  60  display_panel_type     1268 non-null   object
#  61  display_panel_family   1268 non-null   category
#  62  display_hz             1268 non-null   int64
#  63  display_dynamic_range  1268 non-null   category
# dtypes: category(3), datetime64[ns](1), float64(3), int64(9), object(48)
# memory usage: 609.2+ KB

# %%
df[df['display_type'].str.contains("Touch Sampling Rate")]['display_type'].sample(20)
# Out:
# 1097              AMOLED, 120 Hz Refresh Rate, HDR10+, 480 Hz Touch Sampling Rate
# 422                    OLED, 120 Hz Refresh Rate, HDR, 240 Hz Touch Sampling Rate
# 755           ProXDR AMOLED, 120 Hz Refresh Rate, HDR, 240 Hz Touch Sampling Rate
# 966            Super AMOLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 534               AMOLED, 120 Hz Refresh Rate, HDR10+, 240 Hz Touch Sampling Rate
# 1150              AMOLED, 120 Hz Refresh Rate, HDR10+, 300 Hz Touch Sampling Rate
# 231                  IPS LCD, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 704             Super AMOLED, 90 Hz Refresh Rate, SDR, 360 Hz Touch Sampling Rate
# 842              Dot AMOLED, 120 Hz Refresh Rate, SDR, 360 Hz Touch Sampling Rate
# 676            AMOLED, 120 Hz Refresh Rate, LTPO, HDR, 360 Hz Touch Sampling Rate
# 630                  IPS LCD, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 111         IPS LCD, 90 Hz Refresh Rate, Dolby Vision, 180 Hz Touch Sampling Rate
# 829                 IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 461           OLED, 120 Hz Refresh Rate, LTPO, HDR10+, 240 Hz Touch Sampling Rate
# 539     HDR AMOLED, 120 Hz Refresh Rate, Dolby Vision, 240 Hz Touch Sampling Rate
# 1227                    LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 463         AMOLED, 120 Hz Refresh Rate, LTPO, HDR10+, 240 Hz Touch Sampling Rate
# 456                     LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 167               AMOLED, 120 Hz Refresh Rate, HDR10+, 300 Hz Touch Sampling Rate
# 969                  AMOLED, 120 Hz Refresh Rate, HDR, 360 Hz Touch Sampling Rate
# Name: display_type, dtype: object

# %%
# using regx to extract touch sampling rate

def extract_touch_sampling_rate(text):

  t = text.lower()

  match = re.search(r'(\d{2,4})\s*hz\s*touch', t)

  if match:
    return int(match.group(1))

  return np.nan

df['touch_sampling_rate'] = df['display_type'].apply(extract_touch_sampling_rate)

# %%
df['touch_sampling_rate'].value_counts(dropna=False)
# Out:
# touch_sampling_rate
# NaN       416
# 240.0     369
# 180.0     164
# 360.0     121
# 120.0      47
# 300.0      40
# 1000.0     29
# 480.0      27
# 1200.0     13
# 90.0       10
# 720.0       5
# 288.0       5
# 60.0        4
# 270.0       3
# 2000.0      3
# 1500.0      3
# 960.0       2
# 2200.0      2
# 600.0       2
# 2500.0      2
# 3000.0      1
# Name: count, dtype: int64

# %%
df['display_type'].sample(20)
# Out:
# 38                          Super Retina XDR AMOLED, 60 Hz Refresh Rate, Dolby Vision, 120 Hz Touch Sampling Rate
# 653                                                  IPS LCD, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 998                                            Super AMOLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 502                                           Dot AMOLED, 120 Hz Refresh Rate, HDR10+, 360 Hz Touch Sampling Rate
# 898                                                                              IPS LCD, 90 Hz Refresh Rate, SDR
# 944                                                  PLS LCD, 90 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 88                                                                      AMOLED, 120 Hz Refresh Rate, LTPO, HDR10+
# 995                                                                        Super AMOLED, 120 Hz Refresh Rate, SDR
# 576               ProXDR AMOLED, 120 Hz Refresh Rate, HDR10+, 240 Hz Touch Sampling Rate, Anti Reflection Coating
# 480                                               AMOLED, 120 Hz Refresh Rate, HDR10+, 720 Hz Touch Sampling Rate
# 271                                                                           AMOLED, 144 Hz Refresh Rate, HDR10+
# 771                                               AMOLED, 120 Hz Refresh Rate, HDR10+, 240 Hz Touch Sampling Rate
# 1100                                                    LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 655                                                 IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 695                               Smooth Display AMOLED, 120 Hz Refresh Rate, HDR10+, 1000 Hz Touch Sampling Rate
# 1039    Dynamic 2X AMOLED, 120 Hz Refresh Rate, LTPO, HDR10+, 240 Hz Touch Sampling Rate, Anti Reflection Coating
# 206                                 Smooth Display AMOLED, 90 Hz Refresh Rate, HDR10+, 180 Hz Touch Sampling Rate
# 242                                                 IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 1225                                                     LCD, 90 Hz Refresh Rate, SDR, 120 Hz Touch Sampling Rate
# 769                                                    OLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# Name: display_type, dtype: object

# %%
df[df['display_type'].str.contains('LTPO')]['display_type'].count()
# Out:
# np.int64(212)

# %%
def extract_lpo(text):

  t = text.lower()

  if 'ltpo' in t:
    return 1

  return 0

df['has_ltpo'] = df['display_type'].apply(extract_lpo)

# %%
df['has_ltpo'].value_counts()
# Out:
# has_ltpo
# 0    1056
# 1     212
# Name: count, dtype: int64

# %%
df[df['display_type'].str.contains('Anti Reflection Coating')]['display_type'].count()
# Out:
# np.int64(77)

# %%
def extract_anti_reflecting_coating(text):

  t = text.lower()

  if 'anti reflection coating' in t:
    return 1

  return 0

df['has_anti_reflection_coating'] = df['display_type'].apply(extract_anti_reflecting_coating)

# %%
df['has_anti_reflection_coating'].value_counts()
# Out:
# has_anti_reflection_coating
# 0    1191
# 1      77
# Name: count, dtype: int64

# %%
df['display_type'].sample(20)
# Out:
# 732                     OLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 296                   IPS LCD, 60 Hz Refresh Rate, SDR, 120 Hz Touch Sampling Rate
# 968                                               AMOLED, 120 Hz Refresh Rate, HDR
# 583          ProXDR OLED, 120 Hz Refresh Rate, HDR10+, 1200 Hz Touch Sampling Rate
# 90                    AMOLED, 120 Hz Refresh Rate, SDR, 300 Hz Touch Sampling Rate
# 457                AMOLED, 120 Hz Refresh Rate, HDR10+, 240 Hz Touch Sampling Rate
# 1030    Dynamic 2X AMOLED, 120 Hz Refresh Rate, HDR10+, 120 Hz Touch Sampling Rate
# 475                AMOLED, 120 Hz Refresh Rate, HDR10+, 240 Hz Touch Sampling Rate
# 943                   PLS LCD, 90 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 55                 AMOLED, 165 Hz Refresh Rate, HDR10+, 720 Hz Touch Sampling Rate
# 219                                            AMOLED, 120 Hz Refresh Rate, HDR10+
# 653                   IPS LCD, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 868                AMOLED, 120 Hz Refresh Rate, HDR10+, 240 Hz Touch Sampling Rate
# 1157               AMOLED, 120 Hz Refresh Rate, HDR10+, 240 Hz Touch Sampling Rate
# 352                            HDR AMOLED, 165 Hz Refresh Rate, LTPO, Dolby Vision
# 602                  IPS LCD, 120 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 225                  IPS LCD, 120 Hz Refresh Rate, HDR, 240 Hz Touch Sampling Rate
# 213              Ultra AMOLED, 90 Hz Refresh Rate, SDR, 360 Hz Touch Sampling Rate
# 1250                  AMOLED, 120 Hz Refresh Rate, SDR, 360 Hz Touch Sampling Rate
# 883                                      Super AMOLED, 120 Hz Refresh Rate, HDR10+
# Name: display_type, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 67 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
# dtypes: category(3), datetime64[ns](1), float64(4), int64(11), object(48)
# memory usage: 638.9+ KB

# %%
df['display_size'].sample(20)
# Out:
# 429                       6.7 inches, 108 cm², 93.5% Screen To Body Ratio
# 518                    6.74 inches, 109.7 cm², 83.7% Screen To Body Ratio
# 1003                    6.7 inches, 108.1 cm², 85.3% Screen To Body Ratio
# 891                       6.5 inches, 102 cm², 81.8% Screen To Body Ratio
# 1153    6.77 inches Curved Display, 110.9 cm², 93.3% Screen To Body Ratio
# 633                       6.5 inches, 102 cm², 88.7% Screen To Body Ratio
# 277                      6.4 inches, 97.5 cm², 90.2% Screen To Body Ratio
# 883                       6.5 inches, 102 cm², 85.4% Screen To Body Ratio
# 958                     6.6 inches, 104.9 cm², 82.3% Screen To Body Ratio
# 370                                                6.72 inches, 109.6 cm²
# 445                    6.59 inches, 104.5 cm², 90.8% Screen To Body Ratio
# 329                       6.7 inches, 108 cm², 87.9% Screen To Body Ratio
# 685                                6.8 inches, 94.7% Screen To Body Ratio
# 246                        6.5 inches, 45.3 cm², 85% Screen To Body Ratio
# 229                       6.5 inches, 102 cm², 89.2% Screen To Body Ratio
# 892                                                 6.7 inches, 108.4 cm²
# 263               6.67 inches Curved Display, 92.77% Screen To Body Ratio
# 1254                   6.67 inches, 107.4 cm², 85.1% Screen To Body Ratio
# 275        6.7 inches Curved Display, 108.4 cm², 92% Screen To Body Ratio
# 1122                     6.44 inches, 100.1 cm², 88% Screen To Body Ratio
# Name: display_size, dtype: object

# %%
# make new col display_inches

df['display_inches'] = df['display_size'].str.split(' ').str.get(0)

# %%
df['display_inches'].value_counts()
# Out:
# display_inches
# 6.7      185
# 6.67     168
# 6.78     122
# 6.5       77
# 6.6       71
# 6.77      59
# 6.72      58
# 6.74      54
# 6.56      44
# 6.8       36
# 6.58      30
# 6.1       27
# 6.9       27
# 6.4       22
# 6.83      21
# 6.43      20
# 6.44      17
# 6.59      17
# 6.88      15
# 6.71      14
# 6.3       14
# 6.79      14
# 6.52      12
# 6.82      11
# 6.62      11
# 6.55      11
# 6.57       9
# 6.73       9
# 6.38       9
# 6.65       8
# 6.2        8
# 6.51       8
# 7.6        7
# 6.75       7
# 6.68       7
# 6.31       5
# 8          4
# 6.69       4
# 6.66       4
# 6.85       4
# 6.53       3
# 8.03       3
# 6.36       2
# 6.745      2
# 6.32       2
# 7.82       2
# 164.4      1
# 7          1
# 6.15       1
# 6.64       1
# Name: count, dtype: int64

# %%
df[df['display_inches'] == '164.4'] # given in mm not inches
# Out:
#      model_id                model  expert_rating  rating  rating_count  \
# 119       120  Infinix Note 12 Pro             27     4.2       71000.0
#
#      launch_on  old_price  price  launch_price  \
# 119 2022-08-26        NaN  16999         16999
#
#                               display_type            display_size  \
# 119  AMOLED, 60 Hz Refresh Rate, LTPO, SDR  164.4 inches, 76.5 cm²
#
#                                                                                            display_res  \
# 119  FHD+, 1080 x  2400 pixels, 20:9 (393 ppi), 8-bit 16.7 Million Colours, 1000 nits(Peak Brightness)
#
#             body_dimension     weight body_front body_back      body_side  \
# 119  164.4 x 76.5 x 7.8 mm  192 grams      Glass   Plastic  Plastic Frame
#
#         build_quality                                 ports ip_rating  \
# 119  Plastic Material  USB Type-C 2.0, 3.5mm Headphone Jack       NaN
#
#              speaker                                         chipset  \
# 119  Stereo Speakers  MediaTek Helio G99 (6 nm), 422909 Antutu Score
#
#                                                          cpu           gpu  \
# 119  Octa-core (2x2.2 GHz Cortex-A76 & 6x2.0 GHz Cortex-A55)  Mali-G57 MC2
#
#                                                      main_cam  \
# 119  108 MP, f/1.8, (Wide-angle), 0.8 µm, 1/1.67", Auto Focus
#
#                          main_cam2               main_cam3  \
# 119  2 MP, f/2.4, (Depth), 0.64 µm  f/2.4, (QVGA), 0.56 µm
#
#                  main_cam_features                main_video               os  \
# 119  HDR, Panorama, Quad-LED Flash  1440p@30fps, 1080p@60fps  Android 12, XOS
#
#                                                     software_updates  \
# 119  1 year(s) of Software updates and 2 year(s) of Security updates
#
#     ai_features             front_cam front_cam_features  front_video  \
# 119         NaN  16 MP, f/2.0, 0.8 µm                NaN  1440p@30fps
#
#                                        battery     charging         storage  \
# 119  5000 mAh, Lithium Polymer (Non-removable)  33W (wired)  256GB, UFS 2.2
#
#               ram                                 sim            tech  \
# 119  8GB, LPDDR4X  Dual SIM (nano-SIM, dual stand-by)  GSM, HSPA, LTE
#
#                        2g                       3g  \
# 119  2, 3, 5, 8 (4 bands)  1, 2, 4, 5, 8 (5 bands)
#
#                                                            4g   5g  \
# 119  1, 2, 3, 4, 5, 7, 8, 20, 28A, 28B, 38, 40, 41 (13 bands)  NaN
#
#               speed  \
# 119  GSM, HSPA, LTE
#
#                                                             wifi  \
# 119  Wi-Fi 5 802.11 a/b/g/n/ac, Hotspot, Wi-Fi Direct, Dual Band
#
#                  bluetooth positioning_system  nfc  finger_print  \
# 119  5, A2DP, AAC, LE, SBC                GPS  NaN  Side Mounted
#
#                                                                          sensors  \
# 119  Accelerometer, Compass, G-Sensor, Gyroscope, Light Sensor, Proximity Sensor
#
#     add_features main_cam4 front_cam2    brand  is_available  \
# 119          NaN       NaN        NaN  infinix             0
#
#      is_flipkart_available  is_amazon_available  is_official_available  \
# 119                      1                    1                      0
#
#     display_panel_type display_panel_family  display_hz display_dynamic_range  \
# 119             amoled               amoled          60                   SDR
#
#      touch_sampling_rate  has_ltpo  has_anti_reflection_coating display_inches
# 119                  NaN         1                            0          164.4

# %%
# fill with correct value
df.loc[119,'display_inches'] = 6.7

# %%
df['display_inches'].value_counts()
# Out:
# display_inches
# 6.7      185
# 6.67     168
# 6.78     122
# 6.5       77
# 6.6       71
# 6.77      59
# 6.72      58
# 6.74      54
# 6.56      44
# 6.8       36
# 6.58      30
# 6.1       27
# 6.9       27
# 6.4       22
# 6.83      21
# 6.43      20
# 6.44      17
# 6.59      17
# 6.88      15
# 6.71      14
# 6.3       14
# 6.79      14
# 6.52      12
# 6.82      11
# 6.62      11
# 6.55      11
# 6.57       9
# 6.73       9
# 6.38       9
# 6.65       8
# 6.2        8
# 6.51       8
# 7.6        7
# 6.75       7
# 6.68       7
# 6.31       5
# 8          4
# 6.69       4
# 6.66       4
# 6.85       4
# 6.53       3
# 8.03       3
# 6.36       2
# 6.745      2
# 6.32       2
# 7.82       2
# 6.7        1
# 7          1
# 6.15       1
# 6.64       1
# Name: count, dtype: int64

# %%
df['display_inches'].count()
# Out:
# np.int64(1268)

# %%
# convert dtypes of display_inches to float

df['display_inches'] = pd.to_numeric(df['display_inches'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 68 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
# dtypes: category(3), datetime64[ns](1), float64(5), int64(11), object(48)
# memory usage: 648.8+ KB

# %%
df['display_size'].sample(20)
# Out:
# 1021                    6.6 inches, 105.3 cm², 86.8% Screen To Body Ratio
# 405                    6.66 inches, 107.2 cm², 89.9% Screen To Body Ratio
# 211                                   6.78 inches Curved Display, 111 cm²
# 858                    6.67 inches, 107.4 cm², 93.3% Screen To Body Ratio
# 574          6.7 inches Curved Display, 108 cm², 93% Screen To Body Ratio
# 951                       6.5 inches, 103.7 cm², 87% Screen To Body Ratio
# 1089                                               6.58 inches, 104.3 cm²
# 1096    6.77 inches Curved Display, 110.9 cm², 93.1% Screen To Body Ratio
# 350                    6.78 inches, 112.4 cm², 95.5% Screen To Body Ratio
# 505                   6.67 inches, 107.4 cm², 94.27% Screen To Body Ratio
# 550     6.67 inches Curved Display, 107.4 cm², 88.9% Screen To Body Ratio
# 1257    6.73 inches Curved Display, 109.4 cm², 89.6% Screen To Body Ratio
# 946                     6.6 inches, 104.9 cm², 82.5% Screen To Body Ratio
# 1197                   6.56 inches, 103.4 cm², 83.6% Screen To Body Ratio
# 197                    6.72 inches, 108.8 cm², 86.2% Screen To Body Ratio
# 801                    6.79 inches, 109.5 cm², 85.1% Screen To Body Ratio
# 524                    6.79 inches, 109.5 cm², 91.2% Screen To Body Ratio
# 982                                                 6.6 inches, 104.9 cm²
# 25                       6.1 inches, 91.3 cm², 88.3% Screen To Body Ratio
# 1246                   6.58 inches, 104.3 cm², 90.6% Screen To Body Ratio
# Name: display_size, dtype: object

# %%
def extract_body_ratio(text):

  t = text.lower()

  if '%' in t:
    return t

  return np.nan

df['display_body_ratio'] = df['display_size'].apply(extract_body_ratio)

# %%
df['display_body_ratio'].count()
# Out:
# np.int64(1036)

# %%
df['display_body_ratio'] = df['display_body_ratio'].str.split('%').str.get(0).str.split(',').str.get(-1)

# %%
df['display_body_ratio'].value_counts(dropna=False)
# Out:
# display_body_ratio
# NaN       232
#  93        40
#  91.4      36
#  90.8      35
#  83.6      28
#          ...
#  86.48      1
#  93.2       1
#  90.04      1
#  82.9       1
#  94.85      1
# Name: count, Length: 154, dtype: int64

# %%
# convert dtypes to floar
df['display_body_ratio'] = pd.to_numeric(df['display_body_ratio'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 69 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
# dtypes: category(3), datetime64[ns](1), float64(6), int64(11), object(48)
# memory usage: 658.8+ KB

# %%
df['display_size'].sample(20)
# Out:
# 330                            6.7 inches, 108 cm², 87.9% Screen To Body Ratio
# 342       6.82 inches Quad Curved Display, 113 cm², 90.7% Screen To Body Ratio
# 1052                                          6.7 inches Flip Display, 102 cm²
# 780                        6.8 inches Curved Display, 94% Screen To Body Ratio
# 302             6.9 inches Flip Display, 107.6 cm², 85.4% Screen To Body Ratio
# 206                                                       6.44 inches, 100 cm²
# 1020                         6.6 inches, 105.3 cm², 86.8% Screen To Body Ratio
# 1009                                                               6.73 inches
# 1039                         6.7 inches, 107.1 cm², 92.1% Screen To Body Ratio
# 863         6.67 inches Curved Display, 107.4 cm², 93.35% Screen To Body Ratio
# 286          6.7 inches Curved Display, 108.4 cm², 96.47% Screen To Body Ratio
# 954                          6.7 inches, 108.4 cm², 83.6% Screen To Body Ratio
# 934                          6.6 inches, 106.9 cm², 85.8% Screen To Body Ratio
# 687                         6.79 inches, 112.8 cm², 94.2% Screen To Body Ratio
# 351                         6.83 inches, 113.3 cm², 90.1% Screen To Body Ratio
# 1245                        6.58 inches, 104.3 cm², 90.6% Screen To Body Ratio
# 331           6.7 inches Curved Display, 108.4 cm², 89.7% Screen To Body Ratio
# 748                        6.67 inches, 107.2 cm², 89.97% Screen To Body Ratio
# 1164    6.77 inches Quad Curved Display, 110.9 cm², 88.1% Screen To Body Ratio
# 1108                        6.74 inches, 109.7 cm², 85.1% Screen To Body Ratio
# Name: display_size, dtype: object

# %%
df[df['display_size'].str.contains('Curved')]['display_size'].count()
# Out:
# np.int64(263)

# %%
df[df['display_size'].str.contains('Foldable|Flip')]['display_size'].count()
# Out:
# np.int64(35)

# %%
def extract_curved(text):

  if 'Curved' in text:
    return 1
  return 0

df['has_curved'] = df['display_size'].apply(extract_curved)

# %%
df['has_curved'].value_counts()
# Out:
# has_curved
# 0    1005
# 1     263
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 70 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
# dtypes: category(3), datetime64[ns](1), float64(6), int64(12), object(48)
# memory usage: 668.7+ KB

# %%
def extract_foldable(text):

  if 'Foldable' in text or 'Flip' in text:
    return 1

  return 0

df['has_foldable'] = df['display_size'].apply(extract_foldable)

# %%
df['has_foldable'].value_counts()
# Out:
# has_foldable
# 0    1233
# 1      35
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 71 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
# dtypes: category(3), datetime64[ns](1), float64(6), int64(13), object(48)
# memory usage: 678.6+ KB

# %%
df['display_res'].sample(20)
# Out:
# 453                                                                       1.5K, 1280 x  2800 pixels, (453 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 1600 nits(High Brightness), 600 nits(Typical Brightness), Blue Light Filters
# 1064                                                                                                                                             QXGA+, 1968 x  2184 pixels, (386 ppi), 16 Million Colours, 2600 nits(High Brightness)
# 545                                                                                                                                 FHD+, 1080 x  2400 pixels, 20:9 (395 ppi), 10-bit colours, 1000 nits(Peak Brightness), PWM Dimming
# 1015                                                                                                                                            QHD+, 1440 x  3088 pixels, 19.3:9 (500 ppi), 8-bit colours, 1750 nits(High Brightness)
# 554                                                                 FHD+, 1080 x  2400 pixels, 20:9 (411 ppi), 8-bit 16.7 Million Colours, 98% NTSC, 1000 nits(Peak Brightness), TUV Rheinland certification, 4000000:1 Contrast Ratio
# 734                                                                   FHD+, 1080 x  2400 pixels, 20:9 (392 ppi), 8-bit colours, 950 nits(Peak Brightness), 690 nits(High Brightness), 580 nits(Typical Brightness), Blue Light Filters
# 571                                                FHD+, 1080 x  2412 pixels, 20:9 (394 ppi), 10-bit colours, 100% DCI-P3, 950 nits(Peak Brightness), 800 nits(High Brightness), TUV Rheinland certification, 5000000:1 Contrast Ratio
# 782                                                                                          FHD+, 1080 x  2400 pixels, 20:9 (391 ppi), 8-bit 16.7 Million Colours, 83% NTSC, 1000 nits(High Brightness), 800 nits(Typical Brightness)
# 983                                                                                                                 FHD+, 1080 x  2340 pixels, 20:9 (396 ppi), 8-bit 16 Million Colours, 800 nits(Peak Brightness), Eye Comfort Shield
# 1186                                                                                                                             HD+, 720 x  1600 pixels, 20:9 (270 ppi), 8-bit colours, 500 nits(Peak Brightness), Blue Light Filters
# 1090                                                                                                                                               FHD+, 1080 x  2408 pixels, 20:9 (401 ppi), 8-bit colours, 650 nits(Peak Brightness)
# 727                                                                                      HD+, 720 x  1600 pixels, 20:9 (260 ppi), 8-bit 16.7 Million Colours, 83.5% NTSC, 563 nits(Peak Brightness), DC Dimming, 1500:1 Contrast Ratio
# 921                                                                                                            FHD+, 1080 x  2340 pixels, 19.5:9 (385 ppi), 8-bit colours, 100% DCI-P3, 1000 nits(Peak Brightness), Blue Light Filters
# 887                                                                                                   FHD+, 1080 x  2408 pixels, 20:9 (400 ppi), 8-bit 16 Million Colours, 100% DCI-P3, 1000 nits(Peak Brightness), Eye Comfort Shield
# 484                                                                                                                                                  HD+, 720 x  1600 pixels, 20:9 (269 ppi), 8-bit colours, 400 nits(Peak Brightness)
# 984                                                                                                                 FHD+, 1080 x  2340 pixels, 20:9 (396 ppi), 8-bit 16 Million Colours, 800 nits(Peak Brightness), Eye Comfort Shield
# 271                                                                                                                        FHD+, 1080 x  2400 pixels, 20:9 (405 ppi), 10-bit 1 Billion Colours, 100% DCI-P3, 500 nits(Peak Brightness)
# 987                                                                                                                                              FHD+, 1080 x  2340 pixels, 19.5:9 (385 ppi), 8-bit colours, 800 nits(High Brightness)
# 748                                                                          HD+, 720 x  1604 pixels, 20:9 (264 ppi), 8-bit 16.7 Million Colours, 625 nits(High Brightness), 500 nits(Typical Brightness), TUV Rheinland certification
# 866     1.5K, 1220 x  2712 pixels, 20:9 (446 ppi), 12-bit 68 Billion Colours, 100% DCI-P3, 1800 nits(Peak Brightness), 1200 nits(High Brightness), 500 nits(Typical Brightness), TUV Rheinland certification, 5000000:1 Contrast Ratio
# Name: display_res, dtype: object

# %%
df['res_category'] = df['display_res'].str.split(',').str.get(0)

# %%
df['res_category'].value_counts()
# Out:
# res_category
# FHD+                   742
# HD+                    249
# 1.5K                   180
# QHD+                    50
# HD                      16
# FHD                      9
# WQHD+                    6
# 2K                       6
# QXGA+                    6
# 1080 x  2520 pixels      2
# QHD                      1
# 2.5K                     1
# Name: count, dtype: int64

# %%
df[df['res_category'].str.contains('pixels')][['model','display_res']]
# Out:
#                                        model  \
# 1055  Samsung Galaxy Z Flip 7 (12GB + 512GB)
# 1058                 Samsung Galaxy Z Flip 7
#
#                                                                                      display_res
# 1055  1080 x  2520 pixels, 21:9 (397 ppi), 12-bit 16 Million Colours, 2600 nits(High Brightness)
# 1058  1080 x  2520 pixels, 21:9 (397 ppi), 12-bit 16 Million Colours, 2600 nits(High Brightness)

# %%
df.loc[[1055,1058],'res_category'] = 'FHD+'

# %%
df['res_category'].value_counts()
# Out:
# res_category
# FHD+     744
# HD+      249
# 1.5K     180
# QHD+      50
# HD        16
# FHD        9
# 2K         6
# QXGA+      6
# WQHD+      6
# QHD        1
# 2.5K       1
# Name: count, dtype: int64

# %%
df['res_category'] = df['res_category'].replace('QXGA+','QHD+')
df['res_category'] = df['res_category'].replace('WQHD+','QHD+')
df['res_category'] = df['res_category'].replace('QHD','QHD+')
df['res_category'] = df['res_category'].replace('2K','1.5K')
df['res_category'] = df['res_category'].replace('2.5K','1.5K')

# %%
df['res_category'].value_counts()
# Out:
# res_category
# FHD+    744
# HD+     249
# 1.5K    187
# QHD+     63
# HD       16
# FHD       9
# Name: count, dtype: int64

# %%
df['res_category'] = df['res_category'].astype('category')

# %%
df['res_category'].value_counts()
# Out:
# res_category
# FHD+    744
# HD+     249
# 1.5K    187
# QHD+     63
# HD       16
# FHD       9
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 72 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
# dtypes: category(4), datetime64[ns](1), float64(6), int64(13), object(48)
# memory usage: 680.0+ KB

# %%
df['display_res'].sample(20)
# Out:
# 1065                                                                                                                                               QXGA+, 1968 x  2184 pixels, (386 ppi), 16 Million Colours, 2600 nits(High Brightness)
# 486                                                                                                                      HD+, 720 x  1600 pixels, 20:9 (269 ppi), 8-bit colours, 400 nits(Peak Brightness), 400 nits(Typical Brightness)
# 51                                1.5K, 1260 x  2736 pixels, 19.5:9 (460 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 3000 nits(Peak Brightness), 1600 nits(High Brightness), 1000 nits(Typical Brightness), 2000000:1 Contrast Ratio
# 1123                                                                                                                                                 FHD+, 1080 x  2376 pixels, 20:9 (398 ppi), 8-bit colours, 629 nits(Peak Brightness)
# 963                                                                                FHD+, 1080 x  2340 pixels, 19.5:9 (387 ppi), 10-bit colours, 100% DCI-P3, 600 nits(Peak Brightness), 400 nits(Typical Brightness), Eye Comfort Shield
# 439     FHD+, 1264 x  2780 pixels, 20:9 (450 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 4500 nits(Peak Brightness), 1600 nits(High Brightness), 800 nits(Typical Brightness), TUV Rheinland certification, 5000000:1 Contrast Ratio
# 366                                                                                               FHD+, 1080 x  2400 pixels, 20:9 (409 ppi), 10-bit 1 Billion Colours, 100% sRGB, 600 nits(Peak Brightness), TUV Rheinland certification
# 1181                                                             WQHD+, 1440 x  3200 pixels, 20:9 (517 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 1500 nits(High Brightness), TUV Rheinland certification, 8000000:1 Contrast Ratio
# 133                                                                                                            HD+, 720 x  1600 pixels, 20:9 (263 ppi), 8-bit colours, 72% NTSC, 672 nits(Peak Brightness), 560 nits(Typical Brightness)
# 1064                                                                                                                                               QXGA+, 1968 x  2184 pixels, (386 ppi), 16 Million Colours, 2600 nits(High Brightness)
# 1229                                                                                                                    HD+, 720 x  1608 pixels, 20:9 (264 ppi), 8-bit colours, 83% NTSC, 1000 nits(High Brightness), Blue Light Filters
# 496                                                                                                HD+, 720 x  1640 pixels, 20:9 (260 ppi), 8-bit colours, 600 nits(Peak Brightness), TUV Rheinland certification, 1500:1 Contrast Ratio
# 1153                                                                       FHD+, 1080 x  2392 pixels, 20:9 (387 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 4500 nits(Peak Brightness), Blue Light Filters, 8000000:1 Contrast Ratio
# 667                                                                                  HD+, 720 x  1604 pixels, 20:9 (264 ppi), 8-bit 16.7 Million Colours, 83% NTSC, 625 nits(High Brightness), Eye Comfort Shield, 1500:1 Contrast Ratio
# 837                                                           FHD+, 1080 x  2400 pixels, 20:9 (409 ppi), 8-bit colours, 100% DCI-P3, 1000 nits(Peak Brightness), 700 nits(High Brightness), Eye Comfort Shield, 4500000:1 Contrast Ratio
# 98                                             1.5K, 1224 x  2720 pixels, 20:9 (440 ppi), 10-bit colours, 100% DCI-P3, 4500 nits(Peak Brightness), 1600 nits(High Brightness), 700 nits(Typical Brightness), TUV Rheinland certification
# 810                                                                                                    HD+, 720 x  1640 pixels, 20:9 (260 ppi), 8-bit colours, 70% sRGB, 600 nits(High Brightness), DC Dimming, 1000000:1 Contrast Ratio
# 314                                  FHD+, 1080 x  2412 pixels, 20:9 (394 ppi), 10-bit colours, 100% DCI-P3, 1300 nits(Peak Brightness), 1100 nits(High Brightness), 700 nits(Typical Brightness), PWM Dimming, 1000000:1 Contrast Ratio
# 1195                                                                                                                               HD, 720 x  1612 pixels, 20:9 (269 ppi), 8-bit 16 Million Colours, 83% NTSC, 840 nits(Peak Brightness)
# 42                                1.5K, 1206 x  2622 pixels, 19.5:9 (460 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 3000 nits(Peak Brightness), 1600 nits(High Brightness), 1000 nits(Typical Brightness), 2000000:1 Contrast Ratio
# Name: display_res, dtype: object

# %%
df['display_pixels'] = df['display_res'].str.split(',').str.get(1)

# %%
df['display_pixels'].value_counts()
# Out:
# display_pixels
# 1080 x  2400 pixels    307
# 720 x  1600 pixels     128
# 1080 x  2340 pixels     92
# 1080 x  2412 pixels     79
# 1080 x  2408 pixels     75
#                       ...
# 2152 x  2076 pixels      1
# 2076 x  2152 pixels      1
# 1224 x  2912 pixels      1
# 1080 x  2373 pixels      1
# 1080 x  2388 pixels      1
# Name: count, Length: 70, dtype: int64

# %%
df[~df['display_pixels'].str.contains('pixels')][['model','display_res','display_pixels']]
# Out:
#                                        model  \
# 1055  Samsung Galaxy Z Flip 7 (12GB + 512GB)
# 1058                 Samsung Galaxy Z Flip 7
#
#                                                                                      display_res  \
# 1055  1080 x  2520 pixels, 21:9 (397 ppi), 12-bit 16 Million Colours, 2600 nits(High Brightness)
# 1058  1080 x  2520 pixels, 21:9 (397 ppi), 12-bit 16 Million Colours, 2600 nits(High Brightness)
#
#        display_pixels
# 1055   21:9 (397 ppi)
# 1058   21:9 (397 ppi)

# %%
df.loc[[1055,1058],'display_pixels'] = '1080 x 2520 pixels'

# %%
df[df['display_pixels'].str.contains('pixels')]['display_pixels'].count()
# Out:
# np.int64(1268)

# %%
df['res_width'] = df['display_pixels'].str.split('x').str.get(0)

# %%
df['res_width'].value_counts()
# Out:
# res_width
#  1080     676
#  720      267
#  1260      47
#  1440      44
#  1220      38
#  1280      24
#  1272      22
#  1264      19
#  1179      14
#  1290      13
#  1256      10
#  1240       9
#  1206       8
#  1216       7
#  1224       7
#  1320       7
#  1200       7
#  1084       7
#  1170       6
#  1344       5
#  1812       4
#  1968       3
#  1856       3
#  1284       3
#  2400       3
#  1088       3
#  2200       2
# 1080        2
#  2268       2
#  1400       2
#  1236       2
#  2152       1
#  2076       1
# Name: count, dtype: int64

# %%
df['res_width'].count()
# Out:
# np.int64(1268)

# %%
df['res_width'] = pd.to_numeric(df['res_width'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  display_pixels               1268 non-null   object
#  73  res_width                    1268 non-null   int64
# dtypes: category(4), datetime64[ns](1), float64(6), int64(14), object(49)
# memory usage: 699.8+ KB

# %%
df['res_height'] = df['display_pixels'].str.strip().str.split('x').str.get(1).str.split(' ').str.get(2)

# %%
df['res_height'].value_counts()
# Out:
# res_height
# 2400    307
# 1600    128
# 2340     92
# 2800     83
# 2412     81
# 2408     75
# 2392     58
# 1612     56
# 2712     36
# 1604     36
# 2640     21
# 2780     19
# 1650     17
# 2460     16
# 1640     16
# 2772     14
# 2796     13
# 3120     13
# 2556     11
# 2760     10
# 3200     10
# 3168     10
# 2436      9
# 2372      8
# 2622      8
# 2868      7
# 2404      7
# 1608      7
# 1570      7
# 2376      6
# 2532      6
# 3216      6
# 3088      5
# 2992      5
# 2664      4
# 2176      4
# 2720      4
# 2480      4
# 2448      4
# 2778      3
# 2184      3
# 2424      3
# 2736      3
# 2256      3
# 2670      3
# 2160      3
# 1080      3
# 2750      2
# 2856      2
# 2440      2
# 2700      2
# 2652      2
# pi        2
# 3136      2
# 2520      2
# 2152      1
# 2076      1
# 2912      1
# 2373      1
# 2388      1
# Name: count, dtype: int64

# %%
df[df['res_height'].str.contains('pi')]['display_pixels']
# Out:
# 1055    1080 x 2520 pixels
# 1058    1080 x 2520 pixels
# Name: display_pixels, dtype: object

# %%
df.loc[[1055,1058],'res_height'] = 2520

# %%
df['res_height'].value_counts()
# Out:
# res_height
# 2400    307
# 1600    128
# 2340     92
# 2800     83
# 2412     81
# 2408     75
# 2392     58
# 1612     56
# 2712     36
# 1604     36
# 2640     21
# 2780     19
# 1650     17
# 2460     16
# 1640     16
# 2772     14
# 2796     13
# 3120     13
# 2556     11
# 2760     10
# 3200     10
# 3168     10
# 2436      9
# 2372      8
# 2622      8
# 2868      7
# 2404      7
# 1608      7
# 1570      7
# 2376      6
# 2532      6
# 3216      6
# 3088      5
# 2992      5
# 2664      4
# 2176      4
# 2720      4
# 2480      4
# 2448      4
# 2778      3
# 2184      3
# 2424      3
# 2736      3
# 2256      3
# 2670      3
# 2160      3
# 1080      3
# 2750      2
# 2856      2
# 2440      2
# 2700      2
# 2652      2
# 2520      2
# 3136      2
# 2520      2
# 2152      1
# 2076      1
# 2912      1
# 2373      1
# 2388      1
# Name: count, dtype: int64

# %%
df['res_height'] = pd.to_numeric(df['res_height'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 75 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  display_pixels               1268 non-null   object
#  73  res_width                    1268 non-null   int64
#  74  res_height                   1268 non-null   int64
# dtypes: category(4), datetime64[ns](1), float64(6), int64(15), object(49)
# memory usage: 709.7+ KB

# %%
# now drop display_pixels
df.drop(columns='display_pixels',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
# dtypes: category(4), datetime64[ns](1), float64(6), int64(15), object(48)
# memory usage: 699.8+ KB

# %%
df['helper'] = df['display_res'].str.split(',').str.get(2).str.strip()

# %%
def extract_ratio(text):

  if pd.isna(text):
    return np.nan

  if 'colours' in text:
    return np.nan

  if ':' in text:
    return str(text)

  return np.nan

df['aspect_ration_numeric'] = df['helper'].apply(extract_ratio)

# %%
df['x'] = df['aspect_ration_numeric'].str.split(':').str.get(0)

# %%
df['x'].sample(20)
# Out:
# 964       20
# 33      19.5
# 665       20
# 615     19.5
# 1169      20
# 1263      20
# 438      NaN
# 641       20
# 398       20
# 1218      20
# 974       20
# 1061     NaN
# 214       20
# 706       20
# 1022    19.3
# 161     19.8
# 272       20
# 580       20
# 666       20
# 814       20
# Name: x, dtype: object

# %%
df['y'] = df['aspect_ration_numeric'].str.strip().str.split(':').str.get(1).str.strip().str.split(' ').str.get(0)

# %%
df['y'].sample(20)
# Out:
# 661     9
# 671     9
# 1259    9
# 241     9
# 559     9
# 23      9
# 1094    9
# 796     9
# 460     9
# 476     9
# 567     9
# 256     9
# 463     9
# 489     9
# 224     9
# 1173    9
# 644     9
# 1249    9
# 120     9
# 443     9
# Name: y, dtype: object

# %%
df['x'] = pd.to_numeric(df['x'], errors='coerce')
df['y'] = pd.to_numeric(df['y'], errors='coerce')

# %%
df['aspect_ration_numeric'] = df['x'] / df['y']

# %%
df['aspect_ration_numeric'].sample(20)
# Out:
# 502     2.222222
# 790     2.222222
# 1059    2.566667
# 331     2.233333
# 1070    2.222222
# 195     2.222222
# 1212    2.222222
# 209     2.222222
# 206     2.222222
# 420     2.222222
# 1093    2.222222
# 616     2.222222
# 439     2.222222
# 1167    1.126761
# 512     2.222222
# 969     2.166667
# 289     2.222222
# 836     2.222222
# 971     2.222222
# 208     2.222222
# Name: aspect_ration_numeric, dtype: float64

# %%
df['aspect_ration_numeric'] = pd.to_numeric(df['aspect_ration_numeric'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 78 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
#  74  helper                       1266 non-null   object
#  75  aspect_ration_numeric        1185 non-null   float64
#  76  x                            1185 non-null   float64
#  77  y                            1185 non-null   float64
# dtypes: category(4), datetime64[ns](1), float64(9), int64(15), object(49)
# memory usage: 739.5+ KB

# %%
# now drop helper , x and y
df.drop(columns=['helper','x','y'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 75 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
#  74  aspect_ration_numeric        1185 non-null   float64
# dtypes: category(4), datetime64[ns](1), float64(7), int64(15), object(48)
# memory usage: 709.7+ KB

# %%
df['display_res'].sample(20)
# Out:
# 491                                                                                               HD+, 720 x  1650 pixels, 20:9 (268 ppi), 8-bit colours, 500 nits(High Brightness), DC Dimming, 1500:1 Contrast Ratio
# 467                                            FHD+, 1080 x  2412 pixels, 20:9 (394 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 950 nits(Peak Brightness), 800 nits(High Brightness), 500 nits(Typical Brightness)
# 604                                                FHD+, 1280 x  2800 pixels, (452.75 ppi), 10-bit 1.07 Billion Colours, 6500 nits(Peak Brightness), 1800 nits(High Brightness), PWM Dimming, 5000000:1 Contrast Ratio
# 246                                                                                                                                                             HD+, 720 x  1600 pixels, 20:9 (269 ppi), 8-bit colours
# 1233                                                                                 HD+, 720 x  1608 pixels, (264 ppi), 8-bit 16.7 Million Colours, 83% NTSC, 1000 nits(Peak Brightness), TUV Rheinland certification
# 914                                                                                       FHD+, 1080 x  2340 pixels, 19.5:9 (385 ppi), 8-bit 16 Million Colours, 1100 nits(Peak Brightness), 800 nits(High Brightness)
# 644                                                                                       HD+, 720 x  1600 pixels, 20:9 (390 ppi), 8-bit 16.7 Million Colours, 560 nits(High Brightness), 560 nits(Typical Brightness)
# 179                                                             FHD+, 1080 x  2400 pixels, 20:9 (388 ppi), 10-bit 1 Billion Colours, 1300 nits(Peak Brightness), TUV Rheinland certification, 8000000:1 Contrast Ratio
# 1170                                                        FHD+, 1260 x  2800 pixels, 20:9 (452 ppi), 10-bit 1 Billion Colours, 100% DCI-P3, 3000 nits(Peak Brightness), Blue Light Filters, 8000000:1 Contrast Ratio
# 749                                                          HD+, 720 x  1604 pixels, 20:9 (264 ppi), 8-bit 16.7 Million Colours, 625 nits(High Brightness), 500 nits(Typical Brightness), TUV Rheinland certification
# 96                                1.5K, 1224 x  2720 pixels, (440 ppi), 10-bit colours, 100% DCI-P3, 4500 nits(Peak Brightness), 1600 nits(High Brightness), 700 nits(Typical Brightness), TUV Rheinland certification
# 270                                                                                                      FHD+, 1080 x  2400 pixels, 20:9 (395 ppi), 10-bit 1.07 Billion Colours, 100% sRGB, 1250 nits(Peak Brightness)
# 932                                                                                                                  FHD+, 1080 x  2340 pixels, 19.5:9 (403 ppi), 8-bit 16 Million Colours, 1000 nits(Peak Brightness)
# 987                                                                                                                              FHD+, 1080 x  2340 pixels, 19.5:9 (385 ppi), 8-bit colours, 800 nits(High Brightness)
# 147                                              FHD+, 1080 x  2400 pixels, 20:9 (388 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 950 nits(Peak Brightness), TUV Rheinland certification, 1000000:1 Contrast Ratio
# 303                                                                                                       FHD+, 1080 x  2640 pixels, 22:9 (413 ppi), 10-bit 1 Billion Colours, 120% DCI-P3, 1400 nits(Peak Brightness)
# 757                                             FHD+, 1080 x  2400 pixels, 20:9 (395 ppi), 8-bit 16.7 Million Colours, 100% DCI-P3, 2000 nits(Peak Brightness), 600 nits(Typical Brightness), 6000000:1 Contrast Ratio
# 257                                                                                                      FHD+, 1080 x  2400 pixels, 20:9 (411 ppi), 8-bit 16.7 Million Colours, 100% DCI-P3, 700 nits(Peak Brightness)
# 717     FHD+, 1080 x  2400 pixels, 20:9 (395 ppi), 10-bit 16.7 Million Colours, 106% NTSC, 2000 nits(Peak Brightness), 1200 nits(High Brightness), 600 nits(Typical Brightness), PWM Dimming, 5000000:1 Contrast Ratio
# 933                                                                                       FHD+, 1080 x  2340 pixels, 19.5:9 (390 ppi), 8-bit 16 Million Colours, 1000 nits(High Brightness), SGS Display Certification
# Name: display_res, dtype: object

# %%
df['display_ppi'] = df['display_res'].str.split(',').str.get(2).str.split('(').str.get(1).str.strip().str.split(' ').str.get(0)

# %%
df['display_ppi'].value_counts(dropna=False)
# Out:
# display_ppi
# 395      86
# 394      84
# 460      71
# 269      64
# 260      53
#          ..
# 259       1
# 464       1
# 263.6     1
# 383.5     1
# 412       1
# Name: count, Length: 82, dtype: int64

# %%
df[df['display_ppi'].isna()][['model','display_ppi','display_res']]
# Out:
#                                        model display_ppi  \
# 668              Realme C75 5G (6GB + 128GB)         NaN
# 743                         Realme Narzo N55         NaN
# 800                                Redmi 12C         NaN
# 956      Samsung Galaxy F17 5G (6GB + 128GB)         NaN
# 957                    Samsung Galaxy F17 5G         NaN
# 1055  Samsung Galaxy Z Flip 7 (12GB + 512GB)         NaN
# 1058                 Samsung Galaxy Z Flip 7         NaN
#
#                                                                                              display_res
# 668                                    HD+, 720 x  1604 pixels, 8-bit colours, 625 nits(Peak Brightness)
# 743                FHD+, 1080 x  2400 pixels, 20:9 8-bit 16.7 Million Colours, 680 nits(Peak Brightness)
# 800   HD+, 720 x  1650 pixels, 20.6:9 8-bit colours, 500 nits(Typical Brightness), 1500:1 Contrast Ratio
# 956                                                                            FHD+, 1080 x  2340 pixels
# 957                                                                            FHD+, 1080 x  2340 pixels
# 1055          1080 x  2520 pixels, 21:9 (397 ppi), 12-bit 16 Million Colours, 2600 nits(High Brightness)
# 1058          1080 x  2520 pixels, 21:9 (397 ppi), 12-bit 16 Million Colours, 2600 nits(High Brightness)

# %%
df.loc[[1055,1058],'display_ppi'] = 397

# %%
df[df['display_ppi'].isna()][['model','display_ppi','display_res']]
# Out:
#                                    model display_ppi  \
# 668          Realme C75 5G (6GB + 128GB)         NaN
# 743                     Realme Narzo N55         NaN
# 800                            Redmi 12C         NaN
# 956  Samsung Galaxy F17 5G (6GB + 128GB)         NaN
# 957                Samsung Galaxy F17 5G         NaN
#
#                                                                                             display_res
# 668                                   HD+, 720 x  1604 pixels, 8-bit colours, 625 nits(Peak Brightness)
# 743               FHD+, 1080 x  2400 pixels, 20:9 8-bit 16.7 Million Colours, 680 nits(Peak Brightness)
# 800  HD+, 720 x  1650 pixels, 20.6:9 8-bit colours, 500 nits(Typical Brightness), 1500:1 Contrast Ratio
# 956                                                                           FHD+, 1080 x  2340 pixels
# 957                                                                           FHD+, 1080 x  2340 pixels

# %%
calculate_ppi = np.sqrt(df['res_width']**2 + df['res_height']**2) / df['display_inches']

# %%
# fill nan ppi with calculated ppi
df['display_ppi'] = df['display_ppi'].fillna(calculate_ppi)

# %%
df.loc[[668,743,800,956,957]][['model','display_ppi']]
# Out:
#                                    model display_ppi
# 668          Realme C75 5G (6GB + 128GB)  263.596016
# 743                     Realme Narzo N55  391.637718
# 800                            Redmi 12C  268.293589
# 956  Samsung Galaxy F17 5G (6GB + 128GB)  384.657879
# 957                Samsung Galaxy F17 5G  384.657879

# %%
df['display_ppi'].count()
# Out:
# np.int64(1268)

# %%
df['display_ppi'] = pd.to_numeric(df['display_ppi'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
#  74  aspect_ration_numeric        1185 non-null   float64
#  75  display_ppi                  1268 non-null   float64
# dtypes: category(4), datetime64[ns](1), float64(8), int64(15), object(48)
# memory usage: 719.6+ KB

# %%
df['color_depth'] = df['display_res'].str.split(',').str.get(3).str.strip().str.split(' ').str.get(0).str.strip().str.split('-').str.get(0)

# %%
df.loc[[743,668,800,1064,1065,1066],'color_depth'] = 8
df.loc[[291,134,1241,1242,812,813],'color_depth'] = np.nan
df.loc[[1055,1058],'color_depth'] = 12

# %%
df['color_depth'] = pd.to_numeric(df['color_depth'])

# %%
df['color_depth'] = df['color_depth'].fillna(8)

# %%
df['color_depth'].value_counts(dropna=False)
# Out:
# color_depth
# 8.0     736
# 10.0    487
# 12.0     45
# Name: count, dtype: int64

# %%
df['peak_brightness'] = df['display_res'].str.extract(r'(\d+)\s*nits')

# %%
df['peak_brightness'].value_counts(dropna=False)
# Out:
# peak_brightness
# 1000    115
# 1300     85
# 1200     81
# 2000     77
# 4500     70
#        ...
# 920       1
# 564       1
# 629       1
# 200       1
# 1024      1
# Name: count, Length: 74, dtype: int64

# %%
# will fill in eda
df['peak_brightness'].isnull().sum()
# Out:
# np.int64(62)

# %%
df['peak_brightness'] = pd.to_numeric(df['peak_brightness'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 78 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
#  74  aspect_ration_numeric        1185 non-null   float64
#  75  display_ppi                  1268 non-null   float64
#  76  color_depth                  1268 non-null   float64
#  77  peak_brightness              1206 non-null   float64
# dtypes: category(4), datetime64[ns](1), float64(10), int64(15), object(48)
# memory usage: 739.5+ KB

# %%
df['display_res'].sample(20)
# Out:
# 1128                                                                                                                                  FHD+, 1080 x  2376 pixels, 2.2:1 (398 ppi), 8-bit colours, 1300 nits(High Brightness)
# 154                                                                                                            1.5K, 1440 x  3200 pixels, 20:9 (518 ppi), 10-bit 1 Billion Colours, 100% DCI-P3, 1800 nits(Peak Brightness)
# 342     QHD+, 1440 x  3168 pixels, 20:9 (510 ppi), 12-bit colours, 100% DCI-P3, 4500 nits(Peak Brightness), 1600 nits(High Brightness), 800 nits(Typical Brightness), TUV Rheinland certification, 2000000:1 Contrast Ratio
# 73                                                       QHD+, 1344 x  2992 pixels, 20:9 (489 ppi), 8-bit 16 Million Colours, 100% DCI-P3, 2400 nits(Peak Brightness), 1600 nits(High Brightness), 1000000:1 Contrast Ratio
# 719                                                                FHD+, 1080 x  2400 pixels, 20:9 (395 ppi), 8-bit colours, 100% DCI-P3, 2000 nits(Peak Brightness), TUV Rheinland certification, 5000000:1 Contrast Ratio
# 767                                                                                         1.5K, 1272 x  2800 pixels, 19.5:9 (390 ppi), 8-bit colours, 100% DCI-P3, 1500 nits(Peak Brightness), 1200 nits(High Brightness)
# 212                                                                 FHD+, 1080 x  2400 pixels, 20:9 (387 ppi), 10-bit 1.07 Billion Colours, 1300 nits(Peak Brightness), SGS Display Certification, 8000000:1 Contrast Ratio
# 53                   1.5K, 1260 x  2736 pixels, 19.5:9 (460 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 3000 nits(Peak Brightness), 1600 nits(High Brightness), 1000 nits(Typical Brightness), 2000000:1 Contrast Ratio
# 597             1.5K, 1272 x  2800 pixels, (450 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 1500 nits(Peak Brightness), 1200 nits(High Brightness), 600 nits(Typical Brightness), PWM Dimming, 5000000:1 Contrast Ratio
# 1112                                                                                       1.5K, 1260 x  2800 pixels, 20.9 (460 ppi), 10-bit 1 Billion Colours, 100% DCI-P3, 1600 nits(High Brightness), Blue Light Filters
# 1008                                                                                                                        FHD+, 1080 x  2400 pixels, 20:9 (393 ppi), 8-bit 16 Million Colours, 1000 nits(High Brightness)
# 353                                                                                                            FHD+, 1080 x  2400 pixels, 20:9 (397 ppi), 8-bit 16.7 Million Colours, 100% sRGB, 1300 nits(Peak Brightness)
# 908                                                                                       FHD+, 1080 x  2340 pixels, 19.5:9 (396 ppi), 8-bit 16 Million Colours, 100% DCI-P3, 800 nits(High Brightness), Eye Comfort Shield
# 181                                                                                                         FHD+, 1080 x  2400 pixels, 20:9 (388 ppi), 10-bit colours, 1300 nits(Peak Brightness), 8000000:1 Contrast Ratio
# 405                                                                                HD+, 720 x  1604 pixels, 20:9 (264 ppi), 8-bit 16.7 Million Colours, 100% sRGB, 1000 nits(High Brightness), 850 nits(Typical Brightness)
# 191                                                  FHD+, 1080 x  2392 pixels, 20.1:9 (388 ppi), 8-bit colours, 100% DCI-P3, 5000 nits(Peak Brightness), 1300 nits(High Brightness), PWM Dimming, 8000000:1 Contrast Ratio
# 1206                                                                                  HD+, 720 x  1600 pixels, 20:9 (260 ppi), 8-bit 16.7 Million Colours, 70% NTSC, 700 nits(High Brightness), TUV Rheinland certification
# 763                                                   FHD+, 1080 x  2400 pixels, 20:9 (395 ppi), 8-bit colours, 85% DCI-P3, 2000 nits(Peak Brightness), 600 nits(Typical Brightness), PWM Dimming, 2000000:1 Contrast Ratio
# 183                                                  1.5K, 1260 x  2800 pixels, 20:9 (452 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 3000 nits(Peak Brightness), 1400 nits(High Brightness), SGS Display Certification
# 1203                                                                                               HD+, 720 x  1600 pixels, 20:9 (260 ppi), 8-bit colours, 70% NTSC, 840 nits(Peak Brightness), TUV Rheinland certification
# Name: display_res, dtype: object

# %%
df['display_res'].str.contains('Contrast Ratio').sum()
# Out:
# np.int64(491)

# %%
df['helper'] = df['display_res'].str.extract(r'(\d+)\s*:1 Contrast Ratio')

# %%
df['helper'] = pd.to_numeric(df['helper'])

# %%
def high_contrast(text):

  if text > 1000000:
    return 1

  return 0

df['has_high_contrast'] = df['helper'].apply(high_contrast)

# %%
df['has_high_contrast'].value_counts()
# Out:
# has_high_contrast
# 0    892
# 1    376
# Name: count, dtype: int64

# %%
df.drop(columns='helper',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 79 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
#  74  aspect_ration_numeric        1185 non-null   float64
#  75  display_ppi                  1268 non-null   float64
#  76  color_depth                  1268 non-null   float64
#  77  peak_brightness              1206 non-null   float64
#  78  has_high_contrast            1268 non-null   int64
# dtypes: category(4), datetime64[ns](1), float64(10), int64(16), object(48)
# memory usage: 749.4+ KB

# %%
df['body_dimension'].sample(20)
# Out:
# 339        163.3 x 75.3 x 8.8 mm
# 535        164.2 x 76.1 x 8.1 mm
# 36          163 x 77.6 x 8.25 mm
# 1189    158.91 x 73.53 x 7.73 mm
# 186       163.4 x 76.4 x 7.89 mm
# 1233    166.14 x 77.01 x 8.39 mm
# 488        168.8 x 76.4 x 8.8 mm
# 32        149.6 x 71.5 x 8.25 mm
# 166        163.2 x 76.4 x 8.4 mm
# 534       162.4 x 75.7 x 7.99 mm
# 981        166.8 x 77.2 x 9.4 mm
# 1132       164.1 x 74.8 x 7.4 mm
# 501     171.56 x 79.49 x 7.99 mm
# 1054       165.1 x 71.9 x 6.9 mm
# 560        161.6 x 73.9 x 8.2 mm
# 450       162.8 x 77.22 x 8.3 mm
# 866          161.2 x 74.2 x 8 mm
# 296     161.46 x 73.82 x 7.99 mm
# 622        164.3 x 75.6 x 8.5 mm
# 475        157.9 x 74.7 x 7.3 mm
# Name: body_dimension, dtype: object

# %%
df['height_mm'] = df['body_dimension'].str.split('x').str.get(0)

# %%
df['height_mm'] = pd.to_numeric(df['height_mm'],errors='coerce')

# %%
df['height_mm'].describe()
# Out:
# count    1268.000000
# mean      162.904101
# std         4.250095
# min       146.000000
# 25%       161.500000
# 50%       163.515000
# 75%       164.900000
# max       173.000000
# Name: height_mm, dtype: float64

# %%
df['height_mm'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['width_mm'] = df['body_dimension'].str.split('x').str.get(1)

# %%
df['width_mm'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['width_mm'] = pd.to_numeric(df['width_mm'],errors='coerce')

# %%
df['width_mm'].describe()
# Out:
# count    1268.000000
# mean       76.406814
# std         7.279013
# min        70.500000
# 25%        74.700000
# 50%        75.880000
# 75%        76.720000
# max       150.400000
# Name: width_mm, dtype: float64

# %%
df['thickness_mm'] = df['body_dimension'].str.split('x').str.get(2).str.strip().str.split(' ').str.get(0)

# %%
df['thickness_mm'].sample(20)
# Out:
# 743      7.9
# 917      8.3
# 941      8.8
# 442      8.3
# 379     7.99
# 204     8.25
# 725     7.69
# 741      7.5
# 1058     6.5
# 856      8.9
# 306      8.3
# 393      7.7
# 581     7.79
# 1034     8.6
# 56      10.3
# 234        8
# 984      9.3
# 1261    7.75
# 103      8.9
# 93       8.1
# Name: thickness_mm, dtype: object

# %%
df['thickness_mm'] = pd.to_numeric(df['thickness_mm'],errors='coerce')

# %%
df['thickness_mm'].describe()
# Out:
# count    1268.000000
# mean        8.256838
# std         3.548106
# min         4.200000
# 25%         7.800000
# 50%         8.090000
# 75%         8.400000
# max        80.000000
# Name: thickness_mm, dtype: float64

# %%
df[df['thickness_mm'] > 20]
# Out:
#      model_id                      model  expert_rating  rating  rating_count  \
# 525       526  Poco M6 Pro (6GB + 128GB)             55     4.2     1421000.0
# 526       527  Poco M6 Pro (8GB + 256GB)             55     4.2      261000.0
# 527       528                Poco M6 Pro             55     4.3      871000.0
#
#      launch_on  old_price  price  launch_price  \
# 525 2023-08-09     9999.0  11999         10999
# 526 2023-08-09        NaN  14999         10999
# 527 2023-08-09     8999.0  10900         10999
#
#                         display_type            display_size  \
# 525  AMOLED, 90 Hz Refresh Rate, SDR  6.79 inches, 109.5 cm²
# 526  AMOLED, 90 Hz Refresh Rate, SDR  6.79 inches, 109.5 cm²
# 527  AMOLED, 90 Hz Refresh Rate, SDR  6.79 inches, 107.4 cm²
#
#                                                                                                                                                                                                              display_res  \
# 525  FHD+, 1080 x  2460 pixels, 20:9 (396 ppi), 12-bit 1.07 Billion Colours, 1300 nits(Peak Brightness), 550 nits(High Brightness), 1000 nits(Typical Brightness), TUV Rheinland certification, 5000000:1 Contrast Ratio
# 526  FHD+, 1080 x  2460 pixels, 20:9 (396 ppi), 12-bit 1.07 Billion Colours, 1300 nits(Peak Brightness), 550 nits(High Brightness), 1000 nits(Typical Brightness), TUV Rheinland certification, 5000000:1 Contrast Ratio
# 527                             FHD+, 1080 x  2400 pixels, 20:9 (396 ppi), 12-bit 1.07 Billion Colours, 1300 nits(Peak Brightness), 1000 nits(Typical Brightness), TUV Rheinland certification, 5000000:1 Contrast Ratio
#
#        body_dimension     weight body_front body_back      body_side  \
# 525  169 x 76 x 80 mm  199 grams      Glass     Glass  Plastic Frame
# 526  169 x 76 x 80 mm  199 grams      Glass     Glass  Plastic Frame
# 527  169 x 76 x 80 mm  199 grams      Glass     Glass  Plastic Frame
#
#                build_quality                                 ports  \
# 525  Corning Gorilla Glass 3  USB Type-C 2.0, 3.5mm Headphone Jack
# 526  Corning Gorilla Glass 3  USB Type-C 2.0, 3.5mm Headphone Jack
# 527  Corning Gorilla Glass 3  USB Type-C 2.0, 3.5mm Headphone Jack
#
#                             ip_rating       speaker  \
# 525  IP53 (Dust and Splash Resistant)  Mono Speaker
# 526  IP53 (Dust and Splash Resistant)  Mono Speaker
# 527  IP53 (Dust and Splash Resistant)  Mono Speaker
#
#                                                      chipset  \
# 525  Qualcomm Snapdragon 4 Gen 2 (4 nm), 437000 Antutu Score
# 526  Qualcomm Snapdragon 4 Gen 2 (4 nm), 437000 Antutu Score
# 527  Qualcomm Snapdragon 4 Gen 2 (4 nm), 437000 Antutu Score
#
#                                                   cpu         gpu  \
# 525  Octa-core (2x2.2 GHz Cortex-A78 & 6x Cortex-A55)  Adreno 613
# 526  Octa-core (2x2.2 GHz Cortex-A78 & 6x Cortex-A55)  Adreno 613
# 527  Octa-core (2x2.2 GHz Cortex-A78 & 6x Cortex-A55)  Adreno 613
#
#                                          main_cam                  main_cam2  \
# 525  50 MP, f/1.8, 0mm (Wide-angle), 0.8 µm, PDAF  2 MP, f/2.4, 0mm  (Depth)
# 526  50 MP, f/1.8, 0mm (Wide-angle), 0.8 µm, PDAF  2 MP, f/2.4, 0mm  (Depth)
# 527      50 MP, f/1.8, (Wide-angle), 0.8 µm, PDAF  2 MP, f/2.4, 0mm  (Depth)
#
#     main_cam3  \
# 525       NaN
# 526       NaN
# 527       NaN
#
#                                                                        main_cam_features  \
# 525  Film Camera Mode, HDR, LED Flash, Night Mode, Portrait Mode, Slow Motion, Timelapse
# 526  Film Camera Mode, HDR, LED Flash, Night Mode, Portrait Mode, Slow Motion, Timelapse
# 527  Film Camera Mode, HDR, LED Flash, Night Mode, Portrait Mode, Slow Motion, Timelapse
#
#                                   main_video                     os  \
# 525  1080p@30/60fps, 720p@30fps, Slow Motion  Android 13, Poco MIUI
# 526  1080p@30/60fps, 720p@30fps, Slow Motion  Android 13, Poco MIUI
# 527  1080p@30/60fps, 720p@30fps, Slow Motion  Android 13, Poco MIUI
#
#                                                     software_updates  \
# 525  2 year(s) of Software updates and 3 year(s) of Security updates
# 526  2 year(s) of Software updates and 3 year(s) of Security updates
# 527  2 year(s) of Software updates and 3 year(s) of Security updates
#
#     ai_features                    front_cam  \
# 525   AI Camera  16 MP, f/2.45, 0mm, 1.12 µm
# 526   AI Camera  16 MP, f/2.45, 0mm, 1.12 µm
# 527   AI Camera       16 MP, f/2.45, 1.12 µm
#
#                               front_cam_features              front_video  \
# 525                             Face Unlock, HDR  1080p@30fps, Time Lapse
# 526                             Face Unlock, HDR  1080p@30fps, Time Lapse
# 527  Face Unlock, HDR, Night Mode, Portrait Mode  1080p@30fps, Time Lapse
#
#                                        battery       charging         storage  \
# 525  5000 mAh, Lithium Polymer (Non-removable)  22.5W (wired)  128GB, UFS 2.2
# 526  5000 mAh, Lithium Polymer (Non-removable)  22.5W (wired)  256GB, UFS 2.2
# 527  5000 mAh, Lithium Polymer (Non-removable)    18W (wired)  128GB, UFS 2.2
#
#               ram                                        sim            tech  \
# 525  6GB, LPDDR4X  Hybrid Dual SIM (nano-SIM, dual stand-by)  GSM, HSPA, LTE
# 526  8GB, LPDDR4X  Hybrid Dual SIM (nano-SIM, dual stand-by)  GSM, HSPA, LTE
# 527  4GB, LPDDR4X  Hybrid Dual SIM (nano-SIM, dual stand-by)  GSM, HSPA, LTE
#
#                        2g                              3g  \
# 525  2, 3, 5, 8 (4 bands)  1, 2, 4, 5, 6, 8, 19 (7 bands)
# 526  2, 3, 5, 8 (4 bands)  1, 2, 4, 5, 6, 8, 19 (7 bands)
# 527  2, 3, 5, 8 (4 bands)  1, 2, 4, 5, 6, 8, 19 (7 bands)
#
#                                                                                   4g  \
# 525  1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 26, 28, 38, 40, 41, 66, (19 bands)
# 526  1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 26, 28, 38, 40, 41, 66, (19 bands)
# 527  1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 26, 28, 38, 40, 41, 66, (19 bands)
#
#                                            5g           speed  \
# 525  1, 3, 5, 8, 28, 40, 78, SA/NSA (8 bands)  GSM, HSPA, LTE
# 526  1, 3, 5, 8, 28, 40, 78, SA/NSA (8 bands)  GSM, HSPA, LTE
# 527                                       NaN  GSM, HSPA, LTE
#
#                                               wifi               bluetooth  \
# 525  Wi-Fi 5 802.11 a/b/g/n/ac, Hotspot, Dual Band  Unknown, A2DP, LE, SBC
# 526  Wi-Fi 5 802.11 a/b/g/n/ac, Hotspot, Dual Band  Unknown, A2DP, LE, SBC
# 527  Wi-Fi 5 802.11 a/b/g/n/ac, Hotspot, Dual Band  Unknown, A2DP, LE, SBC
#
#     positioning_system  nfc  finger_print  \
# 525       GLONASS, GPS  NaN  Side Mounted
# 526       GLONASS, GPS  NaN  Side Mounted
# 527       GLONASS, GPS  NaN  Side Mounted
#
#                                                  sensors add_features  \
# 525  Accelerometer, Compass, Gyroscope, Proximity Sensor          NaN
# 526  Accelerometer, Compass, Gyroscope, Proximity Sensor          NaN
# 527  Accelerometer, Compass, Gyroscope, Proximity Sensor          NaN
#
#     main_cam4 front_cam2 brand  is_available  is_flipkart_available  \
# 525       NaN        NaN  poco             1                      1
# 526       NaN        NaN  poco             0                      1
# 527       NaN        NaN  poco             1                      1
#
#      is_amazon_available  is_official_available display_panel_type  \
# 525                    1                      0             amoled
# 526                    0                      0             amoled
# 527                    1                      0             amoled
#
#     display_panel_family  display_hz display_dynamic_range  \
# 525               amoled          90                   SDR
# 526               amoled          90                   SDR
# 527               amoled          90                   SDR
#
#      touch_sampling_rate  has_ltpo  has_anti_reflection_coating  \
# 525                  NaN         0                            0
# 526                  NaN         0                            0
# 527                  NaN         0                            0
#
#      display_inches  display_body_ratio  has_curved  has_foldable  \
# 525            6.79                 NaN           0             0
# 526            6.79                 NaN           0             0
# 527            6.79                 NaN           0             0
#
#     res_category  res_width  res_height  aspect_ration_numeric  display_ppi  \
# 525         FHD+       1080        2460               2.222222        396.0
# 526         FHD+       1080        2460               2.222222        396.0
# 527         FHD+       1080        2400               2.222222        396.0
#
#      color_depth  peak_brightness  has_high_contrast  height_mm  width_mm  \
# 525         12.0           1300.0                  1      169.0      76.0
# 526         12.0           1300.0                  1      169.0      76.0
# 527         12.0           1300.0                  1      169.0      76.0
#
#      thickness_mm
# 525          80.0
# 526          80.0
# 527          80.0

# %%
df.loc[[525,526,527],'thickness_mm'] = 8

# %%
df['thickness_mm'].describe()
# Out:
# count    1268.000000
# mean        8.086491
# std         0.610675
# min         4.200000
# 25%         7.800000
# 50%         8.090000
# 75%         8.400000
# max        10.300000
# Name: thickness_mm, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 82 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
#  74  aspect_ration_numeric        1185 non-null   float64
#  75  display_ppi                  1268 non-null   float64
#  76  color_depth                  1268 non-null   float64
#  77  peak_brightness              1206 non-null   float64
#  78  has_high_contrast            1268 non-null   int64
#  79  height_mm                    1268 non-null   float64
#  80  width_mm                     1268 non-null   float64
#  81  thickness_mm                 1268 non-null   float64
# dtypes: category(4), datetime64[ns](1), float64(13), int64(16), object(48)
# memory usage: 779.1+ KB

# %%
df['weight'].sample(20)
# Out:
# 1230      188 grams
# 236     188.8 grams
# 990       192 grams
# 534       190 grams
# 1092      188 grams
# 1116    183.5 grams
# 894       194 grams
# 484       192 grams
# 189       202 grams
# 500       211 grams
# 739       182 grams
# 1134      180 grams
# 372       186 grams
# 888       192 grams
# 355       190 grams
# 395       187 grams
# 311       190 grams
# 162       200 grams
# 381       245 grams
# 940       188 grams
# Name: weight, dtype: object

# %%
df['weight_g'] = df['weight'].str.strip().str.split(' ').str.get(0)

# %%
df['weight_g'] = pd.to_numeric(df['weight_g'],errors='coerce')

# %%
df['weight_g'].describe()
# Out:
# count    1268.000000
# mean      193.758975
# std        14.563168
# min       155.000000
# 25%       185.000000
# 50%       191.000000
# 75%       200.000000
# max       284.000000
# Name: weight_g, dtype: float64

# %%
df['body_front'].sample(20)
# Out:
# 1096                      Glass
# 746                       Glass
# 428      Gorilla Glass Victus 2
# 53             Ceramic Shield 2
# 806               Gorilla Glass
# 1208                      Glass
# 1261     Gorilla Glass Victus 2
# 194             Gorilla Glass 3
# 392                 Panda Glass
# 158                       Glass
# 605             Gorilla Glass 7
# 973                       Glass
# 121                       Glass
# 549      Gorilla Glass Victus 2
# 1265        Xiaomi Shield Glass
# 560                       Glass
# 785             Gorilla Glass 3
# 114                       Glass
# 477     Corning Gorilla Glass 3
# 911                       Glass
# Name: body_front, dtype: object

# %%
df['body_front'].value_counts()
# Out:
# body_front
# Glass                              719
# Gorilla Glass 5                     89
# Gorilla Glass 7i                    61
# Gorilla Glass Victus 2              50
# Gorilla Glass Victus                46
# Gorilla Glass 3                     44
# Panda Glass                         35
# Gorilla Glass                       32
# Gorilla Glass Victus+               22
# Corning Gorilla Glass 5             17
# Corning Gorilla Glass 3             16
# Armorshell Glass                    16
# Ceramic Shield Glass                15
# Ultra Thin Glass                    13
# Shield Glass                        13
# Ceramic Shield 2                    12
# Dragontrail Glass                    8
# AGC Glass                            8
# UTG foldable Glass                   8
# Schott Xensation Glass               7
# Gorilla Glass 7                      7
# Asahi Glass AGC DT-Star2 Glass       6
# Armour Glass                         5
# Gorilla Glass Armour 2.0             4
# Ceramic Guard Glass                  3
# Foldable Glass                       3
# Flexible UTG (ultra thin glass)      2
# Corning Gorilla Glass Ceramic 2      2
# NanoCrystal Shield                   1
# Foldable Ultra Thin Glass            1
# Plastic                              1
# Xiaomi Shield Glass 2.0              1
# Xiaomi Shield Glass                  1
# Name: count, dtype: int64

# %%
def clean_body_front(text):

  t = text.lower()

  if t == 'glass':
    return 'standard glass'

  if 'gorilla glass' in t:

    if 'victus 2' in t:
      return 'gorilla glass victus 2'
    if 'victus+' in t:
      return 'gorilla glass victus+'
    if 'victus' in t:
      return 'gorilla glass victus'
    if '5' in t:
      return 'gorilla glass 5'
    if '3' in t:
      return 'gorilla glass 3'
    if '7i' in t:
      return 'gorilla glass 7i'
    return 'gorilla glass'

  if 'ceramic shield' in t or 'ceramic gaurd' in t:
    return 'ceramic shield'

  if 'utg' in t or 'ultra thin glass' in t or 'foldable glass' in t:
    return 'foldable utg'

  if 'panda' in t:
    return 'panda glass'

  if 'dragontrail' in t:
    return 'dragontrail glass'

  if 'schott' in t:
    return 'schott xensation'

  if 'armorshell' in t:
    return 'armonshell glass'

  return 'other branded glass'

df['front_potection'] = df['body_front'].apply(clean_body_front)

# %%
df['front_potection'].value_counts()
# Out:
# front_potection
# standard glass            719
# gorilla glass 5           106
# gorilla glass 7i           61
# gorilla glass 3            60
# gorilla glass victus 2     50
# gorilla glass victus       46
# gorilla glass              45
# other branded glass        39
# panda glass                35
# foldable utg               27
# ceramic shield             27
# gorilla glass victus+      22
# armonshell glass           16
# dragontrail glass           8
# schott xensation            7
# Name: count, dtype: int64

# %%
df['front_potection'] = df['front_potection'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 84 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
#  74  aspect_ration_numeric        1185 non-null   float64
#  75  display_ppi                  1268 non-null   float64
#  76  color_depth                  1268 non-null   float64
#  77  peak_brightness              1206 non-null   float64
#  78  has_high_contrast            1268 non-null   int64
#  79  height_mm                    1268 non-null   float64
#  80  width_mm                     1268 non-null   float64
#  81  thickness_mm                 1268 non-null   float64
#  82  weight_g                     1268 non-null   float64
#  83  front_potection              1268 non-null   category
# dtypes: category(5), datetime64[ns](1), float64(14), int64(16), object(48)
# memory usage: 790.9+ KB

# %%
df['body_back'].value_counts(dropna=False)
# Out:
# body_back
# Plastic                            642
# Glass                              313
# Vegan Leather                       65
# Gorilla Glass Victus 2              31
# Polycarbonate                       31
# NaN                                 30
# Eco Leather                         22
# Textured Matt Glass                 17
# Gorilla Glass Victus+               15
# Gorilla Glass 5                     11
# AG Glass                            11
# Ceramic Shield                      10
# Colour-infused Glass                 8
# Gorrila Glass 7i                     6
# Panda Glass                          5
# Leather                              4
# Plastic or Eco Leather               4
# Aluminium                            3
# Silicon Vegan                        3
# Gorilla Glass                        3
# Gorilla Glass Victus 3               3
# Corning Gorilla Glass                3
# Plasitc                              2
# Colour Changing Glass                2
# Aromatic Leather                     2
# Gorilla Glass Victus                 2
# Glass or Plastic                     2
# Plastic or Leather                   2
# Transparent Plastic                  2
# Ceramic                              2
# Glass or Eco Leather                 2
# Gorilla Glass 3                      1
# Wood                                 1
# Silicon Polymer                      1
# Eco Leather or Plastic               1
# Plastic or Vegan Leather             1
# Vegan Leather and Glass              1
# Glass or Leather Back                1
# Armor Glass                          1
# Dual Tone Glass and Eco Leather      1
# Panda X Glass                        1
# Name: count, dtype: int64

# %%
def clean_body_back(text):

  if pd.isna(text): return "unknown"
  t = str(text).lower().strip()

  if any(x in t for x in ['plastic', 'polycarbonate', 'plasitc']):
    if 'leather' in t:
      return 'hybrid (plastic/leather)'
    return 'plastic'

  if any(x in t for x in ['leather', 'vegan', 'eco', 'polymer']):
    if 'glass' in t:
      return 'hybrid (glass/leather)'
    return 'leather/vegan leather'

  if 'gorilla glass' in text or 'gorrila glass' in text or 'corning' in text:
    if 'victus 2' in text:
      return 'gorilla glass victus 2'
    if 'victus' in text:
      return 'gorilla glass victus'
    if '5' in text:
      return 'gorilla glass 5'
    return 'gorilla glass others'

  if 'ceramic shield' in t:
    return 'ceramic shield'

  if 'panda' in t:
    return 'panda glass'

  if 'aluminium' in t:
     return 'Metal'
  if 'ceramic' in t:
    return 'Ceramic'
  if 'wood' in t:
    return 'Wood'

  if t == 'glass':
    return 'glass'

  return 'Other'

df['back_material'] = df['body_back'].apply(clean_body_back)

# %%
df['back_material'].value_counts()
# Out:
# back_material
# plastic                     679
# glass                       313
# Other                       114
# leather/vegan leather        97
# unknown                      30
# ceramic shield               10
# hybrid (plastic/leather)      8
# panda glass                   6
# hybrid (glass/leather)        5
# Metal                         3
# Ceramic                       2
# Wood                          1
# Name: count, dtype: int64

# %%
df['back_material'] = df['back_material'].astype('category')

# %%
df['body_side'].value_counts(dropna=False)
# Out:
# body_side
# Plastic Frame                                            940
# Aluminium Frame                                          218
# Metal Frame                                               25
# Titanium Frame                                            23
# NaN                                                       17
# Aluminium Frame, Stainless Steel Hinge                    12
# Armor Aluminium                                            9
# Stainless Steel Frame                                      8
# Aluminium Frame, Aluminum Alloy Hinge                      6
# Aluminium Frame, strength Steel Hinge                      2
# Aluminium Frame, Titanium Alloy Hinge                      2
# Stainless Steel Frame, Stainless Steel Hinge               1
# Aluminium Frame, Aluminium                                 1
# Aluminium Frame, (7000 series), Stainless Steel Hinge      1
# Aluminium Frame, Titanium Alloy                            1
# Aluminium Frame, Carbon Fiber Hinge                        1
# Aluminium Frame, Carbon Fiber Dual Hinge Plates            1
# Name: count, dtype: int64

# %%
def clean_body_side(text):

  if pd.isna(text):
    return 'unknown'

  t = text.lower()

  if 'plastic' in t:
    return 'plastic frame'

  if 'titanium' in t:
    return 'titanium frame'

  if 'stainless steel' in t:
    return 'stainless steel frame'

  if any(x in t for x in ['aluminium', 'aluminum', 'metal', 'armor']):
    if 'hinge' in t:
      return 'aluminium frame (faldable hinge)'
    return 'aluminium/metal frame'

  return 'other'

df['frame_material'] = df['body_side'].apply(clean_body_side)

# %%
df['frame_material'].value_counts()
# Out:
# frame_material
# plastic frame                       940
# aluminium/metal frame               253
# titanium frame                       26
# stainless steel frame                22
# unknown                              17
# aluminium frame (faldable hinge)     10
# Name: count, dtype: int64

# %%
df['frame_material'] = df['frame_material'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 86 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
#  74  aspect_ration_numeric        1185 non-null   float64
#  75  display_ppi                  1268 non-null   float64
#  76  color_depth                  1268 non-null   float64
#  77  peak_brightness              1206 non-null   float64
#  78  has_high_contrast            1268 non-null   int64
#  79  height_mm                    1268 non-null   float64
#  80  width_mm                     1268 non-null   float64
#  81  thickness_mm                 1268 non-null   float64
#  82  weight_g                     1268 non-null   float64
#  83  front_potection              1268 non-null   category
#  84  back_material                1268 non-null   category
#  85  frame_material               1268 non-null   category
# dtypes: category(7), datetime64[ns](1), float64(14), int64(16), object(48)
# memory usage: 794.0+ KB

# %%
df['build_quality'].value_counts(dropna=False).head(20)
# Out:
# build_quality
# NaN                               529
# Plastic Material                  222
# Corning Gorilla Glass 5            62
# Corning Gorilla Glass 7i           33
# Corning Gorilla Glass 3            28
# Corning Gorilla Glass Victus 2     26
# Corning Gorilla Glass Victus+      26
# Ceramic Shield Glass               25
# MIL-STD-810H                       25
# MIL-STD-810H compliant*            19
# Panda glass                        17
# Corning Gorilla Glass              14
# Corning Gorilla Glass victus 2     14
# Schott Xensation Alpha             14
# Corning Gorilla Glass Victus       14
# Schott Xensation                   13
# SGS 5-Star Drop Resistance         13
# Ceramic Shield 2                   12
# Gorilla Glass 5                    10
# Gorilla Glass Victus 2             10
# Name: count, dtype: int64

# %%
def extract_durability(text):
    if pd.isna(text):
      return "Standard"
    text = str(text).lower()

    if 'mil-std' in text:
        return 'Military Grade (MIL-STD)'
    if 'sgs' in text or 'drop resistance' in text:
        return 'SGS Certified Drop Resistance'

    return "Standard/Branded Glass"

df['durability_cert'] = df['build_quality'].apply(extract_durability).astype('category')

# %%
df['durability_cert'].value_counts(dropna=False)
# Out:
# durability_cert
# Standard/Branded Glass           669
# Standard                         529
# Military Grade (MIL-STD)          57
# SGS Certified Drop Resistance     13
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 87 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
#  74  aspect_ration_numeric        1185 non-null   float64
#  75  display_ppi                  1268 non-null   float64
#  76  color_depth                  1268 non-null   float64
#  77  peak_brightness              1206 non-null   float64
#  78  has_high_contrast            1268 non-null   int64
#  79  height_mm                    1268 non-null   float64
#  80  width_mm                     1268 non-null   float64
#  81  thickness_mm                 1268 non-null   float64
#  82  weight_g                     1268 non-null   float64
#  83  front_potection              1268 non-null   category
#  84  back_material                1268 non-null   category
#  85  frame_material               1268 non-null   category
#  86  durability_cert              1268 non-null   category
# dtypes: category(8), datetime64[ns](1), float64(14), int64(16), object(48)
# memory usage: 795.4+ KB

# %%
df['ports'].sample(20)
# Out:
# 218     USB Type-C, 3.5mm Headphone Jack, OTG
# 820        microUSB 2.0, 3.5mm Headphone Jack
# 1099                      USB Type-C 2.0, OTG
# 987                       USB Type-C 2.0, OTG
# 464                       USB Type-C 2.0, OTG
# 301      USB Type-C 2.0, 3.5mm Headphone Jack
# 776                                USB Type-C
# 894      USB Type-C 2.0, 3.5mm Headphone Jack
# 1177                USB Type-C 3.1 Gen 1, OTG
# 789      USB Type-C 2.0, 3.5mm Headphone Jack
# 27               USB Type-C 2.0, Display Port
# 1143                          USB Type-C, OTG
# 1156                          USB Type-C, OTG
# 326                       USB Type-C 2.0, OTG
# 1130                      USB Type-C 2.0, OTG
# 352       USB Type-C 2.0, USB Type-C (bottom)
# 676        USB Type-C 2.0, Infrared Port, OTG
# 179           USB Type-C 2.0, IR Blaster, OTG
# 1241                      USB Type-C 2.0, OTG
# 939                       USB Type-C 2.0, OTG
# Name: ports, dtype: object

# %%
df['ports'].str.contains('3.5mm').sum()
# Out:
# np.int64(535)

# %%
def has_audio_jack(text):

  t = text.lower()

  if '3.5mm' in t:
    return 1

  return 0

df['has_3_5mm_jack'] = df['ports'].apply(has_audio_jack)

# %%
df['has_3_5mm_jack'].value_counts()
# Out:
# has_3_5mm_jack
# 0    733
# 1    535
# Name: count, dtype: int64

# %%
def extract_usb_type(text):

  if pd.isna(text):
    return 'unknown'

  t = text.lower()

  if 'type-c' in t:
    return 'type-c'

  if 'micro' in t:
    return 'microUSB'

  if 'lightning' in t:
    return 'lightning'

  return 'unknown'

df['usb_type'] = df['ports'].apply(extract_usb_type).astype('category')

# %%
df['usb_type'].value_counts()
# Out:
# usb_type
# type-c       1220
# microUSB       34
# lightning      14
# Name: count, dtype: int64

# %%
df['ports'].sample(20)
# Out:
# 1072                          USB Type-C 2.0, OTG
# 1087                          USB Type-C 2.0, OTG
# 1140                          USB Type-C 2.0, OTG
# 1234                          USB Type-C 2.0, OTG
# 836         USB Type-C, 3.5mm Headphone Jack, OTG
# 506                USB Type-C, Infrared Port, OTG
# 717         USB Type-C, 3.5mm Headphone Jack, OTG
# 51                   USB Type-C 2.0, Display Port
# 635       microUSB 2.0, 3.5mm Headphone Jack, OTG
# 859     USB Type-C 2.0, 3.5mm Headphone Jack, OTG
# 970          USB Type-C 2.0, 3.5mm Headphone Jack
# 475                           USB Type-C 2.0, OTG
# 704     USB Type-C 2.0, 3.5mm Headphone Jack, OTG
# 7                               Lightning USB 2.0
# 499              USB Type-C, 3.5mm Headphone Jack
# 43                   USB Type-C 3.2, Display Port
# 349                     USB Type-C 3.2 Gen 1, OTG
# 810          USB Type-C 2.0, 3.5mm Headphone Jack
# 729         USB Type-C, 3.5mm Headphone Jack, OTG
# 551                USB Type-C, Infrared Port, OTG
# Name: ports, dtype: object

# %%
def extract_usb_version(text):

  t = text.lower()

  if '3.2' in t:
    return 3.2

  if '3.1' in t:
    return 3.1

  return 2.0

df['usb_version'] = df['ports'].apply(extract_usb_version)

# %%
df['usb_version'].value_counts()
# Out:
# usb_version
# 2.0    1130
# 3.2     108
# 3.1      30
# Name: count, dtype: int64

# %%
df['ports'].str.contains('OTG').sum()
# Out:
# np.int64(807)

# %%
def has_otg(text):

  t = text.lower()

  if 'otg' in t:
    return 1

  return 0

df['has_otg'] = df['ports'].apply(has_otg)

# %%
df['has_otg'].value_counts()
# Out:
# has_otg
# 1    807
# 0    461
# Name: count, dtype: int64

# %%
df['ports'].sample(20)
# Out:
# 486                 microUSB 2.0, 3.5mm Headphone Jack, OTG
# 515               OTG, USB Type-C 2.0, 3.5mm Headphone Jack
# 608                                          USB Type-C 2.0
# 422     USB Type-C, Infrared Port, OTG, USB Type-C (bottom)
# 50                             USB Type-C 2.0, Display Port
# 773                                     USB Type-C 2.0, OTG
# 720                        USB Type-C, 3.5mm Headphone Jack
# 547                           USB Type-C 2.0, Infrared Port
# 335                           USB Type-C 2.0, Infrared Port
# 1176                              USB Type-C 3.1 Gen 1, OTG
# 678                                USB Type-C, Hi-Res Audio
# 1002                                    USB Type-C 2.0, OTG
# 972                    USB Type-C 2.0, 3.5mm Headphone Jack
# 451                                     USB Type-C 2.0, OTG
# 419                                     USB Type-C 2.0, OTG
# 246               USB Type-C 2.0, 3.5mm Headphone Jack, OTG
# 318                         USB Type-C, USB Type-C (bottom)
# 1040                                             USB Type-C
# 722                        USB Type-C, 3.5mm Headphone Jack
# 285                                     USB Type-C 2.0, OTG
# Name: ports, dtype: object

# %%
df['ports'].str.contains(r'Infrared Port|Infrared Port|IR Blaster').sum()
# Out:
# np.int64(142)

# %%
def has_ir_blaster(text):

  t = text.lower()

  if 'infrared port' in t:
    return 1

  if 'ir blaster' in t:
    return 1

  return 0

df['has_ir_blaster'] = df['ports'].apply(has_ir_blaster)

# %%
df['has_ir_blaster'].value_counts()
# Out:
# has_ir_blaster
# 0    1124
# 1     144
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 92 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
#  74  aspect_ration_numeric        1185 non-null   float64
#  75  display_ppi                  1268 non-null   float64
#  76  color_depth                  1268 non-null   float64
#  77  peak_brightness              1206 non-null   float64
#  78  has_high_contrast            1268 non-null   int64
#  79  height_mm                    1268 non-null   float64
#  80  width_mm                     1268 non-null   float64
#  81  thickness_mm                 1268 non-null   float64
#  82  weight_g                     1268 non-null   float64
#  83  front_potection              1268 non-null   category
#  84  back_material                1268 non-null   category
#  85  frame_material               1268 non-null   category
#  86  durability_cert              1268 non-null   category
#  87  has_3_5mm_jack               1268 non-null   int64
#  88  usb_type                     1268 non-null   category
#  89  usb_version                  1268 non-null   float64
#  90  has_otg                      1268 non-null   int64
#  91  has_ir_blaster               1268 non-null   int64
# dtypes: category(9), datetime64[ns](1), float64(15), int64(19), object(48)
# memory usage: 836.4+ KB

# %%
df['ip_rating'].sample(20)
# Out:
# 375          IP54 (Dust and Water Resistant)
# 256         IP52 (Dust and Splash Resistant)
# 284     IP68/IP69 (Dust and Water Resistant)
# 287          IP68 (Dust and Water Resistant)
# 92           IP65 (Dust and Water Resistant)
# 1050                 IPX8 (Water Resistance)
# 1047      IP68/69 (Dust and Water Resistant)
# 1236         IP64 (Dust and Water Resistant)
# 694                                      NaN
# 1093         IP64 (Dust and Water Resistant)
# 741                                      NaN
# 1218         IP54 (Dust and Water Resistant)
# 118                                      NaN
# 446          IP54 (Dust and Water Resistant)
# 568          IP54 (Dust and Water Resistant)
# 415              IPX4/X5 (Splash Resistance)
# 277          IP68 (Dust and Water Resistant)
# 436                                      NaN
# 1067                 IPX8 (Water Resistance)
# 570          IP54 (Dust and Water Resistant)
# Name: ip_rating, dtype: object

# %%
def water_resistance_level(text):

  if pd.isna(text):
    return 'level 0'

  t = text.lower()

  if any(x in t for x in ['ip67', 'ip68', 'ip69', 'ipx8', 'ipx9', 'ip66/68/69', 'ipx6/x8/x9']):
        return 'level 3'

  if any(x in t for x in ['ip53', 'ip54', 'ip64', 'ip65', 'water resistant']):
        return 'level 2'

  if any(x in t for x in ['water repellent', 'ip48', 'ip52', 'ipx4', 'splash resistant', 'dust and water resistant']):
        return 'level 1'

df['water_resistance_level'] = df['ip_rating'].apply(water_resistance_level).astype('category')

# %%
df['water_resistance_level'].value_counts(dropna=False)
# Out:
# water_resistance_level
# level 2    462
# level 0    353
# level 3    344
# level 1    109
# Name: count, dtype: int64

# %%
df['water_resistance_level'].count()
# Out:
# np.int64(1268)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 93 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
#  74  aspect_ration_numeric        1185 non-null   float64
#  75  display_ppi                  1268 non-null   float64
#  76  color_depth                  1268 non-null   float64
#  77  peak_brightness              1206 non-null   float64
#  78  has_high_contrast            1268 non-null   int64
#  79  height_mm                    1268 non-null   float64
#  80  width_mm                     1268 non-null   float64
#  81  thickness_mm                 1268 non-null   float64
#  82  weight_g                     1268 non-null   float64
#  83  front_potection              1268 non-null   category
#  84  back_material                1268 non-null   category
#  85  frame_material               1268 non-null   category
#  86  durability_cert              1268 non-null   category
#  87  has_3_5mm_jack               1268 non-null   int64
#  88  usb_type                     1268 non-null   category
#  89  usb_version                  1268 non-null   float64
#  90  has_otg                      1268 non-null   int64
#  91  has_ir_blaster               1268 non-null   int64
#  92  water_resistance_level       1268 non-null   category
# dtypes: category(10), datetime64[ns](1), float64(15), int64(19), object(48)
# memory usage: 837.8+ KB

# %%
df['speaker'].sample(30)
# Out:
# 245                            Stereo Speakers
# 607                                Loudspeaker
# 463                            Stereo Speakers
# 1172                           Stereo Speakers
# 1134                               Loudspeaker
# 1185                           Stereo Speakers
# 293     Stereo Speakers (Dolby Atmos Enhanced)
# 123                            Stereo Speakers
# 386                                Loudspeaker
# 1213                               Loudspeaker
# 415                               Mono Speaker
# 901                                Loudspeaker
# 954                               Mono Speaker
# 474                            Stereo Speakers
# 177                            Stereo Speakers
# 324                            Stereo Speakers
# 1038                           Stereo Speakers
# 1133                           Stereo Speakers
# 1124                               Loudspeaker
# 184                            Stereo Speakers
# 1259                           Stereo Speakers
# 193                            Stereo Speakers
# 438                            Stereo Speakers
# 1187                              Mono Speaker
# 1145                              Mono Speaker
# 94                             Stereo Speakers
# 1220                              Mono Speaker
# 932                            Stereo Speakers
# 687                            Stereo Speakers
# 314                            Stereo Speakers
# Name: speaker, dtype: object

# %%
def has_stereo_speakers(text):

  if pd.isna(text):
    return 0

  t = text.lower()

  if 'stereo' in t:
    return 1

  return 0


df['has_stereo_speakers'] = df['speaker'].apply(has_stereo_speakers).astype('int')

# %%
df['has_stereo_speakers'].value_counts()
# Out:
# has_stereo_speakers
# 1    768
# 0    500
# Name: count, dtype: int64

# %%
df['speaker'].sample(20)
# Out:
# 277                                 Stereo Speakers
# 529                                    Mono Speaker
# 679                                 Stereo Speakers
# 420                                     Loudspeaker
# 1130                                    Loudspeaker
# 1174                                Stereo Speakers
# 146                      DTS Audio, Stereo Speakers
# 755                                 Stereo Speakers
# 313                                 Stereo Speakers
# 744                                    Mono Speaker
# 1155                                Stereo Speakers
# 338     24-bit/192kHz Hi-Res Audio, Stereo Speakers
# 48                                  Stereo Speakers
# 1199                                   Mono Speaker
# 1106                                   Mono Speaker
# 950                                    Mono Speaker
# 780                                 Stereo Speakers
# 469                                 Stereo Speakers
# 882                                 Stereo Speakers
# 37          Stereo Speakers (Dolby Atmos Certified)
# Name: speaker, dtype: object

# %%
def has_audio_certification(text):

  if pd.isna(text):
    return 0

  t = text.lower()

  if 'dolby' in t:
    return 1

  if 'hi-res' in t:
    return 1

  if 'dts' in t:
    return 1

  return 0

df['has_audio_certification'] = df['speaker'].apply(has_audio_certification)

# %%
df['has_audio_certification'].value_counts()
# Out:
# has_audio_certification
# 0    1142
# 1     126
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 95 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
#  74  aspect_ration_numeric        1185 non-null   float64
#  75  display_ppi                  1268 non-null   float64
#  76  color_depth                  1268 non-null   float64
#  77  peak_brightness              1206 non-null   float64
#  78  has_high_contrast            1268 non-null   int64
#  79  height_mm                    1268 non-null   float64
#  80  width_mm                     1268 non-null   float64
#  81  thickness_mm                 1268 non-null   float64
#  82  weight_g                     1268 non-null   float64
#  83  front_potection              1268 non-null   category
#  84  back_material                1268 non-null   category
#  85  frame_material               1268 non-null   category
#  86  durability_cert              1268 non-null   category
#  87  has_3_5mm_jack               1268 non-null   int64
#  88  usb_type                     1268 non-null   category
#  89  usb_version                  1268 non-null   float64
#  90  has_otg                      1268 non-null   int64
#  91  has_ir_blaster               1268 non-null   int64
#  92  water_resistance_level       1268 non-null   category
#  93  has_stereo_speakers          1268 non-null   int64
#  94  has_audio_certification      1268 non-null   int64
# dtypes: category(10), datetime64[ns](1), float64(15), int64(21), object(48)
# memory usage: 857.6+ KB

# %%
df['chipset'].sample(20)
# Out:
# 133            MediaTek Dimensity 7300 Ultimate (4 nm), 728840 Antutu Score
# 173               Qualcomm Snapdragon 8s Gen 3 (4 nm), 1489956 Antutu Score
# 372                 Qualcomm Snapdragon 7 Gen 3 (4 nm), 831378 Antutu Score
# 251                     MediaTek Dimensity 7020 (6 nm), 470535 Antutu Score
# 1093                    MediaTek Dimensity 6300 (6 nm), 452218 Antutu Score
# 985                MediaTek Dimensity 6100 Plus (6 nm), 393210 Antutu Score
# 111                                Unisoc T606 (12 nm), 246197 Antutu Score
# 176                     Qualcomm Snapdragon 870 (7 nm), 818358 Antutu Score
# 1063               Qualcomm Snapdragon 8 Gen 3 (4 nm), 2020386 Antutu Score
# 172               Qualcomm Snapdragon 8s Gen 4 (4 nm), 2426162 Antutu Score
# 1210                Qualcomm Snapdragon 4 Gen 2 (4 nm), 427408 Antutu Score
# 1022    Qualcomm Snapdragon 8 Gen 2 for Galaxy (4 nm), 1541246 Antutu Score
# 160          Qualcomm Snapdragon 8 Elite Gen 5 (3 nm), 4186917 Antutu Score
# 1069                     MediaTek Dimensity 700 (7 nm), 388228 Antutu Score
# 768                Qualcomm Snapdragon 7s Gen 3 (4 nm), 615257 Antutu Score
# 1164                                   MediaTek Dimensity 7360 Turbo (4 nm)
# 114                     MediaTek Dimensity 6300 (6 nm), 452218 Antutu Score
# 156                Qualcomm Snapdragon 8 Gen 3 (4 nm), 2020386 Antutu Score
# 235                                Unisoc T606 (12 nm), 246197 Antutu Score
# 533               MediaTek Dimensity 7025 Ultra (6 nm), 531562 Antutu Score
# Name: chipset, dtype: object

# %%
df['processor_brand'] = df['chipset'].str.strip().str.lower().str.split(' ').str.get(0).astype('category')

# %%
df['processor_brand'].value_counts(dropna=False)
# Out:
# processor_brand
# mediatek    599
# qualcomm    460
# samsung      74
# unisoc       61
# apple        54
# google       20
# Name: count, dtype: int64

# %%
df['chipset_brand'] = df['chipset'].str.strip().str.lower().str.split('(').str.get(0).str.strip()

# %%
df['chipset_brand'] = df['chipset_brand'].str.replace('apple', '', case=False).str.strip()
df['chipset_brand'] = df['chipset_brand'].str.replace('qualcomm', '', case=False).str.strip()
df['chipset_brand'] = df['chipset_brand'].str.replace('mediatek', '', case=False).str.strip()
df['chipset_brand'] = df['chipset_brand'].str.replace('samsung', '', case=False).str.strip()
df['chipset_brand'] = df['chipset_brand'].str.replace('unisoc', '', case=False).str.strip()
df['chipset_brand'] = df['chipset_brand'].str.replace('google', '', case=False).str.strip()

# %%
df['chipset_brand'] = df['chipset_brand'].str.split(',').str.get(0)

# %%
df[['processor_brand','chipset_brand']].sample(20)
# Out:
#      processor_brand                           chipset_brand
# 15             apple                              a16 bionic
# 560         mediatek                          dimensity 7050
# 774         mediatek                          dimensity 6400
# 1001         samsung                             exynos 1380
# 731         mediatek                          dimensity 7400
# 1182        mediatek                          dimensity 9000
# 784         qualcomm                          snapdragon 680
# 1131        mediatek                          dimensity 8200
# 902          samsung                             exynos 1330
# 1140        qualcomm                          snapdragon 695
# 1054        qualcomm                      snapdragon 8 gen 3
# 88          qualcomm  snapdragon 7 gen 1 accelerated edition
# 349         qualcomm                snapdragon 8 elite gen 5
# 357         mediatek                          dimensity 9000
# 911         mediatek                          dimensity 6300
# 2              apple                              a15 bionic
# 587         qualcomm                     snapdragon 7s gen 2
# 434         qualcomm                      snapdragon 7 gen 3
# 983         mediatek                     dimensity 6100 plus
# 1191        mediatek                               helio p35

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 97 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
#  74  aspect_ration_numeric        1185 non-null   float64
#  75  display_ppi                  1268 non-null   float64
#  76  color_depth                  1268 non-null   float64
#  77  peak_brightness              1206 non-null   float64
#  78  has_high_contrast            1268 non-null   int64
#  79  height_mm                    1268 non-null   float64
#  80  width_mm                     1268 non-null   float64
#  81  thickness_mm                 1268 non-null   float64
#  82  weight_g                     1268 non-null   float64
#  83  front_potection              1268 non-null   category
#  84  back_material                1268 non-null   category
#  85  frame_material               1268 non-null   category
#  86  durability_cert              1268 non-null   category
#  87  has_3_5mm_jack               1268 non-null   int64
#  88  usb_type                     1268 non-null   category
#  89  usb_version                  1268 non-null   float64
#  90  has_otg                      1268 non-null   int64
#  91  has_ir_blaster               1268 non-null   int64
#  92  water_resistance_level       1268 non-null   category
#  93  has_stereo_speakers          1268 non-null   int64
#  94  has_audio_certification      1268 non-null   int64
#  95  processor_brand              1268 non-null   category
#  96  chipset_brand                1268 non-null   object
# dtypes: category(11), datetime64[ns](1), float64(15), int64(21), object(49)
# memory usage: 869.0+ KB

# %%
df['chipset_nm'] = df['chipset'].str.split('(').str.get(1).str.split(')').str.get(0).str.split(' ').str.get(0)

# %%
df['chipset_nm'] = pd.to_numeric(df['chipset_nm'])

# %%
df['chipset_nm'].value_counts(dropna=False)
# Out:
# chipset_nm
# 4.0     494
# 6.0     390
# 12.0    167
# 3.0      83
# 5.0      73
# 7.0      34
# 8.0      11
# NaN      10
# 22.0      3
# 28.0      2
# 11.0      1
# Name: count, dtype: int64

# %%
df[df['chipset_nm'] == 11]['chipset']
# Out:
# 393    Qualcomm Snapdragon 6s Gen1 (11 nm), 440358 Antutu Score
# Name: chipset, dtype: object

# %%
df[df['chipset_nm'].isnull()]['chipset']
# Out:
# 137                  Unisoc SC9863A1, 148911 Antutu Score
# 188          MediaTek Dimensity 6300, 452218 Antutu Score
# 189          MediaTek Dimensity 6300, 452218 Antutu Score
# 376    MediaTek Dimensity 8350 Apex, 1403197 Antutu Score
# 377    MediaTek Dimensity 8350 Apex, 1403197 Antutu Score
# 378    MediaTek Dimensity 8350 Apex, 1403197 Antutu Score
# 392      Qualcomm Snapdragon 6s Gen1, 440358 Antutu Score
# 612                                              MediaTek
# 613                                              MediaTek
# 614                           MediaTek Dimensity 6400 Max
# Name: chipset, dtype: object

# %%
df['chipset_brand'].sample(20)
# Out:
# 393      snapdragon 6s gen1
# 1143     snapdragon 7 gen 3
# 704           dimensity 920
# 404          dimensity 6300
# 629           dimensity 810
# 897          dimensity 6300
# 425      snapdragon 6 gen 1
# 1149     snapdragon 7 gen 3
# 664                   t7250
# 240          snapdragon 680
# 733          dimensity 6400
# 988          dimensity 6300
# 403          dimensity 6300
# 1094         dimensity 6300
# 539         snapdragon 778g
# 662     dimensity 6100 plus
# 438          dimensity 9400
# 48                  a19 pro
# 927      snapdragon 6 gen 3
# 631          snapdragon 680
# Name: chipset_brand, dtype: object

# %%
df.loc[[612,613],'chipset_brand'] = np.nan

# %%
df.loc[[612,613]][['chipset','chipset_brand']]
# Out:
#       chipset chipset_brand
# 612  MediaTek           NaN
# 613  MediaTek           NaN

# %%
df['antutu_score'] = df['chipset'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)

# %%
df['antutu_score'] = pd.to_numeric(df['antutu_score'])

# %%
df['antutu_score'].sample(20)
# Out:
# 820      136643.0
# 99      1492537.0
# 70       910432.0
# 941      264823.0
# 779     1110000.0
# 301      441369.0
# 881      471697.0
# 863      732353.0
# 242      443228.0
# 1005     678813.0
# 282      777255.0
# 677     1409090.0
# 694      855364.0
# 997      595101.0
# 244      472470.0
# 1077     443228.0
# 578      393210.0
# 170     2426162.0
# 631      310236.0
# 410      146708.0
# Name: antutu_score, dtype: float64

# %%
df[df['antutu_score'].isnull()]['chipset']
# Out:
# 67                       Google Tensor (5 nm)
# 406            MediaTek Dimensity 6300 (6 nm)
# 407            MediaTek Dimensity 6300 (6 nm)
# 408            MediaTek Dimensity 6300 (6 nm)
# 430            MediaTek Dimensity 6300 (6 nm)
# 441            MediaTek Dimensity 9500 (3 nm)
# 443            MediaTek Dimensity 9500 (3 nm)
# 606     MediaTek Dimensity 7300 Energy (4 nm)
# 607     MediaTek Dimensity 7300 Energy (4 nm)
# 612                                  MediaTek
# 613                                  MediaTek
# 614               MediaTek Dimensity 6400 Max
# 735        MediaTek Dimensity 6400 Max (6 nm)
# 736        MediaTek Dimensity 6400 Max (6 nm)
# 765            MediaTek Dimensity 6300 (6 nm)
# 766            MediaTek Dimensity 6300 (6 nm)
# 901                 MediaTek Helio G99 (6 nm)
# 945                 MediaTek Helio G99 (6 nm)
# 976                 MediaTek Helio G99 (6 nm)
# 1163     MediaTek Dimensity 7360 Turbo (4 nm)
# 1164     MediaTek Dimensity 7360 Turbo (4 nm)
# 1165     MediaTek Dimensity 7360 Turbo (4 nm)
# 1176           MediaTek Dimensity 9500 (3 nm)
# 1177           MediaTek Dimensity 9500 (3 nm)
# 1178           MediaTek Dimensity 9500 (3 nm)
# 1179           MediaTek Dimensity 9500 (3 nm)
# 1204           MediaTek Dimensity 6300 (6 nm)
# 1205           MediaTek Dimensity 6300 (6 nm)
# 1206           MediaTek Dimensity 6300 (6 nm)
# 1233       Qualcomm Snapdragon 4 Gen 2 (4 nm)
# 1234       Qualcomm Snapdragon 4 Gen 2 (4 nm)
# Name: chipset, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 99 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  main_cam4                    48 non-null     object
#  54  front_cam2                   9 non-null      object
#  55  brand                        1268 non-null   category
#  56  is_available                 1268 non-null   int64
#  57  is_flipkart_available        1268 non-null   int64
#  58  is_amazon_available          1268 non-null   int64
#  59  is_official_available        1268 non-null   int64
#  60  display_panel_type           1268 non-null   object
#  61  display_panel_family         1268 non-null   category
#  62  display_hz                   1268 non-null   int64
#  63  display_dynamic_range        1268 non-null   category
#  64  touch_sampling_rate          852 non-null    float64
#  65  has_ltpo                     1268 non-null   int64
#  66  has_anti_reflection_coating  1268 non-null   int64
#  67  display_inches               1268 non-null   float64
#  68  display_body_ratio           1036 non-null   float64
#  69  has_curved                   1268 non-null   int64
#  70  has_foldable                 1268 non-null   int64
#  71  res_category                 1268 non-null   category
#  72  res_width                    1268 non-null   int64
#  73  res_height                   1268 non-null   int64
#  74  aspect_ration_numeric        1185 non-null   float64
#  75  display_ppi                  1268 non-null   float64
#  76  color_depth                  1268 non-null   float64
#  77  peak_brightness              1206 non-null   float64
#  78  has_high_contrast            1268 non-null   int64
#  79  height_mm                    1268 non-null   float64
#  80  width_mm                     1268 non-null   float64
#  81  thickness_mm                 1268 non-null   float64
#  82  weight_g                     1268 non-null   float64
#  83  front_potection              1268 non-null   category
#  84  back_material                1268 non-null   category
#  85  frame_material               1268 non-null   category
#  86  durability_cert              1268 non-null   category
#  87  has_3_5mm_jack               1268 non-null   int64
#  88  usb_type                     1268 non-null   category
#  89  usb_version                  1268 non-null   float64
#  90  has_otg                      1268 non-null   int64
#  91  has_ir_blaster               1268 non-null   int64
#  92  water_resistance_level       1268 non-null   category
#  93  has_stereo_speakers          1268 non-null   int64
#  94  has_audio_certification      1268 non-null   int64
#  95  processor_brand              1268 non-null   category
#  96  chipset_brand                1266 non-null   object
#  97  chipset_nm                   1258 non-null   float64
#  98  antutu_score                 1237 non-null   float64
# dtypes: category(11), datetime64[ns](1), float64(17), int64(21), object(49)
# memory usage: 888.8+ KB

# %%
df['cpu'].sample(20)
# Out:
# 579                              Octa-core (2x2.2 GHz Cortex-A76 & 6x2.0 GHz Cortex-A55)
# 442            Octa-core (1x4.21 GHz C1-Ultra & 3x3.5 GHz C1-Premium & 4x2.7 GHz C1-Pro)
# 114                              Octa-core (2x2.4 GHz Cortex-A76 & 6x2.0 GHz Cortex-A55)
# 953                              Octa-core (2x2.4 GHz Cortex-A76 & 6x2.0 GHz Cortex-A55)
# 632                              Octa-core (2x1.8 GHz Cortex-A75 & 6x1.8 GHz Cortex-A55)
# 108                              Octa-core (2x2.2 GHz Cortex-A76 & 6x2.0 GHz Cortex-A55)
# 887                                  Octa-core (2x2.2 GHz Kryo 570 & 6x1.8 GHz Kryo 570)
# 1137      Octa-core (1x3.1 GHz Cortex-A78 & 3x3.0 GHz Cortex-A78 & 4x2.0 GHz Cortex-A55)
# 360      Octa-core (1x2.8 Ghz Cortex-X4 & 4x2.6 GHz Cortex-A720 & 3x1.9 GHz Cortex-A520)
# 583                              Octa-core (4x2.5 GHz Cortex-A78 & 4x2.0 GHz Cortex-A55)
# 481                      Octa-core (2x2.2 GHz Kryo 660 Gold & 6x1.7 GHz Kryo 660 Silver)
# 297                              Octa-core (2x2.0 GHz Cortex-A75 & 6x1.8 GHz Cortex-A55)
# 952                              Octa-core (2x2.2 GHz Cortex-A76 & 6x2.0 GHz Cortex-A55)
# 285                            Octa-core (1xA715 3.35GHz + 3xA715 3.2GHz+ 4xA510 2.2Ghz)
# 1161      Octa-core (1x2.8 GHz Cortex-720 & 4x2.4 GHz Cortex-720 & 3x1.8 GHz Cortex-520)
# 593                            Octa-core (4x2.40 GHz Cortex-A78 & 4x1.95 GHz Cortex-A55)
# 217                                     Octa-core (2x2.4 GHz Cortex-A76 & 6x Cortex-A55)
# 698     Octa-core (1x2.84 GHz Cortex-X1 & 3x2.42 GHz Cortex-A78 & 4x1.80 GHz Cortex-A55)
# 913                              Octa-core (2x2.4 GHz Cortex-A78 & 6x2.0 GHz Cortex-A55)
# 800                              Octa-core (2x2.0 GHz Cortex-A75 & 6x1.8 GHz Cortex-A55)
# Name: cpu, dtype: object

# %%
df['cpu_core_count'] = df['cpu'].str.strip().str.split(' ').str.get(0)

# %%
df['cpu_core_count'].value_counts(dropna=False)
# Out:
# cpu_core_count
# Octa-core    1193
# Hexa-core      54
# Deca-core      13
# Quad-core       4
# Nona-core       4
# Name: count, dtype: int64

# %%
def extract_core_count(text):

  t = text.lower()

  if 'octa' in t:
    return 8

  if 'hexa' in t:
    return 6

  if 'deca' in t:
    return 10

  if 'quad' in t:
    return 4

  if 'nona' in t:
    return 9

df['cpu_core_count'] = df['cpu_core_count'].apply(extract_core_count)

# %%
df['cpu_core_count'].value_counts(dropna=False)
# Out:
# cpu_core_count
# 8     1193
# 6       54
# 10      13
# 4        4
# 9        4
# Name: count, dtype: int64

# %%
df['cpu_max_ghz'] = df['cpu'].str.extract(r'(\d+\.?\d*)\s*[Gg]*\s*[Gg]Hz', flags=re.IGNORECASE)

# %%
df['cpu_max_ghz'].value_counts(dropna=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/displayhook.py:275: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
# cpu_max_ghz
# 2.4     235
# 2.2     195
# 2.5     122
# 2.0      83
# 2.6      58
# 1.8      43
# 3.0      38
# 2.8      38
# 2.3      33
# 3.2      32
# 3.1      27
# 3.35     26
# 3.3      25
# 2.63     22
# 2.40     20
# 4.32     19
# 1.6      16
# 3.19     16
# 3.46     14
# 3.00     13
# 2.05     13
# 4.26     12
# 3.25     12
# 3.36     11
# 2.85     11
# 4.04      9
# 2.84      9
# 3.05      8
# 4.21      7
# NaN       7
# 3.78      7
# 4.47      7
# 4.6       6
# 3.23      6
# 4.05      6
# 3.63      6
# 2.35      6
# 2.9       6
# 3.21      6
# 3.39      5
# 3.4       5
# 2.80      4
# 2.7       4
# 2.75      4
# 3.73      4
# 3         3
# 2.99      3
# 2.30      2
# 2.91      2
# 2.1       1
# 3.20      1
# Name: count, dtype: int64

# %%
df['cpu_max_ghz'] = pd.to_numeric(df['cpu_max_ghz'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Columns: 101 entries, model_id to cpu_max_ghz
# dtypes: category(11), datetime64[ns](1), float64(18), int64(22), object(49)
# memory usage: 908.6+ KB

# %%
df['gpu_brand'] = df['gpu'].str.lower().str.strip().str.split(' ').str.get(0)

# %%
df['gpu_brand'] = df['gpu_brand'].str.replace('-',' ')

# %%
df[df['gpu_brand'] == 'unspecified']['gpu']
# Out:
# 137    Unspecified
# Name: gpu, dtype: object

# %%
df.loc[137,'gpu_brand'] = np.nan

# %%
df['gpu_brand'].value_counts(dropna=False)
# Out:
# gpu_brand
# adreno              454
# mali g57            243
# mali g68             95
# arm                  79
# mali g615            57
# apple                54
# mali g52             50
# powervr              42
# mali g610            34
# img                  29
# xclipse              22
# NaN                  19
# mali                 19
# mali g77             12
# immortalis g720      12
# mali g710            10
# immortalis g715       9
# mali g720             7
# immortalis g925       6
# immortalis g715s      6
# mali g715             5
# mali g78              2
# ge8322                2
# Name: count, dtype: int64

# %%
df['gpu_brand'] = df['gpu_brand'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Columns: 102 entries, model_id to gpu_brand
# dtypes: category(12), datetime64[ns](1), float64(18), int64(22), object(49)
# memory usage: 910.6+ KB

# %%
df['main_cam'].sample(20)
# Out:
# 1191                                              13 MP, f/2.2, 27mm (Wide-angle), Auto Focus
# 1189                                       64 MP, f/1.79, 0mm (Wide-angle), 0.7 µm, OIS, PDAF
# 710                                               108 MP, f/1.8, 26mm (Wide-angle), OIS, PDAF
# 536                                             64 MP, f/1.8, 26mm (Wide-angle), 2.1 µm, PDAF
# 473                                                50 MP, f/1.8, (Wide-angle), 79°, OIS, PDAF
# 96                                                                64 MP, f/1.75, (Wide-angle)
# 847                             108 MP, f/1.9, 26mm (Wide-angle), 0.7 µm, 1/1.52", Auto Focus
# 509                          50 MP, f/1.5, 26mm (Wide-angle), 0.8 µm, 1/1.95", EIS, OIS, PDAF
# 457                                       64 MP, f/1.7, 25mm (Wide-angle), 0.7 µm, 1/2", PDAF
# 357                            50 MP, f/1.8, 24mm (Wide-angle), 1 µm, 1/1.56", EIS, OIS, PDAF
# 857                                                  48 MP, f/1.8, (Wide-angle), 0.8 µm, PDAF
# 419                                     64 MP, f/1.7, 25mm (Wide-angle), 0.7 µm, 1/2.0", PDAF
# 46      48 MP, f/1.78, 24mm (Wide-angle), 1.12 µm, 1/1.28", Dual Pixel PDAF, Sensor-Shift OIS
# 475                                                50 MP, f/1.8, 26mm (Wide-angle), OIS, PDAF
# 410                                          50 MP, f/1.8, 26mm (Wide-angle), 77°, Auto Focus
# 555                   108 MP, f/1.75, 23.6mm (Wide-angle), 0.64 µm, 1/1.67", Auto Focus, PDAF
# 39                              48 MP, f/1.6, 26mm (Wide-angle), 0.7 µm, Dual Pixel PDAF, OIS
# 148                                     108 MP, f/1.65, 24mm (Wide-angle), 1/1.67", OIS, PDAF
# 146                                                 108 MP, f/1.65, 0mm (Wide-angle), 1/1.67"
# 1070                                                     50 MP, f/1.8, 0mm (Wide-angle), PDAF
# Name: main_cam, dtype: object

# %%
df['cam_primary_mp'] = df['main_cam'].str.split(',').str.get(0).str.strip().str.split(' ').str.get(0).astype('int')

# %%
df['cam_primary_mp'].value_counts(dropna=False)
# Out:
# cam_primary_mp
# 50     850
# 64      91
# 48      82
# 108     79
# 13      48
# 8       37
# 200     35
# 32      25
# 12      15
# 16       5
# 100      1
# Name: count, dtype: int64

# %%
df['cam_aperture'] = df['main_cam'].str.split(',').str.get(1).str.split('/').str.get(1).str.strip()

# %%
df['cam_aperture'].value_counts(dropna=False)
# Out:
# cam_aperture
# 1.8        726
# 1.9         80
# 1.88        60
# 1.79        60
# 1.7         53
# 1.6         53
# 1.75        42
# 2.2         42
# 2.0         40
# 1.5         19
# 1.78        18
# 1.68        14
# 1.89        13
# 1.65         9
# 1.85         7
# NaN          6
# 1.57         6
# 1.69         5
# 2.6          4
# 1.4          3
# 1.59         3
# 1.63         2
# 1.4-2.0      1
# 1.6-f        1
# 1.62         1
# Name: count, dtype: int64

# %%
df[df['cam_aperture'] == '1.6-f'][['main_cam','model']]
# Out:
#                                                                                           main_cam  \
# 1262  50 MP, f/1.6-f/4.0, 23mm (Wide-angle), 3.2 µm, 1.0", Auto Focus, Multi-directional PDAF, OIS
#
#                 model
# 1262  Xiaomi 14 Ultra

# %%
df.loc[89,'cam_aperture'] = '1.4'
df.loc[1262,'cam_aperture'] = '1.6'

# %%
df['cam_aperture'].value_counts(dropna=False)
# Out:
# cam_aperture
# 1.8     726
# 1.9      80
# 1.88     60
# 1.79     60
# 1.6      54
# 1.7      53
# 1.75     42
# 2.2      42
# 2.0      40
# 1.5      19
# 1.78     18
# 1.68     14
# 1.89     13
# 1.65      9
# 1.85      7
# 1.57      6
# NaN       6
# 1.69      5
# 1.4       4
# 2.6       4
# 1.59      3
# 1.63      2
# 1.62      1
# Name: count, dtype: int64

# %%
df['cam_aperture'] = pd.to_numeric(df['cam_aperture'])

# %%
df['main_cam'].sample(20)
# Out:
# 673                  50 MP, f/1.69, 22.86mm (Wide-angle), 85°, 1.12 µm, 1/1.4", OIS, PDAF
# 641                               50 MP, f/1.8, 26mm (Wide-angle), 0.64 µm, 1/2.76", PDAF
# 7                                      48 MP, f/1.78, 24mm (Wide-angle), Sensor-Shift OIS
# 63             48 MP, f/1.7, 25mm (Wide-angle), 82°, 0.8 µm, 1/2.0", Dual Pixel PDAF, OIS
# 504                                        64 MP, f/1.79, (Wide-angle), 1/2.0", OIS, PDAF
# 906                                        50 MP, f/1.8, (Wide-angle), 0.8 µm, Auto Focus
# 459                50 MP, f/1.8, 26mm (Wide-angle), 79°, 0.8 µm, 1/1.95", Auto Focus, OIS
# 273             50 MP, f/1.8, 0mm (Wide-angle), 1 µm, 1/1.5", Multi-directional PDAF, OIS
# 610                                                50 MP, f/1.8, 24mm (Wide-angle), 84.4°
# 964                                   108 MP, f/1.8, 24mm (Wide-angle), 0.8 µm, OIS, PDAF
# 1019                                   50 MP, f/1.8, 24mm (Wide-angle), 0.8 µm, OIS, PDAF
# 181                                   50 MP, f/1.9, 24mm (Wide-angle), 1/1.57", OIS, PDAF
# 961                                        50 MP, f/1.8, (Wide-angle), 1/1.96", OIS, PDAF
# 1164                                  200 MP, f/1.88, 85mm (Telephoto), 84°, 1/1.56", OIS
# 95           108 MP, f/1.75, 24mm (Wide-angle), 83.63°, 0.64 µm, 1/1.67", Auto Focus, OIS
# 415                                50 MP, f/1.8, 27mm (Wide-angle), 77°, Auto Focus, PDAF
# 682                             50 MP, f/1.8, 24mm (Wide-angle), 1 µm, 1/1.56", OIS, PDAF
# 592                                 50 MP, f/1.8, 26mm (Wide-angle), 0.8 µm, 1/1.95", OIS
# 52      48 MP, f/1.6, 26mm (Wide-angle), 1 µm, 1/1.56", Dual Pixel PDAF, Sensor-Shift OIS
# 1121                                               64 MP, f/1.89, 26mm (Wide-angle), PDAF
# Name: main_cam, dtype: object

# %%
def extract_ois(text):

  t = text.lower()

  if 'ois' in t:
    return 1

  return 0

df['cam_has_ois'] = df['main_cam'].apply(extract_ois)

# %%
df['cam_has_ois'].value_counts()
# Out:
# cam_has_ois
# 0    661
# 1    607
# Name: count, dtype: int64

# %%
df['cam_sensor_size'] = df['main_cam'].str.extract(r'1/(\d+\.\d+)')

# %%
df['cam_sensor_size'].value_counts(dropna=False)
# Out:
# cam_sensor_size
# NaN     546
# 1.56    192
# 1.95    108
# 2.76     78
# 1.67     36
# 1.28     31
# 2.0      28
# 1.4      21
# 1.57     20
# 2.88     20
# 1.3      19
# 1.55     18
# 1.52     18
# 1.31     15
# 3.1      14
# 1.96     14
# 1.49     11
# 1.97      9
# 1.43      8
# 4.0       7
# 2.55      6
# 2.8       5
# 3.06      5
# 1.76      5
# 1.72      4
# 1.73      4
# 2.5       4
# 2.9       4
# 1.7       3
# 1.5       3
# 3.0       3
# 1.22      2
# 1.33      2
# 2.74      1
# 2.93      1
# 3.6       1
# 0.98      1
# 1.0       1
# Name: count, dtype: int64

# %%
df['cam_sensor_size'] = pd.to_numeric(df['cam_sensor_size'])

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 106 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    model_id                     1268 non-null   int64
#  1    model                        1268 non-null   object
#  2    expert_rating                1268 non-null   int64
#  3    rating                       1268 non-null   float64
#  4    rating_count                 994 non-null    float64
#  5    launch_on                    1268 non-null   datetime64[ns]
#  6    old_price                    844 non-null    float64
#  7    price                        1268 non-null   int64
#  8    launch_price                 1268 non-null   int64
#  9    display_type                 1268 non-null   object
#  10   display_size                 1268 non-null   object
#  11   display_res                  1268 non-null   object
#  12   body_dimension               1268 non-null   object
#  13   weight                       1268 non-null   object
#  14   body_front                   1268 non-null   object
#  15   body_back                    1238 non-null   object
#  16   body_side                    1251 non-null   object
#  17   build_quality                739 non-null    object
#  18   ports                        1268 non-null   object
#  19   ip_rating                    915 non-null    object
#  20   speaker                      1265 non-null   object
#  21   chipset                      1268 non-null   object
#  22   cpu                          1268 non-null   object
#  23   gpu                          1250 non-null   object
#  24   main_cam                     1268 non-null   object
#  25   main_cam2                    1214 non-null   object
#  26   main_cam3                    631 non-null    object
#  27   main_cam_features            1268 non-null   object
#  28   main_video                   1239 non-null   object
#  29   os                           1268 non-null   object
#  30   software_updates             1228 non-null   object
#  31   ai_features                  780 non-null    object
#  32   front_cam                    1268 non-null   object
#  33   front_cam_features           1026 non-null   object
#  34   front_video                  1229 non-null   object
#  35   battery                      1268 non-null   object
#  36   charging                     1268 non-null   object
#  37   storage                      1268 non-null   object
#  38   ram                          1268 non-null   object
#  39   sim                          1264 non-null   object
#  40   tech                         1200 non-null   object
#  41   2g                           1262 non-null   object
#  42   3g                           1264 non-null   object
#  43   4g                           1267 non-null   object
#  44   5g                           1028 non-null   object
#  45   speed                        1264 non-null   object
#  46   wifi                         1268 non-null   object
#  47   bluetooth                    1266 non-null   object
#  48   positioning_system           1268 non-null   object
#  49   nfc                          595 non-null    object
#  50   finger_print                 1192 non-null   object
#  51   sensors                      1268 non-null   object
#  52   add_features                 469 non-null    object
#  53   main_cam4                    48 non-null     object
#  54   front_cam2                   9 non-null      object
#  55   brand                        1268 non-null   category
#  56   is_available                 1268 non-null   int64
#  57   is_flipkart_available        1268 non-null   int64
#  58   is_amazon_available          1268 non-null   int64
#  59   is_official_available        1268 non-null   int64
#  60   display_panel_type           1268 non-null   object
#  61   display_panel_family         1268 non-null   category
#  62   display_hz                   1268 non-null   int64
#  63   display_dynamic_range        1268 non-null   category
#  64   touch_sampling_rate          852 non-null    float64
#  65   has_ltpo                     1268 non-null   int64
#  66   has_anti_reflection_coating  1268 non-null   int64
#  67   display_inches               1268 non-null   float64
#  68   display_body_ratio           1036 non-null   float64
#  69   has_curved                   1268 non-null   int64
#  70   has_foldable                 1268 non-null   int64
#  71   res_category                 1268 non-null   category
#  72   res_width                    1268 non-null   int64
#  73   res_height                   1268 non-null   int64
#  74   aspect_ration_numeric        1185 non-null   float64
#  75   display_ppi                  1268 non-null   float64
#  76   color_depth                  1268 non-null   float64
#  77   peak_brightness              1206 non-null   float64
#  78   has_high_contrast            1268 non-null   int64
#  79   height_mm                    1268 non-null   float64
#  80   width_mm                     1268 non-null   float64
#  81   thickness_mm                 1268 non-null   float64
#  82   weight_g                     1268 non-null   float64
#  83   front_potection              1268 non-null   category
#  84   back_material                1268 non-null   category
#  85   frame_material               1268 non-null   category
#  86   durability_cert              1268 non-null   category
#  87   has_3_5mm_jack               1268 non-null   int64
#  88   usb_type                     1268 non-null   category
#  89   usb_version                  1268 non-null   float64
#  90   has_otg                      1268 non-null   int64
#  91   has_ir_blaster               1268 non-null   int64
#  92   water_resistance_level       1268 non-null   category
#  93   has_stereo_speakers          1268 non-null   int64
#  94   has_audio_certification      1268 non-null   int64
#  95   processor_brand              1268 non-null   category
#  96   chipset_brand                1266 non-null   object
#  97   chipset_nm                   1258 non-null   float64
#  98   antutu_score                 1237 non-null   float64
#  99   cpu_core_count               1268 non-null   int64
#  100  cpu_max_ghz                  1261 non-null   float64
#  101  gpu_brand                    1249 non-null   category
#  102  cam_primary_mp               1268 non-null   int64
#  103  cam_aperture                 1262 non-null   float64
#  104  cam_has_ois                  1268 non-null   int64
#  105  cam_sensor_size              722 non-null    float64
# dtypes: category(12), datetime64[ns](1), float64(20), int64(24), object(49)
# memory usage: 950.2+ KB

# %%
df['main_cam2'].sample(20)
# Out:
# 525                                                                                 2 MP, f/2.4, 0mm  (Depth)
# 113                                                                                      0.08 MP, (Auxiliary)
# 197                                                                     2 MP, f/2.4, (Depth), 0.64 µm, 1/3.0"
# 349                                      50 MP, f/2.0, 16mm  (Ultra-wide), 116°, 0.61 µm, 1/2.88", Auto Focus
# 708                                                                                                       NaN
# 1091                                                                                     2 MP, f/2.4, (Depth)
# 1261                                         50 MP, f/1.98, 50mm  (Telephoto), 0.64 µm, 2x Optical Zoom, PDAF
# 961                                                     8 MP, f/2.2, (Ultra-wide), 123°, 1.12 µm, 1/4.0", OIS
# 905                                                                             2 MP, f/2.4, (Macro), 0.64 µm
# 1258                                                   50 MP, f/1.9, 48mm  (Telephoto), 2x Optical Zoom, PDAF
# 1009                                                                 8 MP, f/2.2, (Ultra-wide), 123°, 1.12 µm
# 959                                                             8 MP, f/2.2, 0mm  (Ultra-wide), 120°, 1.12 µm
# 154                                                                           8 MP, f/2.2, 16mm  (Ultra-wide)
# 1081                                                                                2 MP, f/2.4, 0mm  (Depth)
# 775                                                                     8 MP, f/2.2, 16mm  (Ultra-wide), 112°
# 8                                                                      12 MP, f/2.2, 13mm  (Ultra-wide), 120°
# 508                                                    8 MP, f/2.2, 15mm  (Ultra-wide), 120°, 1.12 µm, 1/4.0"
# 887                                                          8 MP, f/2.2, (Ultra-wide), 123°, 1.12 µm, 1/4.0"
# 839                                                                           8 MP, f/2.2, (Ultra-wide), 118°
# 587     50 MP, f/2.7, 73mm  (Periscope), 32.8°, 0.8 µm, 1/1.95", 3x Optical Zoom, Multi-directional PDAF, OIS
# Name: main_cam2, dtype: object

# %%
df['cam_secondary_mp'] = df['main_cam2'].str.split(',').str.get(0).str.strip().str.split(' ').str.get(0)

# %%
df['cam_secondary_mp'].value_counts(dropna=False)
# Out:
# cam_secondary_mp
# 2              390
# 8              333
# 50             125
# 0.08            97
# 12              82
# NaN             54
# 5               45
# 10              39
# 13              31
# 48              19
# 64              15
# 32              10
# (Auxiliary)      7
# 0.03             6
# f/2.4            5
# 16               4
# f/2.8            2
# 10.8             2
# 180              1
# 200              1
# Name: count, dtype: int64

# %%
df[df['cam_secondary_mp'] == 'f/2.4'][['model','main_cam2']]
# Out:
#                               model                          main_cam2
# 739  Realme Narzo N53 (6GB + 128GB)                f/2.4, 0mm  (Depth)
# 740  Realme Narzo N53 (8GB + 128GB)                     f/2.4, (Depth)
# 741                Realme Narzo N53                     f/2.4, (Depth)
# 744  Realme Narzo N61 (6GB + 128GB)   f/2.4, 0mm  (Auxiliary), 0.64 µm
# 753                    Realme P1 5G  f/2.4, 22mm  (Depth), 88.8°, 1/5"

# %%
df.loc[[638,639,739,740,741,753],'cam_secondary_mp'] = 2
df.loc[[136,138,484,489,745,830,831,744], 'cam_secondary_mp'] = 0.08

# %%
df['cam_secondary_mp'].value_counts(dropna=False)
# Out:
# cam_secondary_mp
# 2       390
# 8       333
# 50      125
# 0.08     97
# 12       82
# NaN      54
# 5        45
# 10       39
# 13       31
# 48       19
# 64       15
# 32       10
# 0.08      8
# 0.03      6
# 2         6
# 16        4
# 10.8      2
# 180       1
# 200       1
# Name: count, dtype: int64

# %%
cam_cols_to_check = ['main_cam2', 'main_cam3', 'main_cam4']

df['has_telephoto'] = df[cam_cols_to_check].apply(
    lambda x: x.str.contains('Telephoto', case=False, na=False)
).any(axis=1).astype(int)

df['has_periscope'] = df[['main_cam2', 'main_cam3', 'main_cam4']].apply(
    lambda x: x.str.contains('Periscope', case=False, na=False)
).any(axis=1).astype(int)

# %%
df['has_telephoto'].value_counts()
# Out:
# has_telephoto
# 0    1070
# 1     198
# Name: count, dtype: int64

# %%
df['has_periscope'].value_counts()
# Out:
# has_periscope
# 0    1219
# 1      49
# Name: count, dtype: int64

# %%
df['main_cam2'].sample(20)
# Out:
# 273                  13 MP, f/2.2, (Ultra-wide), 120°, 1.12 µm, 1/3.0", PDAF
# 347       50 MP, f/2.0, (Telephoto), 0.64 µm, 1/2.76", 2x Optical Zoom, PDAF
# 535                                 8 MP, f/2.2, (Ultra-wide), 118°, 1.12 µm
# 414                                       2 MP, f/2.4, (Depth), 89°, 0.64 µm
# 223                                          8 MP, f/2.2, (Ultra-wide), 120°
# 387                                              2 MP, f/2.4, (Depth), 89.1°
# 1160                                   8 MP, f/2.0, 15mm  (Ultra-wide), 120°
# 67                           12 MP, f/2.2, 17mm  (Ultra-wide), 114°, 1.25 µm
# 1058                 12 MP, f/2.2, 13mm  (Ultra-wide), 123°, 1.12 µm, 1/3.2"
# 295                                            2 MP, f/2.4, (Macro), 1.75 µm
# 429                                  2 MP, f/2.4, 0mm  (Depth), 89°, 0.64 µm
# 939                                               12 MP, f/2.2, (Ultra-wide)
# 350     50 MP, f/2.0, 16mm  (Ultra-wide), 116°, 0.61 µm, 1/2.88", Auto Focus
# 1253                                         8 MP, f/2.2, (Ultra-wide), 120°
# 466             50 MP, f/2.8, (Telephoto), 30°, 3.5x Optical Zoom, OIS, PDAF
# 491                                     0.08 MP, f/2.5, (Auxiliary), 0.56 µm
# 442                 50 MP, f/2.0, 15mm  (Ultra-wide), 120°, 0.64 µm, 1/2.76"
# 649                                                     2 MP, f/2.4, (Depth)
# 504                         8 MP, f/2.2, (Ultra-wide), 119°, 1.12 µm, 1/4.0"
# 1126                    8 MP, f/2.2, 16mm  (Ultra-wide), 120°, 1.12 µm, 1/4"
# Name: main_cam2, dtype: object

# %%
df['cam_optical_zoom'] = df['main_cam2'].str.extract(r'(\d+)x\s+Optical\s+Zoom')

# %%
df['cam_optical_zoom'] = df['cam_optical_zoom'].fillna(0)

# %%
df['cam_optical_zoom'] = df['cam_optical_zoom'].astype(int)

# %%
df['cam_optical_zoom'].value_counts(dropna=False)
# Out:
# cam_optical_zoom
# 0     1097
# 3       89
# 2       38
# 5       36
# 10       5
# 4        2
# 7        1
# Name: count, dtype: int64

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 110 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    model_id                     1268 non-null   int64
#  1    model                        1268 non-null   object
#  2    expert_rating                1268 non-null   int64
#  3    rating                       1268 non-null   float64
#  4    rating_count                 994 non-null    float64
#  5    launch_on                    1268 non-null   datetime64[ns]
#  6    old_price                    844 non-null    float64
#  7    price                        1268 non-null   int64
#  8    launch_price                 1268 non-null   int64
#  9    display_type                 1268 non-null   object
#  10   display_size                 1268 non-null   object
#  11   display_res                  1268 non-null   object
#  12   body_dimension               1268 non-null   object
#  13   weight                       1268 non-null   object
#  14   body_front                   1268 non-null   object
#  15   body_back                    1238 non-null   object
#  16   body_side                    1251 non-null   object
#  17   build_quality                739 non-null    object
#  18   ports                        1268 non-null   object
#  19   ip_rating                    915 non-null    object
#  20   speaker                      1265 non-null   object
#  21   chipset                      1268 non-null   object
#  22   cpu                          1268 non-null   object
#  23   gpu                          1250 non-null   object
#  24   main_cam                     1268 non-null   object
#  25   main_cam2                    1214 non-null   object
#  26   main_cam3                    631 non-null    object
#  27   main_cam_features            1268 non-null   object
#  28   main_video                   1239 non-null   object
#  29   os                           1268 non-null   object
#  30   software_updates             1228 non-null   object
#  31   ai_features                  780 non-null    object
#  32   front_cam                    1268 non-null   object
#  33   front_cam_features           1026 non-null   object
#  34   front_video                  1229 non-null   object
#  35   battery                      1268 non-null   object
#  36   charging                     1268 non-null   object
#  37   storage                      1268 non-null   object
#  38   ram                          1268 non-null   object
#  39   sim                          1264 non-null   object
#  40   tech                         1200 non-null   object
#  41   2g                           1262 non-null   object
#  42   3g                           1264 non-null   object
#  43   4g                           1267 non-null   object
#  44   5g                           1028 non-null   object
#  45   speed                        1264 non-null   object
#  46   wifi                         1268 non-null   object
#  47   bluetooth                    1266 non-null   object
#  48   positioning_system           1268 non-null   object
#  49   nfc                          595 non-null    object
#  50   finger_print                 1192 non-null   object
#  51   sensors                      1268 non-null   object
#  52   add_features                 469 non-null    object
#  53   main_cam4                    48 non-null     object
#  54   front_cam2                   9 non-null      object
#  55   brand                        1268 non-null   category
#  56   is_available                 1268 non-null   int64
#  57   is_flipkart_available        1268 non-null   int64
#  58   is_amazon_available          1268 non-null   int64
#  59   is_official_available        1268 non-null   int64
#  60   display_panel_type           1268 non-null   object
#  61   display_panel_family         1268 non-null   category
#  62   display_hz                   1268 non-null   int64
#  63   display_dynamic_range        1268 non-null   category
#  64   touch_sampling_rate          852 non-null    float64
#  65   has_ltpo                     1268 non-null   int64
#  66   has_anti_reflection_coating  1268 non-null   int64
#  67   display_inches               1268 non-null   float64
#  68   display_body_ratio           1036 non-null   float64
#  69   has_curved                   1268 non-null   int64
#  70   has_foldable                 1268 non-null   int64
#  71   res_category                 1268 non-null   category
#  72   res_width                    1268 non-null   int64
#  73   res_height                   1268 non-null   int64
#  74   aspect_ration_numeric        1185 non-null   float64
#  75   display_ppi                  1268 non-null   float64
#  76   color_depth                  1268 non-null   float64
#  77   peak_brightness              1206 non-null   float64
#  78   has_high_contrast            1268 non-null   int64
#  79   height_mm                    1268 non-null   float64
#  80   width_mm                     1268 non-null   float64
#  81   thickness_mm                 1268 non-null   float64
#  82   weight_g                     1268 non-null   float64
#  83   front_potection              1268 non-null   category
#  84   back_material                1268 non-null   category
#  85   frame_material               1268 non-null   category
#  86   durability_cert              1268 non-null   category
#  87   has_3_5mm_jack               1268 non-null   int64
#  88   usb_type                     1268 non-null   category
#  89   usb_version                  1268 non-null   float64
#  90   has_otg                      1268 non-null   int64
#  91   has_ir_blaster               1268 non-null   int64
#  92   water_resistance_level       1268 non-null   category
#  93   has_stereo_speakers          1268 non-null   int64
#  94   has_audio_certification      1268 non-null   int64
#  95   processor_brand              1268 non-null   category
#  96   chipset_brand                1266 non-null   object
#  97   chipset_nm                   1258 non-null   float64
#  98   antutu_score                 1237 non-null   float64
#  99   cpu_core_count               1268 non-null   int64
#  100  cpu_max_ghz                  1261 non-null   float64
#  101  gpu_brand                    1249 non-null   category
#  102  cam_primary_mp               1268 non-null   int64
#  103  cam_aperture                 1262 non-null   float64
#  104  cam_has_ois                  1268 non-null   int64
#  105  cam_sensor_size              722 non-null    float64
#  106  cam_secondary_mp             1214 non-null   object
#  107  has_telephoto                1268 non-null   int64
#  108  has_periscope                1268 non-null   int64
#  109  cam_optical_zoom             1268 non-null   int64
# dtypes: category(12), datetime64[ns](1), float64(20), int64(27), object(50)
# memory usage: 989.8+ KB

# %%
df['main_cam3'].sample(20)
# Out:
# 51                                                                              NaN
# 60                                                                              NaN
# 632                                                                             NaN
# 223                                                                             NaN
# 346                          8 MP, f/2.2, 16mm  (Ultra-wide), 112°, 1.12 µm, 1/4.0"
# 482                                             2 MP, f/2.4, (Macro), 1.75 µm, 1/5"
# 947                                                   2 MP, f/2.4, (Depth), 0.64 µm
# 1063                                12 MP, f/2.2, 12mm  (Ultra-wide), 123°, 1.12 µm
# 1028    12 MP, f/2.2, 13mm  (Ultra-wide), 120°, 1.4 µm, 1/2.55", Super Steady Video
# 1059                                12 MP, f/2.2, 12mm  (Ultra-wide), 123°, 1.12 µm
# 120                                                                             NaN
# 1109                                                      2 MP, f/2.4, (Depth), 81°
# 227                                                                             NaN
# 635                                                                             NaN
# 1061                                12 MP, f/2.2, 12mm  (Ultra-wide), 123°, 1.12 µm
# 129                                                        2 MP, f/2.4, (Auxiliary)
# 1243                                                                            NaN
# 40                                                                              NaN
# 1232                                                                            NaN
# 754                                                                             NaN
# Name: main_cam3, dtype: object

# %%
df['cam_tertiary_mp'] = df['main_cam3'].str.split(',').str.get(0).str.split(' ').str.get(0)

# %%
df['cam_tertiary_mp'].value_counts(dropna=False)
# Out:
# cam_tertiary_mp
# NaN            637
# 2              330
# 50              63
# 12              62
# 8               49
# 5               31
# 48              28
# 10              13
# 13              10
# 0.08             9
# 0mm              7
# 200              5
# f/2.8            4
# f/2.4            3
# (Auxiliary)      3
# 0.3              2
# 10.5             2
# 88°              2
# 0.07             2
# 3                2
# 32               2
# 10.8             1
# f/2.5            1
# Name: count, dtype: int64

# %%
df[df['cam_tertiary_mp'] == '0mm'][['model','main_cam3']]
# Out:
#                                     model         main_cam3
# 528              Poco M7 5G (8GB + 128GB)  0mm  (Auxiliary)
# 720  Realme Narzo 70 Turbo (12GB + 256GB)               0mm
# 721   Realme Narzo 70 Turbo (8GB + 128GB)               0mm
# 803            Redmi 13C 5G (6GB + 128GB)  0mm  (Auxiliary)
# 804            Redmi 13C 5G (8GB + 256GB)  0mm  (Auxiliary)
# 806               Redmi 13C (6GB + 128GB)  0mm  (Auxiliary)
# 807               Redmi 13C (8GB + 256GB)  0mm  (Auxiliary)

# %%
df.loc[[121,114,119,122],'cam_tertiary_mp'] = 0.07
df.loc[[808,809,810,528,720,721,803,804,806,807],'cam_tertiary_mp'] = 0.08
df.loc[[636,637,706,707],'cam_tertiary_mp'] = 2
df.loc[[553,554],'cam_tertiary_mp'] = np.nan

# %%
df['cam_tertiary_mp'] = pd.to_numeric(df['cam_tertiary_mp'])

# %%
df['cam_tertiary_mp'].value_counts(dropna=False)
# Out:
# cam_tertiary_mp
# NaN       639
# 2.00      334
# 50.00      63
# 12.00      62
# 8.00       49
# 5.00       31
# 48.00      28
# 0.08       19
# 10.00      13
# 13.00      10
# 0.07        6
# 200.00      5
# 10.50       2
# 0.30        2
# 32.00       2
# 3.00        2
# 10.80       1
# Name: count, dtype: int64

# %%
# List of camera columns
cam_cols = ['main_cam', 'main_cam2', 'main_cam3','main_cam4']

# Count non-NaN values across these columns
df['total_cam_count'] = df[cam_cols].notna().sum(axis=1)

# %%
df['total_cam_count'].value_counts(dropna=False)
# Out:
# total_cam_count
# 2    583
# 3    583
# 1     54
# 4     48
# Name: count, dtype: int64

# %%
df[~df['main_cam4'].isnull()]['main_cam4']
# Out:
# 238                                                                     2 MP, f/2.4, (Depth), 175 µm
# 439                 50 MP, f/2.0, 15mm  (Ultra-wide), 120°, 0.64 µm, 1/2.75", Multi-Directional PDAF
# 441                                                                   2 MP, f/2.4, (Monochrome), 88°
# 442                                                                   2 MP, f/2.4, (Monochrome), 88°
# 443                                                                   2 MP, f/2.4, (Monochrome), 88°
# 786                                                                        2 MP, f/2.4, 0mm  (Depth)
# 787                                                                        2 MP, f/2.4, 0mm  (Depth)
# 788                                                                             2 MP, f/2.4, (Depth)
# 836                                                                        2 MP, f/2.4, 0mm  (Depth)
# 837                                                                        2 MP, f/2.4, 0mm  (Depth)
# 838                                                                        2 MP, f/2.4, 0mm  (Depth)
# 842                                                                             2 MP, f/2.4, (Depth)
# 843                                                                             2 MP, f/2.4, (Depth)
# 844                                                                             2 MP, f/2.4, (Depth)
# 845                                                                        2 MP, f/2.4, 0mm  (Depth)
# 846                                                                        2 MP, f/2.4, 0mm  (Depth)
# 847                                                                             2 MP, f/2.4, (Depth)
# 877                                                               2 MP, f/2.4, 0mm  (Depth), 1.75 µm
# 878                                                                    2 MP, f/2.4, (Depth), 1.75 µm
# 879                                                               2 MP, f/2.4, 0mm  (Depth), 1.75 µm
# 880                                                                    2 MP, f/2.4, (Depth), 1.75 µm
# 881                                                                        2 MP, f/2.4, 0mm  (Depth)
# 882                                                                             2 MP, f/2.4, (Depth)
# 883                                                               5 MP, f/2.4, 0mm  (Depth), 1.12 µm
# 884                                                               5 MP, f/2.4, 0mm  (Depth), 1.12 µm
# 885                                                                        5 MP, f/2.4, 0mm  (Depth)
# 915                                                               2 MP, f/2.4, 0mm  (Depth), 0.64 µm
# 916                                                                    2 MP, f/2.4, (Depth), 0.64 µm
# 930                                                                    5 MP, f/2.4, (Depth), 1.12 µm
# 939                                                                             5 MP, f/2.4, (Depth)
# 992                                                                        2 MP, f/2.4, 0mm  (Macro)
# 993                                                                             2 MP, f/2.4, (Macro)
# 1002                                                                            2 MP, f/2.4, (Macro)
# 1003                                                                            2 MP, f/2.4, (Macro)
# 1015    12 MP, f/2.2, 13mm  (Ultra-wide), 120°, 1.4 µm, 1/2.55", Dual Pixel PDAF, Super Steady Video
# 1016    12 MP, f/2.2, 13mm  (Ultra-wide), 120°, 1.4 µm, 1/2.55", Dual Pixel PDAF, Super Steady Video
# 1022          12 MP, f/2.2, 13mm  (Ultra-wide), 1.4 µm, 1/2.55", Dual Pixel PDAF, Super Steady Video
# 1023          12 MP, f/2.2, 13mm  (Ultra-wide), 1.4 µm, 1/2.55", Dual Pixel PDAF, Super Steady Video
# 1024          12 MP, f/2.2, 13mm  (Ultra-wide), 1.4 µm, 1/2.55", Dual Pixel PDAF, Super Steady Video
# 1034    12 MP, f/2.2, 13mm  (Ultra-wide), 120°, 1.4 µm, 1/2.55", Dual Pixel PDAF, Super Steady Video
# 1035          12 MP, f/2.2, (Ultra-wide), 120°, 1.4 µm, 1/2.55", Dual Pixel PDAF, Super Steady Video
# 1036    12 MP, f/2.2, 13mm  (Ultra-wide), 120°, 1.4 µm, 1/2.55", Dual Pixel PDAF, Super Steady Video
# 1045          50 MP, f/1.9, (Ultra-wide), 120°, 0.7 µm, 1/2.55", Dual Pixel PDAF, Super Steady Video
# 1046          50 MP, f/1.9, (Ultra-wide), 120°, 0.7 µm, 1/2.55", Dual Pixel PDAF, Super Steady Video
# 1047          50 MP, f/1.9, (Ultra-wide), 120°, 0.7 µm, 1/2.55", Dual Pixel PDAF, Super Steady Video
# 1181                                      8 MP, f/3.4, (Periscope), 1 µm, 5x Optical Zoom, OIS, PDAF
# 1262            50 MP, f/1.8, 12mm  (Ultra-wide), 122°, 0.7 µm, 1/2.51", Auto Focus, Dual Pixel PDAF
# 1264                       50 MP, f/2.2, 14mm  (Ultra-wide), 115°, 1.28 µm, 1/2.76", Dual Pixel PDAF
# Name: main_cam4, dtype: object

# %%
df['cam_fourth_mp'] = df['main_cam4'].str.split(',').str.get(0).str.split(' ').str.get(0)

# %%
df['cam_fourth_mp'] = pd.to_numeric(df['cam_fourth_mp'])

# %%
df['cam_fourth_mp'].value_counts(dropna=False)
# Out:
# cam_fourth_mp
# NaN     1220
# 2.0       28
# 12.0       8
# 50.0       6
# 5.0        5
# 8.0        1
# Name: count, dtype: int64

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 113 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    model_id                     1268 non-null   int64
#  1    model                        1268 non-null   object
#  2    expert_rating                1268 non-null   int64
#  3    rating                       1268 non-null   float64
#  4    rating_count                 994 non-null    float64
#  5    launch_on                    1268 non-null   datetime64[ns]
#  6    old_price                    844 non-null    float64
#  7    price                        1268 non-null   int64
#  8    launch_price                 1268 non-null   int64
#  9    display_type                 1268 non-null   object
#  10   display_size                 1268 non-null   object
#  11   display_res                  1268 non-null   object
#  12   body_dimension               1268 non-null   object
#  13   weight                       1268 non-null   object
#  14   body_front                   1268 non-null   object
#  15   body_back                    1238 non-null   object
#  16   body_side                    1251 non-null   object
#  17   build_quality                739 non-null    object
#  18   ports                        1268 non-null   object
#  19   ip_rating                    915 non-null    object
#  20   speaker                      1265 non-null   object
#  21   chipset                      1268 non-null   object
#  22   cpu                          1268 non-null   object
#  23   gpu                          1250 non-null   object
#  24   main_cam                     1268 non-null   object
#  25   main_cam2                    1214 non-null   object
#  26   main_cam3                    631 non-null    object
#  27   main_cam_features            1268 non-null   object
#  28   main_video                   1239 non-null   object
#  29   os                           1268 non-null   object
#  30   software_updates             1228 non-null   object
#  31   ai_features                  780 non-null    object
#  32   front_cam                    1268 non-null   object
#  33   front_cam_features           1026 non-null   object
#  34   front_video                  1229 non-null   object
#  35   battery                      1268 non-null   object
#  36   charging                     1268 non-null   object
#  37   storage                      1268 non-null   object
#  38   ram                          1268 non-null   object
#  39   sim                          1264 non-null   object
#  40   tech                         1200 non-null   object
#  41   2g                           1262 non-null   object
#  42   3g                           1264 non-null   object
#  43   4g                           1267 non-null   object
#  44   5g                           1028 non-null   object
#  45   speed                        1264 non-null   object
#  46   wifi                         1268 non-null   object
#  47   bluetooth                    1266 non-null   object
#  48   positioning_system           1268 non-null   object
#  49   nfc                          595 non-null    object
#  50   finger_print                 1192 non-null   object
#  51   sensors                      1268 non-null   object
#  52   add_features                 469 non-null    object
#  53   main_cam4                    48 non-null     object
#  54   front_cam2                   9 non-null      object
#  55   brand                        1268 non-null   category
#  56   is_available                 1268 non-null   int64
#  57   is_flipkart_available        1268 non-null   int64
#  58   is_amazon_available          1268 non-null   int64
#  59   is_official_available        1268 non-null   int64
#  60   display_panel_type           1268 non-null   object
#  61   display_panel_family         1268 non-null   category
#  62   display_hz                   1268 non-null   int64
#  63   display_dynamic_range        1268 non-null   category
#  64   touch_sampling_rate          852 non-null    float64
#  65   has_ltpo                     1268 non-null   int64
#  66   has_anti_reflection_coating  1268 non-null   int64
#  67   display_inches               1268 non-null   float64
#  68   display_body_ratio           1036 non-null   float64
#  69   has_curved                   1268 non-null   int64
#  70   has_foldable                 1268 non-null   int64
#  71   res_category                 1268 non-null   category
#  72   res_width                    1268 non-null   int64
#  73   res_height                   1268 non-null   int64
#  74   aspect_ration_numeric        1185 non-null   float64
#  75   display_ppi                  1268 non-null   float64
#  76   color_depth                  1268 non-null   float64
#  77   peak_brightness              1206 non-null   float64
#  78   has_high_contrast            1268 non-null   int64
#  79   height_mm                    1268 non-null   float64
#  80   width_mm                     1268 non-null   float64
#  81   thickness_mm                 1268 non-null   float64
#  82   weight_g                     1268 non-null   float64
#  83   front_potection              1268 non-null   category
#  84   back_material                1268 non-null   category
#  85   frame_material               1268 non-null   category
#  86   durability_cert              1268 non-null   category
#  87   has_3_5mm_jack               1268 non-null   int64
#  88   usb_type                     1268 non-null   category
#  89   usb_version                  1268 non-null   float64
#  90   has_otg                      1268 non-null   int64
#  91   has_ir_blaster               1268 non-null   int64
#  92   water_resistance_level       1268 non-null   category
#  93   has_stereo_speakers          1268 non-null   int64
#  94   has_audio_certification      1268 non-null   int64
#  95   processor_brand              1268 non-null   category
#  96   chipset_brand                1266 non-null   object
#  97   chipset_nm                   1258 non-null   float64
#  98   antutu_score                 1237 non-null   float64
#  99   cpu_core_count               1268 non-null   int64
#  100  cpu_max_ghz                  1261 non-null   float64
#  101  gpu_brand                    1249 non-null   category
#  102  cam_primary_mp               1268 non-null   int64
#  103  cam_aperture                 1262 non-null   float64
#  104  cam_has_ois                  1268 non-null   int64
#  105  cam_sensor_size              722 non-null    float64
#  106  cam_secondary_mp             1214 non-null   object
#  107  has_telephoto                1268 non-null   int64
#  108  has_periscope                1268 non-null   int64
#  109  cam_optical_zoom             1268 non-null   int64
#  110  cam_tertiary_mp              629 non-null    float64
#  111  total_cam_count              1268 non-null   int64
#  112  cam_fourth_mp                48 non-null     float64
# dtypes: category(12), datetime64[ns](1), float64(22), int64(28), object(50)
# memory usage: 1019.6+ KB

# %%
df['main_cam_features'].sample(50)
# Out:
# 896                                                                                                                                              LED Flash
# 555                                                                                                                               HDR, LED flash, Panorama
# 89                                                                                                                                HDR, LED Flash, Panorama
# 783                                                                                                                               HDR, LED Flash, Panorama
# 1256                                                             Cinematic Mode, Dual LED Dual Tone Flash, HDR, Long Exposure, Night, Panorama, Time-Lapse
# 1232       Double Exposure, Dual View, HDR, HIGH-RES, LED Flash, Micro, Movie, Night, Panorama, Portrait, Portrait Photo & Video, Pro, Slow-Mo, Time-Lapse
# 1045                                                                                                       Auto-HDR, Laser Auto Focus, LED Flash, Panorama
# 32                                                                              Dual LED Dual Tone Flash, HDR (photo/panorama), Laser Auto Focus, Panorama
# 696                                          Cinematic Bokeh, Dual LED Dual Tone Flash, Expert, Filter, HDR, Nightscape, Panorama, Portrait Mode, Pro Mode
# 576                         Auto Focus, Cinematic Aspect Ratio, Cinematic Bokeh, HDR, LED Flash, Panorama, Portrait Filters, Real-time Aperture Adjustment
# 310                                                                                                                HDR, LED Flash, Motion Photos, Panorama
# 61                                                                                                                               HDR, Night Mode, Portrait
# 671                                                                                                Auto Focus, Digital Zoom, Dual LED Flash, HDR, Panorama
# 342                                                                                           Dual LED Flash, Hasselblad Colour Calibration, HDR, Panorama
# 159     Dual LED Flash, HDR, HIGH-RES, Long Exposure, Night, Panorama, Portrait, Portrait Photo & Video, Pro, RGB Halo Ring Light, Slow Motion, Time Lapse
# 970                                                                                                                                              LED Flash
# 213                                                               Double Exposure, Dual View, HDR, LED Flash, Micro, Night Vision, Panorama, Portrait Mode
# 298                                                                                                                   HDR, LED Flash, Panorama, Scene Mode
# 395                                                                                                       HDR, LED Flash, Night, Panorama, Pro, Time-lapse
# 1228                                                      HDR, Night, Panorama, Portrait, Portrait Photo & Video, Pro, Ring-LED Flash, Slow-Mo, Time-lapse
# 516                                                                                                                               HDR, LED flash, Panorama
# 1172                                                                       HDR, Laser Auto Focus, LED Flash, Panorama, Zeiss Optics, Zeiss T* Lens Coating
# 433                                                                                                        Night Mode, Panorama, Portrait Mode, Time-Lapse
# 55                                                                       Auto Focus, DIS, HDR, LED Flash, Macro Mode, Night Mode, OIS, Panorama, PDAF, RAW
# 319                                                                                                                               HDR, LED Flash, Panorama
# 284                            Audio Zoom, Digital Zoom, HDR, HDR10+, Long Exposure, Macro, Night Vision, Panorama, Portrait, Pro, Slow Motion, Time-Lapse
# 685                                                                                                        Color Spectrum Sensor, HDR, LED Flash, Panorama
# 220                                                                                                     Auto Focus, Digital Zoom, HDR, LED Flash, Panorama
# 1075                                                              Double Exposure, HDR, LED Flash, Night, Panorama, Portrait, Pro, Slow Motion, Time-Lapse
# 1059                                                                                                                              HDR, LED Flash, Panorama
# 727                                                                                                                                               Panorama
# 738                                                                                  Dual View, HDR, Hi-Res Mode, LED Flash, Panorama, Slow-Mo, Time Lapse
# 347                                                                                                        Color Spectrum Sensor, HDR, LED Flash, Panorama
# 566                                                                                                                               HDR, LED Flash, Panorama
# 169                                        Digital Zoom, Dual LED Dual Tone Flash, Dual View, HDR, Night Mode, Panorama, Pro Mode, Slow Motion, Time Lapse
# 1112                                                                                                                         HDR, Panorama, Ring-LED Flash
# 924                                                                   Auto Focus, Digital Image Stabilization, Digital Zoom, Face Detection, HDR, Panorama
# 536                                                                                                       Dual View, HDR, LED Flash, Panorama, Super Macro
# 241                                                                                       HDR, LED Flash, Night Vision, Panorama, Pro Mode (long exposure)
# 124                                                      Film Camera Mode, HDR, Night Mode, Panorama, Portrait Mode, Pro Mode, Quad-LED Flash, Slow Motion
# 784                                                                                                                               HDR, LED flash, Panorama
# 1082                                                                                                              Auto Focus, Digital Zoom, HDR, LED Flash
# 487                                                                                                                                    Dual LED Flash, HDR
# 482                                                  Dual LED Flash, Dual View, HDR, Macro, Night, Panorama, Panoramic, Portrait, Pro, Slow-Mo, Time-Lapse
# 716                                  HDR, LED Flash, Long Exposure, Movie, Night Mode, Panorama, Portrait Mode, Professional Mode, Slow Motion, Time-Lapse
# 1242                                                                                               Dual View, LED-Flash, Night mode, Panorama, Slow Motion
# 804                                                                         Film Camera Mode, HDR Panorama, LED Flash, Night Mode, Slow Motion, Time Lapse
# 589                                                HDR, HIGH-RES, LED Flash, Long Exposure, Movie, Night, Panorama, Portrait, Pro, Slow Motion, Time Lapse
# 432                                                                                     Hi-Res Mode, Night Mode, Panorama, Portrait, Pro Mode, Slow Motion
# 557                                                 HDR, LED flash, Movie, Night Mode, Panorama, Portrait Mode, Professional Mode, Slow Motion, Time-Lapse
# Name: main_cam_features, dtype: object

# %%
# 1. Apple Premium Stack (LiDAR & Photonic)
df['is_apple_flagship_tech'] = df['main_cam_features'].str.contains('LiDAR|Photonic Engine', case=False, na=False).astype(int)

# 2. Advanced Focus & Optics (Zeiss & Laser AF)
df['has_laser_af'] = df['main_cam_features'].str.contains('Laser Auto Focus', case=False, na=False).astype(int)
df['has_zeiss_optics'] = df['main_cam_features'].str.contains(r'Zeiss Optics|Zeiss T\*', case=False, na=False).astype(int)

# 3. Stability & Professional Video (OIS & Cinematic/Movie)
df['has_pro_video_features'] = df['main_cam_features'].str.contains('Cinematic|Movie|Dual View', case=False, na=False).astype(int)

# %%
df['is_apple_flagship_tech'].value_counts()
# Out:
# is_apple_flagship_tech
# 0    1240
# 1      28
# Name: count, dtype: int64

# %%
df['has_laser_af'].value_counts()
# Out:
# has_laser_af
# 0    1222
# 1      46
# Name: count, dtype: int64

# %%
df['has_zeiss_optics'].value_counts()
# Out:
# has_zeiss_optics
# 0    1234
# 1      34
# Name: count, dtype: int64

# %%
df['has_pro_video_features'].value_counts()
# Out:
# has_pro_video_features
# 0    1002
# 1     266
# Name: count, dtype: int64

# %%
df[df['has_zeiss_optics'] == 1][['model','main_cam_features']].head(30)
# Out:
#                                model  \
# 1144  Vivo V30 Pro 5G (12GB + 512GB)
# 1145                 Vivo V30 Pro 5G
# 1148         Vivo V40 (12GB + 512GB)
# 1149          Vivo V40 (8GB + 256GB)
# 1150     Vivo V40 Pro (12GB + 512GB)
# 1151                    Vivo V40 Pro
# 1152                        Vivo V40
# 1155         Vivo V50 (12GB + 512GB)
# 1156          Vivo V50 (8GB + 256GB)
# 1157                        Vivo V50
# 1159         Vivo V60 (12GB + 256GB)
# 1160         Vivo V60 (16GB + 512GB)
# 1161          Vivo V60 (8GB + 256GB)
# 1162                        Vivo V60
# 1166                   Vivo X Fold 5
# 1167                Vivo X Fold3 Pro
# 1168        Vivo X100 (16GB + 512GB)
# 1169                   Vivo X100 Pro
# 1170                       Vivo X100
# 1171        Vivo X200 (16GB + 512GB)
# 1172     Vivo X200 FE (16GB + 256GB)
# 1173                    Vivo X200 FE
# 1174                   Vivo X200 Pro
# 1175                       Vivo X200
# 1176        Vivo X300 (12GB + 512GB)
# 1177        Vivo X300 (16GB + 512GB)
# 1178                   Vivo X300 Pro
# 1179                       Vivo X300
# 1180         Vivo X80 (12GB + 256GB)
# 1181                    vivo X80 Pro
#
#                                                                                                                                                                                      main_cam_features
# 1144                                                  Dual View, HDR, HIGH-RES, Micro, Movie, Night, Panorama, Portrait, Pro, Ring-LED Flash, Slow-Mo, Time-lapse, Zeiss Optics, Zeiss T* Lens Coating
# 1145                                                  Dual View, HDR, HIGH-RES, Micro, Movie, Night, Panorama, Portrait, Pro, Ring-LED Flash, Slow-Mo, Time-lapse, Zeiss Optics, Zeiss T* Lens Coating
# 1148                                                 Dual View, HDR, HIGH-RES, Micro, Movie, Night, Panorama, Portrait, Portrait Photo & Video, Pro, Ring-LED Flash, Slow-Mo, Time-Lapse, Zeiss Optics
# 1149                                                 Dual View, HDR, HIGH-RES, Micro, Movie, Night, Panorama, Portrait, Portrait Photo & Video, Pro, Ring-LED Flash, Slow-Mo, Time-Lapse, Zeiss Optics
# 1150                                                 Dual View, HDR, HIGH-RES, Micro, Movie, Night, Panorama, Portrait, Portrait Photo & Video, Pro, Ring-LED Flash, Slow-Mo, Time-lapse, Zeiss Optics
# 1151                                                 Dual View, HDR, HIGH-RES, Micro, Movie, Night, Panorama, Portrait, Portrait Photo & Video, Pro, Ring-LED Flash, Slow-Mo, Time-lapse, Zeiss Optics
# 1152                                                 Dual View, HDR, HIGH-RES, Micro, Movie, Night, Panorama, Portrait, Portrait Photo & Video, Pro, Ring-LED Flash, Slow-Mo, Time-Lapse, Zeiss Optics
# 1155                                                          Dual View, HDR, HIGH-RES, Micro, Movie, Night, Panorama, Portrait, Pro, Pro Mode, Quad-Rear LED Flash, Slow-Mo, Time-lapse, Zeiss Optics
# 1156                                                          Dual View, HDR, HIGH-RES, Micro, Movie, Night, Panorama, Portrait, Pro, Pro Mode, Quad-Rear LED Flash, Slow-Mo, Time-lapse, Zeiss Optics
# 1157                                                          Dual View, HDR, HIGH-RES, Micro, Movie, Night, Panorama, Portrait, Pro, Pro Mode, Quad-Rear LED Flash, Slow-Mo, Time-lapse, Zeiss Optics
# 1159                                                       Dual View, Film Camera Mode, HDR, HIGH-RES, Micro, Movie, Night, panorama, Portrait, Pro, Ring-LED Flash, Slow-Mo, Time Lapse, Zeiss Optics
# 1160                                                       Dual View, Film Camera Mode, HDR, HIGH-RES, Micro, Movie, Night, panorama, Portrait, Pro, Ring-LED Flash, Slow-Mo, Time Lapse, Zeiss Optics
# 1161                                                       Dual View, Film Camera Mode, HDR, HIGH-RES, Micro, Movie, Night, panorama, Portrait, Pro, Ring-LED Flash, Slow-Mo, Time Lapse, Zeiss Optics
# 1162                                                       Dual View, Film Camera Mode, HDR, HIGH-RES, Micro, Movie, Night, panorama, Portrait, Pro, Ring-LED Flash, Slow-Mo, Time Lapse, Zeiss Optics
# 1166                                                                                                              Dual LED Flash, HDR, Laser Auto Focus, Panorama, Zeiss Optics, Zeiss T* Lens Coating
# 1167                                                                                                                                Dual LED Flash, HDR, Panorama, Zeiss Optics, Zeiss T* Lens Coating
# 1168                                                                                                                     3D LUT Support, HDR, LED Flash, Panorama, Zeiss Optics, Zeiss T* Lens Coating
# 1169                                                                                                                     3D LUT Support, HDR, LED Flash, Panorama, Zeiss Optics, Zeiss T* Lens Coating
# 1170                                                                                                   3D LUT Support, HDR, Laser Auto Focus, LED Flash, Panorama, Zeiss Optics, Zeiss T* Lens Coating
# 1171    HDR, HIGH-RES, Laser Auto Focus, LED Flash, Long Exposure, Night, Panorama, Portrait Photo & Video, Pro, Slow-Mo, Super Macro, Time-Lapse, Video Portrait, Zeiss Optics, Zeiss T* Lens Coating
# 1172                                                                                                                   HDR, Laser Auto Focus, LED Flash, Panorama, Zeiss Optics, Zeiss T* Lens Coating
# 1173                                                                                                                   HDR, Laser Auto Focus, LED Flash, Panorama, Zeiss Optics, Zeiss T* Lens Coating
# 1174                  3D LUT Support, HDR, HIGH-RES, Laser Auto Focus, LED Flash, Night, Panorama, Portrait, Portrait Photo & Video, Pro, Super Macro, Time-Lapse, Zeiss Optics, Zeiss T* Lens Coating
# 1175    HDR, HIGH-RES, Laser Auto Focus, LED Flash, Long Exposure, Night, Panorama, Portrait Photo & Video, Pro, Slow-Mo, Super Macro, Time-Lapse, Video Portrait, Zeiss Optics, Zeiss T* Lens Coating
# 1176                                                                                                            3D LUT Import, HDR, Laser AF, LED Flash, Panorama, Zeiss Optics, Zeiss T* lens Coating
# 1177                                                                                                            3D LUT Import, HDR, Laser AF, LED Flash, Panorama, Zeiss Optics, Zeiss T* lens Coating
# 1178                                                                                    3D LUT Import, Colour Spectrum sensor, HDR, Laser AF, LED Flash, Panorama, Zeiss optics, Zeiss T* lens coating
# 1179                                                                                                            3D LUT Import, HDR, Laser AF, LED Flash, Panorama, Zeiss Optics, Zeiss T* lens Coating
# 1180                                     Double Exposure, Dual LED Dual Tone Flash, Dual View, HDR, Laser AF, Panorama, Pixel Shift, Pro, Slow Motion, Time-Lapse, Zeiss Optics, Zeiss T* Lens Coating
# 1181  Double Exposure, Dual LED Dual Tone Flash, HDR, Laser AF, Long Exposure, Micro, Movie, Night, Panorama, Pixel Shift, Portrait, Pro, Slow Motion, Time Lapse, Zeiss Optics, Zeiss T* Lens Coating

# %%
df[df['is_apple_flagship_tech'] == 1][['model','main_cam_features']].head(30)
# Out:
#                                      model  \
# 5          Apple iPhone 14 Pro (6GB + 1TB)
# 6        Apple iPhone 14 Pro (6GB + 256GB)
# 7        Apple iPhone 14 Pro (6GB + 512GB)
# 8      Apple iPhone 14 Pro Max (6GB + 1TB)
# 9    Apple iPhone 14 Pro Max (6GB + 256GB)
# 10   Apple iPhone 14 Pro Max (6GB + 512GB)
# 11                 Apple iPhone 14 Pro Max
# 12                     Apple iPhone 14 Pro
# 14           Apple iPhone 15 (6GB + 256GB)
# 15           Apple iPhone 15 (6GB + 512GB)
# 19         Apple iPhone 15 Pro (8GB + 1TB)
# 20       Apple iPhone 15 Pro (8GB + 256GB)
# 21       Apple iPhone 15 Pro (8GB + 512GB)
# 22     Apple iPhone 15 Pro Max (8GB + 1TB)
# 23   Apple iPhone 15 Pro Max (8GB + 512GB)
# 24                 Apple iPhone 15 Pro Max
# 25                     Apple iPhone 15 Pro
# 26                         Apple iPhone 15
# 43        Apple iPhone 17 Pro (12GB + 1TB)
# 44      Apple iPhone 17 Pro (12GB + 512GB)
# 45    Apple iPhone 17 Pro Max (12GB + 1TB)
# 46    Apple iPhone 17 Pro Max (12GB + 2TB)
# 47  Apple iPhone 17 Pro Max (12GB + 512GB)
# 48                 Apple iPhone 17 Pro Max
# 49                     Apple iPhone 17 Pro
# 51           Apple iPhone Air (12GB + 1TB)
# 52         Apple iPhone Air (12GB + 512GB)
# 53                        Apple iPhone Air
#
#                                                                                                                                                                                      main_cam_features
# 5                                                               Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 6                                                               Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 7                                                               Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 8                                                               Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 9                                                               Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 10                                                              Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 11                                                              Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 12                                                              Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 14                                                                                                      Digital Zoom, Geotagging, HDR, LED Flash, Night Mode, Panorama, Photonic Engine, Portrait Mode
# 15                                                                                                      Digital Zoom, Geotagging, HDR, LED Flash, Night Mode, Panorama, Photonic Engine, Portrait Mode
# 19                                   Digital Zoom, Dual LED Flash, Geotagging, HDR (photo/panorama), Laser Auto Focus, Macro Mode, Night Mode, Panorama, Photonic Engine, TOF 3D LiDAR Scanner (Depth)
# 20                                   Digital Zoom, Dual LED Flash, Geotagging, HDR (photo/panorama), Laser Auto Focus, Macro Mode, Night Mode, Panorama, Photonic Engine, TOF 3D LiDAR Scanner (Depth)
# 21                                   Digital Zoom, Dual LED Flash, Geotagging, HDR (photo/panorama), Laser Auto Focus, Macro Mode, Night Mode, Panorama, Photonic Engine, TOF 3D LiDAR Scanner (Depth)
# 22  ACES, Auto Focus, Continuous Auto Focus, Continuous Shooting, Dual LED Dual Tone Flash, Face Detection, Geotagging, HDR (photo/panorama), Panorama, PDAF, Photonic Engine, Scene Mode, Touch Focus
# 23  ACES, Auto Focus, Continuous Auto Focus, Continuous Shooting, Dual LED Dual Tone Flash, Face Detection, Geotagging, HDR (photo/panorama), Panorama, PDAF, Photonic Engine, Scene Mode, Touch Focus
# 24  ACES, Auto Focus, Continuous Auto Focus, Continuous Shooting, Dual LED Dual Tone Flash, Face Detection, Geotagging, HDR (photo/panorama), Panorama, PDAF, Photonic Engine, Scene Mode, Touch Focus
# 25                                   Digital Zoom, Dual LED Flash, Geotagging, HDR (photo/panorama), Laser Auto Focus, Macro Mode, Night Mode, Panorama, Photonic Engine, TOF 3D LiDAR Scanner (Depth)
# 26                                                                                                      Digital Zoom, Geotagging, HDR, LED Flash, Night Mode, Panorama, Photonic Engine, Portrait Mode
# 43                                   Action Mode, Audio Zoom, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Panorama, Slow Motion, Time-lapse, TOF 3D LiDAR Scanner (depth)
# 44                                   Action Mode, Audio Zoom, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Panorama, Slow Motion, Time-lapse, TOF 3D LiDAR Scanner (depth)
# 45                                   Action Mode, Audio Zoom, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Panorama, Slow Motion, Time-lapse, TOF 3D LiDAR Scanner (Depth)
# 46                                   Action Mode, Audio Zoom, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Panorama, Slow Motion, Time-lapse, TOF 3D LiDAR Scanner (Depth)
# 47                                   Action Mode, Audio Zoom, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Panorama, Slow Motion, Time-lapse, TOF 3D LiDAR Scanner (Depth)
# 48                                   Action Mode, Audio Zoom, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Panorama, Slow Motion, Time-lapse, TOF 3D LiDAR Scanner (Depth)
# 49                                   Action Mode, Audio Zoom, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Panorama, Slow Motion, Time-lapse, TOF 3D LiDAR Scanner (depth)
# 51                                       3D (spatial) Audio, Action Mode, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, Night Mode, Panorama, Photonic Engine, Portrait, Slow-Mo, Time-lapse
# 52                                       3D (spatial) Audio, Action Mode, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, Night Mode, Panorama, Photonic Engine, Portrait, Slow-Mo, Time-lapse
# 53                                       3D (spatial) Audio, Action Mode, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, Night Mode, Panorama, Photonic Engine, Portrait, Slow-Mo, Time-lapse

# %%
df[df['has_laser_af'] == 1][['model','main_cam_features']].head(30)
# Out:
#                                        model  \
# 19           Apple iPhone 15 Pro (8GB + 1TB)
# 20         Apple iPhone 15 Pro (8GB + 256GB)
# 21         Apple iPhone 15 Pro (8GB + 512GB)
# 25                       Apple iPhone 15 Pro
# 29        Apple iPhone 16 Plus (8GB + 256GB)
# 30        Apple iPhone 16 Plus (8GB + 512GB)
# 31                      Apple iPhone 16 Plus
# 32           Apple iPhone 16 Pro (8GB + 1TB)
# 33         Apple iPhone 16 Pro (8GB + 512GB)
# 34       Apple iPhone 16 Pro Max (8GB + 1TB)
# 35     Apple iPhone 16 Pro Max (8GB + 512GB)
# 36                   Apple iPhone 16 Pro Max
# 37                       Apple iPhone 16 Pro
# 63                  Google Pixel 10 Pro Fold
# 64                    Google Pixel 10 Pro XL
# 65                       Google Pixel 10 Pro
# 66                           Google Pixel 10
# 278      Motorola Edge 50 Pro (12GB + 256GB)
# 279                     Motorola Edge 50 Pro
# 280                   Motorola Edge 50 Ultra
# 345               OnePlus 13R (16GB + 512GB)
# 346                              OnePlus 13R
# 349                OnePlus 15 (16GB + 512GB)
# 350                               OnePlus 15
# 439                         Oppo Find X8 Pro
# 442                         Oppo Find X9 Pro
# 1018     Samsung Galaxy S23 FE (8GB + 256GB)
# 1019                   Samsung Galaxy S23 FE
# 1043  Samsung Galaxy S25 Plus (12GB + 512GB)
# 1044                 Samsung Galaxy S25 Plus
#
#                                                                                                                                                                main_cam_features
# 19             Digital Zoom, Dual LED Flash, Geotagging, HDR (photo/panorama), Laser Auto Focus, Macro Mode, Night Mode, Panorama, Photonic Engine, TOF 3D LiDAR Scanner (Depth)
# 20             Digital Zoom, Dual LED Flash, Geotagging, HDR (photo/panorama), Laser Auto Focus, Macro Mode, Night Mode, Panorama, Photonic Engine, TOF 3D LiDAR Scanner (Depth)
# 21             Digital Zoom, Dual LED Flash, Geotagging, HDR (photo/panorama), Laser Auto Focus, Macro Mode, Night Mode, Panorama, Photonic Engine, TOF 3D LiDAR Scanner (Depth)
# 25             Digital Zoom, Dual LED Flash, Geotagging, HDR (photo/panorama), Laser Auto Focus, Macro Mode, Night Mode, Panorama, Photonic Engine, TOF 3D LiDAR Scanner (Depth)
# 29                                                                                                    Dual LED Dual Tone Flash, HDR (photo/panorama), Laser Auto Focus, Panorama
# 30                                                                                                    Dual LED Dual Tone Flash, HDR (photo/panorama), Laser Auto Focus, Panorama
# 31                                                                                                    Dual LED Dual Tone Flash, HDR (photo/panorama), Laser Auto Focus, Panorama
# 32                                                                                                    Dual LED Dual Tone Flash, HDR (photo/panorama), Laser Auto Focus, Panorama
# 33                                                                                                    Dual LED Dual Tone Flash, HDR (photo/panorama), Laser Auto Focus, Panorama
# 34                                                                                                    Dual LED Dual Tone Flash, HDR (photo/panorama), Laser Auto Focus, Panorama
# 35                                                                                                    Dual LED Dual Tone Flash, HDR (photo/panorama), Laser Auto Focus, Panorama
# 36                                                                                                    Dual LED Dual Tone Flash, HDR (photo/panorama), Laser Auto Focus, Panorama
# 37                                                                                                    Dual LED Dual Tone Flash, HDR (photo/panorama), Laser Auto Focus, Panorama
# 63                                                                                                                 Laser Auto Focus, LED Flash, Panorama, Pixel Shift, Ultra-HDR
# 64                                                                                                                  Laser Auto Focus, LED Fash, Panorama, Pixel Shift, Ultra-HDR
# 65                                                                                                                  Laser Auto Focus, LED Fash, Panorama, Pixel Shift, Ultra-HDR
# 66                                                                                                                  Laser Auto Focus, LED Fash, Panorama, Pixel Shift, Ultra-HDR
# 278                                                                                                                                   HDR, Laser Auto Focus, LED Flash, Panorama
# 279                                                                                                                                   HDR, Laser Auto Focus, LED Flash, Panorama
# 280   Assistive Grid, Audio Zoom, Dual LED Flash, HDR, Laser Auto Focus, Leveler, Long Exposure, Macro, Night Vision, Panorama, Portrait, Pro, Slow Motion, Timelapse, Ultra HDR
# 345                   Dual View, Filter, HDR, Hi-Res Mode, Laser Auto Focus, LED Flash, Long Exposure, Movie, Nightscape, Panorama, Portrait Mode, Pro Mode, Slow-Mo, Time-Lapse
# 346                   Dual View, Filter, HDR, Hi-Res Mode, Laser Auto Focus, LED Flash, Long Exposure, Movie, Nightscape, Panorama, Portrait Mode, Pro Mode, Slow-Mo, Time-Lapse
# 349                                                                                                            Color Spectrum Sensor, HDR, Laser Auto Focus, LED Flash, Panorama
# 350                                                                                                            Color Spectrum Sensor, HDR, Laser Auto Focus, LED Flash, Panorama
# 439                                                                            Colour Spectrum sensor, Hasselblad Colour Calibration, HDR, Laser Auto Focus, LED Flash, Panorama
# 442                                                                              Color Spectrum Sensor, Hasselblad Color Calibration, HDR, Laser Auto Focus, LED Flash, Panorama
# 1018                                                                                                                   Dual LED Dual Tone Flash, HDR, Laser Auto Focus, Panorama
# 1019                                                                                                                   Dual LED Dual Tone Flash, HDR, Laser Auto Focus, Panorama
# 1043                                                 Adaptive VDIS, Auto Focus, Auto-HDR, Continuous Shooting, Expert RAW, HDR, Laser Auto Focus, LED Flash, OIS, Panorama, PDAF
# 1044                                                 Adaptive VDIS, Auto Focus, Auto-HDR, Continuous Shooting, Expert RAW, HDR, Laser Auto Focus, LED Flash, OIS, Panorama, PDAF

# %%
df[df['has_pro_video_features'] == 1][['model','main_cam_features']].head(30)
# Out:
#                                       model  \
# 0             Apple iPhone 14 (6GB + 256GB)
# 1             Apple iPhone 14 (6GB + 512GB)
# 2        Apple iPhone 14 Plus (6GB + 256GB)
# 3        Apple iPhone 14 Plus (6GB + 512GB)
# 4                      Apple iPhone 14 Plus
# 5           Apple iPhone 14 Pro (6GB + 1TB)
# 6         Apple iPhone 14 Pro (6GB + 256GB)
# 7         Apple iPhone 14 Pro (6GB + 512GB)
# 8       Apple iPhone 14 Pro Max (6GB + 1TB)
# 9     Apple iPhone 14 Pro Max (6GB + 256GB)
# 10    Apple iPhone 14 Pro Max (6GB + 512GB)
# 11                  Apple iPhone 14 Pro Max
# 12                      Apple iPhone 14 Pro
# 13                          Apple iPhone 14
# 42            Apple iPhone 17 (8GB + 512GB)
# 43         Apple iPhone 17 Pro (12GB + 1TB)
# 44       Apple iPhone 17 Pro (12GB + 512GB)
# 45     Apple iPhone 17 Pro Max (12GB + 1TB)
# 46     Apple iPhone 17 Pro Max (12GB + 2TB)
# 47   Apple iPhone 17 Pro Max (12GB + 512GB)
# 48                  Apple iPhone 17 Pro Max
# 49                      Apple iPhone 17 Pro
# 50                          Apple iPhone 17
# 51            Apple iPhone Air (12GB + 1TB)
# 52          Apple iPhone Air (12GB + 512GB)
# 53                         Apple iPhone Air
# 107         Infinix Hot 30 5G (4GB + 128GB)
# 108         Infinix Hot 30 5G (8GB + 128GB)
# 109                       Infinix Hot 30 5G
# 116                      Infinix Hot 60i 5G
#
#                                                                                                                                                      main_cam_features
# 0                                                             Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
# 1                                                             Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
# 2                                                             Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
# 3                                                             Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
# 4                                                             Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
# 5                               Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 6                               Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 7                               Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 8                               Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 9                               Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 10                              Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 11                              Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 12                              Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF, TOF 3D LiDAR Scanner (Depth)
# 13                                                            Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
# 42                             Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Optical Zoom, Panorama, Portrait Mode, Slow Motion, Time-Lapse
# 43   Action Mode, Audio Zoom, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Panorama, Slow Motion, Time-lapse, TOF 3D LiDAR Scanner (depth)
# 44   Action Mode, Audio Zoom, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Panorama, Slow Motion, Time-lapse, TOF 3D LiDAR Scanner (depth)
# 45   Action Mode, Audio Zoom, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Panorama, Slow Motion, Time-lapse, TOF 3D LiDAR Scanner (Depth)
# 46   Action Mode, Audio Zoom, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Panorama, Slow Motion, Time-lapse, TOF 3D LiDAR Scanner (Depth)
# 47   Action Mode, Audio Zoom, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Panorama, Slow Motion, Time-lapse, TOF 3D LiDAR Scanner (Depth)
# 48   Action Mode, Audio Zoom, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Panorama, Slow Motion, Time-lapse, TOF 3D LiDAR Scanner (Depth)
# 49   Action Mode, Audio Zoom, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Panorama, Slow Motion, Time-lapse, TOF 3D LiDAR Scanner (depth)
# 50                             Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, Optical Zoom, Panorama, Portrait Mode, Slow Motion, Time-Lapse
# 51       3D (spatial) Audio, Action Mode, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, Night Mode, Panorama, Photonic Engine, Portrait, Slow-Mo, Time-lapse
# 52       3D (spatial) Audio, Action Mode, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, Night Mode, Panorama, Photonic Engine, Portrait, Slow-Mo, Time-lapse
# 53       3D (spatial) Audio, Action Mode, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, Night Mode, Panorama, Photonic Engine, Portrait, Slow-Mo, Time-lapse
# 107                                                                                                Dual View, HDR, Night Mode, Panorama, Portrait Mode, Quad LED Flash
# 108                                                                                                Dual View, HDR, Night Mode, Panorama, Portrait Mode, Quad LED Flash
# 109                                                                                                Dual View, HDR, Night Mode, Panorama, Portrait Mode, Quad LED Flash
# 116                                                                                     Dual LED  Flash, Dual View, HDR, Night, Panorama, PRO, Slow Motion, Time Lapse

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 117 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    model_id                     1268 non-null   int64
#  1    model                        1268 non-null   object
#  2    expert_rating                1268 non-null   int64
#  3    rating                       1268 non-null   float64
#  4    rating_count                 994 non-null    float64
#  5    launch_on                    1268 non-null   datetime64[ns]
#  6    old_price                    844 non-null    float64
#  7    price                        1268 non-null   int64
#  8    launch_price                 1268 non-null   int64
#  9    display_type                 1268 non-null   object
#  10   display_size                 1268 non-null   object
#  11   display_res                  1268 non-null   object
#  12   body_dimension               1268 non-null   object
#  13   weight                       1268 non-null   object
#  14   body_front                   1268 non-null   object
#  15   body_back                    1238 non-null   object
#  16   body_side                    1251 non-null   object
#  17   build_quality                739 non-null    object
#  18   ports                        1268 non-null   object
#  19   ip_rating                    915 non-null    object
#  20   speaker                      1265 non-null   object
#  21   chipset                      1268 non-null   object
#  22   cpu                          1268 non-null   object
#  23   gpu                          1250 non-null   object
#  24   main_cam                     1268 non-null   object
#  25   main_cam2                    1214 non-null   object
#  26   main_cam3                    631 non-null    object
#  27   main_cam_features            1268 non-null   object
#  28   main_video                   1239 non-null   object
#  29   os                           1268 non-null   object
#  30   software_updates             1228 non-null   object
#  31   ai_features                  780 non-null    object
#  32   front_cam                    1268 non-null   object
#  33   front_cam_features           1026 non-null   object
#  34   front_video                  1229 non-null   object
#  35   battery                      1268 non-null   object
#  36   charging                     1268 non-null   object
#  37   storage                      1268 non-null   object
#  38   ram                          1268 non-null   object
#  39   sim                          1264 non-null   object
#  40   tech                         1200 non-null   object
#  41   2g                           1262 non-null   object
#  42   3g                           1264 non-null   object
#  43   4g                           1267 non-null   object
#  44   5g                           1028 non-null   object
#  45   speed                        1264 non-null   object
#  46   wifi                         1268 non-null   object
#  47   bluetooth                    1266 non-null   object
#  48   positioning_system           1268 non-null   object
#  49   nfc                          595 non-null    object
#  50   finger_print                 1192 non-null   object
#  51   sensors                      1268 non-null   object
#  52   add_features                 469 non-null    object
#  53   main_cam4                    48 non-null     object
#  54   front_cam2                   9 non-null      object
#  55   brand                        1268 non-null   category
#  56   is_available                 1268 non-null   int64
#  57   is_flipkart_available        1268 non-null   int64
#  58   is_amazon_available          1268 non-null   int64
#  59   is_official_available        1268 non-null   int64
#  60   display_panel_type           1268 non-null   object
#  61   display_panel_family         1268 non-null   category
#  62   display_hz                   1268 non-null   int64
#  63   display_dynamic_range        1268 non-null   category
#  64   touch_sampling_rate          852 non-null    float64
#  65   has_ltpo                     1268 non-null   int64
#  66   has_anti_reflection_coating  1268 non-null   int64
#  67   display_inches               1268 non-null   float64
#  68   display_body_ratio           1036 non-null   float64
#  69   has_curved                   1268 non-null   int64
#  70   has_foldable                 1268 non-null   int64
#  71   res_category                 1268 non-null   category
#  72   res_width                    1268 non-null   int64
#  73   res_height                   1268 non-null   int64
#  74   aspect_ration_numeric        1185 non-null   float64
#  75   display_ppi                  1268 non-null   float64
#  76   color_depth                  1268 non-null   float64
#  77   peak_brightness              1206 non-null   float64
#  78   has_high_contrast            1268 non-null   int64
#  79   height_mm                    1268 non-null   float64
#  80   width_mm                     1268 non-null   float64
#  81   thickness_mm                 1268 non-null   float64
#  82   weight_g                     1268 non-null   float64
#  83   front_potection              1268 non-null   category
#  84   back_material                1268 non-null   category
#  85   frame_material               1268 non-null   category
#  86   durability_cert              1268 non-null   category
#  87   has_3_5mm_jack               1268 non-null   int64
#  88   usb_type                     1268 non-null   category
#  89   usb_version                  1268 non-null   float64
#  90   has_otg                      1268 non-null   int64
#  91   has_ir_blaster               1268 non-null   int64
#  92   water_resistance_level       1268 non-null   category
#  93   has_stereo_speakers          1268 non-null   int64
#  94   has_audio_certification      1268 non-null   int64
#  95   processor_brand              1268 non-null   category
#  96   chipset_brand                1266 non-null   object
#  97   chipset_nm                   1258 non-null   float64
#  98   antutu_score                 1237 non-null   float64
#  99   cpu_core_count               1268 non-null   int64
#  100  cpu_max_ghz                  1261 non-null   float64
#  101  gpu_brand                    1249 non-null   category
#  102  cam_primary_mp               1268 non-null   int64
#  103  cam_aperture                 1262 non-null   float64
#  104  cam_has_ois                  1268 non-null   int64
#  105  cam_sensor_size              722 non-null    float64
#  106  cam_secondary_mp             1214 non-null   object
#  107  has_telephoto                1268 non-null   int64
#  108  has_periscope                1268 non-null   int64
#  109  cam_optical_zoom             1268 non-null   int64
#  110  cam_tertiary_mp              629 non-null    float64
#  111  total_cam_count              1268 non-null   int64
#  112  cam_fourth_mp                48 non-null     float64
#  113  is_apple_flagship_tech       1268 non-null   int64
#  114  has_laser_af                 1268 non-null   int64
#  115  has_zeiss_optics             1268 non-null   int64
#  116  has_pro_video_features       1268 non-null   int64
# dtypes: category(12), datetime64[ns](1), float64(22), int64(32), object(50)
# memory usage: 1.0+ MB

# %%
df['cam_has_ois'].value_counts()
# Out:
# cam_has_ois
# 0    661
# 1    607
# Name: count, dtype: int64

# %%
df['cam_has_ois'] = ((df['cam_has_ois'] == 1) | df['main_cam_features'].str.contains('OIS', case=False, na=False)).astype(int)

# %%
df['cam_has_ois'].value_counts()
# Out:
# cam_has_ois
# 0    658
# 1    610
# Name: count, dtype: int64

# %%
df['main_video'].sample(20)
# Out:
# 700                                                                       1080p@30fps, Slow Motion
# 455                                                                    1080p@30/60fps, 720p@120fps
# 1155                                                          4K@30fps, 1080p@30fps, gyro-EIS, OIS
# 87                                                              4K@30fps, 1080p@30/60fps, gyro-EIS
# 1225                                                                                   1080p@30fps
# 1109                                                                                      4K@30fps
# 606                                                           4K@30fps, 1080p@30fps, gyro-EIS, OIS
# 1205                                                                                   1080p@30fps
# 773                                                                                 1080p@30/60fps
# 268     8K@24/30fps, 4K@30/60fps, 1080p@30/60/120/240/960fps, 10-bit HDR10+, gyro-EIS, Slow Motion
# 355                                        4K@30fps, 1080p@30/60/120/480fps, gyro-EIS, Slow Motion
# 889                                                                                    1080p@30fps
# 1213                                                                                   1080p@30fps
# 1161                                                       4K@30fps, 1080p@30/60fps, gyro-EIS, OIS
# 660                                                                        1080p@30fps, 720p@30fps
# 372                                              4K@30fps, 1080p@30/60fps, 720p@30/60fps, gyro-EIS
# 988                                                                          1080p@30fps, gyro-EIS
# 478                                                                        1080p@30fps, 720p@30fps
# 1137                                                                                   4K@30/60fps
# 811                                                                                    1080p@30fps
# Name: main_video, dtype: object

# %%
def get_max_resolution(text):
    if pd.isna(text):
      return 'Unknown'

    res_upper = text.upper()

    if '8K' in res_upper:
        return '8K'
    elif '4K' in res_upper:
        return '4K'
    elif '1440p' in res_upper:
        return '1440p'
    elif '1080P' in res_upper:
        return '1080p'
    elif '720P' in res_upper:
        return '720p'
    else:
        return 'Standard'

df['max_video_res'] = df['main_video'].apply(get_max_resolution).astype('category')

# %%
df['max_video_res'].value_counts()
# Out:
# max_video_res
# 4K          579
# 1080p       531
# 8K          112
# Unknown      29
# Standard     17
# Name: count, dtype: int64

# %%
df['video_has_eis'] = df['main_video'].str.contains('EIS', case=True, na=False).astype(int)

# %%
df['video_has_eis'].value_counts()
# Out:
# video_has_eis
# 0    726
# 1    542
# Name: count, dtype: int64

# %%
df['video_is_pro_grade'] = df['main_video'].str.contains(r'Dolby Vision|HDR10\+|10-bit', case=True, na=False).astype('int')

# %%
df['video_is_pro_grade'].value_counts()
# Out:
# video_is_pro_grade
# 0    1093
# 1     175
# Name: count, dtype: int64

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 120 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    model_id                     1268 non-null   int64
#  1    model                        1268 non-null   object
#  2    expert_rating                1268 non-null   int64
#  3    rating                       1268 non-null   float64
#  4    rating_count                 994 non-null    float64
#  5    launch_on                    1268 non-null   datetime64[ns]
#  6    old_price                    844 non-null    float64
#  7    price                        1268 non-null   int64
#  8    launch_price                 1268 non-null   int64
#  9    display_type                 1268 non-null   object
#  10   display_size                 1268 non-null   object
#  11   display_res                  1268 non-null   object
#  12   body_dimension               1268 non-null   object
#  13   weight                       1268 non-null   object
#  14   body_front                   1268 non-null   object
#  15   body_back                    1238 non-null   object
#  16   body_side                    1251 non-null   object
#  17   build_quality                739 non-null    object
#  18   ports                        1268 non-null   object
#  19   ip_rating                    915 non-null    object
#  20   speaker                      1265 non-null   object
#  21   chipset                      1268 non-null   object
#  22   cpu                          1268 non-null   object
#  23   gpu                          1250 non-null   object
#  24   main_cam                     1268 non-null   object
#  25   main_cam2                    1214 non-null   object
#  26   main_cam3                    631 non-null    object
#  27   main_cam_features            1268 non-null   object
#  28   main_video                   1239 non-null   object
#  29   os                           1268 non-null   object
#  30   software_updates             1228 non-null   object
#  31   ai_features                  780 non-null    object
#  32   front_cam                    1268 non-null   object
#  33   front_cam_features           1026 non-null   object
#  34   front_video                  1229 non-null   object
#  35   battery                      1268 non-null   object
#  36   charging                     1268 non-null   object
#  37   storage                      1268 non-null   object
#  38   ram                          1268 non-null   object
#  39   sim                          1264 non-null   object
#  40   tech                         1200 non-null   object
#  41   2g                           1262 non-null   object
#  42   3g                           1264 non-null   object
#  43   4g                           1267 non-null   object
#  44   5g                           1028 non-null   object
#  45   speed                        1264 non-null   object
#  46   wifi                         1268 non-null   object
#  47   bluetooth                    1266 non-null   object
#  48   positioning_system           1268 non-null   object
#  49   nfc                          595 non-null    object
#  50   finger_print                 1192 non-null   object
#  51   sensors                      1268 non-null   object
#  52   add_features                 469 non-null    object
#  53   main_cam4                    48 non-null     object
#  54   front_cam2                   9 non-null      object
#  55   brand                        1268 non-null   category
#  56   is_available                 1268 non-null   int64
#  57   is_flipkart_available        1268 non-null   int64
#  58   is_amazon_available          1268 non-null   int64
#  59   is_official_available        1268 non-null   int64
#  60   display_panel_type           1268 non-null   object
#  61   display_panel_family         1268 non-null   category
#  62   display_hz                   1268 non-null   int64
#  63   display_dynamic_range        1268 non-null   category
#  64   touch_sampling_rate          852 non-null    float64
#  65   has_ltpo                     1268 non-null   int64
#  66   has_anti_reflection_coating  1268 non-null   int64
#  67   display_inches               1268 non-null   float64
#  68   display_body_ratio           1036 non-null   float64
#  69   has_curved                   1268 non-null   int64
#  70   has_foldable                 1268 non-null   int64
#  71   res_category                 1268 non-null   category
#  72   res_width                    1268 non-null   int64
#  73   res_height                   1268 non-null   int64
#  74   aspect_ration_numeric        1185 non-null   float64
#  75   display_ppi                  1268 non-null   float64
#  76   color_depth                  1268 non-null   float64
#  77   peak_brightness              1206 non-null   float64
#  78   has_high_contrast            1268 non-null   int64
#  79   height_mm                    1268 non-null   float64
#  80   width_mm                     1268 non-null   float64
#  81   thickness_mm                 1268 non-null   float64
#  82   weight_g                     1268 non-null   float64
#  83   front_potection              1268 non-null   category
#  84   back_material                1268 non-null   category
#  85   frame_material               1268 non-null   category
#  86   durability_cert              1268 non-null   category
#  87   has_3_5mm_jack               1268 non-null   int64
#  88   usb_type                     1268 non-null   category
#  89   usb_version                  1268 non-null   float64
#  90   has_otg                      1268 non-null   int64
#  91   has_ir_blaster               1268 non-null   int64
#  92   water_resistance_level       1268 non-null   category
#  93   has_stereo_speakers          1268 non-null   int64
#  94   has_audio_certification      1268 non-null   int64
#  95   processor_brand              1268 non-null   category
#  96   chipset_brand                1266 non-null   object
#  97   chipset_nm                   1258 non-null   float64
#  98   antutu_score                 1237 non-null   float64
#  99   cpu_core_count               1268 non-null   int64
#  100  cpu_max_ghz                  1261 non-null   float64
#  101  gpu_brand                    1249 non-null   category
#  102  cam_primary_mp               1268 non-null   int64
#  103  cam_aperture                 1262 non-null   float64
#  104  cam_has_ois                  1268 non-null   int64
#  105  cam_sensor_size              722 non-null    float64
#  106  cam_secondary_mp             1214 non-null   object
#  107  has_telephoto                1268 non-null   int64
#  108  has_periscope                1268 non-null   int64
#  109  cam_optical_zoom             1268 non-null   int64
#  110  cam_tertiary_mp              629 non-null    float64
#  111  total_cam_count              1268 non-null   int64
#  112  cam_fourth_mp                48 non-null     float64
#  113  is_apple_flagship_tech       1268 non-null   int64
#  114  has_laser_af                 1268 non-null   int64
#  115  has_zeiss_optics             1268 non-null   int64
#  116  has_pro_video_features       1268 non-null   int64
#  117  max_video_res                1268 non-null   category
#  118  video_has_eis                1268 non-null   int64
#  119  video_is_pro_grade           1268 non-null   int64
# dtypes: category(13), datetime64[ns](1), float64(22), int64(34), object(50)
# memory usage: 1.1+ MB

# %%
df['os'].sample(20)
# Out:
# 755         Android 14, Realme UI
# 999            Android 14, One UI
# 1012           Android 12, One UI
# 559         Android 13, Realme UI
# 1028           Android 14, One UI
# 850        Android 12, Redmi MIUI
# 673         Android 14, Realme UI
# 444           Android 12, ColorOS
# 381          Android 13, OxygenOS
# 576         Android 14, Realme UI
# 122               Android 12, XOS
# 54             Android 12, ROG UI
# 852        Android 12, Redmi MIUI
# 1074    Android 12, Vivo Funtouch
# 748         Android 14, Realme UI
# 154     Android 13, iQOO Funtouch
# 1023           Android 13, One UI
# 591         Android 15, Realme UI
# 661         Android 14, Realme UI
# 35                         iOS 18
# Name: os, dtype: object

# %%
df['os_type'] = df['os'].str.extract(r'(Android|iOS|google android)')[0].str.lower().astype('category')

# %%
df['os_type'].value_counts(dropna=False)
# Out:
# os_type
# android    1214
# ios          54
# Name: count, dtype: int64

# %%
df['os_version_num'] = df['os'].str.extract(r'(\d+)').astype(float)

# %%
df['os_version_num'].value_counts(dropna=False)
# Out:
# os_version_num
# 14.0    333
# 15.0    315
# 13.0    235
# 12.0    226
# 11.0     78
# 16.0     41
# 18.0     18
# 26.0     12
# 17.0     10
# Name: count, dtype: int64

# %%
df['is_android_go'] = df['os'].str.contains('Go', case=False, na=False).astype(int)

# %%
df['is_android_go'].value_counts()
# Out:
# is_android_go
# 0    1229
# 1      39
# Name: count, dtype: int64

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 123 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    model_id                     1268 non-null   int64
#  1    model                        1268 non-null   object
#  2    expert_rating                1268 non-null   int64
#  3    rating                       1268 non-null   float64
#  4    rating_count                 994 non-null    float64
#  5    launch_on                    1268 non-null   datetime64[ns]
#  6    old_price                    844 non-null    float64
#  7    price                        1268 non-null   int64
#  8    launch_price                 1268 non-null   int64
#  9    display_type                 1268 non-null   object
#  10   display_size                 1268 non-null   object
#  11   display_res                  1268 non-null   object
#  12   body_dimension               1268 non-null   object
#  13   weight                       1268 non-null   object
#  14   body_front                   1268 non-null   object
#  15   body_back                    1238 non-null   object
#  16   body_side                    1251 non-null   object
#  17   build_quality                739 non-null    object
#  18   ports                        1268 non-null   object
#  19   ip_rating                    915 non-null    object
#  20   speaker                      1265 non-null   object
#  21   chipset                      1268 non-null   object
#  22   cpu                          1268 non-null   object
#  23   gpu                          1250 non-null   object
#  24   main_cam                     1268 non-null   object
#  25   main_cam2                    1214 non-null   object
#  26   main_cam3                    631 non-null    object
#  27   main_cam_features            1268 non-null   object
#  28   main_video                   1239 non-null   object
#  29   os                           1268 non-null   object
#  30   software_updates             1228 non-null   object
#  31   ai_features                  780 non-null    object
#  32   front_cam                    1268 non-null   object
#  33   front_cam_features           1026 non-null   object
#  34   front_video                  1229 non-null   object
#  35   battery                      1268 non-null   object
#  36   charging                     1268 non-null   object
#  37   storage                      1268 non-null   object
#  38   ram                          1268 non-null   object
#  39   sim                          1264 non-null   object
#  40   tech                         1200 non-null   object
#  41   2g                           1262 non-null   object
#  42   3g                           1264 non-null   object
#  43   4g                           1267 non-null   object
#  44   5g                           1028 non-null   object
#  45   speed                        1264 non-null   object
#  46   wifi                         1268 non-null   object
#  47   bluetooth                    1266 non-null   object
#  48   positioning_system           1268 non-null   object
#  49   nfc                          595 non-null    object
#  50   finger_print                 1192 non-null   object
#  51   sensors                      1268 non-null   object
#  52   add_features                 469 non-null    object
#  53   main_cam4                    48 non-null     object
#  54   front_cam2                   9 non-null      object
#  55   brand                        1268 non-null   category
#  56   is_available                 1268 non-null   int64
#  57   is_flipkart_available        1268 non-null   int64
#  58   is_amazon_available          1268 non-null   int64
#  59   is_official_available        1268 non-null   int64
#  60   display_panel_type           1268 non-null   object
#  61   display_panel_family         1268 non-null   category
#  62   display_hz                   1268 non-null   int64
#  63   display_dynamic_range        1268 non-null   category
#  64   touch_sampling_rate          852 non-null    float64
#  65   has_ltpo                     1268 non-null   int64
#  66   has_anti_reflection_coating  1268 non-null   int64
#  67   display_inches               1268 non-null   float64
#  68   display_body_ratio           1036 non-null   float64
#  69   has_curved                   1268 non-null   int64
#  70   has_foldable                 1268 non-null   int64
#  71   res_category                 1268 non-null   category
#  72   res_width                    1268 non-null   int64
#  73   res_height                   1268 non-null   int64
#  74   aspect_ration_numeric        1185 non-null   float64
#  75   display_ppi                  1268 non-null   float64
#  76   color_depth                  1268 non-null   float64
#  77   peak_brightness              1206 non-null   float64
#  78   has_high_contrast            1268 non-null   int64
#  79   height_mm                    1268 non-null   float64
#  80   width_mm                     1268 non-null   float64
#  81   thickness_mm                 1268 non-null   float64
#  82   weight_g                     1268 non-null   float64
#  83   front_potection              1268 non-null   category
#  84   back_material                1268 non-null   category
#  85   frame_material               1268 non-null   category
#  86   durability_cert              1268 non-null   category
#  87   has_3_5mm_jack               1268 non-null   int64
#  88   usb_type                     1268 non-null   category
#  89   usb_version                  1268 non-null   float64
#  90   has_otg                      1268 non-null   int64
#  91   has_ir_blaster               1268 non-null   int64
#  92   water_resistance_level       1268 non-null   category
#  93   has_stereo_speakers          1268 non-null   int64
#  94   has_audio_certification      1268 non-null   int64
#  95   processor_brand              1268 non-null   category
#  96   chipset_brand                1266 non-null   object
#  97   chipset_nm                   1258 non-null   float64
#  98   antutu_score                 1237 non-null   float64
#  99   cpu_core_count               1268 non-null   int64
#  100  cpu_max_ghz                  1261 non-null   float64
#  101  gpu_brand                    1249 non-null   category
#  102  cam_primary_mp               1268 non-null   int64
#  103  cam_aperture                 1262 non-null   float64
#  104  cam_has_ois                  1268 non-null   int64
#  105  cam_sensor_size              722 non-null    float64
#  106  cam_secondary_mp             1214 non-null   object
#  107  has_telephoto                1268 non-null   int64
#  108  has_periscope                1268 non-null   int64
#  109  cam_optical_zoom             1268 non-null   int64
#  110  cam_tertiary_mp              629 non-null    float64
#  111  total_cam_count              1268 non-null   int64
#  112  cam_fourth_mp                48 non-null     float64
#  113  is_apple_flagship_tech       1268 non-null   int64
#  114  has_laser_af                 1268 non-null   int64
#  115  has_zeiss_optics             1268 non-null   int64
#  116  has_pro_video_features       1268 non-null   int64
#  117  max_video_res                1268 non-null   category
#  118  video_has_eis                1268 non-null   int64
#  119  video_is_pro_grade           1268 non-null   int64
#  120  os_type                      1268 non-null   category
#  121  os_version_num               1268 non-null   float64
#  122  is_android_go                1268 non-null   int64
# dtypes: category(14), datetime64[ns](1), float64(23), int64(35), object(50)
# memory usage: 1.1+ MB

# %%
df['software_updates'].sample(20)
# Out:
# 73                           7 year(s) of Software and Security updates
# 185     3 year(s) of Software updates and 4 year(s) of Security updates
# 473     3 year(s) of Software updates and 4 year(s) of Security updates
# 516                          2 year(s) of Software and Security updates
# 193     2 year(s) of Software updates and 3 year(s) of Security updates
# 573     2 year(s) of Software updates and 3 year(s) of Security updates
# 219     2 year(s) of Software updates and 3 year(s) of Security updates
# 278     3 year(s) of Software updates and 4 year(s) of Security updates
# 346     4 year(s) of Software updates and 6 year(s) of Security updates
# 412     1 year(s) of Software updates and 2 year(s) of Security updates
# 1053                         7 year(s) of Software and Security updates
# 1016    4 year(s) of Software updates and 5 year(s) of Security updates
# 747     2 year(s) of Software updates and 3 year(s) of Security updates
# 1085    1 year(s) of Software updates and 2 year(s) of Security updates
# 762     2 year(s) of Software updates and 3 year(s) of Security updates
# 234     1 year(s) of Software updates and 3 year(s) of Security updates
# 477     2 year(s) of Software updates and 3 year(s) of Security updates
# 1026                         7 year(s) of Software and Security updates
# 1259    4 year(s) of Software updates and 5 year(s) of Security updates
# 811     2 year(s) of Software updates and 4 year(s) of Security updates
# Name: software_updates, dtype: object

# %%
def get_years(text, keyword):
    if pd.isna(text): return 0

    text = text.lower()

    combined_match = re.search(r'(\d+)\s*year.*?software\s*and\s*security', text)
    if combined_match:
        return float(combined_match.group(1))

    specific_match = re.search(r'(\d+)\s*year.*?' + keyword.lower(), text)
    if specific_match:
        return float(specific_match.group(1))

    return 0

df['os_update_years'] = df['software_updates'].apply(lambda x: get_years(x, 'software'))
df['security_update_years'] = df['software_updates'].apply(lambda x: get_years(x, 'security'))

# %%
df['os_update_years'].value_counts(dropna=False)
# Out:
# os_update_years
# 2.0    540
# 3.0    256
# 4.0    145
# 1.0    102
# 7.0     78
# 0.0     65
# 5.0     44
# 6.0     38
# Name: count, dtype: int64

# %%
df['security_update_years'].value_counts(dropna=False)
# Out:
# security_update_years
# 2.0    554
# 3.0    262
# 4.0    145
# 1.0    107
# 7.0     78
# 5.0     44
# 0.0     40
# 6.0     38
# Name: count, dtype: int64

# %%
df[df['security_update_years'] == 0][['model','software_updates','security_update_years']].head(50)
# Out:
#                                     model software_updates  \
# 111         Infinix Hot 30i (8GB + 128GB)              NaN
# 112                       Infinix Hot 30i              NaN
# 113                       Infinix Hot 40i              NaN
# 134                      Infinix Smart 10              NaN
# 228                Moto E13 (8GB + 128GB)              NaN
# 229                              Moto E13              NaN
# 250         Moto G54 Power (12GB + 256GB)              NaN
# 251                        Moto G54 Power              NaN
# 389             Oppo A3 Pro (8GB + 256GB)              NaN
# 392             Oppo A3x 4G (4GB + 128GB)              NaN
# 421             Oppo F27 5G (8GB + 256GB)              NaN
# 423    Oppo F27 Pro Plus 5G (8GB + 256GB)              NaN
# 430                           Oppo F31 5G              NaN
# 431           Oppo F31 Pro (12GB + 256GB)              NaN
# 432            Oppo F31 Pro (8GB + 256GB)              NaN
# 435                          Oppo F31 Pro              NaN
# 438           Oppo Find X8 (16GB + 512GB)              NaN
# 475         Oppo Reno14 5G (12GB + 512GB)              NaN
# 593   Realme 14 Pro Lite 5G (8GB + 256GB)              NaN
# 636               Realme C31 (4GB + 64GB)              NaN
# 642              Realme C51 (4GB + 128GB)              NaN
# 643                            Realme C51              NaN
# 668           Realme C75 5G (6GB + 128GB)              NaN
# 669                         Realme C75 5G              NaN
# 714     Realme Narzo 60X 5G (6GB + 128GB)              NaN
# 715                   Realme Narzo 60X 5G              NaN
# 767       Realme P3 Pro 5G (12GB + 256GB)              NaN
# 768        Realme P3 Pro 5G (8GB + 256GB)              NaN
# 799               Redmi 12C (6GB + 128GB)              NaN
# 800                             Redmi 12C              NaN
# 823                Redmi A3 (4GB + 128GB)              NaN
# 824                Redmi A3 (6GB + 128GB)              NaN
# 1090                          Vivo T2x 5G              NaN
# 1187                            Vivo Y02t              NaN
# 1188                            Vivo Y100              NaN
# 1220                          Vivo Y28 5G              NaN
# 1233            Vivo Y31 5G (6GB + 128GB)              NaN
# 1234                          Vivo Y31 5G              NaN
# 1239                             Vivo Y36              NaN
# 1247                          Vivo Y58 5G              NaN
#
#       security_update_years
# 111                     0.0
# 112                     0.0
# 113                     0.0
# 134                     0.0
# 228                     0.0
# 229                     0.0
# 250                     0.0
# 251                     0.0
# 389                     0.0
# 392                     0.0
# 421                     0.0
# 423                     0.0
# 430                     0.0
# 431                     0.0
# 432                     0.0
# 435                     0.0
# 438                     0.0
# 475                     0.0
# 593                     0.0
# 636                     0.0
# 642                     0.0
# 643                     0.0
# 668                     0.0
# 669                     0.0
# 714                     0.0
# 715                     0.0
# 767                     0.0
# 768                     0.0
# 799                     0.0
# 800                     0.0
# 823                     0.0
# 824                     0.0
# 1090                    0.0
# 1187                    0.0
# 1188                    0.0
# 1220                    0.0
# 1233                    0.0
# 1234                    0.0
# 1239                    0.0
# 1247                    0.0

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 125 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    model_id                     1268 non-null   int64
#  1    model                        1268 non-null   object
#  2    expert_rating                1268 non-null   int64
#  3    rating                       1268 non-null   float64
#  4    rating_count                 994 non-null    float64
#  5    launch_on                    1268 non-null   datetime64[ns]
#  6    old_price                    844 non-null    float64
#  7    price                        1268 non-null   int64
#  8    launch_price                 1268 non-null   int64
#  9    display_type                 1268 non-null   object
#  10   display_size                 1268 non-null   object
#  11   display_res                  1268 non-null   object
#  12   body_dimension               1268 non-null   object
#  13   weight                       1268 non-null   object
#  14   body_front                   1268 non-null   object
#  15   body_back                    1238 non-null   object
#  16   body_side                    1251 non-null   object
#  17   build_quality                739 non-null    object
#  18   ports                        1268 non-null   object
#  19   ip_rating                    915 non-null    object
#  20   speaker                      1265 non-null   object
#  21   chipset                      1268 non-null   object
#  22   cpu                          1268 non-null   object
#  23   gpu                          1250 non-null   object
#  24   main_cam                     1268 non-null   object
#  25   main_cam2                    1214 non-null   object
#  26   main_cam3                    631 non-null    object
#  27   main_cam_features            1268 non-null   object
#  28   main_video                   1239 non-null   object
#  29   os                           1268 non-null   object
#  30   software_updates             1228 non-null   object
#  31   ai_features                  780 non-null    object
#  32   front_cam                    1268 non-null   object
#  33   front_cam_features           1026 non-null   object
#  34   front_video                  1229 non-null   object
#  35   battery                      1268 non-null   object
#  36   charging                     1268 non-null   object
#  37   storage                      1268 non-null   object
#  38   ram                          1268 non-null   object
#  39   sim                          1264 non-null   object
#  40   tech                         1200 non-null   object
#  41   2g                           1262 non-null   object
#  42   3g                           1264 non-null   object
#  43   4g                           1267 non-null   object
#  44   5g                           1028 non-null   object
#  45   speed                        1264 non-null   object
#  46   wifi                         1268 non-null   object
#  47   bluetooth                    1266 non-null   object
#  48   positioning_system           1268 non-null   object
#  49   nfc                          595 non-null    object
#  50   finger_print                 1192 non-null   object
#  51   sensors                      1268 non-null   object
#  52   add_features                 469 non-null    object
#  53   main_cam4                    48 non-null     object
#  54   front_cam2                   9 non-null      object
#  55   brand                        1268 non-null   category
#  56   is_available                 1268 non-null   int64
#  57   is_flipkart_available        1268 non-null   int64
#  58   is_amazon_available          1268 non-null   int64
#  59   is_official_available        1268 non-null   int64
#  60   display_panel_type           1268 non-null   object
#  61   display_panel_family         1268 non-null   category
#  62   display_hz                   1268 non-null   int64
#  63   display_dynamic_range        1268 non-null   category
#  64   touch_sampling_rate          852 non-null    float64
#  65   has_ltpo                     1268 non-null   int64
#  66   has_anti_reflection_coating  1268 non-null   int64
#  67   display_inches               1268 non-null   float64
#  68   display_body_ratio           1036 non-null   float64
#  69   has_curved                   1268 non-null   int64
#  70   has_foldable                 1268 non-null   int64
#  71   res_category                 1268 non-null   category
#  72   res_width                    1268 non-null   int64
#  73   res_height                   1268 non-null   int64
#  74   aspect_ration_numeric        1185 non-null   float64
#  75   display_ppi                  1268 non-null   float64
#  76   color_depth                  1268 non-null   float64
#  77   peak_brightness              1206 non-null   float64
#  78   has_high_contrast            1268 non-null   int64
#  79   height_mm                    1268 non-null   float64
#  80   width_mm                     1268 non-null   float64
#  81   thickness_mm                 1268 non-null   float64
#  82   weight_g                     1268 non-null   float64
#  83   front_potection              1268 non-null   category
#  84   back_material                1268 non-null   category
#  85   frame_material               1268 non-null   category
#  86   durability_cert              1268 non-null   category
#  87   has_3_5mm_jack               1268 non-null   int64
#  88   usb_type                     1268 non-null   category
#  89   usb_version                  1268 non-null   float64
#  90   has_otg                      1268 non-null   int64
#  91   has_ir_blaster               1268 non-null   int64
#  92   water_resistance_level       1268 non-null   category
#  93   has_stereo_speakers          1268 non-null   int64
#  94   has_audio_certification      1268 non-null   int64
#  95   processor_brand              1268 non-null   category
#  96   chipset_brand                1266 non-null   object
#  97   chipset_nm                   1258 non-null   float64
#  98   antutu_score                 1237 non-null   float64
#  99   cpu_core_count               1268 non-null   int64
#  100  cpu_max_ghz                  1261 non-null   float64
#  101  gpu_brand                    1249 non-null   category
#  102  cam_primary_mp               1268 non-null   int64
#  103  cam_aperture                 1262 non-null   float64
#  104  cam_has_ois                  1268 non-null   int64
#  105  cam_sensor_size              722 non-null    float64
#  106  cam_secondary_mp             1214 non-null   object
#  107  has_telephoto                1268 non-null   int64
#  108  has_periscope                1268 non-null   int64
#  109  cam_optical_zoom             1268 non-null   int64
#  110  cam_tertiary_mp              629 non-null    float64
#  111  total_cam_count              1268 non-null   int64
#  112  cam_fourth_mp                48 non-null     float64
#  113  is_apple_flagship_tech       1268 non-null   int64
#  114  has_laser_af                 1268 non-null   int64
#  115  has_zeiss_optics             1268 non-null   int64
#  116  has_pro_video_features       1268 non-null   int64
#  117  max_video_res                1268 non-null   category
#  118  video_has_eis                1268 non-null   int64
#  119  video_is_pro_grade           1268 non-null   int64
#  120  os_type                      1268 non-null   category
#  121  os_version_num               1268 non-null   float64
#  122  is_android_go                1268 non-null   int64
#  123  os_update_years              1268 non-null   float64
#  124  security_update_years        1268 non-null   float64
# dtypes: category(14), datetime64[ns](1), float64(25), int64(35), object(50)
# memory usage: 1.1+ MB

# %%
df['ai_features'].sample(30)
# Out:
# 303                                                                                 NaN
# 895                                                                           AI Camera
# 404                AI Clarity Enhancer, AI Eraser 2.0, AI Reflection Remover, AI Unblur
# 1144                                                                        AI Portrait
# 671                        AI Eye-Protection Display, AI Smart Charging, realme Next AI
# 506                     AI Album Search, AI Expansion, AI Magic Erase Pro, AI Subtitles
# 1165                   AI Image Expander, AI Portrait, AI SuperLink, AI Ultra HD Pixels
# 919                                                                                 NaN
# 1074                                                                          AI Camera
# 281                      Auto Night Vision, Auto Smile Capture, Google Lens Integration
# 821                                                                           AI Camera
# 313                                                                    Circle to Search
# 1131                                                                          AI Camera
# 1161                                                          AI Best Face, AI Portrait
# 34                                                                   Apple Intelligence
# 806                                                                           AI Camera
# 12                                                                                  NaN
# 613                                              AI Erase, AI Smart Clips, AI Snap Mode
# 876                       AI Clear Capture, AI Cutout, AI Erase Pro, AI Image Expansion
# 81                         Add Me, Best Take, Face Unblur, Magic Editor, Portrait Light
# 813                                                                    AI Erase, AI Sky
# 420                                                                              Eraser
# 931                                                                AI Camera, Galaxy AI
# 219                                                                            AI Erase
# 453                                     AI De-glare, AI Elimination, AI Ultra HD Pixels
# 382                                                                                 NaN
# 625     AI Beauty, AI Night Mode, AI Portrait, AI Scene recognition, Noise Cancellation
# 284                                               AI Experience, Google Gemini, moto AI
# 1056                                                        Circle to Search, Galaxy AI
# 23                                                                   Apple Intelligence
# Name: ai_features, dtype: object

# %%
df['has_gen_ai'] = df['ai_features'].str.contains(r'Galaxy AI|Apple Intelligence|Circle|Eraser|Gemini|Assist|Generative|Summary|Writer|Interpreter|Reimage').astype(float)
df['has_gen_ai'] = df['has_gen_ai'].fillna(0).astype(int)

# %%
df['has_gen_ai'].value_counts(dropna=False)
# Out:
# has_gen_ai
# 0    941
# 1    327
# Name: count, dtype: int64

# %%
df['has_ai_camera'] = df['ai_features'].str.contains(r'AI Camera|AI Beauty|Scene recognition|AI HDR|Portrait').astype(float)
df['has_ai_camera'] = df['has_ai_camera'].fillna(0)

# %%
df['has_ai_camera'].value_counts(dropna=False)
# Out:
# has_ai_camera
# 0.0    876
# 1.0    392
# Name: count, dtype: int64

# %%
# Agar phone Gen-AI hai, toh Basic AI ko 0 kar do taaki overlap na ho
df.loc[df['has_gen_ai'] == 1, 'has_ai_camera'] = 0

# %%
df['has_gen_ai'].value_counts(dropna=False)
# Out:
# has_gen_ai
# 0    941
# 1    327
# Name: count, dtype: int64

# %%
df['has_ai_camera'].value_counts(dropna=False)
# Out:
# has_ai_camera
# 0.0    940
# 1.0    328
# Name: count, dtype: int64

# %%
df['ai_feature_count'] = df['ai_features'].apply(lambda x: len(str(x).split(',')) if pd.notna(x) else 0)

# %%
df['ai_feature_count'] = df['ai_feature_count'].astype(int)

# %%
df['ai_feature_count'].value_counts(dropna=False)
# Out:
# ai_feature_count
# 0     488
# 1     333
# 3     122
# 4     110
# 2     103
# 5      56
# 7      24
# 6      13
# 9      10
# 8       5
# 11      3
# 10      1
# Name: count, dtype: int64

# %%
df[df['ai_feature_count'] == 6][['model','ai_features','has_gen_ai','has_ai_camera']]
# Out:
#                                   model  \
# 170          iQOO Neo 10 (12GB + 256GB)
# 171          iQOO Neo 10 (16GB + 512GB)
# 172           iQOO Neo 10 (8GB + 256GB)
# 182                         iQOO Neo 10
# 345          OnePlus 13R (16GB + 512GB)
# 346                         OnePlus 13R
# 649                          Realme C55
# 1038  Samsung Galaxy S25 (12GB + 512GB)
# 1150        Vivo V40 Pro (12GB + 512GB)
# 1151                       Vivo V40 Pro
# 1155            Vivo V50 (12GB + 512GB)
# 1156             Vivo V50 (8GB + 256GB)
# 1157                           Vivo V50
#
#                                                                                                        ai_features  \
# 170              AI Cut Out, AI Eraser, AI Image Expander, AI Note Assist, Circle to Search, Live Call Translation
# 171              AI Cut Out, AI Eraser, AI Image Expander, AI Note Assist, Circle to Search, Live Call Translation
# 172              AI Cut Out, AI Eraser, AI Image Expander, AI Note Assist, Circle to Search, Live Call Translation
# 182              AI Cut Out, AI Eraser, AI Image Expander, AI Note Assist, Circle to Search, Live Call Translation
# 345             AI Detail Boost, AI Reflection Eraser, AI Unblur, Circle to Search, Intelligent Search, OnePlus AI
# 346             AI Detail Boost, AI Reflection Eraser, AI Unblur, Circle to Search, Intelligent Search, OnePlus AI
# 649                                 AI Beauty, AI Camera, AI HDR, AI Night Mode, AI Portrait, AI Scene Recognition
# 1038                             Browsing assist, Call assist, Chat assist, Interpreter, Note assist, Photo assist
# 1150  AI 3D Studio Lighting, AI Aura Light Portrait, AI Camera, AI Erase, AI Neural Network Unit, AI Photo Enhance
# 1151  AI 3D Studio Lighting, AI Aura Light Portrait, AI Camera, AI Erase, AI Neural Network Unit, AI Photo Enhance
# 1155          AI Eraser 2.0, AI Image Studio, AI SuperLink, AI Transcript, Circle to Search, Live Call Translation
# 1156          AI Eraser 2.0, AI Image Studio, AI SuperLink, AI Transcript, Circle to Search, Live Call Translation
# 1157          AI Eraser 2.0, AI Image Studio, AI SuperLink, AI Transcript, Circle to Search, Live Call Translation
#
#       has_gen_ai  has_ai_camera
# 170            1            0.0
# 171            1            0.0
# 172            1            0.0
# 182            1            0.0
# 345            1            0.0
# 346            1            0.0
# 649            0            1.0
# 1038           1            0.0
# 1150           0            1.0
# 1151           0            1.0
# 1155           1            0.0
# 1156           1            0.0
# 1157           1            0.0

# %%
df['cam_secondary_mp'] = pd.to_numeric(df['cam_secondary_mp'])

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 128 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    model_id                     1268 non-null   int64
#  1    model                        1268 non-null   object
#  2    expert_rating                1268 non-null   int64
#  3    rating                       1268 non-null   float64
#  4    rating_count                 994 non-null    float64
#  5    launch_on                    1268 non-null   datetime64[ns]
#  6    old_price                    844 non-null    float64
#  7    price                        1268 non-null   int64
#  8    launch_price                 1268 non-null   int64
#  9    display_type                 1268 non-null   object
#  10   display_size                 1268 non-null   object
#  11   display_res                  1268 non-null   object
#  12   body_dimension               1268 non-null   object
#  13   weight                       1268 non-null   object
#  14   body_front                   1268 non-null   object
#  15   body_back                    1238 non-null   object
#  16   body_side                    1251 non-null   object
#  17   build_quality                739 non-null    object
#  18   ports                        1268 non-null   object
#  19   ip_rating                    915 non-null    object
#  20   speaker                      1265 non-null   object
#  21   chipset                      1268 non-null   object
#  22   cpu                          1268 non-null   object
#  23   gpu                          1250 non-null   object
#  24   main_cam                     1268 non-null   object
#  25   main_cam2                    1214 non-null   object
#  26   main_cam3                    631 non-null    object
#  27   main_cam_features            1268 non-null   object
#  28   main_video                   1239 non-null   object
#  29   os                           1268 non-null   object
#  30   software_updates             1228 non-null   object
#  31   ai_features                  780 non-null    object
#  32   front_cam                    1268 non-null   object
#  33   front_cam_features           1026 non-null   object
#  34   front_video                  1229 non-null   object
#  35   battery                      1268 non-null   object
#  36   charging                     1268 non-null   object
#  37   storage                      1268 non-null   object
#  38   ram                          1268 non-null   object
#  39   sim                          1264 non-null   object
#  40   tech                         1200 non-null   object
#  41   2g                           1262 non-null   object
#  42   3g                           1264 non-null   object
#  43   4g                           1267 non-null   object
#  44   5g                           1028 non-null   object
#  45   speed                        1264 non-null   object
#  46   wifi                         1268 non-null   object
#  47   bluetooth                    1266 non-null   object
#  48   positioning_system           1268 non-null   object
#  49   nfc                          595 non-null    object
#  50   finger_print                 1192 non-null   object
#  51   sensors                      1268 non-null   object
#  52   add_features                 469 non-null    object
#  53   main_cam4                    48 non-null     object
#  54   front_cam2                   9 non-null      object
#  55   brand                        1268 non-null   category
#  56   is_available                 1268 non-null   int64
#  57   is_flipkart_available        1268 non-null   int64
#  58   is_amazon_available          1268 non-null   int64
#  59   is_official_available        1268 non-null   int64
#  60   display_panel_type           1268 non-null   object
#  61   display_panel_family         1268 non-null   category
#  62   display_hz                   1268 non-null   int64
#  63   display_dynamic_range        1268 non-null   category
#  64   touch_sampling_rate          852 non-null    float64
#  65   has_ltpo                     1268 non-null   int64
#  66   has_anti_reflection_coating  1268 non-null   int64
#  67   display_inches               1268 non-null   float64
#  68   display_body_ratio           1036 non-null   float64
#  69   has_curved                   1268 non-null   int64
#  70   has_foldable                 1268 non-null   int64
#  71   res_category                 1268 non-null   category
#  72   res_width                    1268 non-null   int64
#  73   res_height                   1268 non-null   int64
#  74   aspect_ration_numeric        1185 non-null   float64
#  75   display_ppi                  1268 non-null   float64
#  76   color_depth                  1268 non-null   float64
#  77   peak_brightness              1206 non-null   float64
#  78   has_high_contrast            1268 non-null   int64
#  79   height_mm                    1268 non-null   float64
#  80   width_mm                     1268 non-null   float64
#  81   thickness_mm                 1268 non-null   float64
#  82   weight_g                     1268 non-null   float64
#  83   front_potection              1268 non-null   category
#  84   back_material                1268 non-null   category
#  85   frame_material               1268 non-null   category
#  86   durability_cert              1268 non-null   category
#  87   has_3_5mm_jack               1268 non-null   int64
#  88   usb_type                     1268 non-null   category
#  89   usb_version                  1268 non-null   float64
#  90   has_otg                      1268 non-null   int64
#  91   has_ir_blaster               1268 non-null   int64
#  92   water_resistance_level       1268 non-null   category
#  93   has_stereo_speakers          1268 non-null   int64
#  94   has_audio_certification      1268 non-null   int64
#  95   processor_brand              1268 non-null   category
#  96   chipset_brand                1266 non-null   object
#  97   chipset_nm                   1258 non-null   float64
#  98   antutu_score                 1237 non-null   float64
#  99   cpu_core_count               1268 non-null   int64
#  100  cpu_max_ghz                  1261 non-null   float64
#  101  gpu_brand                    1249 non-null   category
#  102  cam_primary_mp               1268 non-null   int64
#  103  cam_aperture                 1262 non-null   float64
#  104  cam_has_ois                  1268 non-null   int64
#  105  cam_sensor_size              722 non-null    float64
#  106  cam_secondary_mp             1214 non-null   float64
#  107  has_telephoto                1268 non-null   int64
#  108  has_periscope                1268 non-null   int64
#  109  cam_optical_zoom             1268 non-null   int64
#  110  cam_tertiary_mp              629 non-null    float64
#  111  total_cam_count              1268 non-null   int64
#  112  cam_fourth_mp                48 non-null     float64
#  113  is_apple_flagship_tech       1268 non-null   int64
#  114  has_laser_af                 1268 non-null   int64
#  115  has_zeiss_optics             1268 non-null   int64
#  116  has_pro_video_features       1268 non-null   int64
#  117  max_video_res                1268 non-null   category
#  118  video_has_eis                1268 non-null   int64
#  119  video_is_pro_grade           1268 non-null   int64
#  120  os_type                      1268 non-null   category
#  121  os_version_num               1268 non-null   float64
#  122  is_android_go                1268 non-null   int64
#  123  os_update_years              1268 non-null   float64
#  124  security_update_years        1268 non-null   float64
#  125  has_gen_ai                   1268 non-null   int64
#  126  has_ai_camera                1268 non-null   float64
#  127  ai_feature_count             1268 non-null   int64
# dtypes: category(14), datetime64[ns](1), float64(27), int64(37), object(49)
# memory usage: 1.1+ MB

# %%
df['front_cam'].sample(30)
# Out:
# 951                                                           13 MP, f/2.0, 0mm, 1 µm
# 924                                                     13 MP, f/2.2, 1.12 µm, 1/3.1"
# 300                                                           16 MP, f/2.4, 0mm, 1 µm
# 836                                        13 MP, f/2.4, 0mm  (Wide), 1.12 µm, 1/3.1"
# 132                                                   8 MP, f/2.0, 0mm  (Wide), 77.8°
# 740                                                         8 MP, f/2.0, (Wide-angle)
# 754                                           16 MP, f/2.4, 24mm, 83°, 0.8 µm, 1/3.0"
# 729                                                               8 MP, f/2.0, (Wide)
# 493                                                   8 MP, f/2.0, (Wide-angle), 1 µm
# 106                                                                 8 MP, f/1.8, 1 µm
# 996                                                                13 MP, f/2.2, 1 µm
# 1046    12 MP, f/2.2, 26mm  (Wide), 80°, 1.12 µm, 1/4.0", Auto Focus, Dual Pixel PDAF
# 1023                       12 MP, f/2.2, 26mm  (Wide-angle), 1.12 µm, Dual Pixel PDAF
# 167                                                                      16 MP, f/2.5
# 28                                       12 MP, f/1.9, 23mm  (Wide), 1 µm, 1/3", PDAF
# 465                                             50 MP, f/2.0, (Wide), 90°, Auto Focus
# 1214                                                              8 MP, f/1.8, (Wide)
# 559                                                16 MP, f/2.5, 23mm  (Wide), 0.8 µm
# 108                                                         8 MP, f/2.0, (Wide-angle)
# 118                                                                      16 MP, f/2.0
# 613                                                                             50 MP
# 1224                                                     8 MP, f/2.0, (Wide), 0.64 µm
# 194                                                             32 MP, f/2.45, (Wide)
# 779                                              50 MP, f/2.4, (Wide), 86.7°, 1/2.88"
# 155                                                                     16 MP, f/2.45
# 781                                                          8 MP, f/2.0, (Wide), 80°
# 940                                                                 5 MP, f/2.2, 1 µm
# 1083                                                              8 MP, f/1.8, (Wide)
# 1210                                                       16 MP, f/2.0, 28mm  (Wide)
# 320                                50 MP, f/2.2, 24mm  (Wide), 81.2°, 0.8 µm, 1/2.76"
# Name: front_cam, dtype: object

# %%
df['front_cam_mp'] = df['front_cam'].str.split(',').str.get(0).str.strip().str.split(' ').str.get(0).astype(float)

# %%
df['front_cam_mp'].value_counts(dropna=False)
# Out:
# front_cam_mp
# 16.0    316
# 8.0     254
# 32.0    203
# 5.0     122
# 50.0    116
# 13.0     88
# 12.0     82
# 10.0     26
# 20.0     26
# 18.0     12
# 4.0       7
# 42.0      5
# 10.5      4
# 64.0      3
# 40.0      2
# 44.0      2
# Name: count, dtype: int64

# %%
df['is_front_af'] = (df['front_cam'].str.contains('Auto Focus|PDAF|AF') | df['front_cam_features'].str.contains('Auto Focus|PDAF|AF') | df['front_video'].str.contains('Auto Focus|PDAF|AF')).astype(int)

# %%
df['is_front_af'].value_counts()
# Out:
# is_front_af
# 0    1045
# 1     223
# Name: count, dtype: int64

# %%
df['front_eis'] = (df['front_cam'].str.contains(r'EIS|gyro-EIS') | df['front_video'].str.contains(r'EIS|gyro-EIS') | df['front_cam_features'].str.contains(r'EIS|gyro-EIS')).astype(int)

# %%
df['front_eis'].value_counts()
# Out:
# front_eis
# 0    995
# 1    273
# Name: count, dtype: int64

# %%
df['is_dual_front'] = df['front_cam2'].notna().astype(int)

# %%
df['is_dual_front'].value_counts()
# Out:
# is_dual_front
# 0    1259
# 1       9
# Name: count, dtype: int64

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 132 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    model_id                     1268 non-null   int64
#  1    model                        1268 non-null   object
#  2    expert_rating                1268 non-null   int64
#  3    rating                       1268 non-null   float64
#  4    rating_count                 994 non-null    float64
#  5    launch_on                    1268 non-null   datetime64[ns]
#  6    old_price                    844 non-null    float64
#  7    price                        1268 non-null   int64
#  8    launch_price                 1268 non-null   int64
#  9    display_type                 1268 non-null   object
#  10   display_size                 1268 non-null   object
#  11   display_res                  1268 non-null   object
#  12   body_dimension               1268 non-null   object
#  13   weight                       1268 non-null   object
#  14   body_front                   1268 non-null   object
#  15   body_back                    1238 non-null   object
#  16   body_side                    1251 non-null   object
#  17   build_quality                739 non-null    object
#  18   ports                        1268 non-null   object
#  19   ip_rating                    915 non-null    object
#  20   speaker                      1265 non-null   object
#  21   chipset                      1268 non-null   object
#  22   cpu                          1268 non-null   object
#  23   gpu                          1250 non-null   object
#  24   main_cam                     1268 non-null   object
#  25   main_cam2                    1214 non-null   object
#  26   main_cam3                    631 non-null    object
#  27   main_cam_features            1268 non-null   object
#  28   main_video                   1239 non-null   object
#  29   os                           1268 non-null   object
#  30   software_updates             1228 non-null   object
#  31   ai_features                  780 non-null    object
#  32   front_cam                    1268 non-null   object
#  33   front_cam_features           1026 non-null   object
#  34   front_video                  1229 non-null   object
#  35   battery                      1268 non-null   object
#  36   charging                     1268 non-null   object
#  37   storage                      1268 non-null   object
#  38   ram                          1268 non-null   object
#  39   sim                          1264 non-null   object
#  40   tech                         1200 non-null   object
#  41   2g                           1262 non-null   object
#  42   3g                           1264 non-null   object
#  43   4g                           1267 non-null   object
#  44   5g                           1028 non-null   object
#  45   speed                        1264 non-null   object
#  46   wifi                         1268 non-null   object
#  47   bluetooth                    1266 non-null   object
#  48   positioning_system           1268 non-null   object
#  49   nfc                          595 non-null    object
#  50   finger_print                 1192 non-null   object
#  51   sensors                      1268 non-null   object
#  52   add_features                 469 non-null    object
#  53   main_cam4                    48 non-null     object
#  54   front_cam2                   9 non-null      object
#  55   brand                        1268 non-null   category
#  56   is_available                 1268 non-null   int64
#  57   is_flipkart_available        1268 non-null   int64
#  58   is_amazon_available          1268 non-null   int64
#  59   is_official_available        1268 non-null   int64
#  60   display_panel_type           1268 non-null   object
#  61   display_panel_family         1268 non-null   category
#  62   display_hz                   1268 non-null   int64
#  63   display_dynamic_range        1268 non-null   category
#  64   touch_sampling_rate          852 non-null    float64
#  65   has_ltpo                     1268 non-null   int64
#  66   has_anti_reflection_coating  1268 non-null   int64
#  67   display_inches               1268 non-null   float64
#  68   display_body_ratio           1036 non-null   float64
#  69   has_curved                   1268 non-null   int64
#  70   has_foldable                 1268 non-null   int64
#  71   res_category                 1268 non-null   category
#  72   res_width                    1268 non-null   int64
#  73   res_height                   1268 non-null   int64
#  74   aspect_ration_numeric        1185 non-null   float64
#  75   display_ppi                  1268 non-null   float64
#  76   color_depth                  1268 non-null   float64
#  77   peak_brightness              1206 non-null   float64
#  78   has_high_contrast            1268 non-null   int64
#  79   height_mm                    1268 non-null   float64
#  80   width_mm                     1268 non-null   float64
#  81   thickness_mm                 1268 non-null   float64
#  82   weight_g                     1268 non-null   float64
#  83   front_potection              1268 non-null   category
#  84   back_material                1268 non-null   category
#  85   frame_material               1268 non-null   category
#  86   durability_cert              1268 non-null   category
#  87   has_3_5mm_jack               1268 non-null   int64
#  88   usb_type                     1268 non-null   category
#  89   usb_version                  1268 non-null   float64
#  90   has_otg                      1268 non-null   int64
#  91   has_ir_blaster               1268 non-null   int64
#  92   water_resistance_level       1268 non-null   category
#  93   has_stereo_speakers          1268 non-null   int64
#  94   has_audio_certification      1268 non-null   int64
#  95   processor_brand              1268 non-null   category
#  96   chipset_brand                1266 non-null   object
#  97   chipset_nm                   1258 non-null   float64
#  98   antutu_score                 1237 non-null   float64
#  99   cpu_core_count               1268 non-null   int64
#  100  cpu_max_ghz                  1261 non-null   float64
#  101  gpu_brand                    1249 non-null   category
#  102  cam_primary_mp               1268 non-null   int64
#  103  cam_aperture                 1262 non-null   float64
#  104  cam_has_ois                  1268 non-null   int64
#  105  cam_sensor_size              722 non-null    float64
#  106  cam_secondary_mp             1214 non-null   float64
#  107  has_telephoto                1268 non-null   int64
#  108  has_periscope                1268 non-null   int64
#  109  cam_optical_zoom             1268 non-null   int64
#  110  cam_tertiary_mp              629 non-null    float64
#  111  total_cam_count              1268 non-null   int64
#  112  cam_fourth_mp                48 non-null     float64
#  113  is_apple_flagship_tech       1268 non-null   int64
#  114  has_laser_af                 1268 non-null   int64
#  115  has_zeiss_optics             1268 non-null   int64
#  116  has_pro_video_features       1268 non-null   int64
#  117  max_video_res                1268 non-null   category
#  118  video_has_eis                1268 non-null   int64
#  119  video_is_pro_grade           1268 non-null   int64
#  120  os_type                      1268 non-null   category
#  121  os_version_num               1268 non-null   float64
#  122  is_android_go                1268 non-null   int64
#  123  os_update_years              1268 non-null   float64
#  124  security_update_years        1268 non-null   float64
#  125  has_gen_ai                   1268 non-null   int64
#  126  has_ai_camera                1268 non-null   float64
#  127  ai_feature_count             1268 non-null   int64
#  128  front_cam_mp                 1268 non-null   float64
#  129  is_front_af                  1268 non-null   int64
#  130  front_eis                    1268 non-null   int64
#  131  is_dual_front                1268 non-null   int64
# dtypes: category(14), datetime64[ns](1), float64(28), int64(40), object(49)
# memory usage: 1.2+ MB

# %%
df['front_cam_features'].sample(30)
# Out:
# 240                                      Auto Smile Capture, Dual Video, Filters, Gesture Selfie, HdR, Portrait Mode, Pro Mode
# 1011                                                                                                                       HdR
# 1077                                                                                                               Face Unlock
# 574                                   AI Beauty Mode, AI Scene Recognition, Face recognition, Filters, Panorama, Portrait Mode
# 1145                                                                         Dual-LED Flash, Face Unlock, HDR, Night, Portrait
# 622     Bokeh Effect Control, Face recognition, Face unlock, Filters, HdR, Night mode, panorama, Panoramic View, Portrait Mode
# 174                                                                                 Night, panorama, Portrait, Pro, Time Lapse
# 682                                                                                                                        NaN
# 754                                                                                      Dual Video, Portrait Mode, Time Lapse
# 1051                                                                                                                       HDR
# 547                                                                                                                        NaN
# 679                                                                                                                Face Unlock
# 262                                                                                                           EIS, Fixed Focus
# 90                                                                                                            Face unlock, HDR
# 517                                                                                                           Face unlock, HdR
# 872                                                                                                 Face Unlock, HDR, Panorama
# 1257                                            AI Face Unlock, AI portrait mode, HdR, panorama, Selfie Night Mode, Time Lapse
# 645                                                              AI Beauty Mode, Face recognition, Filters, HDR, Portrait Mode
# 453                                                                      Face Unlock, Night Mode, Panorama, Portrait, Pro Mode
# 507                                                 Face Unlock, HDR, Night mode, Palm Shutter, Panorama, Portrait, Time Lapse
# 1135                                                                                                                       NaN
# 1210                                                                                              Face unlock, Night, Portrait
# 111                                                      AI Beauty Mode, Dual LED Flash, Night mode, Portrait Mode, Time Lapse
# 363                                                                                                                   Portrait
# 916                                                                                                                        NaN
# 77                                                                                                  Face Unlock, HDR, Panorama
# 2                                                                                        Auto Focus, Cinematic mode (4k@30fps)
# 665                                                                                                              HDR, Panorama
# 428                                                                                                           Face Unlock, HDR
# 590                                                                                          Face Unlock, Night Mode, Panorama
# Name: front_cam_features, dtype: object

# %%
df['has_front_pro_features'] = (df['front_cam_features'].str.contains(r'Dual-view Video|Dual Video|Cinematic|Time-lapse|Pro|Dolby Vision|HDR10\+|Eye Auto Focus|Eye AF|ProRes|3D \(spatial\)', case=False, na=False) |
                                df['front_video'].str.contains(r'Dual-view Video|Dual Video|Cinematic|Time-lapse|Pro|Dolby Vision|HDR10\+|Eye Auto Focus|Eye AF|ProRes|3D \(spatial\)', case=False, na=False)).astype(int)

# %%
df['has_front_pro_features'].value_counts()
# Out:
# has_front_pro_features
# 0    967
# 1    301
# Name: count, dtype: int64

# %%
df['has_front_flash'] = df['front_cam_features'].str.contains('Flash', case=False, na=False).astype(int)

# %%
df['has_front_flash'].value_counts()
# Out:
# has_front_flash
# 0    1191
# 1      77
# Name: count, dtype: int64

# %%
df['is_zeiss_front'] = (df['front_cam_features'].str.contains('Zeiss',case=False, na=False) | df['front_video'].str.contains('Zeiss',case=False, na=False)).astype(int)

# %%
df['is_zeiss_front'].value_counts()
# Out:
# is_zeiss_front
# 0    1256
# 1      12
# Name: count, dtype: int64

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 135 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    model_id                     1268 non-null   int64
#  1    model                        1268 non-null   object
#  2    expert_rating                1268 non-null   int64
#  3    rating                       1268 non-null   float64
#  4    rating_count                 994 non-null    float64
#  5    launch_on                    1268 non-null   datetime64[ns]
#  6    old_price                    844 non-null    float64
#  7    price                        1268 non-null   int64
#  8    launch_price                 1268 non-null   int64
#  9    display_type                 1268 non-null   object
#  10   display_size                 1268 non-null   object
#  11   display_res                  1268 non-null   object
#  12   body_dimension               1268 non-null   object
#  13   weight                       1268 non-null   object
#  14   body_front                   1268 non-null   object
#  15   body_back                    1238 non-null   object
#  16   body_side                    1251 non-null   object
#  17   build_quality                739 non-null    object
#  18   ports                        1268 non-null   object
#  19   ip_rating                    915 non-null    object
#  20   speaker                      1265 non-null   object
#  21   chipset                      1268 non-null   object
#  22   cpu                          1268 non-null   object
#  23   gpu                          1250 non-null   object
#  24   main_cam                     1268 non-null   object
#  25   main_cam2                    1214 non-null   object
#  26   main_cam3                    631 non-null    object
#  27   main_cam_features            1268 non-null   object
#  28   main_video                   1239 non-null   object
#  29   os                           1268 non-null   object
#  30   software_updates             1228 non-null   object
#  31   ai_features                  780 non-null    object
#  32   front_cam                    1268 non-null   object
#  33   front_cam_features           1026 non-null   object
#  34   front_video                  1229 non-null   object
#  35   battery                      1268 non-null   object
#  36   charging                     1268 non-null   object
#  37   storage                      1268 non-null   object
#  38   ram                          1268 non-null   object
#  39   sim                          1264 non-null   object
#  40   tech                         1200 non-null   object
#  41   2g                           1262 non-null   object
#  42   3g                           1264 non-null   object
#  43   4g                           1267 non-null   object
#  44   5g                           1028 non-null   object
#  45   speed                        1264 non-null   object
#  46   wifi                         1268 non-null   object
#  47   bluetooth                    1266 non-null   object
#  48   positioning_system           1268 non-null   object
#  49   nfc                          595 non-null    object
#  50   finger_print                 1192 non-null   object
#  51   sensors                      1268 non-null   object
#  52   add_features                 469 non-null    object
#  53   main_cam4                    48 non-null     object
#  54   front_cam2                   9 non-null      object
#  55   brand                        1268 non-null   category
#  56   is_available                 1268 non-null   int64
#  57   is_flipkart_available        1268 non-null   int64
#  58   is_amazon_available          1268 non-null   int64
#  59   is_official_available        1268 non-null   int64
#  60   display_panel_type           1268 non-null   object
#  61   display_panel_family         1268 non-null   category
#  62   display_hz                   1268 non-null   int64
#  63   display_dynamic_range        1268 non-null   category
#  64   touch_sampling_rate          852 non-null    float64
#  65   has_ltpo                     1268 non-null   int64
#  66   has_anti_reflection_coating  1268 non-null   int64
#  67   display_inches               1268 non-null   float64
#  68   display_body_ratio           1036 non-null   float64
#  69   has_curved                   1268 non-null   int64
#  70   has_foldable                 1268 non-null   int64
#  71   res_category                 1268 non-null   category
#  72   res_width                    1268 non-null   int64
#  73   res_height                   1268 non-null   int64
#  74   aspect_ration_numeric        1185 non-null   float64
#  75   display_ppi                  1268 non-null   float64
#  76   color_depth                  1268 non-null   float64
#  77   peak_brightness              1206 non-null   float64
#  78   has_high_contrast            1268 non-null   int64
#  79   height_mm                    1268 non-null   float64
#  80   width_mm                     1268 non-null   float64
#  81   thickness_mm                 1268 non-null   float64
#  82   weight_g                     1268 non-null   float64
#  83   front_potection              1268 non-null   category
#  84   back_material                1268 non-null   category
#  85   frame_material               1268 non-null   category
#  86   durability_cert              1268 non-null   category
#  87   has_3_5mm_jack               1268 non-null   int64
#  88   usb_type                     1268 non-null   category
#  89   usb_version                  1268 non-null   float64
#  90   has_otg                      1268 non-null   int64
#  91   has_ir_blaster               1268 non-null   int64
#  92   water_resistance_level       1268 non-null   category
#  93   has_stereo_speakers          1268 non-null   int64
#  94   has_audio_certification      1268 non-null   int64
#  95   processor_brand              1268 non-null   category
#  96   chipset_brand                1266 non-null   object
#  97   chipset_nm                   1258 non-null   float64
#  98   antutu_score                 1237 non-null   float64
#  99   cpu_core_count               1268 non-null   int64
#  100  cpu_max_ghz                  1261 non-null   float64
#  101  gpu_brand                    1249 non-null   category
#  102  cam_primary_mp               1268 non-null   int64
#  103  cam_aperture                 1262 non-null   float64
#  104  cam_has_ois                  1268 non-null   int64
#  105  cam_sensor_size              722 non-null    float64
#  106  cam_secondary_mp             1214 non-null   float64
#  107  has_telephoto                1268 non-null   int64
#  108  has_periscope                1268 non-null   int64
#  109  cam_optical_zoom             1268 non-null   int64
#  110  cam_tertiary_mp              629 non-null    float64
#  111  total_cam_count              1268 non-null   int64
#  112  cam_fourth_mp                48 non-null     float64
#  113  is_apple_flagship_tech       1268 non-null   int64
#  114  has_laser_af                 1268 non-null   int64
#  115  has_zeiss_optics             1268 non-null   int64
#  116  has_pro_video_features       1268 non-null   int64
#  117  max_video_res                1268 non-null   category
#  118  video_has_eis                1268 non-null   int64
#  119  video_is_pro_grade           1268 non-null   int64
#  120  os_type                      1268 non-null   category
#  121  os_version_num               1268 non-null   float64
#  122  is_android_go                1268 non-null   int64
#  123  os_update_years              1268 non-null   float64
#  124  security_update_years        1268 non-null   float64
#  125  has_gen_ai                   1268 non-null   int64
#  126  has_ai_camera                1268 non-null   float64
#  127  ai_feature_count             1268 non-null   int64
#  128  front_cam_mp                 1268 non-null   float64
#  129  is_front_af                  1268 non-null   int64
#  130  front_eis                    1268 non-null   int64
#  131  is_dual_front                1268 non-null   int64
#  132  has_front_pro_features       1268 non-null   int64
#  133  has_front_flash              1268 non-null   int64
#  134  is_zeiss_front               1268 non-null   int64
# dtypes: category(14), datetime64[ns](1), float64(28), int64(43), object(49)
# memory usage: 1.2+ MB

# %%
df['front_video'].sample(30)
# Out:
# 748                                                                                                                               1080p@30fps, 720@30fps
# 1094                                                                                                                                         1080p@30fps
# 1152                                                                                                                                         1080p@30fps
# 892                                                                                                                                          1080p@30fps
# 388                                                                                                                           1080/720p@30fps, 720@30fps
# 1128                                                                                                                                         1080p@30fps
# 586                                                                                                                                1080p@30fps, 4k@30fps
# 790                                                                                                                                          1080p@30fps
# 1132                                                                                                                  1080p@30fps, 4K@30/60fps, gyro-EIS
# 1107                                                                                                                                           Supported
# 864                                                                                                                                       1080p@30/60fps
# 20                                                                            1080p@25/30/60/120fps, 4K@24/25/30/60fps, gyro-EIS, ProRes Video Recording
# 587                                                                                                                     1080p@30fps, 4k@30fps, 720@30fps
# 594                                                                                                                     1080@30fps, 4k@30fps, 720p@30fps
# 807                                                                                                                              1080p@30fps, 720p@30fps
# 996                                                                                                                                          1080p@30fps
# 1139                                                                                                                                         1080p@30fps
# 1252                                                                                                                                         1080p@30fps
# 198                                                                                                                                          1080p@30fps
# 172                                                                                                                                          1080p@30fps
# 841                                                                                                                                          1080p@30fps
# 210                                                                                                                                          1080p@30fps
# 1216                                                                                                                                         1080p@30fps
# 521                                                                                                                                          1080p@30fps
# 650                                                                                                                                           720p@30fps
# 1134                                                                                                                               1080p@30fps, gyro-EIS
# 69                                                                                                                                        1080p@30/60fps
# 209                                                                                                                                          1080p@30fps
# 50      1080p@25/30/60/120fps, 4K@24/25/30/60fps, Cinematic Mode (4k@30fps), Cinematic Video Stabilisation, gyro-EIS, Stereo Sound Recording, Time Lapse
# 629                                                                                                                                          1080p@30fps
# Name: front_video, dtype: object

# %%
df['max_video_res'].value_counts()
# Out:
# max_video_res
# 4K          579
# 1080p       531
# 8K          112
# Unknown      29
# Standard     17
# Name: count, dtype: int64

# %%
def max_front_video_res(text):

  if pd.isna(text):
    return 'unknown'

  t = text.lower()

  if '8k' in t:
        return '8K'
  elif '4k' in t:
      return '4K'
  elif '1080p' in t or '1080' in t:
      return '1080p'
  else:
      return 'standard'

df['max_front_video_res'] = df['front_video'].apply(max_front_video_res).astype('category')

# %%
df['max_front_video_res'].value_counts()
# Out:
# max_front_video_res
# 1080p       910
# 4K          206
# standard    110
# unknown      39
# 8K            3
# Name: count, dtype: int64

# %%
df[['model','front_video','max_front_video_res']].sample(20)
# Out:
#                                         model  \
# 211                 iQOO Z7 Pro (8GB + 256GB)
# 516                     Poco M5 (6GB + 128GB)
# 762                Realme P3 5G (8GB + 128GB)
# 797                 Redmi 12 5G (8GB + 256GB)
# 985                     Samsung Galaxy M15 5G
# 856                 Redmi Note 12 Pro Plus 5G
# 328             OnePlus 10T 5G (12GB + 256GB)
# 356                           OnePlus Nord 2T
# 36                    Apple iPhone 16 Pro Max
# 639                                Realme C33
# 1002      Samsung Galaxy M53 5G (8GB + 128GB)
# 749         Realme Narzo N65 5G (8GB + 128GB)
# 1136              Vivo V29 Pro (12GB + 256GB)
# 1132               Vivo V27 Pro (8GB + 256GB)
# 637                                Realme C31
# 1035  Samsung Galaxy S24 Ultra (12GB + 512GB)
# 440                              Oppo Find X8
# 152                         Infinix Zero Flip
# 499                 POCO C85 5G (6GB + 128GB)
# 1236                          Vivo Y31 Pro 5G
#
#                                                    front_video  \
# 211                                                1080p@30fps
# 516                                                1080p@30fps
# 762                                                 1080@30fps
# 797                                                1080p@30fps
# 985                                                1080p@30fps
# 856                                             1080p@30/60fps
# 328                                                1080p@30fps
# 356                                      1080p@30fps, gyro-EIS
# 36    1080p@25/30/60fps, 4K@24/25/30/60fps, 8k@60fps, gyro-EIS
# 639                                                 720p@30fps
# 1002                                     1080p@30fps, 4K@30fps
# 749                                     1080p@30fps, 720@30fps
# 1136                                                  4k@30fps
# 1132                        1080p@30fps, 4K@30/60fps, gyro-EIS
# 637                                                 720p@30fps
# 1035                                     1080p@30fps, gyro-EIS
# 440                                   1080p@30/60fps, gyro-EIS
# 152                                         1080p@30/60/120fps
# 499                                                1080p@30fps
# 1236                                                       NaN
#
#      max_front_video_res
# 211                1080p
# 516                1080p
# 762                1080p
# 797                1080p
# 985                1080p
# 856                1080p
# 328                1080p
# 356                1080p
# 36                    8K
# 639             standard
# 1002                  4K
# 749                1080p
# 1136                  4K
# 1132                  4K
# 637             standard
# 1035               1080p
# 440                1080p
# 152                1080p
# 499                1080p
# 1236             unknown

# %%
df['battery'].sample(20)
# Out:
# 1234        6500 mAh, Lithium Ion (Non-removable)
# 748     5000 mAh, Lithium Polymer (Non-removable)
# 522     5000 mAh, Lithium Polymer (Non-removable)
# 1255    5000 mAh, Lithium Polymer (Non-removable)
# 812      7000 mAh, Silicon Carbon (Non-removable)
# 1040        3900 mAh, Lithium Ion (Non-removable)
# 710     5000 mAh, Lithium Polymer (Non-removable)
# 671     5500 mAh, Lithium Polymer (Non-removable)
# 975         5000 mAh, Lithium Ion (Non-removable)
# 981     6000 mAh, Lithium Polymer (Non-removable)
# 377     7100 mAh, Lithium Polymer (Non-removable)
# 1215        5000 mAh, Lithium Ion (Non-removable)
# 372     5500 mAh, Lithium Polymer (Non-removable)
# 398         5800 mAh, Lithium Ion (Non-removable)
# 924     5000 mAh, Lithium Polymer (Non-removable)
# 1054    4000 mAh, Lithium Polymer (Non-removable)
# 301     5000 mAh, Lithium Polymer (Non-removable)
# 201     5000 mAh, Lithium Polymer (Non-removable)
# 466      6200 mAh, Silicon Carbon (Non-removable)
# 800     5000 mAh, Lithium Polymer (Non-removable)
# Name: battery, dtype: object

# %%
df['battery_mah'] = df['battery'].str.split(',').str.get(0).str.strip().str.split(' ').str.get(0).astype(int)

# %%
df['battery_mah'].value_counts(dropna=False)
# Out:
# battery_mah
# 5000    598
# 6000    137
# 5500     68
# 7000     60
# 4500     51
#        ...
# 4230      1
# 6510      1
# 4820      1
# 5410      1
# 5240      1
# Name: count, Length: 87, dtype: int64

# %%
df['battery_mah'].describe()
# Out:
# count    1268.000000
# mean     5222.625394
# std       741.887845
# min      3149.000000
# 25%      5000.000000
# 50%      5000.000000
# 75%      5500.000000
# max      7550.000000
# Name: battery_mah, dtype: float64

# %%
def battery_type(text):

  t = text.lower()

  if 'lithium polymer' in t:
    return 'lithium polymer'

  if 'lithium ion' in t:
    return 'lithium ion'

  if 'silicon carbon' in t:
    return 'silicon carbon'

  if 'semi-solid state' in t:
    return 'semi solid state'

  return 'unknown'

df['battery_type'] = df['battery'].apply(battery_type)

# %%
df.loc[[1056,1057], 'battery_type'] = 'lithium polymer'

# %%
df.loc[df['battery_type'] == 'unknown','battery_type'] = 'lithium polymer'
df.loc[df['battery_type'] == 'semi solid state','battery_type'] = 'lithium polymer'

# %%
df['battery_type'].value_counts()
# Out:
# battery_type
# lithium polymer    850
# lithium ion        321
# silicon carbon      97
# Name: count, dtype: int64

# %%
df['battery_type'] = df['battery_type'].astype('category')

# %%
df.info(verbose=True , show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 138 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    model_id                     1268 non-null   int64
#  1    model                        1268 non-null   object
#  2    expert_rating                1268 non-null   int64
#  3    rating                       1268 non-null   float64
#  4    rating_count                 994 non-null    float64
#  5    launch_on                    1268 non-null   datetime64[ns]
#  6    old_price                    844 non-null    float64
#  7    price                        1268 non-null   int64
#  8    launch_price                 1268 non-null   int64
#  9    display_type                 1268 non-null   object
#  10   display_size                 1268 non-null   object
#  11   display_res                  1268 non-null   object
#  12   body_dimension               1268 non-null   object
#  13   weight                       1268 non-null   object
#  14   body_front                   1268 non-null   object
#  15   body_back                    1238 non-null   object
#  16   body_side                    1251 non-null   object
#  17   build_quality                739 non-null    object
#  18   ports                        1268 non-null   object
#  19   ip_rating                    915 non-null    object
#  20   speaker                      1265 non-null   object
#  21   chipset                      1268 non-null   object
#  22   cpu                          1268 non-null   object
#  23   gpu                          1250 non-null   object
#  24   main_cam                     1268 non-null   object
#  25   main_cam2                    1214 non-null   object
#  26   main_cam3                    631 non-null    object
#  27   main_cam_features            1268 non-null   object
#  28   main_video                   1239 non-null   object
#  29   os                           1268 non-null   object
#  30   software_updates             1228 non-null   object
#  31   ai_features                  780 non-null    object
#  32   front_cam                    1268 non-null   object
#  33   front_cam_features           1026 non-null   object
#  34   front_video                  1229 non-null   object
#  35   battery                      1268 non-null   object
#  36   charging                     1268 non-null   object
#  37   storage                      1268 non-null   object
#  38   ram                          1268 non-null   object
#  39   sim                          1264 non-null   object
#  40   tech                         1200 non-null   object
#  41   2g                           1262 non-null   object
#  42   3g                           1264 non-null   object
#  43   4g                           1267 non-null   object
#  44   5g                           1028 non-null   object
#  45   speed                        1264 non-null   object
#  46   wifi                         1268 non-null   object
#  47   bluetooth                    1266 non-null   object
#  48   positioning_system           1268 non-null   object
#  49   nfc                          595 non-null    object
#  50   finger_print                 1192 non-null   object
#  51   sensors                      1268 non-null   object
#  52   add_features                 469 non-null    object
#  53   main_cam4                    48 non-null     object
#  54   front_cam2                   9 non-null      object
#  55   brand                        1268 non-null   category
#  56   is_available                 1268 non-null   int64
#  57   is_flipkart_available        1268 non-null   int64
#  58   is_amazon_available          1268 non-null   int64
#  59   is_official_available        1268 non-null   int64
#  60   display_panel_type           1268 non-null   object
#  61   display_panel_family         1268 non-null   category
#  62   display_hz                   1268 non-null   int64
#  63   display_dynamic_range        1268 non-null   category
#  64   touch_sampling_rate          852 non-null    float64
#  65   has_ltpo                     1268 non-null   int64
#  66   has_anti_reflection_coating  1268 non-null   int64
#  67   display_inches               1268 non-null   float64
#  68   display_body_ratio           1036 non-null   float64
#  69   has_curved                   1268 non-null   int64
#  70   has_foldable                 1268 non-null   int64
#  71   res_category                 1268 non-null   category
#  72   res_width                    1268 non-null   int64
#  73   res_height                   1268 non-null   int64
#  74   aspect_ration_numeric        1185 non-null   float64
#  75   display_ppi                  1268 non-null   float64
#  76   color_depth                  1268 non-null   float64
#  77   peak_brightness              1206 non-null   float64
#  78   has_high_contrast            1268 non-null   int64
#  79   height_mm                    1268 non-null   float64
#  80   width_mm                     1268 non-null   float64
#  81   thickness_mm                 1268 non-null   float64
#  82   weight_g                     1268 non-null   float64
#  83   front_potection              1268 non-null   category
#  84   back_material                1268 non-null   category
#  85   frame_material               1268 non-null   category
#  86   durability_cert              1268 non-null   category
#  87   has_3_5mm_jack               1268 non-null   int64
#  88   usb_type                     1268 non-null   category
#  89   usb_version                  1268 non-null   float64
#  90   has_otg                      1268 non-null   int64
#  91   has_ir_blaster               1268 non-null   int64
#  92   water_resistance_level       1268 non-null   category
#  93   has_stereo_speakers          1268 non-null   int64
#  94   has_audio_certification      1268 non-null   int64
#  95   processor_brand              1268 non-null   category
#  96   chipset_brand                1266 non-null   object
#  97   chipset_nm                   1258 non-null   float64
#  98   antutu_score                 1237 non-null   float64
#  99   cpu_core_count               1268 non-null   int64
#  100  cpu_max_ghz                  1261 non-null   float64
#  101  gpu_brand                    1249 non-null   category
#  102  cam_primary_mp               1268 non-null   int64
#  103  cam_aperture                 1262 non-null   float64
#  104  cam_has_ois                  1268 non-null   int64
#  105  cam_sensor_size              722 non-null    float64
#  106  cam_secondary_mp             1214 non-null   float64
#  107  has_telephoto                1268 non-null   int64
#  108  has_periscope                1268 non-null   int64
#  109  cam_optical_zoom             1268 non-null   int64
#  110  cam_tertiary_mp              629 non-null    float64
#  111  total_cam_count              1268 non-null   int64
#  112  cam_fourth_mp                48 non-null     float64
#  113  is_apple_flagship_tech       1268 non-null   int64
#  114  has_laser_af                 1268 non-null   int64
#  115  has_zeiss_optics             1268 non-null   int64
#  116  has_pro_video_features       1268 non-null   int64
#  117  max_video_res                1268 non-null   category
#  118  video_has_eis                1268 non-null   int64
#  119  video_is_pro_grade           1268 non-null   int64
#  120  os_type                      1268 non-null   category
#  121  os_version_num               1268 non-null   float64
#  122  is_android_go                1268 non-null   int64
#  123  os_update_years              1268 non-null   float64
#  124  security_update_years        1268 non-null   float64
#  125  has_gen_ai                   1268 non-null   int64
#  126  has_ai_camera                1268 non-null   float64
#  127  ai_feature_count             1268 non-null   int64
#  128  front_cam_mp                 1268 non-null   float64
#  129  is_front_af                  1268 non-null   int64
#  130  front_eis                    1268 non-null   int64
#  131  is_dual_front                1268 non-null   int64
#  132  has_front_pro_features       1268 non-null   int64
#  133  has_front_flash              1268 non-null   int64
#  134  is_zeiss_front               1268 non-null   int64
#  135  max_front_video_res          1268 non-null   category
#  136  battery_mah                  1268 non-null   int64
#  137  battery_type                 1268 non-null   category
# dtypes: category(16), datetime64[ns](1), float64(28), int64(44), object(49)
# memory usage: 1.2+ MB

# %%
df['charging'].sample(30)
# Out:
# 487                                                                                                                             10W (wired)
# 364                                                                                                80W (wired), 5W (reverse wired), PD, PPS
# 85      100W (wired), 66W (wireless), Reverse Wireless Charging Supported, 5W (reverse wired)100% in 41min (wired), 64% in 30min (wireless)
# 879                                                                                                                             25W (wired)
# 1127                                                                                           44W (wired)61% in 30min (wired) (advertised)
# 851                                                                                           67W (wired)100% in 46min (wired) (advertised)
# 162                                                                                            120W (wired)50% in 6min (wired) (advertised)
# 782                                                                                                                             45W (wired)
# 1061                25W (wired), 15W (wireless), 4.5W (reverse wireless), Reverse Wired Charging Supported50% in 30min (wired) (advertised)
# 901                                                                                                                             25W (wired)
# 562                                                                                          100W (wired)100% in 26min (wired) (advertised)
# 808                                                                                                                             18W (wired)
# 118                                                                                                                             33W (wired)
# 202                                                                                           18W (wired), Reverse Wired Charging Supported
# 441                                                                      80W (wired), 50W (wireless), 10W (reverse wireless), PD, PPS, UFCS
# 179                                                                                          120W (wired)100% in 25min (wired) (advertised)
# 591                                                                                                         45W (wired)50% in 36min (wired)
# 683                                                                                                                            120W (wired)
# 1129                                                                                           66W (wired)40% in 15min (wired) (advertised)
# 786                                                                                                         18W (wired), 9W (reverse wired)
# 18       20W (wired), 15W (wireless), Reverse Wireless Charging Supported, 4.5W (reverse wired), Qi, Qi2, 50% in 30min (wired) (advertised)
# 572                                                                                            67W (wired)50% in 19min (wired) (advertised)
# 1140                                                                                                                            44W (wired)
# 1085                                                         44W (wired), Reverse Wired Charging Supported50% in 25min (wired) (advertised)
# 224                                                                                                       44W (wired), 7.5W (reverse wired)
# 713                                                                                           33W (wired)50% in NaNmin (wired) (advertised)
# 319                                                                                    33W (wired), 5W (reverse wired)100% in 60min (wired)
# 538                                                                                           33W (wired)100% in 60min (wired) (advertised)
# 723                                                                                            45W (wired)50% in 30min (wired) (advertised)
# 1101                                                                                          44W (wired)100% in 90min (wired) (advertised)
# Name: charging, dtype: object

# %%
df['charging_watts'] = df['charging'].str.split(',').str.get(0).str.split(' ').str.get(0).str.replace('W','').astype(float)

# %%
df['charging_watts'].value_counts(dropna=False)
# Out:
# charging_watts
# 45.0     155
# 80.0     140
# 25.0     137
# 33.0     129
# 18.0     103
# 15.0      75
# 44.0      72
# 10.0      71
# 67.0      67
# 120.0     62
# 90.0      52
# 20.0      38
# 30.0      33
# 100.0     30
# 66.0      21
# 68.0      17
# 65.0      16
# 60.0      11
# 40.0       9
# 50.0       7
# 125.0      5
# 27.0       3
# 150.0      3
# 35.0       3
# 23.0       2
# 37.0       2
# 22.5       2
# 29.0       1
# 70.0       1
# 180.0      1
# Name: count, dtype: int64

# %%
df['charging_watts'].describe()
# Out:
# count    1268.000000
# mean       47.894322
# std        30.613064
# min        10.000000
# 25%        25.000000
# 50%        44.000000
# 75%        67.000000
# max       180.000000
# Name: charging_watts, dtype: float64

# %%
df['wireless_watts'] = df['charging'].str.extract(r'(\d+)W\s*\(wireless\)').astype(float)

# %%
df['wireless_watts'].value_counts(dropna=False)
# Out:
# wireless_watts
# NaN     1078
# 15.0      85
# 50.0      42
# 25.0      18
# 5.0       10
# 20.0       9
# 40.0       7
# 23.0       5
# 30.0       4
# 22.0       3
# 18.0       2
# 66.0       2
# 80.0       2
# 21.0       1
# Name: count, dtype: int64

# %%
df['wireless_watts'].describe()
# Out:
# count    190.000000
# mean      26.236842
# std       16.253993
# min        5.000000
# 25%       15.000000
# 50%       16.500000
# 75%       40.000000
# max       80.000000
# Name: wireless_watts, dtype: float64

# %%
df['has_wireless'] = df['charging'].str.contains('wireless').astype(int)

# %%
df['has_wireless'].value_counts()
# Out:
# has_wireless
# 0    1068
# 1     200
# Name: count, dtype: int64

# %%
df['has_reverse_charging'] = df['charging'].str.contains('reverse',).astype(int)

# %%
df['has_reverse_charging'].value_counts()
# Out:
# has_reverse_charging
# 0    1052
# 1     216
# Name: count, dtype: int64

# %%
df['wired_full_charge_time'] = df['charging'].str.extract(r'100% in\s*(\d+)\s*min.*?\(wired\)').astype(float)

# %%
df['wired_full_charge_time'].value_counts(dropna=False)
# Out:
# wired_full_charge_time
# NaN      1058
# 60.0       21
# 46.0       12
# 44.0       10
# 42.0       10
# 56.0        8
# 26.0        8
# 35.0        8
# 45.0        8
# 32.0        7
# 90.0        7
# 61.0        7
# 40.0        6
# 19.0        6
# 48.0        6
# 70.0        5
# 55.0        5
# 29.0        4
# 28.0        4
# 38.0        4
# 41.0        4
# 25.0        4
# 18.0        4
# 31.0        4
# 58.0        3
# 79.0        3
# 33.0        3
# 30.0        3
# 17.0        3
# 43.0        3
# 0.0         3
# 47.0        3
# 15.0        2
# 108.0       2
# 75.0        2
# 145.0       2
# 54.0        2
# 52.0        2
# 69.0        2
# 57.0        2
# 80.0        2
# 12.0        1
# 49.0        1
# 100.0       1
# 63.0        1
# 71.0        1
# 139.0       1
# Name: count, dtype: int64

# %%
df[df['wired_full_charge_time'] == 145][['model','charging']]
# Out:
#                        model                           charging
# 1197  Vivo Y18 (4GB + 128GB)  15W (wired)100% in 145min (wired)
# 1198                Vivo Y18  15W (wired)100% in 145min (wired)

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 144 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    model_id                     1268 non-null   int64
#  1    model                        1268 non-null   object
#  2    expert_rating                1268 non-null   int64
#  3    rating                       1268 non-null   float64
#  4    rating_count                 994 non-null    float64
#  5    launch_on                    1268 non-null   datetime64[ns]
#  6    old_price                    844 non-null    float64
#  7    price                        1268 non-null   int64
#  8    launch_price                 1268 non-null   int64
#  9    display_type                 1268 non-null   object
#  10   display_size                 1268 non-null   object
#  11   display_res                  1268 non-null   object
#  12   body_dimension               1268 non-null   object
#  13   weight                       1268 non-null   object
#  14   body_front                   1268 non-null   object
#  15   body_back                    1238 non-null   object
#  16   body_side                    1251 non-null   object
#  17   build_quality                739 non-null    object
#  18   ports                        1268 non-null   object
#  19   ip_rating                    915 non-null    object
#  20   speaker                      1265 non-null   object
#  21   chipset                      1268 non-null   object
#  22   cpu                          1268 non-null   object
#  23   gpu                          1250 non-null   object
#  24   main_cam                     1268 non-null   object
#  25   main_cam2                    1214 non-null   object
#  26   main_cam3                    631 non-null    object
#  27   main_cam_features            1268 non-null   object
#  28   main_video                   1239 non-null   object
#  29   os                           1268 non-null   object
#  30   software_updates             1228 non-null   object
#  31   ai_features                  780 non-null    object
#  32   front_cam                    1268 non-null   object
#  33   front_cam_features           1026 non-null   object
#  34   front_video                  1229 non-null   object
#  35   battery                      1268 non-null   object
#  36   charging                     1268 non-null   object
#  37   storage                      1268 non-null   object
#  38   ram                          1268 non-null   object
#  39   sim                          1264 non-null   object
#  40   tech                         1200 non-null   object
#  41   2g                           1262 non-null   object
#  42   3g                           1264 non-null   object
#  43   4g                           1267 non-null   object
#  44   5g                           1028 non-null   object
#  45   speed                        1264 non-null   object
#  46   wifi                         1268 non-null   object
#  47   bluetooth                    1266 non-null   object
#  48   positioning_system           1268 non-null   object
#  49   nfc                          595 non-null    object
#  50   finger_print                 1192 non-null   object
#  51   sensors                      1268 non-null   object
#  52   add_features                 469 non-null    object
#  53   main_cam4                    48 non-null     object
#  54   front_cam2                   9 non-null      object
#  55   brand                        1268 non-null   category
#  56   is_available                 1268 non-null   int64
#  57   is_flipkart_available        1268 non-null   int64
#  58   is_amazon_available          1268 non-null   int64
#  59   is_official_available        1268 non-null   int64
#  60   display_panel_type           1268 non-null   object
#  61   display_panel_family         1268 non-null   category
#  62   display_hz                   1268 non-null   int64
#  63   display_dynamic_range        1268 non-null   category
#  64   touch_sampling_rate          852 non-null    float64
#  65   has_ltpo                     1268 non-null   int64
#  66   has_anti_reflection_coating  1268 non-null   int64
#  67   display_inches               1268 non-null   float64
#  68   display_body_ratio           1036 non-null   float64
#  69   has_curved                   1268 non-null   int64
#  70   has_foldable                 1268 non-null   int64
#  71   res_category                 1268 non-null   category
#  72   res_width                    1268 non-null   int64
#  73   res_height                   1268 non-null   int64
#  74   aspect_ration_numeric        1185 non-null   float64
#  75   display_ppi                  1268 non-null   float64
#  76   color_depth                  1268 non-null   float64
#  77   peak_brightness              1206 non-null   float64
#  78   has_high_contrast            1268 non-null   int64
#  79   height_mm                    1268 non-null   float64
#  80   width_mm                     1268 non-null   float64
#  81   thickness_mm                 1268 non-null   float64
#  82   weight_g                     1268 non-null   float64
#  83   front_potection              1268 non-null   category
#  84   back_material                1268 non-null   category
#  85   frame_material               1268 non-null   category
#  86   durability_cert              1268 non-null   category
#  87   has_3_5mm_jack               1268 non-null   int64
#  88   usb_type                     1268 non-null   category
#  89   usb_version                  1268 non-null   float64
#  90   has_otg                      1268 non-null   int64
#  91   has_ir_blaster               1268 non-null   int64
#  92   water_resistance_level       1268 non-null   category
#  93   has_stereo_speakers          1268 non-null   int64
#  94   has_audio_certification      1268 non-null   int64
#  95   processor_brand              1268 non-null   category
#  96   chipset_brand                1266 non-null   object
#  97   chipset_nm                   1258 non-null   float64
#  98   antutu_score                 1237 non-null   float64
#  99   cpu_core_count               1268 non-null   int64
#  100  cpu_max_ghz                  1261 non-null   float64
#  101  gpu_brand                    1249 non-null   category
#  102  cam_primary_mp               1268 non-null   int64
#  103  cam_aperture                 1262 non-null   float64
#  104  cam_has_ois                  1268 non-null   int64
#  105  cam_sensor_size              722 non-null    float64
#  106  cam_secondary_mp             1214 non-null   float64
#  107  has_telephoto                1268 non-null   int64
#  108  has_periscope                1268 non-null   int64
#  109  cam_optical_zoom             1268 non-null   int64
#  110  cam_tertiary_mp              629 non-null    float64
#  111  total_cam_count              1268 non-null   int64
#  112  cam_fourth_mp                48 non-null     float64
#  113  is_apple_flagship_tech       1268 non-null   int64
#  114  has_laser_af                 1268 non-null   int64
#  115  has_zeiss_optics             1268 non-null   int64
#  116  has_pro_video_features       1268 non-null   int64
#  117  max_video_res                1268 non-null   category
#  118  video_has_eis                1268 non-null   int64
#  119  video_is_pro_grade           1268 non-null   int64
#  120  os_type                      1268 non-null   category
#  121  os_version_num               1268 non-null   float64
#  122  is_android_go                1268 non-null   int64
#  123  os_update_years              1268 non-null   float64
#  124  security_update_years        1268 non-null   float64
#  125  has_gen_ai                   1268 non-null   int64
#  126  has_ai_camera                1268 non-null   float64
#  127  ai_feature_count             1268 non-null   int64
#  128  front_cam_mp                 1268 non-null   float64
#  129  is_front_af                  1268 non-null   int64
#  130  front_eis                    1268 non-null   int64
#  131  is_dual_front                1268 non-null   int64
#  132  has_front_pro_features       1268 non-null   int64
#  133  has_front_flash              1268 non-null   int64
#  134  is_zeiss_front               1268 non-null   int64
#  135  max_front_video_res          1268 non-null   category
#  136  battery_mah                  1268 non-null   int64
#  137  battery_type                 1268 non-null   category
#  138  charging_watt                1268 non-null   float64
#  139  charging_watts               1268 non-null   float64
#  140  wireless_watts               190 non-null    float64
#  141  has_wireless                 1268 non-null   int64
#  142  has_reverse_charging         1268 non-null   int64
#  143  wired_full_charge_time       210 non-null    float64
# dtypes: category(16), datetime64[ns](1), float64(32), int64(46), object(49)
# memory usage: 1.3+ MB

# %%
df['storage'].sample(30)
# Out:
# 193     256GB, UFS 2.2
# 1043    512GB, UFS 4.0
# 711     256GB, UFS 2.2
# 862     256GB, UFS 2.2
# 13         128GB, NvMe
# 479     256GB, UFS 2.2
# 998     256GB, UFS 2.2
# 830     128GB, UFS 2.2
# 517      64GB, UFS 2.2
# 1049    256GB, UFS 3.1
# 86      256GB, UFS 3.1
# 1031    128GB, UFS 3.1
# 404     128GB, UFS 2.2
# 383     32GB, eMMC 5.1
# 876     128GB, UFS 2.2
# 531     128GB, UFS 2.2
# 254     128GB, UFS 2.2
# 188     128GB, UFS 2.2
# 509     256GB, UFS 4.1
# 47         512GB, NvMe
# 1046    512GB, UFS 4.0
# 843      64GB, UFS 2.2
# 119     256GB, UFS 2.2
# 1157    128GB, UFS 2.2
# 1021    256GB, UFS 4.0
# 294     128GB, UFS 2.2
# 680     512GB, UFS 4.0
# 1238    128GB, UFS 2.2
# 1138    128GB, UFS 2.2
# 541     128GB, UFS 2.2
# Name: storage, dtype: object

# %%
df['rom'] = df['storage'].str.split(',').str.get(0).str.replace('GB','')

# %%
df['rom'] = df['rom'].str.replace('1TB','1024')
df['rom'] = df['rom'].str.replace('2TB','2048')
df['rom'] = df['rom'].astype(int)

# %%
df['rom'].value_counts(dropna=False)
# Out:
# rom
# 128     588
# 256     403
# 64      133
# 512     110
# 1024     17
# 32       16
# 2048      1
# Name: count, dtype: int64

# %%
df['storage_type'] = df['storage'].str.split(',').str.get(1).str.strip()

# %%
df['storage_type'].value_counts(dropna=False)
# Out:
# storage_type
# UFS 2.2     527
# UFS 3.1     314
# eMMC 5.1    153
# UFS 4.0     132
# NvMe         52
# UFS 2.1      39
# UFS 4.1      27
# UFS          13
# NaN           5
# UFS 2.0       3
# UFS 3.2       2
# uMCP          1
# Name: count, dtype: int64

# %%
# 1. Mapping logic to simplify versions
storage_map = {
    'UFS 4.1': 'UFS 4.0',
    'UFS 4.0': 'UFS 4.0',
    'UFS 3.2': 'UFS 3.1',
    'UFS 3.1': 'UFS 3.1',
    'UFS 2.2': 'UFS 2.x',
    'UFS 2.1': 'UFS 2.x',
    'UFS 2.0': 'UFS 2.x',
    'eMMC 5.1': 'eMMC',
    'NvMe': 'NVMe',
    'uMCP': 'UFS 2.x', # uMCP usually mid-range, maps closest to UFS 2.x performance
    'UFS': 'UFS (Generic)'
}

df['storage_type'] = df['storage_type'].replace(storage_map)

# 2. Handling 5 NaNs based on Brand or Price (Simple Fill for now)
df['storage_type'] = df['storage_type'].fillna('UFS (Generic)')

# %%
df['storage_type'].value_counts(dropna=False)
# Out:
# storage_type
# UFS 2.x          570
# UFS 3.1          316
# UFS 4.0          159
# eMMC             153
# NVMe              52
# UFS (Generic)     18
# Name: count, dtype: int64
