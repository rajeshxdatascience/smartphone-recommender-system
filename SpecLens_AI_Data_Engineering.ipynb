# %% [markdown]
# <a href="https://colab.research.google.com/github/rajeshxdatascience/SpecLens-AI/blob/main/SpecLens_AI_Data_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.width',None)
pd.set_option('display.max_colwidth',None)

# %%
df = pd.read_csv('/content/12_jan_smartphones_coloumns_for_ml.csv')

# %%
df.head()
# Out:
#    model_id                               model  expert_rating  rating  \
# 0         1       Apple iPhone 14 (6GB + 256GB)             69     4.6
# 1         2       Apple iPhone 14 (6GB + 512GB)             69     4.6
# 2         3  Apple iPhone 14 Plus (6GB + 256GB)             72     4.6
# 3         4  Apple iPhone 14 Plus (6GB + 512GB)             72     4.6
# 4         5                Apple iPhone 14 Plus             72     4.6
#
#     rating_count market_status    launch_on  \
# 0  (321KRatings)      In Stock  07 Sep 2022
# 1  (321KRatings)  Out of Stock  07 Sep 2022
# 2   (87KRatings)  Out of Stock  07 Sep 2022
# 3   (87KRatings)  Out of Stock  07 Sep 2022
# 4   (87KRatings)      In Stock  07 Sep 2022
#
#                                              old_price    price launch_price  \
# 0    Was ₹56,999 2 day(s) ago Was ₹56,999 2 day(s) ago  ₹64,900      ₹79,900
# 1  Lowest price since launch Lowest price since launch  ₹89,900      ₹79,900
# 2  Lowest price since launch Lowest price since launch  ₹79,900      ₹89,900
# 3  Lowest price since launch Lowest price since launch  ₹99,900      ₹89,900
# 4  Lowest price since launch Lowest price since launch  ₹69,900      ₹89,900
#
#                                               display_type  \
# 0  Super Retina XDR OLED, 60 Hz Refresh Rate, Dolby Vision
# 1  Super Retina XDR OLED, 60 Hz Refresh Rate, Dolby Vision
# 2  Super Retina XDR OLED, 60 Hz Refresh Rate, Dolby Vision
# 3  Super Retina XDR OLED, 60 Hz Refresh Rate, Dolby Vision
# 4  Super Retina XDR OLED, 60 Hz Refresh Rate, Dolby Vision
#
#                                         display_size  \
# 0     6.1 inches, 90.2 cm², 86% Screen To Body Ratio
# 1     6.1 inches, 90.2 cm², 86% Screen To Body Ratio
# 2  6.7 inches, 109.8 cm², 87.4% Screen To Body Ratio
# 3  6.7 inches, 109.8 cm², 87.4% Screen To Body Ratio
# 4  6.7 inches, 109.8 cm², 87.4% Screen To Body Ratio
#
#                                                                                                                                                   display_res  \
# 0                                FHD+, 1170 x  2532 pixels, 19.5:9 (460 ppi), 8-bit colours, 82% DCI-P3, 1200 nits(Peak Brightness), 2000000:1 Contrast Ratio
# 1                                FHD+, 1170 x  2532 pixels, 19.5:9 (460 ppi), 8-bit colours, 82% DCI-P3, 1200 nits(Peak Brightness), 2000000:1 Contrast Ratio
# 2  FHD+, 1284 x  2778 pixels, 19.5:9 (458 ppi), 8-bit colours, 85% DCI-P3, 1200 nits(Peak Brightness), 800 nits(Typical Brightness), 2000000:1 Contrast Ratio
# 3  FHD+, 1284 x  2778 pixels, 19.5:9 (458 ppi), 8-bit colours, 85% DCI-P3, 1200 nits(Peak Brightness), 800 nits(Typical Brightness), 2000000:1 Contrast Ratio
# 4  FHD+, 1284 x  2778 pixels, 19.5:9 (458 ppi), 8-bit colours, 85% DCI-P3, 1200 nits(Peak Brightness), 800 nits(Typical Brightness), 2000000:1 Contrast Ratio
#
#           body_dimension     weight body_front body_back        body_side  \
# 0  146.7 x 71.5 x 7.8 mm  172 grams      Glass     Glass  Aluminium Frame
# 1  146.7 x 71.5 x 7.8 mm  172 grams      Glass     Glass  Aluminium Frame
# 2  160.8 x 78.1 x 7.8 mm  203 grams      Glass     Glass  Aluminium Frame
# 3  160.8 x 78.1 x 7.8 mm  203 grams      Glass     Glass  Aluminium Frame
# 4  160.8 x 78.1 x 7.8 mm  203 grams      Glass     Glass  Aluminium Frame
#
#         build_quality              ports                        ip_rating  \
# 0  Corning-made Glass  Lightning USB 2.0  IP68 (Dust and Water Resistant)
# 1  Corning-made Glass  Lightning USB 2.0  IP68 (Dust and Water Resistant)
# 2  Corning-made Glass  Lightning USB 2.0  IP68 (Dust and Water Resistant)
# 3  Corning-made Glass  Lightning USB 2.0  IP68 (Dust and Water Resistant)
# 4  Corning-made Glass  Lightning USB 2.0  IP68 (Dust and Water Resistant)
#
#            speaker                                        chipset  \
# 0  Stereo Speakers  Apple A15 Bionic (5 nm), 1287587 Antutu Score
# 1  Stereo Speakers  Apple A15 Bionic (5 nm), 1287587 Antutu Score
# 2  Stereo Speakers  Apple A15 Bionic (5 nm), 1287587 Antutu Score
# 3  Stereo Speakers  Apple A15 Bionic (5 nm), 1287587 Antutu Score
# 4  Stereo Speakers  Apple A15 Bionic (5 nm), 1287587 Antutu Score
#
#                                                       cpu  \
# 0  Hexa-core (2x3.23 GHz Avalanche + 4x1.82 GHz Blizzard)
# 1  Hexa-core (2x3.23 GHz Avalanche + 4x1.82 GHz Blizzard)
# 2  Hexa-core (2x3.23 GHz Avalanche + 4x1.82 GHz Blizzard)
# 3  Hexa-core (2x3.23 GHz Avalanche + 4x1.82 GHz Blizzard)
# 4  Hexa-core (2x3.23 GHz Avalanche + 4x1.82 GHz Blizzard)
#
#                            gpu  \
# 0  Apple GPU (5-core graphics)
# 1  Apple GPU (5-core graphics)
# 2  Apple GPU (5-core graphics)
# 3  Apple GPU (5-core graphics)
# 4  Apple GPU (5-core graphics)
#
#                                             main_cam  \
# 0  12 MP, f/1.5, 26mm (Wide-angle), Sensor-Shift OIS
# 1  12 MP, f/1.5, 26mm (Wide-angle), Sensor-Shift OIS
# 2  12 MP, f/1.5, 26mm (Wide-angle), Sensor-Shift OIS
# 3  12 MP, f/1.5, 26mm (Wide-angle), Sensor-Shift OIS
# 4  12 MP, f/1.5, 26mm (Wide-angle), Sensor-Shift OIS
#
#                                 main_cam2 main_cam3  \
# 0  12 MP, f/2.4, 13mm  (Ultra-wide), 120°       NaN
# 1  12 MP, f/2.4, 13mm  (Ultra-wide), 120°       NaN
# 2  12 MP, f/2.4, 13mm  (Ultra-wide), 120°       NaN
# 3  12 MP, f/2.4, 13mm  (Ultra-wide), 120°       NaN
# 4  12 MP, f/2.4, 13mm  (Ultra-wide), 120°       NaN
#
#                                                                                           main_cam_features  \
# 0  Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
# 1  Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
# 2  Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
# 3  Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
# 4  Auto Focus, Cinematic Mode, Digital Zoom, Dual LED Dual Tone Flash, HDR, Night Mode, OIS, Panorama, PDAF
#
#                                                                                                                               main_video  \
# 0  4K@24/25/30/60fps, 1080p@25/30/60/120/240fps, 720p@30fps, Cinematic mode, Dolby Vision HDR (up to 60fps), HDR, Stereo Sound Recording
# 1  4K@24/25/30/60fps, 1080p@25/30/60/120/240fps, 720p@30fps, Cinematic mode, Dolby Vision HDR (up to 60fps), HDR, Stereo Sound Recording
# 2                          4K@24/25/30/60fps, 1080p@25/30/60/120/240fps, 720p@30fps, Cinematic mode, Dolby Vision HDR (up to 60fps), HDR
# 3                          4K@24/25/30/60fps, 1080p@25/30/60/120/240fps, 720p@30fps, Cinematic mode, Dolby Vision HDR (up to 60fps), HDR
# 4                          4K@24/25/30/60fps, 1080p@25/30/60/120/240fps, 720p@30fps, Cinematic mode, Dolby Vision HDR (up to 60fps), HDR
#
#        os                            software_updates ai_features  \
# 0  iOS 16  5 year(s) of Software and Security updates         NaN
# 1  iOS 16  5 year(s) of Software and Security updates         NaN
# 2  iOS 16  5 year(s) of Software and Security updates         NaN
# 3  iOS 16  5 year(s) of Software and Security updates         NaN
# 4  iOS 16  5 year(s) of Software and Security updates         NaN
#
#                                   front_cam  \
# 0  12 MP, f/1.9, 23mm  (Wide), 1/3.6", PDAF
# 1  12 MP, f/1.9, 23mm  (Wide), 1/3.6", PDAF
# 2  12 MP, f/1.9, 23mm  (Wide), 1/3.6", PDAF
# 3  12 MP, f/1.9, 23mm  (Wide), 1/3.6", PDAF
# 4  12 MP, f/1.9, 23mm  (Wide), 1/3.6", PDAF
#
#                       front_cam_features  \
# 0  Auto Focus, Cinematic mode (4k@30fps)
# 1  Auto Focus, Cinematic mode (4k@30fps)
# 2  Auto Focus, Cinematic mode (4k@30fps)
# 3  Auto Focus, Cinematic mode (4k@30fps)
# 4  Auto Focus, Cinematic mode (4k@30fps)
#
#                                           front_video  \
# 0  1080p@25/30/60/120fps, 4K@24/25/30/60fps, gyro-EIS
# 1  1080p@25/30/60/120fps, 4K@24/25/30/60fps, gyro-EIS
# 2  1080p@25/30/60/120fps, 4K@24/25/30/60fps, gyro-EIS
# 3  1080p@25/30/60/120fps, 4K@24/25/30/60fps, gyro-EIS
# 4  1080p@25/30/60/120fps, 4K@24/25/30/60fps, gyro-EIS
#
#                                  battery  \
# 0  3279 mAh, Lithium Ion (Non-removable)
# 1  3279 mAh, Lithium Ion (Non-removable)
# 2  4323 mAh, Lithium Ion (Non-removable)
# 3  4323 mAh, Lithium Ion (Non-removable)
# 4  4323 mAh, Lithium Ion (Non-removable)
#
#                                                                     charging  \
# 0  20W (wired), Wireless Charging Supported50% in 30min (wired) (advertised)
# 1  20W (wired), Wireless Charging Supported50% in 30min (wired) (advertised)
# 2  20W (wired), Wireless Charging Supported50% in 30min (wired) (advertised)
# 3  20W (wired), Wireless Charging Supported50% in 30min (wired) (advertised)
# 4  20W (wired), Wireless Charging Supported50% in 30min (wired) (advertised)
#
#        storage           ram  \
# 0  256GB, NvMe  6GB, LPDDR4X
# 1  512GB, NvMe  6GB, LPDDR4X
# 2  256GB, NvMe  6GB, LPDDR4X
# 3  512GB, NvMe  6GB, LPDDR4X
# 4  128GB, NvMe  6GB, LPDDR4X
#
#                                                                                    sim  \
# 0                                                                    nano-SIM and eSIM
# 1                                                                    nano-SIM and eSIM
# 2  nano-SIM and eSIM (international), Dual eSIM (USA), Nano-SIM, dual stand-by (China)
# 3  nano-SIM and eSIM (international), Dual eSIM (USA), Nano-SIM, dual stand-by (China)
# 4  nano-SIM and eSIM (international), Dual eSIM (USA), Nano-SIM, dual stand-by (China)
#
#                              tech                              2g  \
# 0  5G, CDMA, EVDO, GSM, HSPA, LTE  1800, 1900, 850, 900 (4 bands)
# 1  5G, CDMA, EVDO, GSM, HSPA, LTE  1800, 1900, 850, 900 (4 bands)
# 2  5G, CDMA, EVDO, GSM, HSPA, LTE  1800, 1900, 850, 900 (4 bands)
# 3  5G, CDMA, EVDO, GSM, HSPA, LTE  1800, 1900, 850, 900 (4 bands)
# 4  5G, CDMA, EVDO, GSM, HSPA, LTE  1800, 1900, 850, 900 (4 bands)
#
#                                                                                 3g  \
# 0  UMTS/HSPA+/DC-HSDPA 850, 900, 1700(AWS), 1900, 2100, CDMA2000 1xEV-DO (6 bands)
# 1  UMTS/HSPA+/DC-HSDPA 850, 900, 1700(AWS), 1900, 2100, CDMA2000 1xEV-DO (6 bands)
# 2                    UMTS/HSPA+/DC-HSDPA 850, 900, 1700(AWS), 1900, 2100 (5 bands)
# 3                    UMTS/HSPA+/DC-HSDPA 850, 900, 1700(AWS), 1900, 2100 (5 bands)
# 4                    UMTS/HSPA+/DC-HSDPA 850, 900, 1700(AWS), 1900, 2100 (5 bands)
#
#                                                                                                                    4g  \
# 0  LTE 1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 30, 32, 34, 38, 39, 40, 41, 42, 46, 48, 66 (27 bands)
# 1  LTE 1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 30, 32, 34, 38, 39, 40, 41, 42, 46, 48, 66 (27 bands)
# 2  LTE 1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 30, 32, 34, 38, 39, 40, 41, 42, 46, 48, 66 (27 bands)
# 3  LTE 1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 30, 32, 34, 38, 39, 40, 41, 42, 46, 48, 66 (27 bands)
# 4  LTE 1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 30, 32, 34, 38, 39, 40, 41, 42, 46, 48, 66 (27 bands)
#
#                                                                                                     5g  \
# 0  SA/NSA/Sub6 1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 30, 38, 40, 41, 48, 66, 70, 77, 78, 79 (21 bands)
# 1  SA/NSA/Sub6 1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 30, 38, 40, 41, 48, 66, 70, 77, 78, 79 (21 bands)
# 2  SA/NSA/Sub6 1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 30, 38, 40, 41, 48, 66, 70, 77, 78, 79 (21 bands)
# 3  SA/NSA/Sub6 1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 30, 38, 40, 41, 48, 66, 70, 77, 78, 79 (21 bands)
# 4  SA/NSA/Sub6 1, 2, 3, 5, 7, 8, 12, 20, 25, 26, 28, 30, 38, 40, 41, 48, 66, 70, 77, 78, 79 (21 bands)
#
#                       speed  \
# 0  5G, GSM, HSPA, LTE, UMTS
# 1  5G, GSM, HSPA, LTE, UMTS
# 2  5G, GSM, HSPA, LTE, UMTS
# 3  5G, GSM, HSPA, LTE, UMTS
# 4  5G, GSM, HSPA, LTE, UMTS
#
#                                                              wifi  \
# 0  Wi-Fi 6 802.11 a/b/g/n/ac/ax, Hotspot, Wi-Fi Direct, Dual Band
# 1  Wi-Fi 6 802.11 a/b/g/n/ac/ax, Hotspot, Wi-Fi Direct, Dual Band
# 2  Wi-Fi 6 802.11 a/b/g/n/ac/ax, Hotspot, Wi-Fi Direct, Dual Band
# 3  Wi-Fi 6 802.11 a/b/g/n/ac/ax, Hotspot, Wi-Fi Direct, Dual Band
# 4  Wi-Fi 6 802.11 a/b/g/n/ac/ax, Hotspot, Wi-Fi Direct, Dual Band
#
#        bluetooth                positioning_system        nfc finger_print  \
# 0  5.3, A2DP, LE  BDS, GALILEO, GLONASS, GPS, QZSS  Supported          NaN
# 1  5.3, A2DP, LE  BDS, GALILEO, GLONASS, GPS, QZSS  Supported          NaN
# 2  5.3, A2DP, LE  BDS, GALILEO, GLONASS, GPS, QZSS  Supported          NaN
# 3  5.3, A2DP, LE  BDS, GALILEO, GLONASS, GPS, QZSS  Supported          NaN
# 4  5.3, A2DP, LE  BDS, GALILEO, GLONASS, GPS, QZSS  Supported          NaN
#
#                                                                                                         sensors  \
# 0  Accelerometer, Barometer Sensor, Compass, Face ID, Gyroscope, Proximity Sensor, Ultra Wideband (UWB) Support
# 1  Accelerometer, Barometer Sensor, Compass, Face ID, Gyroscope, Proximity Sensor, Ultra Wideband (UWB) Support
# 2  Accelerometer, Barometer Sensor, Compass, Face ID, Gyroscope, Proximity Sensor, Ultra Wideband (UWB) Support
# 3  Accelerometer, Barometer Sensor, Compass, Face ID, Gyroscope, Proximity Sensor, Ultra Wideband (UWB) Support
# 4  Accelerometer, Barometer Sensor, Compass, Face ID, Gyroscope, Proximity Sensor, Ultra Wideband (UWB) Support
#
#                 add_features  \
# 0  Linear Resonant Actuators
# 1  Linear Resonant Actuators
# 2  Linear Resonant Actuators
# 3  Linear Resonant Actuators
# 4  Linear Resonant Actuators
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         flipkart_buy_link  \
# 0                                                                                         https://www.flipkart.com/apple-iphone-14-starlight-256-gb/p/itmaeda15697bb79?pid=MOBGHWFHBJGZYRZC&lid=LSTMOBGHWFHBJGZYRZCUALABX&marketplace=FLIPKART&q=iphone+14+&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=d16ab4a6-25f4-4cb9-8d77-ecbd3f8a6a54.MOBGHWFHBJGZYRZC.SEARCH&ppt=pp&ppn=pp&ssid=kueh4gc0g00000001729242962911&qH=e683ba9749683369&affid=contactbe1
# 1                                                                                          https://www.flipkart.com/apple-iphone-14-midnight-512-gb/p/itm01540a8ff03de?pid=MOBGHWFHBEMUZSBY&lid=LSTMOBGHWFHBEMUZSBYWJC9VQ&marketplace=FLIPKART&q=iphone+14+&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=organic&iid=d16ab4a6-25f4-4cb9-8d77-ecbd3f8a6a54.MOBGHWFHBEMUZSBY.SEARCH&ppt=pp&ppn=pp&ssid=kueh4gc0g00000001729242962911&qH=e683ba9749683369&affid=contactbe1
# 2  https://www.flipkart.com/apple-iphone-14-plus-starlight-256-gb/p/itm8ee001dd954a2?pid=MOBGHWFHQGM9B4EU&lid=LSTMOBGHWFHQGM9B4EUGHBHUP&marketplace=FLIPKART&q=14+plus+iphone&store=tyy%2F4io&srno=s_1_4&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&fm=organic&iid=463edb55-77b0-4ae0-b1cf-07d79dcb5f45.MOBGHWFHQGM9B4EU.SEARCH&ppt=pp&ppn=pp&ssid=74yvvmat5s0000001729233498497&qH=94ddc8675cffe2b2&affid=contactbe1
# 3       https://www.flipkart.com/apple-iphone-14-plus-blue-512-gb/p/itm9b829cc08a732?pid=MOBGHWFHKHPYMQX8&lid=LSTMOBGHWFHKHPYMQX8K7QHSJ&marketplace=FLIPKART&q=14+plus+iphone&store=tyy%2F4io&srno=s_1_7&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&fm=organic&iid=463edb55-77b0-4ae0-b1cf-07d79dcb5f45.MOBGHWFHKHPYMQX8.SEARCH&ppt=pp&ppn=pp&ssid=74yvvmat5s0000001729233498497&qH=94ddc8675cffe2b2&affid=contactbe1
# 4  https://www.flipkart.com/apple-iphone-14-plus-starlight-128-gb/p/itmc922ddc8af349?pid=MOBGHWFHVCB2YZYR&lid=LSTMOBGHWFHVCB2YZYRBDOEVN&marketplace=FLIPKART&q=14+plus+iphone&store=tyy%2F4io&srno=s_1_3&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&fm=organic&iid=463edb55-77b0-4ae0-b1cf-07d79dcb5f45.MOBGHWFHVCB2YZYR.SEARCH&ppt=pp&ppn=pp&ssid=74yvvmat5s0000001729233498497&qH=94ddc8675cffe2b2&affid=contactbe1
#
#                                                                     amazon_buy_link  \
# 0  https://www.amazon.in/dp/B0BDJS3MRM?tag=beebomgadge0d-21&linkCode=ogv&th=1&psc=1
# 1  https://www.amazon.in/dp/B0BDJGX2XZ?tag=beebomgadge0d-21&linkCode=ogv&th=1&psc=1
# 2                                                                               NaN
# 3                                                                               NaN
# 4  https://www.amazon.in/dp/B0BDJFTGK6?tag=beebomgadge0d-21&linkCode=ogv&th=1&psc=1
#
#   official_store_link
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 57 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   model_id             1268 non-null   int64
#  1   model                1268 non-null   object
#  2   expert_rating        1268 non-null   int64
#  3   rating               1268 non-null   float64
#  4   rating_count         994 non-null    object
#  5   market_status        1268 non-null   object
#  6   launch_on            1268 non-null   object
#  7   old_price            1149 non-null   object
#  8   price                1268 non-null   object
#  9   launch_price         1268 non-null   object
#  10  display_type         1268 non-null   object
#  11  display_size         1268 non-null   object
#  12  display_res          1268 non-null   object
#  13  body_dimension       1268 non-null   object
#  14  weight               1268 non-null   object
#  15  body_front           1268 non-null   object
#  16  body_back            1238 non-null   object
#  17  body_side            1251 non-null   object
#  18  build_quality        739 non-null    object
#  19  ports                1268 non-null   object
#  20  ip_rating            915 non-null    object
#  21  speaker              1265 non-null   object
#  22  chipset              1268 non-null   object
#  23  cpu                  1268 non-null   object
#  24  gpu                  1250 non-null   object
#  25  main_cam             1268 non-null   object
#  26  main_cam2            1214 non-null   object
#  27  main_cam3            631 non-null    object
#  28  main_cam_features    1268 non-null   object
#  29  main_video           1239 non-null   object
#  30  os                   1268 non-null   object
#  31  software_updates     1228 non-null   object
#  32  ai_features          780 non-null    object
#  33  front_cam            1268 non-null   object
#  34  front_cam_features   1026 non-null   object
#  35  front_video          1229 non-null   object
#  36  battery              1268 non-null   object
#  37  charging             1268 non-null   object
#  38  storage              1268 non-null   object
#  39  ram                  1268 non-null   object
#  40  sim                  1264 non-null   object
#  41  tech                 1200 non-null   object
#  42  2g                   1262 non-null   object
#  43  3g                   1264 non-null   object
#  44  4g                   1267 non-null   object
#  45  5g                   1028 non-null   object
#  46  speed                1264 non-null   object
#  47  wifi                 1268 non-null   object
#  48  bluetooth            1266 non-null   object
#  49  positioning_system   1268 non-null   object
#  50  nfc                  595 non-null    object
#  51  finger_print         1192 non-null   object
#  52  sensors              1268 non-null   object
#  53  add_features         469 non-null    object
#  54  flipkart_buy_link    1085 non-null   object
#  55  amazon_buy_link      724 non-null    object
#  56  official_store_link  610 non-null    object
# dtypes: float64(1), int64(2), object(54)
# memory usage: 564.8+ KB

# %%
df['brand'] = df['model'].str.lower().str.split(' ').str.get(0)

# %%
df['brand'].value_counts()
# Out:
# brand
# realme      231
# samsung     196
# vivo        177
# oppo        100
# redmi        93
# iqoo         74
# poco         70
# infinix      61
# oneplus      59
# apple        54
# motorola     40
# moto         38
# google       20
# nothing      18
# xiaomi       18
# honor        10
# asus          5
# cmf           4
# Name: count, dtype: int64

# %%
df.loc[df['brand'].str.contains('moto'),'brand'] = 'motorola'

# %%
df['brand'].value_counts()
# Out:
# brand
# realme      231
# samsung     196
# vivo        177
# oppo        100
# redmi        93
# motorola     78
# iqoo         74
# poco         70
# infinix      61
# oneplus      59
# apple        54
# google       20
# nothing      18
# xiaomi       18
# honor        10
# asus          5
# cmf           4
# Name: count, dtype: int64

# %%
df['brand'].count()
# Out:
# np.int64(1268)

# %%
df['brand'] = df['brand'].astype('category')

# %%
df['expert_rating'].value_counts()
# Out:
# expert_rating
# 80    57
# 73    45
# 84    41
# 74    41
# 68    37
#       ..
# 47     4
# 28     3
# 26     3
# 29     2
# 22     1
# Name: count, Length: 70, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# 4.3    299
# 4.4    271
# 4.2    236
# 4.5    134
# 4.1     92
# 4.6     70
# 4.7     46
# 4.8     29
# 4.0     29
# 2.0     16
# 3.9     15
# 1.0     12
# 3.8      5
# 3.4      5
# 3.5      2
# 3.7      2
# 3.6      2
# 5.0      1
# 4.9      1
# 3.0      1
# Name: count, dtype: int64

# %%
df['rating_count'] = df['rating_count'].str.lower().str.split('r').str.get(0)

# %%
df['rating_count'] = df['rating_count'].str.replace('(','')

# %%
df['rating_count'] = df['rating_count'].str.replace('k',"1000")

# %%
df['rating_count'] = df['rating_count'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 58 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   model_id             1268 non-null   int64
#  1   model                1268 non-null   object
#  2   expert_rating        1268 non-null   int64
#  3   rating               1268 non-null   float64
#  4   rating_count         994 non-null    float64
#  5   market_status        1268 non-null   object
#  6   launch_on            1268 non-null   object
#  7   old_price            1149 non-null   object
#  8   price                1268 non-null   object
#  9   launch_price         1268 non-null   object
#  10  display_type         1268 non-null   object
#  11  display_size         1268 non-null   object
#  12  display_res          1268 non-null   object
#  13  body_dimension       1268 non-null   object
#  14  weight               1268 non-null   object
#  15  body_front           1268 non-null   object
#  16  body_back            1238 non-null   object
#  17  body_side            1251 non-null   object
#  18  build_quality        739 non-null    object
#  19  ports                1268 non-null   object
#  20  ip_rating            915 non-null    object
#  21  speaker              1265 non-null   object
#  22  chipset              1268 non-null   object
#  23  cpu                  1268 non-null   object
#  24  gpu                  1250 non-null   object
#  25  main_cam             1268 non-null   object
#  26  main_cam2            1214 non-null   object
#  27  main_cam3            631 non-null    object
#  28  main_cam_features    1268 non-null   object
#  29  main_video           1239 non-null   object
#  30  os                   1268 non-null   object
#  31  software_updates     1228 non-null   object
#  32  ai_features          780 non-null    object
#  33  front_cam            1268 non-null   object
#  34  front_cam_features   1026 non-null   object
#  35  front_video          1229 non-null   object
#  36  battery              1268 non-null   object
#  37  charging             1268 non-null   object
#  38  storage              1268 non-null   object
#  39  ram                  1268 non-null   object
#  40  sim                  1264 non-null   object
#  41  tech                 1200 non-null   object
#  42  2g                   1262 non-null   object
#  43  3g                   1264 non-null   object
#  44  4g                   1267 non-null   object
#  45  5g                   1028 non-null   object
#  46  speed                1264 non-null   object
#  47  wifi                 1268 non-null   object
#  48  bluetooth            1266 non-null   object
#  49  positioning_system   1268 non-null   object
#  50  nfc                  595 non-null    object
#  51  finger_print         1192 non-null   object
#  52  sensors              1268 non-null   object
#  53  add_features         469 non-null    object
#  54  flipkart_buy_link    1085 non-null   object
#  55  amazon_buy_link      724 non-null    object
#  56  official_store_link  610 non-null    object
#  57  brand                1268 non-null   category
# dtypes: category(1), float64(2), int64(2), object(53)
# memory usage: 566.7+ KB

# %%
df['market_status'].value_counts()
# Out:
# market_status
# In Stock        896
# Out of Stock    372
# Name: count, dtype: int64

# %%
def market(text):

  t = text.lower()

  if t == 'in stock':
    return 1
  elif t == 'out of stock':
    return 0

df['is_available'] = df['market_status'].apply(market)

# %%
df['is_available'].value_counts()
# Out:
# is_available
# 1    896
# 0    372
# Name: count, dtype: int64

# %%
df.drop(columns='market_status',inplace=True)

# %%
df['launch_on']
# Out:
# 0       07 Sep 2022
# 1       07 Sep 2022
# 2       07 Sep 2022
# 3       07 Sep 2022
# 4       07 Sep 2022
#            ...
# 1263    07 Mar 2024
# 1264    11 Mar 2025
# 1265    11 Mar 2025
# 1266    09 May 2023
# 1267    09 May 2023
# Name: launch_on, Length: 1268, dtype: object

# %%
df['launch_on'] = pd.to_datetime(df['launch_on'])

# %%
df['launch_on']
# Out:
# 0      2022-09-07
# 1      2022-09-07
# 2      2022-09-07
# 3      2022-09-07
# 4      2022-09-07
#           ...
# 1263   2024-03-07
# 1264   2025-03-11
# 1265   2025-03-11
# 1266   2023-05-09
# 1267   2023-05-09
# Name: launch_on, Length: 1268, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 58 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   model_id             1268 non-null   int64
#  1   model                1268 non-null   object
#  2   expert_rating        1268 non-null   int64
#  3   rating               1268 non-null   float64
#  4   rating_count         994 non-null    float64
#  5   launch_on            1268 non-null   datetime64[ns]
#  6   old_price            1149 non-null   object
#  7   price                1268 non-null   object
#  8   launch_price         1268 non-null   object
#  9   display_type         1268 non-null   object
#  10  display_size         1268 non-null   object
#  11  display_res          1268 non-null   object
#  12  body_dimension       1268 non-null   object
#  13  weight               1268 non-null   object
#  14  body_front           1268 non-null   object
#  15  body_back            1238 non-null   object
#  16  body_side            1251 non-null   object
#  17  build_quality        739 non-null    object
#  18  ports                1268 non-null   object
#  19  ip_rating            915 non-null    object
#  20  speaker              1265 non-null   object
#  21  chipset              1268 non-null   object
#  22  cpu                  1268 non-null   object
#  23  gpu                  1250 non-null   object
#  24  main_cam             1268 non-null   object
#  25  main_cam2            1214 non-null   object
#  26  main_cam3            631 non-null    object
#  27  main_cam_features    1268 non-null   object
#  28  main_video           1239 non-null   object
#  29  os                   1268 non-null   object
#  30  software_updates     1228 non-null   object
#  31  ai_features          780 non-null    object
#  32  front_cam            1268 non-null   object
#  33  front_cam_features   1026 non-null   object
#  34  front_video          1229 non-null   object
#  35  battery              1268 non-null   object
#  36  charging             1268 non-null   object
#  37  storage              1268 non-null   object
#  38  ram                  1268 non-null   object
#  39  sim                  1264 non-null   object
#  40  tech                 1200 non-null   object
#  41  2g                   1262 non-null   object
#  42  3g                   1264 non-null   object
#  43  4g                   1267 non-null   object
#  44  5g                   1028 non-null   object
#  45  speed                1264 non-null   object
#  46  wifi                 1268 non-null   object
#  47  bluetooth            1266 non-null   object
#  48  positioning_system   1268 non-null   object
#  49  nfc                  595 non-null    object
#  50  finger_print         1192 non-null   object
#  51  sensors              1268 non-null   object
#  52  add_features         469 non-null    object
#  53  flipkart_buy_link    1085 non-null   object
#  54  amazon_buy_link      724 non-null    object
#  55  official_store_link  610 non-null    object
#  56  brand                1268 non-null   category
#  57  is_available         1268 non-null   int64
# dtypes: category(1), datetime64[ns](1), float64(2), int64(3), object(51)
# memory usage: 566.7+ KB

# %%
df['old_price'].value_counts()
# Out:
# old_price
# Lowest price since launch Lowest price since launch      305
# Was ₹7,999 2 month(s) ago Was ₹7,999 2 month(s) ago        8
# Was ₹15,999 2 month(s) ago Was ₹15,999 2 month(s) ago      8
# Was ₹22,999 2 month(s) ago Was ₹22,999 2 month(s) ago      7
# Was ₹13,999 2 month(s) ago Was ₹13,999 2 month(s) ago      7
#                                                         ...
# Was ₹47,839 22 day(s) ago Was ₹47,839 22 day(s) ago        1
# Was ₹25,999 2 month(s) ago Was ₹25,999 2 month(s) ago      1
# Was ₹34,999 10 day(s) ago Was ₹34,999 10 day(s) ago        1
# Was ₹23,799 5 day(s) ago Was ₹23,799 5 day(s) ago          1
# Was ₹21,300 1 month(s) ago Was ₹21,300 1 month(s) ago      1
# Name: count, Length: 667, dtype: int64

# %%
df['old_price'] = df['old_price'].str.lower().str.split(' ').str.get(1)

# %%
df.loc[df['old_price'] == 'price','old_price'] = np.nan

# %%
df['old_price'].value_counts(dropna=False)
# Out:
# old_price
# NaN        424
# ₹11,999     18
# ₹9,999      16
# ₹22,999     16
# ₹10,999     15
#           ...
# ₹13,898      1
# ₹12,754      1
# ₹11,874      1
# ₹11,450      1
# ₹22,319      1
# Name: count, Length: 448, dtype: int64

# %%
df['old_price'] = df['old_price'].str.replace('₹','')

# %%
df['old_price'] = df['old_price'].str.replace(',','')

# %%
df['old_price'] = df['old_price'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 58 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   model_id             1268 non-null   int64
#  1   model                1268 non-null   object
#  2   expert_rating        1268 non-null   int64
#  3   rating               1268 non-null   float64
#  4   rating_count         994 non-null    float64
#  5   launch_on            1268 non-null   datetime64[ns]
#  6   old_price            844 non-null    float64
#  7   price                1268 non-null   object
#  8   launch_price         1268 non-null   object
#  9   display_type         1268 non-null   object
#  10  display_size         1268 non-null   object
#  11  display_res          1268 non-null   object
#  12  body_dimension       1268 non-null   object
#  13  weight               1268 non-null   object
#  14  body_front           1268 non-null   object
#  15  body_back            1238 non-null   object
#  16  body_side            1251 non-null   object
#  17  build_quality        739 non-null    object
#  18  ports                1268 non-null   object
#  19  ip_rating            915 non-null    object
#  20  speaker              1265 non-null   object
#  21  chipset              1268 non-null   object
#  22  cpu                  1268 non-null   object
#  23  gpu                  1250 non-null   object
#  24  main_cam             1268 non-null   object
#  25  main_cam2            1214 non-null   object
#  26  main_cam3            631 non-null    object
#  27  main_cam_features    1268 non-null   object
#  28  main_video           1239 non-null   object
#  29  os                   1268 non-null   object
#  30  software_updates     1228 non-null   object
#  31  ai_features          780 non-null    object
#  32  front_cam            1268 non-null   object
#  33  front_cam_features   1026 non-null   object
#  34  front_video          1229 non-null   object
#  35  battery              1268 non-null   object
#  36  charging             1268 non-null   object
#  37  storage              1268 non-null   object
#  38  ram                  1268 non-null   object
#  39  sim                  1264 non-null   object
#  40  tech                 1200 non-null   object
#  41  2g                   1262 non-null   object
#  42  3g                   1264 non-null   object
#  43  4g                   1267 non-null   object
#  44  5g                   1028 non-null   object
#  45  speed                1264 non-null   object
#  46  wifi                 1268 non-null   object
#  47  bluetooth            1266 non-null   object
#  48  positioning_system   1268 non-null   object
#  49  nfc                  595 non-null    object
#  50  finger_print         1192 non-null   object
#  51  sensors              1268 non-null   object
#  52  add_features         469 non-null    object
#  53  flipkart_buy_link    1085 non-null   object
#  54  amazon_buy_link      724 non-null    object
#  55  official_store_link  610 non-null    object
#  56  brand                1268 non-null   category
#  57  is_available         1268 non-null   int64
# dtypes: category(1), datetime64[ns](1), float64(3), int64(3), object(50)
# memory usage: 566.7+ KB

# %%
df['price'] = df['price'].str.replace('₹','')

# %%
df['price'] = df['price'].str.replace(',','')

# %%
df['price'] = df['price'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 58 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   model_id             1268 non-null   int64
#  1   model                1268 non-null   object
#  2   expert_rating        1268 non-null   int64
#  3   rating               1268 non-null   float64
#  4   rating_count         994 non-null    float64
#  5   launch_on            1268 non-null   datetime64[ns]
#  6   old_price            844 non-null    float64
#  7   price                1268 non-null   int64
#  8   launch_price         1268 non-null   object
#  9   display_type         1268 non-null   object
#  10  display_size         1268 non-null   object
#  11  display_res          1268 non-null   object
#  12  body_dimension       1268 non-null   object
#  13  weight               1268 non-null   object
#  14  body_front           1268 non-null   object
#  15  body_back            1238 non-null   object
#  16  body_side            1251 non-null   object
#  17  build_quality        739 non-null    object
#  18  ports                1268 non-null   object
#  19  ip_rating            915 non-null    object
#  20  speaker              1265 non-null   object
#  21  chipset              1268 non-null   object
#  22  cpu                  1268 non-null   object
#  23  gpu                  1250 non-null   object
#  24  main_cam             1268 non-null   object
#  25  main_cam2            1214 non-null   object
#  26  main_cam3            631 non-null    object
#  27  main_cam_features    1268 non-null   object
#  28  main_video           1239 non-null   object
#  29  os                   1268 non-null   object
#  30  software_updates     1228 non-null   object
#  31  ai_features          780 non-null    object
#  32  front_cam            1268 non-null   object
#  33  front_cam_features   1026 non-null   object
#  34  front_video          1229 non-null   object
#  35  battery              1268 non-null   object
#  36  charging             1268 non-null   object
#  37  storage              1268 non-null   object
#  38  ram                  1268 non-null   object
#  39  sim                  1264 non-null   object
#  40  tech                 1200 non-null   object
#  41  2g                   1262 non-null   object
#  42  3g                   1264 non-null   object
#  43  4g                   1267 non-null   object
#  44  5g                   1028 non-null   object
#  45  speed                1264 non-null   object
#  46  wifi                 1268 non-null   object
#  47  bluetooth            1266 non-null   object
#  48  positioning_system   1268 non-null   object
#  49  nfc                  595 non-null    object
#  50  finger_print         1192 non-null   object
#  51  sensors              1268 non-null   object
#  52  add_features         469 non-null    object
#  53  flipkart_buy_link    1085 non-null   object
#  54  amazon_buy_link      724 non-null    object
#  55  official_store_link  610 non-null    object
#  56  brand                1268 non-null   category
#  57  is_available         1268 non-null   int64
# dtypes: category(1), datetime64[ns](1), float64(3), int64(4), object(49)
# memory usage: 566.7+ KB

# %%
df['launch_price'] = df['launch_price'].str.replace('₹','').str.replace(',','').astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 58 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   model_id             1268 non-null   int64
#  1   model                1268 non-null   object
#  2   expert_rating        1268 non-null   int64
#  3   rating               1268 non-null   float64
#  4   rating_count         994 non-null    float64
#  5   launch_on            1268 non-null   datetime64[ns]
#  6   old_price            844 non-null    float64
#  7   price                1268 non-null   int64
#  8   launch_price         1268 non-null   int64
#  9   display_type         1268 non-null   object
#  10  display_size         1268 non-null   object
#  11  display_res          1268 non-null   object
#  12  body_dimension       1268 non-null   object
#  13  weight               1268 non-null   object
#  14  body_front           1268 non-null   object
#  15  body_back            1238 non-null   object
#  16  body_side            1251 non-null   object
#  17  build_quality        739 non-null    object
#  18  ports                1268 non-null   object
#  19  ip_rating            915 non-null    object
#  20  speaker              1265 non-null   object
#  21  chipset              1268 non-null   object
#  22  cpu                  1268 non-null   object
#  23  gpu                  1250 non-null   object
#  24  main_cam             1268 non-null   object
#  25  main_cam2            1214 non-null   object
#  26  main_cam3            631 non-null    object
#  27  main_cam_features    1268 non-null   object
#  28  main_video           1239 non-null   object
#  29  os                   1268 non-null   object
#  30  software_updates     1228 non-null   object
#  31  ai_features          780 non-null    object
#  32  front_cam            1268 non-null   object
#  33  front_cam_features   1026 non-null   object
#  34  front_video          1229 non-null   object
#  35  battery              1268 non-null   object
#  36  charging             1268 non-null   object
#  37  storage              1268 non-null   object
#  38  ram                  1268 non-null   object
#  39  sim                  1264 non-null   object
#  40  tech                 1200 non-null   object
#  41  2g                   1262 non-null   object
#  42  3g                   1264 non-null   object
#  43  4g                   1267 non-null   object
#  44  5g                   1028 non-null   object
#  45  speed                1264 non-null   object
#  46  wifi                 1268 non-null   object
#  47  bluetooth            1266 non-null   object
#  48  positioning_system   1268 non-null   object
#  49  nfc                  595 non-null    object
#  50  finger_print         1192 non-null   object
#  51  sensors              1268 non-null   object
#  52  add_features         469 non-null    object
#  53  flipkart_buy_link    1085 non-null   object
#  54  amazon_buy_link      724 non-null    object
#  55  official_store_link  610 non-null    object
#  56  brand                1268 non-null   category
#  57  is_available         1268 non-null   int64
# dtypes: category(1), datetime64[ns](1), float64(3), int64(5), object(48)
# memory usage: 566.7+ KB

# %%
df['is_flipkart_available'] = df['flipkart_buy_link'].notna().astype('int')

# %%
df['is_flipkart_available'].value_counts()
# Out:
# is_flipkart_available
# 1    1085
# 0     183
# Name: count, dtype: int64

# %%
df['is_amazon_available'] = df['amazon_buy_link'].notna().astype('int')

# %%
df['is_amazon_available'].value_counts()
# Out:
# is_amazon_available
# 1    724
# 0    544
# Name: count, dtype: int64

# %%
df['is_official_available'] = df['official_store_link'].notna().astype('int')

# %%
df['is_official_available'].value_counts()
# Out:
# is_official_available
# 0    658
# 1    610
# Name: count, dtype: int64

# %%
df.drop(columns=['flipkart_buy_link','amazon_buy_link','official_store_link'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 58 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   model_id               1268 non-null   int64
#  1   model                  1268 non-null   object
#  2   expert_rating          1268 non-null   int64
#  3   rating                 1268 non-null   float64
#  4   rating_count           994 non-null    float64
#  5   launch_on              1268 non-null   datetime64[ns]
#  6   old_price              844 non-null    float64
#  7   price                  1268 non-null   int64
#  8   launch_price           1268 non-null   int64
#  9   display_type           1268 non-null   object
#  10  display_size           1268 non-null   object
#  11  display_res            1268 non-null   object
#  12  body_dimension         1268 non-null   object
#  13  weight                 1268 non-null   object
#  14  body_front             1268 non-null   object
#  15  body_back              1238 non-null   object
#  16  body_side              1251 non-null   object
#  17  build_quality          739 non-null    object
#  18  ports                  1268 non-null   object
#  19  ip_rating              915 non-null    object
#  20  speaker                1265 non-null   object
#  21  chipset                1268 non-null   object
#  22  cpu                    1268 non-null   object
#  23  gpu                    1250 non-null   object
#  24  main_cam               1268 non-null   object
#  25  main_cam2              1214 non-null   object
#  26  main_cam3              631 non-null    object
#  27  main_cam_features      1268 non-null   object
#  28  main_video             1239 non-null   object
#  29  os                     1268 non-null   object
#  30  software_updates       1228 non-null   object
#  31  ai_features            780 non-null    object
#  32  front_cam              1268 non-null   object
#  33  front_cam_features     1026 non-null   object
#  34  front_video            1229 non-null   object
#  35  battery                1268 non-null   object
#  36  charging               1268 non-null   object
#  37  storage                1268 non-null   object
#  38  ram                    1268 non-null   object
#  39  sim                    1264 non-null   object
#  40  tech                   1200 non-null   object
#  41  2g                     1262 non-null   object
#  42  3g                     1264 non-null   object
#  43  4g                     1267 non-null   object
#  44  5g                     1028 non-null   object
#  45  speed                  1264 non-null   object
#  46  wifi                   1268 non-null   object
#  47  bluetooth              1266 non-null   object
#  48  positioning_system     1268 non-null   object
#  49  nfc                    595 non-null    object
#  50  finger_print           1192 non-null   object
#  51  sensors                1268 non-null   object
#  52  add_features           469 non-null    object
#  53  brand                  1268 non-null   category
#  54  is_available           1268 non-null   int64
#  55  is_flipkart_available  1268 non-null   int64
#  56  is_amazon_available    1268 non-null   int64
#  57  is_official_available  1268 non-null   int64
# dtypes: category(1), datetime64[ns](1), float64(3), int64(8), object(45)
# memory usage: 566.7+ KB

# %%
df['display_type'].sample(10)
# Out:
# 1149                                                    AMOLED, 120 Hz Refresh Rate, HDR10+, 480 Hz Touch Sampling Rate
# 1043    Dynamic 2X AMOLED, 120 Hz Refresh Rate, LTPO, Dolby Vision, 240 Hz Touch Sampling Rate, Anti Reflection Coating
# 1143                                                    AMOLED, 120 Hz Refresh Rate, HDR10+, 300 Hz Touch Sampling Rate
# 725                                                       IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 640                                                        IPS LCD, 60 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 1160                                                                                AMOLED, 120 Hz Refresh Rate, HDR10+
# 442                                  ProXDR AMOLED, 120 Hz Refresh Rate, LTPO, Dolby Vision, 240 Hz Touch Sampling Rate
# 108                                                       IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 954                                                   Super AMOLED, 90 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 1234                                                                                  IPS LCD, 120 Hz Refresh Rate, SDR
# Name: display_type, dtype: object

# %%
# creating column for display_panel_type

df['display_panel_type'] = df['display_type'].str.lower().str.split(',').str.get(0)

# %%
df['display_panel_type'].value_counts(dropna=False)
# Out:
# display_panel_type
# amoled                          324
# ips lcd                         310
# super amoled                    105
# lcd                              68
# dynamic 2x amoled                60
# super retina xdr oled            49
# oled                             40
# proxdr amoled                    32
# p-oled                           30
# pls lcd                          27
# dot amoled                       25
# hdr amoled                       23
# e4 amoled                        17
# dot ips lcd                      16
# fluid amoled                     10
# e5 amoled                         9
# ultra smooth display ips lcd      9
# super actua oled                  8
# smooth display amoled             8
# pro hdr amoled                    8
# turbo amoled                      7
# proxdr oled                       7
# ultra amoled                      7
# e6 amoled                         6
# flow amoled                       6
# q10+ amoled                       6
# 3d amoled amoled                  5
# super retina xdr amoled           5
# q10 amoled                        4
# tft lcd                           4
# hyperglow amoled                  3
# e7 amoled                         3
# fluid oled                        2
# tft ips                           2
# ips                               2
# led                               2
# u8 amoled                         2
# ultra smooth display amoled       2
# ultra smooth display lcd          2
# trinity engine amoled             2
# boundless display ips lcd         2
# smooth display oled               1
# true colour display amoled        1
# dynamic ips lcd                   1
# hdr oled                          1
# super actua ips lcd               1
# ips a-si                          1
# smooth display ips lcd            1
# smooth display lcd                1
# dynamic amoled                    1
# Name: count, dtype: int64

# %%
# there are more than 50+ category so we have to make new column

def display_panel_family(text):

    t = text.lower()

    if 'amoled' in t:
      return 'amoled'

    if 'oled' in t and 'amoled' not in t:
      return 'oled'

    if 'ips lcd' in t or ('ips' in t and 'tft' not in t):
      return 'ips lcd'

    if 'tft' in t:
      return 'tft'

    if 'led' in t:
      return 'led'

    if 'lcd' in t:
      return 'lcd'

    return 'unknown'

df['display_panel_family'] = df['display_panel_type'].apply(display_panel_family)

# %%
df['display_panel_family'].value_counts()
# Out:
# display_panel_family
# amoled     681
# ips lcd    343
# oled       138
# lcd         98
# tft          6
# led          2
# Name: count, dtype: int64

# %%
# convert display_panel_family from object dtypes to category

df['display_panel_family'] = df['display_panel_family'].astype('category')

# %%
df['display_type'].sample(10)
# Out:
# 376     Ultra AMOLED, 120 Hz Refresh Rate, HDR10+, 120 Hz Touch Sampling Rate
# 979               IPS LCD, 90 Hz Refresh Rate, SDR, 90 Hz Touch Sampling Rate
# 290                                          IPS LCD, 90 Hz Refresh Rate, SDR
# 811             IPS LCD, 120 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 134             IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 1049                           Dynamic 2X AMOLED, 120 Hz Refresh Rate, HDR10+
# 1235                                        IPS LCD, 120 Hz Refresh Rate, SDR
# 1                     Super Retina XDR OLED, 60 Hz Refresh Rate, Dolby Vision
# 592                OLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 894                                          IPS LCD, 90 Hz Refresh Rate, SDR
# Name: display_type, dtype: object

# %%
# creating new col from display_type name display_hz

df['display_hz'] = df['display_type'].str.lower().str.split(',').str.get(1)

# %%
df['display_hz'] = df['display_hz'].str.split(' ').str.get(1)

# %%
df['display_hz'].value_counts()
# Out:
# display_hz
# 120    781
# 90     274
# 60     119
# 144     81
# 165     12
# sdr      1
# Name: count, dtype: int64

# %%
df[df['display_hz'].str.contains('sdr')]
# Out:
#      model_id                   model  expert_rating  rating  rating_count  \
# 228       229  Moto E13 (8GB + 128GB)             50     4.1      371000.0
#
#      launch_on  old_price  price  launch_price  display_type  \
# 228 2023-02-08        NaN   9299          6999  IPS LCD, SDR
#
#                                         display_size  \
# 228  6.5 inches, 102 cm², 89.2% Screen To Body Ratio
#
#                                                 display_res  \
# 228  HD+, 720 x  1600 pixels, 20:9 (269 ppi), 8-bit colours
#
#                body_dimension       weight body_front body_back  \
# 228  164.19 x 74.95 x 8.47 mm  179.5 grams      Glass   Plastic
#
#          body_side     build_quality  \
# 228  Plastic Frame  Plastic Material
#
#                                          ports  \
# 228  USB Type-C 2.0, 3.5mm Headphone Jack, OTG
#
#                             ip_rating       speaker  \
# 228  IP52 (Dust and Splash Resistant)  Mono Speaker
#
#                                       chipset  \
# 228  Unisoc T606 (12 nm), 246197 Antutu Score
#
#                                                          cpu           gpu  \
# 228  Octa-core (2x1.6 GHz Cortex-A75 & 6x1.6 GHz Cortex-A55)  Mali-G57 MP1
#
#                                       main_cam main_cam2 main_cam3  \
# 228  13 MP, f/2.2, (Wide-angle), 1.12 µm, PDAF       NaN       NaN
#
#                       main_cam_features   main_video  \
# 228  HDR, LED Flash, Panorama, Pro Mode  1080p@30fps
#
#                                os software_updates  \
# 228  Android Go 13, Motorola MyUx              NaN
#
#                                   ai_features  \
# 228  AI Beauty, AI Camera, Auto Smile Capture
#
#                                     front_cam  \
# 228  5 MP, f/2.2, (Wide-angle), 1.12 µm, 1/5"
#
#                             front_cam_features  front_video  \
# 228  AI Beauty Mode, HDR Photos, Portrait Mode  1080p@30fps
#
#                                        battery     charging          storage  \
# 228  5000 mAh, Lithium Polymer (Non-removable)  10W (wired)  128GB, eMMC 5.1
#
#               ram                                        sim            tech  \
# 228  8GB, LPDDR4X  Hybrid Dual SIM (2 Nano SIMs + 1 microSD)  GSM, HSPA, LTE
#
#                     2g                 3g  \
# 228  3, 5, 8 (3 bands)  1, 5, 8 (3 bands)
#
#                                                4g   5g           speed  \
# 228  1, 3, 5, 7, 8, 20, 28, 38, 40, 41 (10 bands)  NaN  GSM, HSPA, LTE
#
#                                               wifi           bluetooth  \
# 228  Wi-Fi 5 802.11 a/b/g/n/ac, Hotspot, Dual Band  A2DP, AAC, LE, SBC
#
#                             positioning_system  nfc finger_print  \
# 228  A-GPS, GALILEO, GLONASS, GPS, LTEPP, SUPL  NaN          NaN
#
#                                                    sensors add_features  \
# 228  Accelerometer, Ambient Light Sensor, Proximity Sensor          NaN
#
#         brand  is_available  is_flipkart_available  is_amazon_available  \
# 228  motorola             0                      0                    1
#
#      is_official_available display_panel_type display_panel_family display_hz
# 228                      0            ips lcd              ips lcd        sdr

# %%
# this model display_hz is not available so fill 60 as default
df.loc[228,'display_hz'] = 60

# %%
df['display_hz'].value_counts()
# Out:
# display_hz
# 120    781
# 90     274
# 60     119
# 144     81
# 165     12
# 60       1
# Name: count, dtype: int64

# %%
# converting data types of diplay_hz to numeric

df['display_hz'] = pd.to_numeric(df['display_hz'],errors='coerce')

# %%
df['display_hz'].dtypes
# Out:
# dtype('int64')

# %%
df['display_type'].sample(20)
# Out:
# 15                                             Super Retina XDR OLED, 60 Hz Refresh Rate, HDR10
# 301                                p-OLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 1211                                                        E4 AMOLED, 120 Hz Refresh Rate, SDR
# 65                                                         OLED, 120 Hz Refresh Rate, LTPO, HDR
# 985                           Super AMOLED, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 606                                                              OLED, 120 Hz Refresh Rate, SDR
# 1015                                       Dynamic 2X AMOLED, 120 Hz Refresh Rate, LTPO, HDR10+
# 47      Super Retina XDR OLED, 120 Hz Refresh Rate, LTPO, Dolby Vision, Anti Reflection Coating
# 1244                         U8 AMOLED, 120 Hz Refresh Rate, HDR10+, 300 Hz Touch Sampling Rate
# 1257             E5 AMOLED, 120 Hz Refresh Rate, LTPO, Dolby Vision, 480 Hz Touch Sampling Rate
# 1152                            AMOLED, 120 Hz Refresh Rate, HDR10+, 480 Hz Touch Sampling Rate
# 677                          AMOLED, 120 Hz Refresh Rate, LTPO, HDR, 360 Hz Touch Sampling Rate
# 633                                IPS LCD, 60 Hz Refresh Rate, SDR, 120 Hz Touch Sampling Rate
# 766                               IPS LCD, 120 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 284                            p-OLED, 120 Hz Refresh Rate, HDR10+, 1500 Hz Touch Sampling Rate
# 174                        HDR AMOLED, 144 Hz Refresh Rate, HDR10+, 2000 Hz Touch Sampling Rate
# 925                          Super AMOLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 679                          AMOLED, 120 Hz Refresh Rate, LTPO, HDR, 360 Hz Touch Sampling Rate
# 49      Super Retina XDR OLED, 120 Hz Refresh Rate, LTPO, Dolby Vision, Anti Reflection Coating
# 1179                                             Q10+ AMOLED, 120 Hz Refresh Rate, LTPO, HDR10+
# Name: display_type, dtype: object

# %%
# keeping only hdr10+ , hd10 and sdr
def display_dynamic_range(text):

  t = text

  if 'Dolby Vision' in t:
    return 'Dolby Vision'
  if 'HDR10+' in t:
    return 'HDR10+'
  if 'ProXDR' in t:
    return 'ProXDR'
  if 'HDR' in t:
    return 'HDR'
  if 'HDR10' in t:
    return 'HDR10'
  if 'Pro HDR' in t:
    return 'HDR'

  return 'SDR'

df['display_dynamic_range'] = df['display_type'].apply(display_dynamic_range)

# %%
df['display_dynamic_range'].value_counts(dropna=False)
# Out:
# display_dynamic_range
# SDR             660
# HDR10+          371
# Dolby Vision    138
# HDR              87
# ProXDR           12
# Name: count, dtype: int64

# %%
df['display_dynamic_range'].count()
# Out:
# np.int64(1268)

# %%
df[df['display_dynamic_range'].str.contains('SDR')]['display_type'].sample(20)
# Out:
# 1200                                          LCD, 90 Hz Refresh Rate, SDR
# 1218                                      IPS LCD, 90 Hz Refresh Rate, SDR
# 646           IPS LCD, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 497          IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 809          IPS LCD, 120 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 418                       Smooth Display IPS LCD, 120 Hz Refresh Rate, SDR
# 401                                       IPS LCD, 90 Hz Refresh Rate, SDR
# 131           AMOLED, 144 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 1010    Super AMOLED, 120 Hz Refresh Rate, SDR, 360 Hz Touch Sampling Rate
# 990                                  Super AMOLED, 90 Hz Refresh Rate, SDR
# 1253          AMOLED, 120 Hz Refresh Rate, SDR, 360 Hz Touch Sampling Rate
# 1229             LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 716          AMOLED, 120 Hz Refresh Rate, SDR, 2200 Hz Touch Sampling Rate
# 1206                                          LCD, 90 Hz Refresh Rate, SDR
# 453           AMOLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 838                                       AMOLED, 120 Hz Refresh Rate, SDR
# 434       Q10 AMOLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 633           IPS LCD, 60 Hz Refresh Rate, SDR, 120 Hz Touch Sampling Rate
# 786                                       IPS LCD, 90 Hz Refresh Rate, SDR
# 742           IPS LCD, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# Name: display_type, dtype: object

# %%
# converting display_dynamic_range into category
df['display_dynamic_range'] = df['display_dynamic_range'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 62 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   model_id               1268 non-null   int64
#  1   model                  1268 non-null   object
#  2   expert_rating          1268 non-null   int64
#  3   rating                 1268 non-null   float64
#  4   rating_count           994 non-null    float64
#  5   launch_on              1268 non-null   datetime64[ns]
#  6   old_price              844 non-null    float64
#  7   price                  1268 non-null   int64
#  8   launch_price           1268 non-null   int64
#  9   display_type           1268 non-null   object
#  10  display_size           1268 non-null   object
#  11  display_res            1268 non-null   object
#  12  body_dimension         1268 non-null   object
#  13  weight                 1268 non-null   object
#  14  body_front             1268 non-null   object
#  15  body_back              1238 non-null   object
#  16  body_side              1251 non-null   object
#  17  build_quality          739 non-null    object
#  18  ports                  1268 non-null   object
#  19  ip_rating              915 non-null    object
#  20  speaker                1265 non-null   object
#  21  chipset                1268 non-null   object
#  22  cpu                    1268 non-null   object
#  23  gpu                    1250 non-null   object
#  24  main_cam               1268 non-null   object
#  25  main_cam2              1214 non-null   object
#  26  main_cam3              631 non-null    object
#  27  main_cam_features      1268 non-null   object
#  28  main_video             1239 non-null   object
#  29  os                     1268 non-null   object
#  30  software_updates       1228 non-null   object
#  31  ai_features            780 non-null    object
#  32  front_cam              1268 non-null   object
#  33  front_cam_features     1026 non-null   object
#  34  front_video            1229 non-null   object
#  35  battery                1268 non-null   object
#  36  charging               1268 non-null   object
#  37  storage                1268 non-null   object
#  38  ram                    1268 non-null   object
#  39  sim                    1264 non-null   object
#  40  tech                   1200 non-null   object
#  41  2g                     1262 non-null   object
#  42  3g                     1264 non-null   object
#  43  4g                     1267 non-null   object
#  44  5g                     1028 non-null   object
#  45  speed                  1264 non-null   object
#  46  wifi                   1268 non-null   object
#  47  bluetooth              1266 non-null   object
#  48  positioning_system     1268 non-null   object
#  49  nfc                    595 non-null    object
#  50  finger_print           1192 non-null   object
#  51  sensors                1268 non-null   object
#  52  add_features           469 non-null    object
#  53  brand                  1268 non-null   category
#  54  is_available           1268 non-null   int64
#  55  is_flipkart_available  1268 non-null   int64
#  56  is_amazon_available    1268 non-null   int64
#  57  is_official_available  1268 non-null   int64
#  58  display_panel_type     1268 non-null   object
#  59  display_panel_family   1268 non-null   category
#  60  display_hz             1268 non-null   int64
#  61  display_dynamic_range  1268 non-null   category
# dtypes: category(3), datetime64[ns](1), float64(3), int64(9), object(46)
# memory usage: 589.4+ KB

# %%
df[df['display_type'].str.contains("Touch Sampling Rate")]['display_type'].sample(20)
# Out:
# 1121                     AMOLED, 90 Hz Refresh Rate, HDR10+, 180 Hz Touch Sampling Rate
# 666                       IPS LCD, 120 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 1250                       AMOLED, 120 Hz Refresh Rate, SDR, 360 Hz Touch Sampling Rate
# 461                 OLED, 120 Hz Refresh Rate, LTPO, HDR10+, 240 Hz Touch Sampling Rate
# 841                  Dot AMOLED, 120 Hz Refresh Rate, HDR10, 360 Hz Touch Sampling Rate
# 515                     Dot AMOLED, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 670                           LCD, 144 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 394                       IPS LCD, 120 Hz Refresh Rate, SDR, 120 Hz Touch Sampling Rate
# 709                        IPS LCD, 60 Hz Refresh Rate, SDR, 120 Hz Touch Sampling Rate
# 856       Pro HDR AMOLED, 120 Hz Refresh Rate, Dolby Vision, 240 Hz Touch Sampling Rate
# 105                       IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 726                        IPS LCD, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 623                   Super AMOLED, 90 Hz Refresh Rate, SDR, 360 Hz Touch Sampling Rate
# 695     Smooth Display AMOLED, 120 Hz Refresh Rate, HDR10+, 1000 Hz Touch Sampling Rate
# 755                 ProXDR AMOLED, 120 Hz Refresh Rate, HDR, 240 Hz Touch Sampling Rate
# 449                        AMOLED, 120 Hz Refresh Rate, HDR, 180 Hz Touch Sampling Rate
# 398                       IPS LCD, 120 Hz Refresh Rate, SDR, 120 Hz Touch Sampling Rate
# 312                     AMOLED, 120 Hz Refresh Rate, HDR10+, 240 Hz Touch Sampling Rate
# 833                       IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 736                        AMOLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# Name: display_type, dtype: object

# %%
# using regx to extract touch sampling rate

def extract_touch_sampling_rate(text):

  t = text.lower()

  match = re.search(r'(\d{2,4})\s*hz\s*touch', t)

  if match:
    return int(match.group(1))

  return np.nan

df['touch_sampling_rate'] = df['display_type'].apply(extract_touch_sampling_rate)

# %%
df['touch_sampling_rate'].value_counts(dropna=False)
# Out:
# touch_sampling_rate
# NaN       416
# 240.0     369
# 180.0     164
# 360.0     121
# 120.0      47
# 300.0      40
# 1000.0     29
# 480.0      27
# 1200.0     13
# 90.0       10
# 720.0       5
# 288.0       5
# 60.0        4
# 270.0       3
# 2000.0      3
# 1500.0      3
# 960.0       2
# 2200.0      2
# 600.0       2
# 2500.0      2
# 3000.0      1
# Name: count, dtype: int64

# %%
df['display_type'].sample(20)
# Out:
# 646                            IPS LCD, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 1155                        AMOLED, 120 Hz Refresh Rate, HDR10+, 240 Hz Touch Sampling Rate
# 406                               LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 502                     Dot AMOLED, 120 Hz Refresh Rate, HDR10+, 360 Hz Touch Sampling Rate
# 1191                                                       IPS LCD, 60 Hz Refresh Rate, SDR
# 472                         AMOLED, 120 Hz Refresh Rate, HDR10+, 240 Hz Touch Sampling Rate
# 554                                                   Super AMOLED, 90 Hz Refresh Rate, SDR
# 1017                                         Dynamic 2X AMOLED, 120 Hz Refresh Rate, HDR10+
# 1220                                                       IPS LCD, 90 Hz Refresh Rate, SDR
# 157                E7 AMOLED, 144 Hz Refresh Rate, LTPO, HDR10+, 300 Hz Touch Sampling Rate
# 462                   AMOLED, 120 Hz Refresh Rate, LTPO, HDR10+, 240 Hz Touch Sampling Rate
# 1265    Pro HDR AMOLED, 120 Hz Refresh Rate, LTPO, Dolby Vision, 300 Hz Touch Sampling Rate
# 635                            IPS LCD, 60 Hz Refresh Rate, SDR, 120 Hz Touch Sampling Rate
# 583                   ProXDR OLED, 120 Hz Refresh Rate, HDR10+, 1200 Hz Touch Sampling Rate
# 89                                        HDR OLED, 120 Hz Refresh Rate, LTPO, Dolby Vision
# 98                             AMOLED, 144 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 213                       Ultra AMOLED, 90 Hz Refresh Rate, SDR, 360 Hz Touch Sampling Rate
# 892                                                        IPS LCD, 60 Hz Refresh Rate, SDR
# 740                            IPS LCD, 90 Hz Refresh Rate, SDR, 180 Hz Touch Sampling Rate
# 694                                                     AMOLED, 120 Hz Refresh Rate, HDR10+
# Name: display_type, dtype: object

# %%
df[df['display_type'].str.contains('LTPO')]['display_type'].count()
# Out:
# np.int64(212)

# %%
def extract_lpo(text):

  t = text.lower()

  if 'ltpo' in t:
    return 1

  return 0

df['has_ltpo'] = df['display_type'].apply(extract_lpo)

# %%
df['has_ltpo'].value_counts()
# Out:
# has_ltpo
# 0    1056
# 1     212
# Name: count, dtype: int64

# %%
df[df['display_type'].str.contains('Anti Reflection Coating')]['display_type'].count()
# Out:
# np.int64(77)

# %%
def extract_anti_reflecting_coating(text):

  t = text.lower()

  if 'anti reflection coating' in t:
    return 1

  return 0

df['has_anti_reflection_coating'] = df['display_type'].apply(extract_anti_reflecting_coating)

# %%
df['has_anti_reflection_coating'].value_counts()
# Out:
# has_anti_reflection_coating
# 0    1191
# 1      77
# Name: count, dtype: int64

# %%
df['display_type'].sample(20)
# Out:
# 342     ProXDR AMOLED, 120 Hz Refresh Rate, LTPO, Dolby Vision, 360 Hz Touch Sampling Rate
# 520                                                       IPS LCD, 90 Hz Refresh Rate, SDR
# 1110                       AMOLED, 120 Hz Refresh Rate, HDR10+, 480 Hz Touch Sampling Rate
# 963                                                 Super AMOLED, 120 Hz Refresh Rate, SDR
# 530                          IPS LCD, 144 Hz Refresh Rate, SDR, 288 Hz Touch Sampling Rate
# 216                          AMOLED, 120 Hz Refresh Rate, HDR, 1200 Hz Touch Sampling Rate
# 430                           AMOLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 84                                                         AMOLED, 90 Hz Refresh Rate, SDR
# 1146                          AMOLED, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 977                                                       PLS LCD, 90 Hz Refresh Rate, SDR
# 155               E6 AMOLED, 144 Hz Refresh Rate, LTPO, HDR10+, 360 Hz Touch Sampling Rate
# 521                                                       IPS LCD, 90 Hz Refresh Rate, SDR
# 1068                            Dynamic 2X AMOLED, 120 Hz Refresh Rate, LTPO, Dolby Vision
# 97                            AMOLED, 144 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 271                                                    AMOLED, 144 Hz Refresh Rate, HDR10+
# 528                          IPS LCD, 120 Hz Refresh Rate, SDR, 240 Hz Touch Sampling Rate
# 1188                                                    AMOLED, 90 Hz Refresh Rate, HDR10+
# 489                                                       IPS LCD, 60 Hz Refresh Rate, SDR
# 694                                                    AMOLED, 120 Hz Refresh Rate, HDR10+
# 417                            AMOLED, 90 Hz Refresh Rate, SDR, 120 Hz Touch Sampling Rate
# Name: display_type, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 65 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
# dtypes: category(3), datetime64[ns](1), float64(4), int64(11), object(46)
# memory usage: 619.1+ KB

# %%
df['display_size'].sample(20)
# Out:
# 864     6.67 inches Curved Display, 107.4 cm², 93.35% Screen To Body Ratio
# 133                     6.67 inches, 107.4 cm², 90.2% Screen To Body Ratio
# 1201                    6.56 inches, 103.4 cm², 83.6% Screen To Body Ratio
# 196                     6.72 inches, 108.8 cm², 86.2% Screen To Body Ratio
# 98                        6.78 inches, 111 cm², 93.7% Screen To Body Ratio
# 35                       6.9 inches, 115.6 cm², 92.3% Screen To Body Ratio
# 995                                                  6.5 inches, 103.7 cm²
# 731      6.77 inches Curved Display, 109.3 cm², 93.7% Screen To Body Ratio
# 944                     6.7 inches, 108.4 cm², 83.65% Screen To Body Ratio
# 723                       6.72 inches, 109 cm², 91.4% Screen To Body Ratio
# 48                       6.9 inches, 116.7 cm², 90.7% Screen To Body Ratio
# 805                                                 6.74 inches, 109.7 cm²
# 796                                                 6.79 inches, 109.5 cm²
# 946                      6.6 inches, 104.9 cm², 82.5% Screen To Body Ratio
# 508                     6.83 inches, 114.5 cm², 90.2% Screen To Body Ratio
# 30                         6.7 inches, 110.2 cm², 88% Screen To Body Ratio
# 955                     6.65 inches, 108.4 cm², 83.6% Screen To Body Ratio
# 729                    6.67 inches, 107.2 cm², 89.97% Screen To Body Ratio
# 636                        6.5 inches, 102 cm², 88.7% Screen To Body Ratio
# 349                     6.78 inches, 112.4 cm², 95.5% Screen To Body Ratio
# Name: display_size, dtype: object

# %%
# make new col display_inches

df['display_inches'] = df['display_size'].str.split(' ').str.get(0)

# %%
df['display_inches'].value_counts()
# Out:
# display_inches
# 6.7      185
# 6.67     168
# 6.78     122
# 6.5       77
# 6.6       71
# 6.77      59
# 6.72      58
# 6.74      54
# 6.56      44
# 6.8       36
# 6.58      30
# 6.1       27
# 6.9       27
# 6.4       22
# 6.83      21
# 6.43      20
# 6.44      17
# 6.59      17
# 6.88      15
# 6.71      14
# 6.3       14
# 6.79      14
# 6.52      12
# 6.82      11
# 6.62      11
# 6.55      11
# 6.57       9
# 6.73       9
# 6.38       9
# 6.65       8
# 6.2        8
# 6.51       8
# 7.6        7
# 6.75       7
# 6.68       7
# 6.31       5
# 8          4
# 6.69       4
# 6.66       4
# 6.85       4
# 6.53       3
# 8.03       3
# 6.36       2
# 6.745      2
# 6.32       2
# 7.82       2
# 164.4      1
# 7          1
# 6.15       1
# 6.64       1
# Name: count, dtype: int64

# %%
df[df['display_inches'] == '164.4'] # given in mm not inches
# Out:
#      model_id                model  expert_rating  rating  rating_count  \
# 119       120  Infinix Note 12 Pro             27     4.2       71000.0
#
#      launch_on  old_price  price  launch_price  \
# 119 2022-08-26        NaN  16999         16999
#
#                               display_type            display_size  \
# 119  AMOLED, 60 Hz Refresh Rate, LTPO, SDR  164.4 inches, 76.5 cm²
#
#                                                                                            display_res  \
# 119  FHD+, 1080 x  2400 pixels, 20:9 (393 ppi), 8-bit 16.7 Million Colours, 1000 nits(Peak Brightness)
#
#             body_dimension     weight body_front body_back      body_side  \
# 119  164.4 x 76.5 x 7.8 mm  192 grams      Glass   Plastic  Plastic Frame
#
#         build_quality                                 ports ip_rating  \
# 119  Plastic Material  USB Type-C 2.0, 3.5mm Headphone Jack       NaN
#
#              speaker                                         chipset  \
# 119  Stereo Speakers  MediaTek Helio G99 (6 nm), 422909 Antutu Score
#
#                                                          cpu           gpu  \
# 119  Octa-core (2x2.2 GHz Cortex-A76 & 6x2.0 GHz Cortex-A55)  Mali-G57 MC2
#
#                                                      main_cam  \
# 119  108 MP, f/1.8, (Wide-angle), 0.8 µm, 1/1.67", Auto Focus
#
#                          main_cam2               main_cam3  \
# 119  2 MP, f/2.4, (Depth), 0.64 µm  f/2.4, (QVGA), 0.56 µm
#
#                  main_cam_features                main_video               os  \
# 119  HDR, Panorama, Quad-LED Flash  1440p@30fps, 1080p@60fps  Android 12, XOS
#
#                                                     software_updates  \
# 119  1 year(s) of Software updates and 2 year(s) of Security updates
#
#     ai_features             front_cam front_cam_features  front_video  \
# 119         NaN  16 MP, f/2.0, 0.8 µm                NaN  1440p@30fps
#
#                                        battery     charging         storage  \
# 119  5000 mAh, Lithium Polymer (Non-removable)  33W (wired)  256GB, UFS 2.2
#
#               ram                                 sim            tech  \
# 119  8GB, LPDDR4X  Dual SIM (nano-SIM, dual stand-by)  GSM, HSPA, LTE
#
#                        2g                       3g  \
# 119  2, 3, 5, 8 (4 bands)  1, 2, 4, 5, 8 (5 bands)
#
#                                                            4g   5g  \
# 119  1, 2, 3, 4, 5, 7, 8, 20, 28A, 28B, 38, 40, 41 (13 bands)  NaN
#
#               speed  \
# 119  GSM, HSPA, LTE
#
#                                                             wifi  \
# 119  Wi-Fi 5 802.11 a/b/g/n/ac, Hotspot, Wi-Fi Direct, Dual Band
#
#                  bluetooth positioning_system  nfc  finger_print  \
# 119  5, A2DP, AAC, LE, SBC                GPS  NaN  Side Mounted
#
#                                                                          sensors  \
# 119  Accelerometer, Compass, G-Sensor, Gyroscope, Light Sensor, Proximity Sensor
#
#     add_features    brand  is_available  is_flipkart_available  \
# 119          NaN  infinix             0                      1
#
#      is_amazon_available  is_official_available display_panel_type  \
# 119                    1                      0             amoled
#
#     display_panel_family  display_hz display_dynamic_range  \
# 119               amoled          60                   SDR
#
#      touch_sampling_rate  has_ltpo  has_anti_reflection_coating display_inches
# 119                  NaN         1                            0          164.4

# %%
# fill with correct value
df.loc[119,'display_inches'] = 6.7

# %%
df['display_inches'].value_counts()
# Out:
# display_inches
# 6.7      185
# 6.67     168
# 6.78     122
# 6.5       77
# 6.6       71
# 6.77      59
# 6.72      58
# 6.74      54
# 6.56      44
# 6.8       36
# 6.58      30
# 6.1       27
# 6.9       27
# 6.4       22
# 6.83      21
# 6.43      20
# 6.44      17
# 6.59      17
# 6.88      15
# 6.71      14
# 6.3       14
# 6.79      14
# 6.52      12
# 6.82      11
# 6.62      11
# 6.55      11
# 6.57       9
# 6.73       9
# 6.38       9
# 6.65       8
# 6.2        8
# 6.51       8
# 7.6        7
# 6.75       7
# 6.68       7
# 6.31       5
# 8          4
# 6.69       4
# 6.66       4
# 6.85       4
# 6.53       3
# 8.03       3
# 6.36       2
# 6.745      2
# 6.32       2
# 7.82       2
# 6.7        1
# 7          1
# 6.15       1
# 6.64       1
# Name: count, dtype: int64

# %%
df['display_inches'].count()
# Out:
# np.int64(1268)

# %%
# convert dtypes of display_inches to float

df['display_inches'] = pd.to_numeric(df['display_inches'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 66 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
# dtypes: category(3), datetime64[ns](1), float64(5), int64(11), object(46)
# memory usage: 629.0+ KB

# %%
df['display_size'].sample(20)
# Out:
# 857                                                6.67 inches, 107.4 cm²
# 322                      6.77 inches, 111.5 cm², 88% Screen To Body Ratio
# 155                        6.78 inches, 111 cm², 93% Screen To Body Ratio
# 195                    6.72 inches, 108.8 cm², 86.2% Screen To Body Ratio
# 887                     6.6 inches, 104.9 cm², 82.3% Screen To Body Ratio
# 393                    6.66 inches, 107.2 cm², 89.9% Screen To Body Ratio
# 263               6.67 inches Curved Display, 92.77% Screen To Body Ratio
# 1135     6.78 inches Curved Display, 111 cm², 93.53% Screen To Body Ratio
# 667                   6.67 inches, 107.2 cm², 89.97% Screen To Body Ratio
# 709                       6.5 inches, 102 cm², 88.7% Screen To Body Ratio
# 1124    6.56 inches Curved Display, 104.6 cm², 89.5% Screen To Body Ratio
# 1023                                 6.8 inches Curved Display, 114.7 cm²
# 940                                                   6.5 inches, 102 cm²
# 769     6.83 inches Curved Display, 150.9 cm², 93.8% Screen To Body Ratio
# 335                                 6.74 inches Curved Display, 109.2 cm²
# 107                    6.78 inches, 109.2 cm², 90.6% Screen To Body Ratio
# 287                    6.67 inches, 108.4 cm², 89.3% Screen To Body Ratio
# 959                                                 6.5 inches, 103.7 cm²
# 309                                                   6.7 inches, 108 cm²
# 655                   6.67 inches, 107.2 cm², 89.97% Screen To Body Ratio
# Name: display_size, dtype: object

# %%
def extract_body_ratio(text):

  t = text.lower()

  if '%' in t:
    return t

  return np.nan

df['display_body_ratio'] = df['display_size'].apply(extract_body_ratio)

# %%
df['display_body_ratio'].count()
# Out:
# np.int64(1036)

# %%
df['display_body_ratio'] = df['display_body_ratio'].str.split('%').str.get(0).str.split(',').str.get(-1)

# %%
df['display_body_ratio'].value_counts(dropna=False)
# Out:
# display_body_ratio
# NaN       232
#  93        40
#  91.4      36
#  90.8      35
#  83.6      28
#          ...
#  86.48      1
#  93.2       1
#  90.04      1
#  82.9       1
#  94.85      1
# Name: count, Length: 154, dtype: int64

# %%
# convert dtypes to floar
df['display_body_ratio'] = pd.to_numeric(df['display_body_ratio'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 67 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
# dtypes: category(3), datetime64[ns](1), float64(6), int64(11), object(46)
# memory usage: 638.9+ KB

# %%
df['display_size'].sample(20)
# Out:
# 745                   6.74 inches, 109.7 cm², 90.3% Screen To Body Ratio
# 839                     6.67 inches, 107.4 cm², 86% Screen To Body Ratio
# 212                                  6.78 inches Curved Display, 111 cm²
# 73      6.7 inches Curved Display, 108.7 cm², 87.4% Screen To Body Ratio
# 478                    6.43 inches, 99.8 cm², 90.8% Screen To Body Ratio
# 1016    6.8 inches Curved Display, 114.7 cm², 90.2% Screen To Body Ratio
# 19                      6.1 inches, 91.3 cm², 88.3% Screen To Body Ratio
# 594         6.7 inches Curved Display, 108 cm², 93% Screen To Body Ratio
# 1197                  6.56 inches, 103.4 cm², 83.6% Screen To Body Ratio
# 227                   6.72 inches, 108.8 cm², 90.2% Screen To Body Ratio
# 543                   6.67 inches, 107.4 cm², 94.2% Screen To Body Ratio
# 792                   6.58 inches, 104.3 cm², 83.6% Screen To Body Ratio
# 357                   6.74 inches, 109.2 cm², 93.5% Screen To Body Ratio
# 998                    6.6 inches, 106.9 cm², 83.8% Screen To Body Ratio
# 889                      6.5 inches, 102 cm², 81.3% Screen To Body Ratio
# 717                  6.67 inches, 107.4 cm², 92.65% Screen To Body Ratio
# 693                      6.7 inches, 108 cm², 94.2% Screen To Body Ratio
# 703                     6.4 inches, 98.9 cm², 90.8% Screen To Body Ratio
# 775                                6.77 inches, 94% Screen To Body Ratio
# 255                      6.5 inches, 102 cm², 85.5% Screen To Body Ratio
# Name: display_size, dtype: object

# %%
df[df['display_size'].str.contains('Curved')]['display_size'].count()
# Out:
# np.int64(263)

# %%
df[df['display_size'].str.contains('Foldable|Flip')]['display_size'].count()
# Out:
# np.int64(35)

# %%
def extract_curved(text):

  if 'Curved' in text:
    return 1
  return 0

df['has_curved'] = df['display_size'].apply(extract_curved)

# %%
df['has_curved'].value_counts()
# Out:
# has_curved
# 0    1005
# 1     263
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 68 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
# dtypes: category(3), datetime64[ns](1), float64(6), int64(12), object(46)
# memory usage: 648.8+ KB

# %%
def extract_foldable(text):

  if 'Foldable' in text or 'Flip' in text:
    return 1

  return 0

df['has_foldable'] = df['display_size'].apply(extract_foldable)

# %%
df['has_foldable'].value_counts()
# Out:
# has_foldable
# 0    1233
# 1      35
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 69 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
# dtypes: category(3), datetime64[ns](1), float64(6), int64(13), object(46)
# memory usage: 658.8+ KB

# %%
df['display_res'].sample(20)
# Out:
# 433                                     FHD+, 1280 x  2800 pixels, (453 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 1600 nits(Peak Brightness), 600 nits(High Brightness)
# 1132                                                         FHD+, 1080 x  2400 pixels, 20:9 (388 ppi), 10-bit colours, 1300 nits(Peak Brightness), SGS Display Certification
# 357                                         FHD+, 1240 x  2772 pixels, 20.1:9 (450 ppi), 10-bit colours, 100% DCI-P3, 1450 nits(High Brightness), TUV Rheinland certification
# 828                                                                             HD+, 720 x  1650 pixels, 20:9 (268 ppi), 8-bit colours, 500 nits(Peak Brightness), DC Dimming
# 1136                                                                                    1.5K, 1260 x  2800 pixels, 20:9 (453 ppi), 10-bit colours, 1300 nits(Peak Brightness)
# 903                                                                                                       FHD+, 1080 x  2408 pixels, 20:9 (400 ppi), 8-bit 16 Million Colours
# 1210                                                    FHD+, 1080 x  2400 pixels, 20:9 (394 ppi), 8-bit colours, 100% DCI-P3, 1800 nits(High Brightness), Blue Light Filters
# 75            FHD+, 1080 x  2400 pixels, 20:9 (430 ppi), 10-bit colours, 2000 nits(Peak Brightness), 1400 nits(High Brightness), Blue Light Filters, 1000000:1 Contrast Ratio
# 181                                                           FHD+, 1080 x  2400 pixels, 20:9 (388 ppi), 10-bit colours, 1300 nits(Peak Brightness), 8000000:1 Contrast Ratio
# 748                 HD+, 720 x  1604 pixels, 20:9 (264 ppi), 8-bit 16.7 Million Colours, 625 nits(High Brightness), 500 nits(Typical Brightness), TUV Rheinland certification
# 524                                                          FHD+, 1080 x  2400 pixels, 20:9 (396 ppi), 8-bit colours, 550 nits(Peak Brightness), TUV Rheinland certification
# 1228                                                         HD+, 720 x  1608 pixels, 20:9 (264 ppi), 8-bit colours, 83% NTSC, 1000 nits(High Brightness), Blue Light Filters
# 69                                                           FHD+, 1080 x  2400 pixels, 20:9 (416 ppi), 8-bit colours, 1400 nits(Peak Brightness), 1000 nits(High Brightness)
# 1086                                                     FHD+, 1080 x  2400 pixels, 20:9 (388 ppi), 10-bit colours, 1300 nits(High Brightness), 1300 nits(Typical Brightness)
# 147     FHD+, 1080 x  2400 pixels, 20:9 (388 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 950 nits(Peak Brightness), TUV Rheinland certification, 1000000:1 Contrast Ratio
# 1155                                FHD+, 1080 x  2392 pixels, 20.9 (388 ppi), 10-bit colours, 100% DCI-P3, 4500 nits(Peak Brightness), PWM Dimming, 5000000:1 Contrast Ratio
# 1128                                                                                    FHD+, 1080 x  2376 pixels, 2.2:1 (398 ppi), 8-bit colours, 1300 nits(High Brightness)
# 485                                                           HD+, 720 x  1600 pixels, 20:9 (269 ppi), 8-bit colours, 400 nits(Peak Brightness), 400 nits(Typical Brightness)
# 238                                                                     HD+, 720 x  1600 pixels, 20:9 (268 ppi), 8-bit colours, 500 nits(Peak Brightness), Blue Light Filters
# 297                                                                                          HD, 720 x  1612 pixels, 20:9 (269 ppi), 8-bit colours, 537 nits(Peak Brightness)
# Name: display_res, dtype: object

# %%
df['res_category'] = df['display_res'].str.split(',').str.get(0)

# %%
df['res_category'].value_counts()
# Out:
# res_category
# FHD+                   742
# HD+                    249
# 1.5K                   180
# QHD+                    50
# HD                      16
# FHD                      9
# WQHD+                    6
# 2K                       6
# QXGA+                    6
# 1080 x  2520 pixels      2
# QHD                      1
# 2.5K                     1
# Name: count, dtype: int64

# %%
df[df['res_category'].str.contains('pixels')][['model','display_res']]
# Out:
#                                        model  \
# 1055  Samsung Galaxy Z Flip 7 (12GB + 512GB)
# 1058                 Samsung Galaxy Z Flip 7
#
#                                                                                      display_res
# 1055  1080 x  2520 pixels, 21:9 (397 ppi), 12-bit 16 Million Colours, 2600 nits(High Brightness)
# 1058  1080 x  2520 pixels, 21:9 (397 ppi), 12-bit 16 Million Colours, 2600 nits(High Brightness)

# %%
df.loc[[1055,1058],'res_category'] = 'FHD+'

# %%
df['res_category'].value_counts()
# Out:
# res_category
# FHD+     744
# HD+      249
# 1.5K     180
# QHD+      50
# HD        16
# FHD        9
# 2K         6
# QXGA+      6
# WQHD+      6
# QHD        1
# 2.5K       1
# Name: count, dtype: int64

# %%
df['res_category'] = df['res_category'].replace('QXGA+','QHD+')
df['res_category'] = df['res_category'].replace('WQHD+','QHD+')
df['res_category'] = df['res_category'].replace('QHD','QHD+')
df['res_category'] = df['res_category'].replace('2K','1.5K')
df['res_category'] = df['res_category'].replace('2.5K','1.5K')

# %%
df['res_category'].value_counts()
# Out:
# res_category
# FHD+    744
# HD+     249
# 1.5K    187
# QHD+     63
# HD       16
# FHD       9
# Name: count, dtype: int64

# %%
df['res_category'] = df['res_category'].astype('category')

# %%
df['res_category'].value_counts()
# Out:
# res_category
# FHD+    744
# HD+     249
# 1.5K    187
# QHD+     63
# HD       16
# FHD       9
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 70 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
# dtypes: category(4), datetime64[ns](1), float64(6), int64(13), object(46)
# memory usage: 660.2+ KB

# %%
df['display_res'].sample(20)
# Out:
# 174                                                                                  1.5K, 1260 x  2800 pixels, 20:9 (452 ppi), 10-bit 1 Billion Colours, 100% DCI-P3, 4500 nits(High Brightness), PWM Dimming, 5000000:1 Contrast Ratio
# 651                                                      HD+, 720 x  1600 pixels, 20:9 (260 ppi), 8-bit colours, 83.5% NTSC, 560 nits(High Brightness), 450 nits(Typical Brightness), TUV Rheinland certification, 1500:1 Contrast Ratio
# 16                                                                FHD+, 1290 x  2796 pixels, 19.5:9 (460 ppi), 8-bit colours, 100% DCI-P3, 2000 nits(Peak Brightness), 1000 nits(High Brightness), PWM Dimming, 2000000:1 Contrast Ratio
# 1206                                                                                               HD+, 720 x  1600 pixels, 20:9 (260 ppi), 8-bit 16.7 Million Colours, 70% NTSC, 700 nits(High Brightness), TUV Rheinland certification
# 391                                                                                                                          HD+, 720 x  1612 pixels, 20:9 (269 ppi), 8-bit 16.7 Million Colours, 100% DCI-P3, 720 nits(Peak Brightness)
# 638                                                                                                         HD+, 720 x  1600 pixels, 20:9 (270 ppi), 8-bit 16.7 Million Colours, 400 nits(Peak Brightness), 400 nits(Typical Brightness)
# 479                                    FHD+, 1080 x  2400 pixels, 20:9 (409 ppi), 8-bit 16.7 Million Colours, 100% DCI-P3, 800 nits(Peak Brightness), 600 nits(High Brightness), 430 nits(Typical Brightness), SGS Display Certification
# 857                                                                               FHD+, 1080 x  2400 pixels, 20:9 (395 ppi), 8-bit colours, 100% DCI-P3, 1200 nits(Peak Brightness), SGS Display Certification, 4500000:1 Contrast Ratio
# 300                                                                                                                                                                             FHD+, 1080 x  2400 pixels, 20:9 (405 ppi), 8-bit colours
# 692                                                               FHD+, 1080 x  2412 pixels, 20:9 (394 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 1000 nits(Peak Brightness), TUV Rheinland certification, 5000000:1 Contrast Ratio
# 5                                                                           1.5K, 1179 x  2556 pixels, 19.5:9 (460 ppi), 8-bit colours, 100% DCI-P3, 2000 nits(Peak Brightness), 1000 nits(Typical Brightness), 2000000:1 Contrast Ratio
# 1262    WQHD+, 1440 x  3200 pixels, 20:9 (522 ppi), 12-bit 68 Billion Colours, 100% DCI-P3, 3000 nits(Peak Brightness), 1000 nits(High Brightness), 1000 nits(Typical Brightness), TUV Rheinland certification, 8000000:1 Contrast Ratio
# 447                                                                                                        HD+, 720 x  1604 pixels, 20:9 (264 ppi), 8-bit 16.7 Million Colours, 83% NTSC, 1000 nits(High Brightness), Blue Light Filters
# 634                                                                                                                                              HD+, 720 x  1600 pixels, 20:9 (270 ppi), 8-bit 16.7 Million Colours, Blue Light Filters
# 631                                                                                                                                  FHD+, 1080 x  2412 pixels, 20:9 (401 ppi), 8-bit 16.7 Million Colours, 480 nits(Typical Brightness)
# 908                                                                                                    FHD+, 1080 x  2340 pixels, 19.5:9 (396 ppi), 8-bit 16 Million Colours, 100% DCI-P3, 800 nits(High Brightness), Eye Comfort Shield
# 1191                                                                                                                               HD+, 720 x  1600 pixels, 20:9 (270 ppi), 8-bit colours, 400 nits(Peak Brightness), Blue Light Filters
# 655                                                                                                  HD+, 720 x  1604 pixels, 20:9 (264 ppi), 8-bit colours, 625 nits(High Brightness), 500 nits(Typical Brightness), Eye Comfort Shield
# 636                                                                                     HD+, 720 x  1600 pixels, 20:9 (270 ppi), 8-bit 16.7 Million Colours, 400 nits(Peak Brightness), 400 nits(Typical Brightness), Eye Comfort Shield
# 664                                                                       HD+, 720 x  1600 pixels, 20:9 (264 ppi), 8-bit colours, 83.5% NTSC, 563 nits(Peak Brightness), 450 nits(Typical Brightness), DC Dimming, 1500:1 Contrast Ratio
# Name: display_res, dtype: object

# %%
df['display_pixels'] = df['display_res'].str.split(',').str.get(1)

# %%
df['display_pixels'].value_counts()
# Out:
# display_pixels
# 1080 x  2400 pixels    307
# 720 x  1600 pixels     128
# 1080 x  2340 pixels     92
# 1080 x  2412 pixels     79
# 1080 x  2408 pixels     75
#                       ...
# 2152 x  2076 pixels      1
# 2076 x  2152 pixels      1
# 1224 x  2912 pixels      1
# 1080 x  2373 pixels      1
# 1080 x  2388 pixels      1
# Name: count, Length: 70, dtype: int64

# %%
df[~df['display_pixels'].str.contains('pixels')][['model','display_res','display_pixels']]
# Out:
#                                        model  \
# 1055  Samsung Galaxy Z Flip 7 (12GB + 512GB)
# 1058                 Samsung Galaxy Z Flip 7
#
#                                                                                      display_res  \
# 1055  1080 x  2520 pixels, 21:9 (397 ppi), 12-bit 16 Million Colours, 2600 nits(High Brightness)
# 1058  1080 x  2520 pixels, 21:9 (397 ppi), 12-bit 16 Million Colours, 2600 nits(High Brightness)
#
#        display_pixels
# 1055   21:9 (397 ppi)
# 1058   21:9 (397 ppi)

# %%
df.loc[[1055,1058],'display_pixels'] = '1080 x 2520 pixels'

# %%
df[df['display_pixels'].str.contains('pixels')]['display_pixels'].count()
# Out:
# np.int64(1268)

# %%
df['res_width'] = df['display_pixels'].str.split('x').str.get(0)

# %%
df['res_width'].value_counts()
# Out:
# res_width
#  1080     676
#  720      267
#  1260      47
#  1440      44
#  1220      38
#  1280      24
#  1272      22
#  1264      19
#  1179      14
#  1290      13
#  1256      10
#  1240       9
#  1206       8
#  1216       7
#  1224       7
#  1320       7
#  1200       7
#  1084       7
#  1170       6
#  1344       5
#  1812       4
#  1968       3
#  1856       3
#  1284       3
#  2400       3
#  1088       3
#  2200       2
# 1080        2
#  2268       2
#  1400       2
#  1236       2
#  2152       1
#  2076       1
# Name: count, dtype: int64

# %%
df['res_width'].count()
# Out:
# np.int64(1268)

# %%
df['res_width'] = pd.to_numeric(df['res_width'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 72 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  display_pixels               1268 non-null   object
#  71  res_width                    1268 non-null   int64
# dtypes: category(4), datetime64[ns](1), float64(6), int64(14), object(47)
# memory usage: 680.0+ KB

# %%
df['res_height'] = df['display_pixels'].str.strip().str.split('x').str.get(1).str.split(' ').str.get(2)

# %%
df['res_height'].value_counts()
# Out:
# res_height
# 2400    307
# 1600    128
# 2340     92
# 2800     83
# 2412     81
# 2408     75
# 2392     58
# 1612     56
# 2712     36
# 1604     36
# 2640     21
# 2780     19
# 1650     17
# 2460     16
# 1640     16
# 2772     14
# 2796     13
# 3120     13
# 2556     11
# 2760     10
# 3200     10
# 3168     10
# 2436      9
# 2372      8
# 2622      8
# 2868      7
# 2404      7
# 1608      7
# 1570      7
# 2376      6
# 2532      6
# 3216      6
# 3088      5
# 2992      5
# 2664      4
# 2176      4
# 2720      4
# 2480      4
# 2448      4
# 2778      3
# 2184      3
# 2424      3
# 2736      3
# 2256      3
# 2670      3
# 2160      3
# 1080      3
# 2750      2
# 2856      2
# 2440      2
# 2700      2
# 2652      2
# pi        2
# 3136      2
# 2520      2
# 2152      1
# 2076      1
# 2912      1
# 2373      1
# 2388      1
# Name: count, dtype: int64

# %%
df[df['res_height'].str.contains('pi')]['display_pixels']
# Out:
# 1055    1080 x 2520 pixels
# 1058    1080 x 2520 pixels
# Name: display_pixels, dtype: object

# %%
df.loc[[1055,1058],'res_height'] = 2520

# %%
df['res_height'].value_counts()
# Out:
# res_height
# 2400    307
# 1600    128
# 2340     92
# 2800     83
# 2412     81
# 2408     75
# 2392     58
# 1612     56
# 2712     36
# 1604     36
# 2640     21
# 2780     19
# 1650     17
# 2460     16
# 1640     16
# 2772     14
# 2796     13
# 3120     13
# 2556     11
# 2760     10
# 3200     10
# 3168     10
# 2436      9
# 2372      8
# 2622      8
# 2868      7
# 2404      7
# 1608      7
# 1570      7
# 2376      6
# 2532      6
# 3216      6
# 3088      5
# 2992      5
# 2664      4
# 2176      4
# 2720      4
# 2480      4
# 2448      4
# 2778      3
# 2184      3
# 2424      3
# 2736      3
# 2256      3
# 2670      3
# 2160      3
# 1080      3
# 2750      2
# 2856      2
# 2440      2
# 2700      2
# 2652      2
# 2520      2
# 3136      2
# 2520      2
# 2152      1
# 2076      1
# 2912      1
# 2373      1
# 2388      1
# Name: count, dtype: int64

# %%
df['res_height'] = pd.to_numeric(df['res_height'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 73 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  display_pixels               1268 non-null   object
#  71  res_width                    1268 non-null   int64
#  72  res_height                   1268 non-null   int64
# dtypes: category(4), datetime64[ns](1), float64(6), int64(15), object(47)
# memory usage: 689.9+ KB

# %%
# now drop display_pixels
df.drop(columns='display_pixels',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 72 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
# dtypes: category(4), datetime64[ns](1), float64(6), int64(15), object(46)
# memory usage: 680.0+ KB

# %%
df['helper'] = df['display_res'].str.split(',').str.get(2).str.strip()

# %%
def extract_ratio(text):

  if pd.isna(text):
    return np.nan

  if 'colours' in text:
    return np.nan

  if ':' in text:
    return str(text)

  return np.nan

df['aspect_ration_numeric'] = df['helper'].apply(extract_ratio)

# %%
df['x'] = df['aspect_ration_numeric'].str.split(':').str.get(0)

# %%
df['x'].sample(20)
# Out:
# 51      19.5
# 1146      20
# 570       20
# 876       20
# 481       20
# 1109      20
# 315       20
# 233       20
# 791       20
# 451      NaN
# 1072    19.5
# 1028    19.5
# 1106      20
# 624       20
# 1256      20
# 700       20
# 814       20
# 886       20
# 232       20
# 290       20
# Name: x, dtype: object

# %%
df['y'] = df['aspect_ration_numeric'].str.strip().str.split(':').str.get(1).str.strip().str.split(' ').str.get(0)

# %%
df['y'].sample(20)
# Out:
# 286     9
# 374     9
# 31      9
# 707     9
# 1146    9
# 1182    9
# 1164    9
# 728     9
# 1137    9
# 499     9
# 132     9
# 531     9
# 133     9
# 32      9
# 87      9
# 51      9
# 1048    9
# 1256    9
# 204     9
# 1054    9
# Name: y, dtype: object

# %%
df['x'] = pd.to_numeric(df['x'], errors='coerce')
df['y'] = pd.to_numeric(df['y'], errors='coerce')

# %%
df['aspect_ration_numeric'] = df['x'] / df['y']

# %%
df['aspect_ration_numeric'].sample(20)
# Out:
# 20      2.166667
# 404     2.222222
# 1112         NaN
# 408     2.166667
# 908     2.166667
# 771     2.222222
# 1086    2.222222
# 236     2.222222
# 341     2.200000
# 311     2.222222
# 182     2.222222
# 836     2.222222
# 1110    2.222222
# 696     2.222222
# 4       2.166667
# 924     2.166667
# 1226    2.222222
# 46      2.166667
# 506     2.222222
# 87      2.222222
# Name: aspect_ration_numeric, dtype: float64

# %%
df['aspect_ration_numeric'] = pd.to_numeric(df['aspect_ration_numeric'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  helper                       1266 non-null   object
#  73  aspect_ration_numeric        1185 non-null   float64
#  74  x                            1185 non-null   float64
#  75  y                            1185 non-null   float64
# dtypes: category(4), datetime64[ns](1), float64(9), int64(15), object(47)
# memory usage: 719.6+ KB

# %%
# now drop helper , x and y
df.drop(columns=['helper','x','y'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 73 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
# dtypes: category(4), datetime64[ns](1), float64(7), int64(15), object(46)
# memory usage: 689.9+ KB

# %%
df['display_res'].sample(20)
# Out:
# 1103                                                                  1.5K, 1080 x  2392 pixels, 20:9 (388 ppi), 8-bit colours, 100% DCI-P3, 5000 nits(High Brightness), PWM Dimming, 1000000:1 Contrast Ratio
# 67                                                                                                                                         FHD+, 1080 x  2400 pixels, 20:9 (429 ppi), 8-bit 16 Million Colours
# 403                                                                   HD+, 720 x  1604 pixels, 20:9 (264 ppi), 8-bit 16.7 Million Colours, 100% sRGB, 1000 nits(High Brightness), 850 nits(Typical Brightness)
# 805                                                               HD+, 720 x  1600 pixels, 20:9 (260 ppi), 8-bit colours, 600 nits(Peak Brightness), 450 nits(Typical Brightness), TUV Rheinland certification
# 182           1.5K, 1260 x  2800 pixels, 20:9 (453 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 5500 nits(Peak Brightness), 2000 nits(High Brightness), SGS Display Certification, 8000000:1 Contrast Ratio
# 801                                                          FHD+, 1080 x  2460 pixels, 20:9 (396 ppi), 8-bit colours, 69% sRGB, 550 nits(High Brightness), TUV Rheinland certification, 1500:1 Contrast Ratio
# 1216                                                                                                             HD+, 720 x  1612 pixels, 20.1:9 (270 ppi), 8-bit colours, 70% NTSC, 530 nits(High Brightness)
# 825                                                                                                      HD+, 720 x  1650 pixels, 20:9 (268 ppi), 8-bit colours, 500 nits(Peak Brightness), Blue Light Filters
# 365                                                                     FHD+, 1080 x  2400 pixels, 20:9 (409 ppi), 10-bit 1 Billion Colours, 100% sRGB, 600 nits(Peak Brightness), TUV Rheinland certification
# 339                                                                            1.5K, 1264 x  2780 pixels, 19.8:9 (450 ppi), 10-bit colours, 80% DCI-P3, 4500 nits(Peak Brightness), 1600 nits(High Brightness)
# 476                                                 FHD+, 1256 x  2760 pixels, 20:9 (460 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 1200 nits(Peak Brightness), 600 nits(Typical Brightness), PWM Dimming
# 538                                FHD+, 1080 x  2400 pixels, 20:9 (395 ppi), 10-bit colours, 100% DCI-P3, 1200 nits(Peak Brightness), 700 nits(High Brightness), Blue Light Filters, 4500000:1 Contrast Ratio
# 767                                                                            1.5K, 1272 x  2800 pixels, 19.5:9 (390 ppi), 8-bit colours, 100% DCI-P3, 1500 nits(Peak Brightness), 1200 nits(High Brightness)
# 52      1.5K, 1260 x  2736 pixels, 19.5:9 (460 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 3000 nits(Peak Brightness), 1600 nits(High Brightness), 1000 nits(Typical Brightness), 2000000:1 Contrast Ratio
# 788                                                                                                    FHD+, 1080 x  2400 pixels, 20:9 (405 ppi), 8-bit colours, 400 nits(Peak Brightness), Blue Light Filters
# 1102                                                                           FHD+, 1080 x  2408 pixels, 20:9 (393 ppi), 8-bit 16.7 Million Colours, 83% NTSC, 1000 nits(Peak Brightness), Blue Light Filters
# 1108                                                                    HD+, 720 x  1600 pixels, 20:9 (260 ppi), 8-bit 16.7 Million Colours, 70% NTSC, 1000 nits(High Brightness), TUV Rheinland certification
# 852         FHD+, 1080 x  2400 pixels, 20:9 (394 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 1200 nits(Peak Brightness), 900 nits(High Brightness), 500 nits(Typical Brightness), 5000000:1 Contrast Ratio
# 1243                                                                                                         FHD+, 1080 x  2392 pixels, 20:9 (387 ppi), 8-bit colours, 100% DCI-P3, 4500 nits(Peak Brightness)
# 388                                                                                      HD+, 720 x  1604 pixels, 20:9 (264 ppi), 8-bit 16.7 Million Colours, 83% NTSC, 1000 nits(High Brightness), DC Dimming
# Name: display_res, dtype: object

# %%
df['display_ppi'] = df['display_res'].str.split(',').str.get(2).str.split('(').str.get(1).str.strip().str.split(' ').str.get(0)

# %%
df['display_ppi'].value_counts(dropna=False)
# Out:
# display_ppi
# 395      86
# 394      84
# 460      71
# 269      64
# 260      53
#          ..
# 259       1
# 464       1
# 263.6     1
# 383.5     1
# 412       1
# Name: count, Length: 82, dtype: int64

# %%
df[df['display_ppi'].isna()][['model','display_ppi','display_res']]
# Out:
#                                        model display_ppi  \
# 668              Realme C75 5G (6GB + 128GB)         NaN
# 743                         Realme Narzo N55         NaN
# 800                                Redmi 12C         NaN
# 956      Samsung Galaxy F17 5G (6GB + 128GB)         NaN
# 957                    Samsung Galaxy F17 5G         NaN
# 1055  Samsung Galaxy Z Flip 7 (12GB + 512GB)         NaN
# 1058                 Samsung Galaxy Z Flip 7         NaN
#
#                                                                                              display_res
# 668                                    HD+, 720 x  1604 pixels, 8-bit colours, 625 nits(Peak Brightness)
# 743                FHD+, 1080 x  2400 pixels, 20:9 8-bit 16.7 Million Colours, 680 nits(Peak Brightness)
# 800   HD+, 720 x  1650 pixels, 20.6:9 8-bit colours, 500 nits(Typical Brightness), 1500:1 Contrast Ratio
# 956                                                                            FHD+, 1080 x  2340 pixels
# 957                                                                            FHD+, 1080 x  2340 pixels
# 1055          1080 x  2520 pixels, 21:9 (397 ppi), 12-bit 16 Million Colours, 2600 nits(High Brightness)
# 1058          1080 x  2520 pixels, 21:9 (397 ppi), 12-bit 16 Million Colours, 2600 nits(High Brightness)

# %%
df.loc[[1055,1058],'display_ppi'] = 397

# %%
df[df['display_ppi'].isna()][['model','display_ppi','display_res']]
# Out:
#                                    model display_ppi  \
# 668          Realme C75 5G (6GB + 128GB)         NaN
# 743                     Realme Narzo N55         NaN
# 800                            Redmi 12C         NaN
# 956  Samsung Galaxy F17 5G (6GB + 128GB)         NaN
# 957                Samsung Galaxy F17 5G         NaN
#
#                                                                                             display_res
# 668                                   HD+, 720 x  1604 pixels, 8-bit colours, 625 nits(Peak Brightness)
# 743               FHD+, 1080 x  2400 pixels, 20:9 8-bit 16.7 Million Colours, 680 nits(Peak Brightness)
# 800  HD+, 720 x  1650 pixels, 20.6:9 8-bit colours, 500 nits(Typical Brightness), 1500:1 Contrast Ratio
# 956                                                                           FHD+, 1080 x  2340 pixels
# 957                                                                           FHD+, 1080 x  2340 pixels

# %%
calculate_ppi = np.sqrt(df['res_width']**2 + df['res_height']**2) / df['display_inches']

# %%
# fill nan ppi with calculated ppi
df['display_ppi'] = df['display_ppi'].fillna(calculate_ppi)

# %%
df.loc[[668,743,800,956,957]][['model','display_ppi']]
# Out:
#                                    model display_ppi
# 668          Realme C75 5G (6GB + 128GB)  263.596016
# 743                     Realme Narzo N55  391.637718
# 800                            Redmi 12C  268.293589
# 956  Samsung Galaxy F17 5G (6GB + 128GB)  384.657879
# 957                Samsung Galaxy F17 5G  384.657879

# %%
df['display_ppi'].count()
# Out:
# np.int64(1268)

# %%
df['display_ppi'] = pd.to_numeric(df['display_ppi'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
#  73  display_ppi                  1268 non-null   float64
# dtypes: category(4), datetime64[ns](1), float64(8), int64(15), object(46)
# memory usage: 699.8+ KB

# %%
df['color_depth'] = df['display_res'].str.split(',').str.get(3).str.strip().str.split(' ').str.get(0).str.strip().str.split('-').str.get(0)

# %%
df.loc[[743,668,800,1064,1065,1066],'color_depth'] = 8
df.loc[[291,134,1241,1242,812,813],'color_depth'] = np.nan
df.loc[[1055,1058],'color_depth'] = 12

# %%
df['color_depth'] = pd.to_numeric(df['color_depth'])

# %%
df['color_depth'] = df['color_depth'].fillna(8)

# %%
df['color_depth'].value_counts(dropna=False)
# Out:
# color_depth
# 8.0     736
# 10.0    487
# 12.0     45
# Name: count, dtype: int64

# %%
df['peak_brightness'] = df['display_res'].str.extract(r'(\d+)\s*nits')

# %%
df['peak_brightness'].value_counts(dropna=False)
# Out:
# peak_brightness
# 1000    115
# 1300     85
# 1200     81
# 2000     77
# 4500     70
#        ...
# 920       1
# 564       1
# 629       1
# 200       1
# 1024      1
# Name: count, Length: 74, dtype: int64

# %%
# will fill in eda
df['peak_brightness'].isnull().sum()
# Out:
# np.int64(62)

# %%
df['peak_brightness'] = pd.to_numeric(df['peak_brightness'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
#  73  display_ppi                  1268 non-null   float64
#  74  color_depth                  1268 non-null   float64
#  75  peak_brightness              1206 non-null   float64
# dtypes: category(4), datetime64[ns](1), float64(10), int64(15), object(46)
# memory usage: 719.6+ KB

# %%
df['display_res'].sample(20)
# Out:
# 265                                                                                                            FHD+, 1080 x  2640 pixels, 22:9 (413 ppi), 10-bit 1 Billion Colours, 120% DCI-P3, 3000 nits(High Brightness)
# 640                                                              FHD, 1080 x  2408 pixels, 20:9 (401 ppi), 8-bit 16.7 Million Colours, 600 nits(High Brightness), 480 nits(Typical Brightness), TUV Rheinland certification
# 635                                                                                                                                 HD+, 720 x  1600 pixels, 20:9 (270 ppi), 8-bit 16.7 Million Colours, Blue Light Filters
# 373                                                    FHD+, 1080 x  2412 pixels, 20:9 (394 ppi), 10-bit 1 Billion Colours, 100% DCI-P3, 1100 nits(Peak Brightness), 900 nits(High Brightness), TUV Rheinland certification
# 525     FHD+, 1080 x  2460 pixels, 20:9 (396 ppi), 12-bit 1.07 Billion Colours, 1300 nits(Peak Brightness), 550 nits(High Brightness), 1000 nits(Typical Brightness), TUV Rheinland certification, 5000000:1 Contrast Ratio
# 495                                                                                                          HD+, 720 x  1640 pixels, 20:9 (260 ppi), 8-bit colours, 600 nits(Peak Brightness), TUV Rheinland certification
# 310                     FHD+, 1080 x  2412 pixels, 20:9 (394 ppi), 10-bit colours, 100% DCI-P3, 1300 nits(Peak Brightness), 1100 nits(High Brightness), 700 nits(Typical Brightness), PWM Dimming, 1000000:1 Contrast Ratio
# 1233                                                                                      HD+, 720 x  1608 pixels, (264 ppi), 8-bit 16.7 Million Colours, 83% NTSC, 1000 nits(Peak Brightness), TUV Rheinland certification
# 570                             FHD+, 1080 x  2400 pixels, 20:9 (395 ppi), 10-bit 16.7 Million Colours, 100% DCI-P3, 2000 nits(High Brightness), 600 nits(Typical Brightness), Blue Light Filters, 5000000:1 Contrast Ratio
# 621                                                                                                                                     FHD+, 1080 x  2400 pixels, 20:9 (400 ppi), 8-bit colours, 600 nits(High Brightness)
# 96                                     1.5K, 1224 x  2720 pixels, (440 ppi), 10-bit colours, 100% DCI-P3, 4500 nits(Peak Brightness), 1600 nits(High Brightness), 700 nits(Typical Brightness), TUV Rheinland certification
# 57                                                                                                                         FHD+, 1080 x  2448 pixels, 20:9 (395 ppi), 10-bit 16 Million Colours, 1500 nits(Peak Brightness)
# 690                                                   FHD+, 1080 x  2400 pixels, 20:9 (398 ppi), 8-bit 16.7 Million Colours, 100% DCI-P3, 1300 nits(Peak Brightness), TUV Rheinland certification, 5000000:1 Contrast Ratio
# 1014                                                           FHD+, 1080 x  2340 pixels, 19.5:9 (393 ppi), 8-bit 16 Million Colours, 100% DCI-P3, 1750 nits(High Brightness), Eye Comfort Shield, 3000000:1 Contrast Ratio
# 271                                                                                                             FHD+, 1080 x  2400 pixels, 20:9 (405 ppi), 10-bit 1 Billion Colours, 100% DCI-P3, 500 nits(Peak Brightness)
# 802                                                                       FHD+, 1080 x  2460 pixels, 20:9 (396 ppi), 8-bit colours, 69% sRGB, 550 nits(High Brightness), TUV Rheinland certification, 1500:1 Contrast Ratio
# 475                                                                                                    1.5K, 1256 x  2760 pixels, (460 ppi), 10-bit 1 Billion Colours, 100% DCI-P3, 1200 nits(Peak Brightness), PWM Dimming
# 421                                                                         FHD+, 1080 x  2400 pixels, 20:9 (395 ppi), 10-bit colours, 2100 nits(Peak Brightness), 1200 nits(High Brightness), 600 nits(Typical Brightness)
# 1146                                                          FHD+, 1080 x  2400 pixels, 20:9 (388 ppi), 10-bit 1.07 Billion Colours, 100% DCI-P3, 1300 nits(Peak Brightness), Blue Light Filters, 8000000:1 Contrast Ratio
# 59                                            FHD+, 1080 x  2400 pixels, 20:9 (395 ppi), 8-bit colours, 100% DCI-P3, 2000 nits(Peak Brightness), 700 nits(Typical Brightness), Blue Light Filters, 1000000:1 Contrast Ratio
# Name: display_res, dtype: object

# %%
df['display_res'].str.contains('Contrast Ratio').sum()
# Out:
# np.int64(491)

# %%
df['helper'] = df['display_res'].str.extract(r'(\d+)\s*:1 Contrast Ratio')

# %%
df['helper'] = pd.to_numeric(df['helper'])

# %%
def high_contrast(text):

  if text > 1000000:
    return 1

  return 0

df['has_high_contrast'] = df['helper'].apply(high_contrast)

# %%
df['has_high_contrast'].value_counts()
# Out:
# has_high_contrast
# 0    892
# 1    376
# Name: count, dtype: int64

# %%
df.drop(columns='helper',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 77 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
#  73  display_ppi                  1268 non-null   float64
#  74  color_depth                  1268 non-null   float64
#  75  peak_brightness              1206 non-null   float64
#  76  has_high_contrast            1268 non-null   int64
# dtypes: category(4), datetime64[ns](1), float64(10), int64(16), object(46)
# memory usage: 729.6+ KB

# %%
df['body_dimension'].sample(20)
# Out:
# 1186     163.96 x 75.2 x 8.28 mm
# 742        165.6 x 75.9 x 7.9 mm
# 372        162.5 x 75.3 x 8.4 mm
# 305      171.3 x 73.99 x 7.25 mm
# 265      171.3 x 73.99 x 7.25 mm
# 1178    161.98 x 75.48 x 7.99 mm
# 34          163 x 77.6 x 8.25 mm
# 743        165.6 x 75.9 x 7.9 mm
# 1156     163.29 x 76.72 x 7.4 mm
# 576     161.47 x 74.02 x 8.75 mm
# 1061      153.5 x 132.6 x 5.6 mm
# 615     166.07 x 77.93 x 8.28 mm
# 1081       164.26 x 76.08 x 8 mm
# 671          162 x 75.1 x 8.6 mm
# 519            168 x 78 x 8.1 mm
# 879        165.4 x 76.9 x 8.4 mm
# 609     162.26 x 76.15 x 7.69 mm
# 1119       165.7 x 76.3 x 8.1 mm
# 227         165.7 x 76 x 7.99 mm
# 904          167.7 x 78 x 9.1 mm
# Name: body_dimension, dtype: object

# %%
df['height_mm'] = df['body_dimension'].str.split('x').str.get(0)

# %%
df['height_mm'] = pd.to_numeric(df['height_mm'],errors='coerce')

# %%
df['height_mm'].describe()
# Out:
# count    1268.000000
# mean      162.904101
# std         4.250095
# min       146.000000
# 25%       161.500000
# 50%       163.515000
# 75%       164.900000
# max       173.000000
# Name: height_mm, dtype: float64

# %%
df['height_mm'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['width_mm'] = df['body_dimension'].str.split('x').str.get(1)

# %%
df['width_mm'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['width_mm'] = pd.to_numeric(df['width_mm'],errors='coerce')

# %%
df['width_mm'].describe()
# Out:
# count    1268.000000
# mean       76.406814
# std         7.279013
# min        70.500000
# 25%        74.700000
# 50%        75.880000
# 75%        76.720000
# max       150.400000
# Name: width_mm, dtype: float64

# %%
df['thickness_mm'] = df['body_dimension'].str.split('x').str.get(2).str.strip().str.split(' ').str.get(0)

# %%
df['thickness_mm'].sample(20)
# Out:
# 496     8.26
# 1146     7.7
# 27       7.8
# 597        8
# 813      8.4
# 546      8.3
# 659     7.89
# 845     8.09
# 1198    8.39
# 641      8.1
# 1046     8.2
# 996      8.8
# 579     7.69
# 583      7.6
# 252      8.6
# 40       7.8
# 694      8.2
# 1036     8.6
# 231      8.5
# 241        8
# Name: thickness_mm, dtype: object

# %%
df['thickness_mm'] = pd.to_numeric(df['thickness_mm'],errors='coerce')

# %%
df['thickness_mm'].describe()
# Out:
# count    1268.000000
# mean        8.256838
# std         3.548106
# min         4.200000
# 25%         7.800000
# 50%         8.090000
# 75%         8.400000
# max        80.000000
# Name: thickness_mm, dtype: float64

# %%
df[df['thickness_mm'] > 20]
# Out:
#      model_id                      model  expert_rating  rating  rating_count  \
# 525       526  Poco M6 Pro (6GB + 128GB)             55     4.2     1421000.0
# 526       527  Poco M6 Pro (8GB + 256GB)             55     4.2      261000.0
# 527       528                Poco M6 Pro             55     4.3      871000.0
#
#      launch_on  old_price  price  launch_price  \
# 525 2023-08-09     9999.0  11999         10999
# 526 2023-08-09        NaN  14999         10999
# 527 2023-08-09     8999.0  10900         10999
#
#                         display_type            display_size  \
# 525  AMOLED, 90 Hz Refresh Rate, SDR  6.79 inches, 109.5 cm²
# 526  AMOLED, 90 Hz Refresh Rate, SDR  6.79 inches, 109.5 cm²
# 527  AMOLED, 90 Hz Refresh Rate, SDR  6.79 inches, 107.4 cm²
#
#                                                                                                                                                                                                              display_res  \
# 525  FHD+, 1080 x  2460 pixels, 20:9 (396 ppi), 12-bit 1.07 Billion Colours, 1300 nits(Peak Brightness), 550 nits(High Brightness), 1000 nits(Typical Brightness), TUV Rheinland certification, 5000000:1 Contrast Ratio
# 526  FHD+, 1080 x  2460 pixels, 20:9 (396 ppi), 12-bit 1.07 Billion Colours, 1300 nits(Peak Brightness), 550 nits(High Brightness), 1000 nits(Typical Brightness), TUV Rheinland certification, 5000000:1 Contrast Ratio
# 527                             FHD+, 1080 x  2400 pixels, 20:9 (396 ppi), 12-bit 1.07 Billion Colours, 1300 nits(Peak Brightness), 1000 nits(Typical Brightness), TUV Rheinland certification, 5000000:1 Contrast Ratio
#
#        body_dimension     weight body_front body_back      body_side  \
# 525  169 x 76 x 80 mm  199 grams      Glass     Glass  Plastic Frame
# 526  169 x 76 x 80 mm  199 grams      Glass     Glass  Plastic Frame
# 527  169 x 76 x 80 mm  199 grams      Glass     Glass  Plastic Frame
#
#                build_quality                                 ports  \
# 525  Corning Gorilla Glass 3  USB Type-C 2.0, 3.5mm Headphone Jack
# 526  Corning Gorilla Glass 3  USB Type-C 2.0, 3.5mm Headphone Jack
# 527  Corning Gorilla Glass 3  USB Type-C 2.0, 3.5mm Headphone Jack
#
#                             ip_rating       speaker  \
# 525  IP53 (Dust and Splash Resistant)  Mono Speaker
# 526  IP53 (Dust and Splash Resistant)  Mono Speaker
# 527  IP53 (Dust and Splash Resistant)  Mono Speaker
#
#                                                      chipset  \
# 525  Qualcomm Snapdragon 4 Gen 2 (4 nm), 437000 Antutu Score
# 526  Qualcomm Snapdragon 4 Gen 2 (4 nm), 437000 Antutu Score
# 527  Qualcomm Snapdragon 4 Gen 2 (4 nm), 437000 Antutu Score
#
#                                                   cpu         gpu  \
# 525  Octa-core (2x2.2 GHz Cortex-A78 & 6x Cortex-A55)  Adreno 613
# 526  Octa-core (2x2.2 GHz Cortex-A78 & 6x Cortex-A55)  Adreno 613
# 527  Octa-core (2x2.2 GHz Cortex-A78 & 6x Cortex-A55)  Adreno 613
#
#                                          main_cam                  main_cam2  \
# 525  50 MP, f/1.8, 0mm (Wide-angle), 0.8 µm, PDAF  2 MP, f/2.4, 0mm  (Depth)
# 526  50 MP, f/1.8, 0mm (Wide-angle), 0.8 µm, PDAF  2 MP, f/2.4, 0mm  (Depth)
# 527      50 MP, f/1.8, (Wide-angle), 0.8 µm, PDAF  2 MP, f/2.4, 0mm  (Depth)
#
#     main_cam3  \
# 525       NaN
# 526       NaN
# 527       NaN
#
#                                                                        main_cam_features  \
# 525  Film Camera Mode, HDR, LED Flash, Night Mode, Portrait Mode, Slow Motion, Timelapse
# 526  Film Camera Mode, HDR, LED Flash, Night Mode, Portrait Mode, Slow Motion, Timelapse
# 527  Film Camera Mode, HDR, LED Flash, Night Mode, Portrait Mode, Slow Motion, Timelapse
#
#                                   main_video                     os  \
# 525  1080p@30/60fps, 720p@30fps, Slow Motion  Android 13, Poco MIUI
# 526  1080p@30/60fps, 720p@30fps, Slow Motion  Android 13, Poco MIUI
# 527  1080p@30/60fps, 720p@30fps, Slow Motion  Android 13, Poco MIUI
#
#                                                     software_updates  \
# 525  2 year(s) of Software updates and 3 year(s) of Security updates
# 526  2 year(s) of Software updates and 3 year(s) of Security updates
# 527  2 year(s) of Software updates and 3 year(s) of Security updates
#
#     ai_features                    front_cam  \
# 525   AI Camera  16 MP, f/2.45, 0mm, 1.12 µm
# 526   AI Camera  16 MP, f/2.45, 0mm, 1.12 µm
# 527   AI Camera       16 MP, f/2.45, 1.12 µm
#
#                               front_cam_features              front_video  \
# 525                             Face Unlock, HDR  1080p@30fps, Time Lapse
# 526                             Face Unlock, HDR  1080p@30fps, Time Lapse
# 527  Face Unlock, HDR, Night Mode, Portrait Mode  1080p@30fps, Time Lapse
#
#                                        battery       charging         storage  \
# 525  5000 mAh, Lithium Polymer (Non-removable)  22.5W (wired)  128GB, UFS 2.2
# 526  5000 mAh, Lithium Polymer (Non-removable)  22.5W (wired)  256GB, UFS 2.2
# 527  5000 mAh, Lithium Polymer (Non-removable)    18W (wired)  128GB, UFS 2.2
#
#               ram                                        sim            tech  \
# 525  6GB, LPDDR4X  Hybrid Dual SIM (nano-SIM, dual stand-by)  GSM, HSPA, LTE
# 526  8GB, LPDDR4X  Hybrid Dual SIM (nano-SIM, dual stand-by)  GSM, HSPA, LTE
# 527  4GB, LPDDR4X  Hybrid Dual SIM (nano-SIM, dual stand-by)  GSM, HSPA, LTE
#
#                        2g                              3g  \
# 525  2, 3, 5, 8 (4 bands)  1, 2, 4, 5, 6, 8, 19 (7 bands)
# 526  2, 3, 5, 8 (4 bands)  1, 2, 4, 5, 6, 8, 19 (7 bands)
# 527  2, 3, 5, 8 (4 bands)  1, 2, 4, 5, 6, 8, 19 (7 bands)
#
#                                                                                   4g  \
# 525  1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 26, 28, 38, 40, 41, 66, (19 bands)
# 526  1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 26, 28, 38, 40, 41, 66, (19 bands)
# 527  1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 26, 28, 38, 40, 41, 66, (19 bands)
#
#                                            5g           speed  \
# 525  1, 3, 5, 8, 28, 40, 78, SA/NSA (8 bands)  GSM, HSPA, LTE
# 526  1, 3, 5, 8, 28, 40, 78, SA/NSA (8 bands)  GSM, HSPA, LTE
# 527                                       NaN  GSM, HSPA, LTE
#
#                                               wifi               bluetooth  \
# 525  Wi-Fi 5 802.11 a/b/g/n/ac, Hotspot, Dual Band  Unknown, A2DP, LE, SBC
# 526  Wi-Fi 5 802.11 a/b/g/n/ac, Hotspot, Dual Band  Unknown, A2DP, LE, SBC
# 527  Wi-Fi 5 802.11 a/b/g/n/ac, Hotspot, Dual Band  Unknown, A2DP, LE, SBC
#
#     positioning_system  nfc  finger_print  \
# 525       GLONASS, GPS  NaN  Side Mounted
# 526       GLONASS, GPS  NaN  Side Mounted
# 527       GLONASS, GPS  NaN  Side Mounted
#
#                                                  sensors add_features brand  \
# 525  Accelerometer, Compass, Gyroscope, Proximity Sensor          NaN  poco
# 526  Accelerometer, Compass, Gyroscope, Proximity Sensor          NaN  poco
# 527  Accelerometer, Compass, Gyroscope, Proximity Sensor          NaN  poco
#
#      is_available  is_flipkart_available  is_amazon_available  \
# 525             1                      1                    1
# 526             0                      1                    0
# 527             1                      1                    1
#
#      is_official_available display_panel_type display_panel_family  \
# 525                      0             amoled               amoled
# 526                      0             amoled               amoled
# 527                      0             amoled               amoled
#
#      display_hz display_dynamic_range  touch_sampling_rate  has_ltpo  \
# 525          90                   SDR                  NaN         0
# 526          90                   SDR                  NaN         0
# 527          90                   SDR                  NaN         0
#
#      has_anti_reflection_coating  display_inches  display_body_ratio  \
# 525                            0            6.79                 NaN
# 526                            0            6.79                 NaN
# 527                            0            6.79                 NaN
#
#      has_curved  has_foldable res_category  res_width  res_height  \
# 525           0             0         FHD+       1080        2460
# 526           0             0         FHD+       1080        2460
# 527           0             0         FHD+       1080        2400
#
#      aspect_ration_numeric  display_ppi  color_depth  peak_brightness  \
# 525               2.222222        396.0         12.0           1300.0
# 526               2.222222        396.0         12.0           1300.0
# 527               2.222222        396.0         12.0           1300.0
#
#      has_high_contrast  height_mm  width_mm  thickness_mm
# 525                  1      169.0      76.0          80.0
# 526                  1      169.0      76.0          80.0
# 527                  1      169.0      76.0          80.0

# %%
df.loc[[525,526,527],'thickness_mm'] = 8

# %%
df['thickness_mm'].describe()
# Out:
# count    1268.000000
# mean        8.086491
# std         0.610675
# min         4.200000
# 25%         7.800000
# 50%         8.090000
# 75%         8.400000
# max        10.300000
# Name: thickness_mm, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 80 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
#  73  display_ppi                  1268 non-null   float64
#  74  color_depth                  1268 non-null   float64
#  75  peak_brightness              1206 non-null   float64
#  76  has_high_contrast            1268 non-null   int64
#  77  height_mm                    1268 non-null   float64
#  78  width_mm                     1268 non-null   float64
#  79  thickness_mm                 1268 non-null   float64
# dtypes: category(4), datetime64[ns](1), float64(13), int64(16), object(46)
# memory usage: 759.3+ KB

# %%
df['weight'].sample(20)
# Out:
# 356       190 grams
# 988       191 grams
# 310       190 grams
# 514     179.5 grams
# 1207      190 grams
# 460       177 grams
# 457       185 grams
# 864       205 grams
# 986       200 grams
# 16        201 grams
# 898       191 grams
# 1023      234 grams
# 132     195.4 grams
# 473       187 grams
# 1148      190 grams
# 1130      180 grams
# 659       190 grams
# 1152      190 grams
# 1189      181 grams
# 55        239 grams
# Name: weight, dtype: object

# %%
df['weight_g'] = df['weight'].str.strip().str.split(' ').str.get(0)

# %%
df['weight_g'] = pd.to_numeric(df['weight_g'],errors='coerce')

# %%
df['weight_g'].describe()
# Out:
# count    1268.000000
# mean      193.758975
# std        14.563168
# min       155.000000
# 25%       185.000000
# 50%       191.000000
# 75%       200.000000
# max       284.000000
# Name: weight_g, dtype: float64

# %%
df['body_front'].sample(20)
# Out:
# 648                      Glass
# 162                      Glass
# 1192                     Glass
# 4                        Glass
# 315           Gorilla Glass 7i
# 756                      Glass
# 829                      Glass
# 133                      Glass
# 685                      Glass
# 394                      Glass
# 438           Gorilla Glass 7i
# 191                      Glass
# 1128                     Glass
# 419                      Glass
# 939            Gorilla Glass 5
# 1064        UTG foldable Glass
# 768           Gorilla Glass 7i
# 1240    Schott Xensation Glass
# 495                      Glass
# 1173              Shield Glass
# Name: body_front, dtype: object

# %%
df['body_front'].value_counts()
# Out:
# body_front
# Glass                              719
# Gorilla Glass 5                     89
# Gorilla Glass 7i                    61
# Gorilla Glass Victus 2              50
# Gorilla Glass Victus                46
# Gorilla Glass 3                     44
# Panda Glass                         35
# Gorilla Glass                       32
# Gorilla Glass Victus+               22
# Corning Gorilla Glass 5             17
# Corning Gorilla Glass 3             16
# Armorshell Glass                    16
# Ceramic Shield Glass                15
# Ultra Thin Glass                    13
# Shield Glass                        13
# Ceramic Shield 2                    12
# Dragontrail Glass                    8
# AGC Glass                            8
# UTG foldable Glass                   8
# Schott Xensation Glass               7
# Gorilla Glass 7                      7
# Asahi Glass AGC DT-Star2 Glass       6
# Armour Glass                         5
# Gorilla Glass Armour 2.0             4
# Ceramic Guard Glass                  3
# Foldable Glass                       3
# Flexible UTG (ultra thin glass)      2
# Corning Gorilla Glass Ceramic 2      2
# NanoCrystal Shield                   1
# Foldable Ultra Thin Glass            1
# Plastic                              1
# Xiaomi Shield Glass 2.0              1
# Xiaomi Shield Glass                  1
# Name: count, dtype: int64

# %%
def clean_body_front(text):

  t = text.lower()

  if t == 'glass':
    return 'standard glass'

  if 'gorilla glass' in t:

    if 'victus 2' in t:
      return 'gorilla glass victus 2'
    if 'victus+' in t:
      return 'gorilla glass victus+'
    if 'victus' in t:
      return 'gorilla glass victus'
    if '5' in t:
      return 'gorilla glass 5'
    if '3' in t:
      return 'gorilla glass 3'
    if '7i' in t:
      return 'gorilla glass 7i'
    return 'gorilla glass'

  if 'ceramic shield' in t or 'ceramic gaurd' in t:
    return 'ceramic shield'

  if 'utg' in t or 'ultra thin glass' in t or 'foldable glass' in t:
    return 'foldable utg'

  if 'panda' in t:
    return 'panda glass'

  if 'dragontrail' in t:
    return 'dragontrail glass'

  if 'schott' in t:
    return 'schott xensation'

  if 'armorshell' in t:
    return 'armonshell glass'

  return 'other branded glass'

df['front_potection'] = df['body_front'].apply(clean_body_front)

# %%
df['front_potection'].value_counts()
# Out:
# front_potection
# standard glass            719
# gorilla glass 5           106
# gorilla glass 7i           61
# gorilla glass 3            60
# gorilla glass victus 2     50
# gorilla glass victus       46
# gorilla glass              45
# other branded glass        39
# panda glass                35
# foldable utg               27
# ceramic shield             27
# gorilla glass victus+      22
# armonshell glass           16
# dragontrail glass           8
# schott xensation            7
# Name: count, dtype: int64

# %%
df['front_potection'] = df['front_potection'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 82 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
#  73  display_ppi                  1268 non-null   float64
#  74  color_depth                  1268 non-null   float64
#  75  peak_brightness              1206 non-null   float64
#  76  has_high_contrast            1268 non-null   int64
#  77  height_mm                    1268 non-null   float64
#  78  width_mm                     1268 non-null   float64
#  79  thickness_mm                 1268 non-null   float64
#  80  weight_g                     1268 non-null   float64
#  81  front_potection              1268 non-null   category
# dtypes: category(5), datetime64[ns](1), float64(14), int64(16), object(46)
# memory usage: 771.1+ KB

# %%
df['body_back'].value_counts(dropna=False)
# Out:
# body_back
# Plastic                            642
# Glass                              313
# Vegan Leather                       65
# Gorilla Glass Victus 2              31
# Polycarbonate                       31
# NaN                                 30
# Eco Leather                         22
# Textured Matt Glass                 17
# Gorilla Glass Victus+               15
# Gorilla Glass 5                     11
# AG Glass                            11
# Ceramic Shield                      10
# Colour-infused Glass                 8
# Gorrila Glass 7i                     6
# Panda Glass                          5
# Leather                              4
# Plastic or Eco Leather               4
# Aluminium                            3
# Silicon Vegan                        3
# Gorilla Glass                        3
# Gorilla Glass Victus 3               3
# Corning Gorilla Glass                3
# Plasitc                              2
# Colour Changing Glass                2
# Aromatic Leather                     2
# Gorilla Glass Victus                 2
# Glass or Plastic                     2
# Plastic or Leather                   2
# Transparent Plastic                  2
# Ceramic                              2
# Glass or Eco Leather                 2
# Gorilla Glass 3                      1
# Wood                                 1
# Silicon Polymer                      1
# Eco Leather or Plastic               1
# Plastic or Vegan Leather             1
# Vegan Leather and Glass              1
# Glass or Leather Back                1
# Armor Glass                          1
# Dual Tone Glass and Eco Leather      1
# Panda X Glass                        1
# Name: count, dtype: int64

# %%
def clean_body_back(text):

  if pd.isna(text): return "unknown"
  t = str(text).lower().strip()

  if any(x in t for x in ['plastic', 'polycarbonate', 'plasitc']):
    if 'leather' in t:
      return 'hybrid (plastic/leather)'
    return 'plastic'

  if any(x in t for x in ['leather', 'vegan', 'eco', 'polymer']):
    if 'glass' in t:
      return 'hybrid (glass/leather)'
    return 'leather/vegan leather'

  if 'gorilla glass' in text or 'gorrila glass' in text or 'corning' in text:
    if 'victus 2' in text:
      return 'gorilla glass victus 2'
    if 'victus' in text:
      return 'gorilla glass victus'
    if '5' in text:
      return 'gorilla glass 5'
    return 'gorilla glass others'

  if 'ceramic shield' in t:
    return 'ceramic shield'

  if 'panda' in t:
    return 'panda glass'

  if 'aluminium' in t:
     return 'Metal'
  if 'ceramic' in t:
    return 'Ceramic'
  if 'wood' in t:
    return 'Wood'

  if t == 'glass':
    return 'glass'

  return 'Other'

df['back_material'] = df['body_back'].apply(clean_body_back)

# %%
df['back_material'].value_counts()
# Out:
# back_material
# plastic                     679
# glass                       313
# Other                       114
# leather/vegan leather        97
# unknown                      30
# ceramic shield               10
# hybrid (plastic/leather)      8
# panda glass                   6
# hybrid (glass/leather)        5
# Metal                         3
# Ceramic                       2
# Wood                          1
# Name: count, dtype: int64

# %%
df['back_material'] = df['back_material'].astype('category')

# %%
df['body_side'].value_counts(dropna=False)
# Out:
# body_side
# Plastic Frame                                            940
# Aluminium Frame                                          218
# Metal Frame                                               25
# Titanium Frame                                            23
# NaN                                                       17
# Aluminium Frame, Stainless Steel Hinge                    12
# Armor Aluminium                                            9
# Stainless Steel Frame                                      8
# Aluminium Frame, Aluminum Alloy Hinge                      6
# Aluminium Frame, strength Steel Hinge                      2
# Aluminium Frame, Titanium Alloy Hinge                      2
# Stainless Steel Frame, Stainless Steel Hinge               1
# Aluminium Frame, Aluminium                                 1
# Aluminium Frame, (7000 series), Stainless Steel Hinge      1
# Aluminium Frame, Titanium Alloy                            1
# Aluminium Frame, Carbon Fiber Hinge                        1
# Aluminium Frame, Carbon Fiber Dual Hinge Plates            1
# Name: count, dtype: int64

# %%
def clean_body_side(text):

  if pd.isna(text):
    return 'unknown'

  t = text.lower()

  if 'plastic' in t:
    return 'plastic frame'

  if 'titanium' in t:
    return 'titanium frame'

  if 'stainless steel' in t:
    return 'stainless steel frame'

  if any(x in t for x in ['aluminium', 'aluminum', 'metal', 'armor']):
    if 'hinge' in t:
      return 'aluminium frame (faldable hinge)'
    return 'aluminium/metal frame'

  return 'other'

df['frame_material'] = df['body_side'].apply(clean_body_side)

# %%
df['frame_material'].value_counts()
# Out:
# frame_material
# plastic frame                       940
# aluminium/metal frame               253
# titanium frame                       26
# stainless steel frame                22
# unknown                              17
# aluminium frame (faldable hinge)     10
# Name: count, dtype: int64

# %%
df['frame_material'] = df['frame_material'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 84 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
#  73  display_ppi                  1268 non-null   float64
#  74  color_depth                  1268 non-null   float64
#  75  peak_brightness              1206 non-null   float64
#  76  has_high_contrast            1268 non-null   int64
#  77  height_mm                    1268 non-null   float64
#  78  width_mm                     1268 non-null   float64
#  79  thickness_mm                 1268 non-null   float64
#  80  weight_g                     1268 non-null   float64
#  81  front_potection              1268 non-null   category
#  82  back_material                1268 non-null   category
#  83  frame_material               1268 non-null   category
# dtypes: category(7), datetime64[ns](1), float64(14), int64(16), object(46)
# memory usage: 774.2+ KB

# %%
df['build_quality'].value_counts(dropna=False).head(20)
# Out:
# build_quality
# NaN                               529
# Plastic Material                  222
# Corning Gorilla Glass 5            62
# Corning Gorilla Glass 7i           33
# Corning Gorilla Glass 3            28
# Corning Gorilla Glass Victus 2     26
# Corning Gorilla Glass Victus+      26
# Ceramic Shield Glass               25
# MIL-STD-810H                       25
# MIL-STD-810H compliant*            19
# Panda glass                        17
# Corning Gorilla Glass              14
# Corning Gorilla Glass victus 2     14
# Schott Xensation Alpha             14
# Corning Gorilla Glass Victus       14
# Schott Xensation                   13
# SGS 5-Star Drop Resistance         13
# Ceramic Shield 2                   12
# Gorilla Glass 5                    10
# Gorilla Glass Victus 2             10
# Name: count, dtype: int64

# %%
def extract_durability(text):
    if pd.isna(text):
      return "Standard"
    text = str(text).lower()

    if 'mil-std' in text:
        return 'Military Grade (MIL-STD)'
    if 'sgs' in text or 'drop resistance' in text:
        return 'SGS Certified Drop Resistance'

    return "Standard/Branded Glass"

df['durability_cert'] = df['build_quality'].apply(extract_durability).astype('category')

# %%
df['durability_cert'].value_counts(dropna=False)
# Out:
# durability_cert
# Standard/Branded Glass           669
# Standard                         529
# Military Grade (MIL-STD)          57
# SGS Certified Drop Resistance     13
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 85 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
#  73  display_ppi                  1268 non-null   float64
#  74  color_depth                  1268 non-null   float64
#  75  peak_brightness              1206 non-null   float64
#  76  has_high_contrast            1268 non-null   int64
#  77  height_mm                    1268 non-null   float64
#  78  width_mm                     1268 non-null   float64
#  79  thickness_mm                 1268 non-null   float64
#  80  weight_g                     1268 non-null   float64
#  81  front_potection              1268 non-null   category
#  82  back_material                1268 non-null   category
#  83  frame_material               1268 non-null   category
#  84  durability_cert              1268 non-null   category
# dtypes: category(8), datetime64[ns](1), float64(14), int64(16), object(46)
# memory usage: 775.6+ KB

# %%
df['ports'].sample(20)
# Out:
# 884                          USB Type-C 2.0, OTG
# 499             USB Type-C, 3.5mm Headphone Jack
# 603                               USB Type-C 2.0
# 602        USB Type-C, 3.5mm Headphone Jack, OTG
# 704    USB Type-C 2.0, 3.5mm Headphone Jack, OTG
# 216                          USB Type-C 2.0, OTG
# 893         USB Type-C 2.0, 3.5mm Headphone Jack
# 473                          USB Type-C 2.0, OTG
# 461                          USB Type-C 2.0, OTG
# 826             USB Type-C, 3.5mm Headphone Jack
# 348           USB Type-C 2.0, Infrared Port, OTG
# 267                          USB Type-C 3.1, OTG
# 810         USB Type-C 2.0, 3.5mm Headphone Jack
# 961                          USB Type-C 2.0, OTG
# 134    USB Type-C 2.0, 3.5mm Headphone Jack, OTG
# 364                USB Type-C 2.0, Infrared Port
# 269        USB Type-C 3.1, Display Port 1.4, OTG
# 963                          USB Type-C 2.0, OTG
# 754                          USB Type-C 2.0, OTG
# 587                              USB Type-C, OTG
# Name: ports, dtype: object

# %%
df['ports'].str.contains('3.5mm').sum()
# Out:
# np.int64(535)

# %%
def has_audio_jack(text):

  t = text.lower()

  if '3.5mm' in t:
    return 1

  return 0

df['has_3_5mm_jack'] = df['ports'].apply(has_audio_jack)

# %%
df['has_3_5mm_jack'].value_counts()
# Out:
# has_3_5mm_jack
# 0    733
# 1    535
# Name: count, dtype: int64

# %%
def extract_usb_type(text):

  if pd.isna(text):
    return 'unknown'

  t = text.lower()

  if 'type-c' in t:
    return 'type-c'

  if 'micro' in t:
    return 'microUSB'

  if 'lightning' in t:
    return 'lightning'

  return 'unknown'

df['usb_type'] = df['ports'].apply(extract_usb_type).astype('category')

# %%
df['usb_type'].value_counts()
# Out:
# usb_type
# type-c       1220
# microUSB       34
# lightning      14
# Name: count, dtype: int64

# %%
df['ports'].sample(20)
# Out:
# 219                                               USB Type-C, OTG
# 54      OTG, USB Type-C 2.0, USB Type-C 3.1, 3.5mm Headphone Jack
# 526                          USB Type-C 2.0, 3.5mm Headphone Jack
# 961                                           USB Type-C 2.0, OTG
# 885                                           USB Type-C 2.0, OTG
# 726                              USB Type-C, 3.5mm Headphone Jack
# 1031                                    USB Type-C 3.2 Gen 1, OTG
# 451                                           USB Type-C 2.0, OTG
# 819                            microUSB 2.0, 3.5mm Headphone Jack
# 55      OTG, USB Type-C 2.0, USB Type-C 3.1, 3.5mm Headphone Jack
# 153                                           USB Type-C 2.0, OTG
# 751                     USB Type-C 2.0, 3.5mm Headphone Jack, OTG
# 456                         USB Type-C, 3.5mm Headphone Jack, OTG
# 882                                           USB Type-C 2.0, OTG
# 298                          USB Type-C 2.0, 3.5mm Headphone Jack
# 8                                               Lightning USB 2.0
# 156                               USB Type-C 2.0, IR Blaster, OTG
# 530                                                    USB Type-C
# 518                                           USB Type-C 2.0, OTG
# 404                         USB Type-C, 3.5mm Headphone Jack, OTG
# Name: ports, dtype: object

# %%
def extract_usb_version(text):

  t = text.lower()

  if '3.2' in t:
    return 3.2

  if '3.1' in t:
    return 3.1

  return 2.0

df['usb_version'] = df['ports'].apply(extract_usb_version)

# %%
df['usb_version'].value_counts()
# Out:
# usb_version
# 2.0    1130
# 3.2     108
# 3.1      30
# Name: count, dtype: int64

# %%
df['ports'].str.contains('OTG').sum()
# Out:
# np.int64(807)

# %%
def has_otg(text):

  t = text.lower()

  if 'otg' in t:
    return 1

  return 0

df['has_otg'] = df['ports'].apply(has_otg)

# %%
df['has_otg'].value_counts()
# Out:
# has_otg
# 1    807
# 0    461
# Name: count, dtype: int64

# %%
df['ports'].sample(20)
# Out:
# 295                         USB Type-C 2.0, 3.5mm Headphone Jack
# 964                                          USB Type-C 2.0, OTG
# 254                         USB Type-C 2.0, 3.5mm Headphone Jack
# 570                                              USB Type-C, OTG
# 397                    USB Type-C 2.0, 3.5mm Headphone Jack, OTG
# 444                        USB Type-C, 3.5mm Headphone Jack, OTG
# 849                         USB Type-C 2.0, 3.5mm Headphone Jack
# 149                               USB Type-C, Infrared Port, OTG
# 562                                          USB Type-C 2.0, OTG
# 1144                                             USB Type-C, OTG
# 340                                USB Type-C 2.0, Infrared Port
# 385                      microUSB 2.0, 3.5mm Headphone Jack, OTG
# 1060                            USB Type-C 3.2, Display Port 1.2
# 35                              USB Type-C 3.2, Display Port 1.2
# 411                        USB Type-C, 3.5mm Headphone Jack, OTG
# 1223                   USB Type-C 2.0, 3.5mm Headphone Jack, OTG
# 874                           USB Type-C 2.0, Infrared Port, OTG
# 886                    USB Type-C 2.0, 3.5mm Headphone Jack, OTG
# 273                                          USB Type-C 2.0, OTG
# 1252    USB Type-C 2.0, 3.5mm Headphone Jack, Infrared Port, OTG
# Name: ports, dtype: object

# %%
df['ports'].str.contains(r'Infrared Port|Infrared Port|IR Blaster').sum()
# Out:
# np.int64(142)

# %%
def has_ir_blaster(text):

  t = text.lower()

  if 'infrared port' in t:
    return 1

  if 'ir blaster' in t:
    return 1

  return 0

df['has_ir_blaster'] = df['ports'].apply(has_ir_blaster)

# %%
df['has_ir_blaster'].value_counts()
# Out:
# has_ir_blaster
# 0    1124
# 1     144
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 90 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
#  73  display_ppi                  1268 non-null   float64
#  74  color_depth                  1268 non-null   float64
#  75  peak_brightness              1206 non-null   float64
#  76  has_high_contrast            1268 non-null   int64
#  77  height_mm                    1268 non-null   float64
#  78  width_mm                     1268 non-null   float64
#  79  thickness_mm                 1268 non-null   float64
#  80  weight_g                     1268 non-null   float64
#  81  front_potection              1268 non-null   category
#  82  back_material                1268 non-null   category
#  83  frame_material               1268 non-null   category
#  84  durability_cert              1268 non-null   category
#  85  has_3_5mm_jack               1268 non-null   int64
#  86  usb_type                     1268 non-null   category
#  87  usb_version                  1268 non-null   float64
#  88  has_otg                      1268 non-null   int64
#  89  has_ir_blaster               1268 non-null   int64
# dtypes: category(9), datetime64[ns](1), float64(15), int64(19), object(46)
# memory usage: 816.6+ KB

# %%
df['ip_rating'].sample(20)
# Out:
# 277        IP68 (Dust and Water Resistant)
# 842       IP53 (Dust and Splash Resistant)
# 573        IP65 (Dust and Water Resistant)
# 1091       IP54 (Dust and Water Resistant)
# 463        IP69 (Dust and Water Resistant)
# 1161    IP68/69 (Dust and Water Resistant)
# 952                                    NaN
# 623                                    NaN
# 1076                                   NaN
# 135                                    NaN
# 64         IP68 (Dust and Water Resistant)
# 738        IP65 (Dust and Water Resistant)
# 569        IP54 (Dust and Water Resistant)
# 917                                    NaN
# 1172    IP68/69 (Dust and Water Resistant)
# 545        IP54 (Dust and Water Resistant)
# 953                                    NaN
# 114        IP54 (Dust and Water Resistant)
# 722        IP65 (Dust and Water Resistant)
# 946                                    NaN
# Name: ip_rating, dtype: object

# %%
def water_resistance_level(text):

  if pd.isna(text):
    return 'level 0'

  t = text.lower()

  if any(x in t for x in ['ip67', 'ip68', 'ip69', 'ipx8', 'ipx9', 'ip66/68/69', 'ipx6/x8/x9']):
        return 'level 3'

  if any(x in t for x in ['ip53', 'ip54', 'ip64', 'ip65', 'water resistant']):
        return 'level 2'

  if any(x in t for x in ['water repellent', 'ip48', 'ip52', 'ipx4', 'splash resistant', 'dust and water resistant']):
        return 'level 1'

df['water_resistance_level'] = df['ip_rating'].apply(water_resistance_level).astype('category')

# %%
df['water_resistance_level'].value_counts(dropna=False)
# Out:
# water_resistance_level
# level 2    462
# level 0    353
# level 3    344
# level 1    109
# Name: count, dtype: int64

# %%
df['water_resistance_level'].count()
# Out:
# np.int64(1268)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 91 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
#  73  display_ppi                  1268 non-null   float64
#  74  color_depth                  1268 non-null   float64
#  75  peak_brightness              1206 non-null   float64
#  76  has_high_contrast            1268 non-null   int64
#  77  height_mm                    1268 non-null   float64
#  78  width_mm                     1268 non-null   float64
#  79  thickness_mm                 1268 non-null   float64
#  80  weight_g                     1268 non-null   float64
#  81  front_potection              1268 non-null   category
#  82  back_material                1268 non-null   category
#  83  frame_material               1268 non-null   category
#  84  durability_cert              1268 non-null   category
#  85  has_3_5mm_jack               1268 non-null   int64
#  86  usb_type                     1268 non-null   category
#  87  usb_version                  1268 non-null   float64
#  88  has_otg                      1268 non-null   int64
#  89  has_ir_blaster               1268 non-null   int64
#  90  water_resistance_level       1268 non-null   category
# dtypes: category(10), datetime64[ns](1), float64(15), int64(19), object(46)
# memory usage: 818.0+ KB

# %%
df['speaker'].sample(30)
# Out:
# 211                                      Loudspeaker
# 193                                  Stereo Speakers
# 276                                  Stereo Speakers
# 731                                  Stereo Speakers
# 359     Dual-mic Noise Cancellation, Stereo Speakers
# 138                                      Loudspeaker
# 529                                     Mono Speaker
# 94                                   Stereo Speakers
# 420                                      Loudspeaker
# 32           Stereo Speakers (Dolby Atmos Certified)
# 789                                      Loudspeaker
# 877                                      Loudspeaker
# 876                                  Stereo Speakers
# 795                                      Loudspeaker
# 916                                     Mono Speaker
# 516          24-bit/192kHz Hi-Res Audio, Loudspeaker
# 197                                  Stereo Speakers
# 1009                                    Mono Speaker
# 306                                  Stereo Speakers
# 752                                  Stereo Speakers
# 724     Dual-mic Noise Cancellation, Stereo Speakers
# 1025                                 Stereo Speakers
# 524                                     Mono Speaker
# 145                                  Stereo Speakers
# 936                                  Stereo Speakers
# 1195                                     Loudspeaker
# 522                                     Mono Speaker
# 811                                     Mono Speaker
# 310                                  Stereo Speakers
# 1091                                 Stereo Speakers
# Name: speaker, dtype: object

# %%
def has_stereo_speakers(text):

  if pd.isna(text):
    return 0

  t = text.lower()

  if 'stereo' in t:
    return 1

  return 0


df['has_stereo_speakers'] = df['speaker'].apply(has_stereo_speakers).astype('int')

# %%
df['has_stereo_speakers'].value_counts()
# Out:
# has_stereo_speakers
# 1    768
# 0    500
# Name: count, dtype: int64

# %%
df['speaker'].sample(20)
# Out:
# 872                             Stereo Speakers
# 345                             Stereo Speakers
# 461                                 Loudspeaker
# 1143                               Mono Speaker
# 107                             Stereo Speakers
# 63                              Stereo Speakers
# 687                             Stereo Speakers
# 555                             Stereo Speakers
# 79                              Stereo Speakers
# 1177                            Stereo Speakers
# 282     Stereo Speakers (Dolby Atmos Certified)
# 1218                               Mono Speaker
# 391                                 Loudspeaker
# 407                                 Loudspeaker
# 116                             Stereo Speakers
# 513               Hi-Res Audio, Stereo Speakers
# 106                                 Loudspeaker
# 444                             Stereo Speakers
# 333                             Stereo Speakers
# 157                             Stereo Speakers
# Name: speaker, dtype: object

# %%
def has_audio_certification(text):

  if pd.isna(text):
    return 0

  t = text.lower()

  if 'dolby' in t:
    return 1

  if 'hi-res' in t:
    return 1

  if 'dts' in t:
    return 1

  return 0

df['has_audio_certification'] = df['speaker'].apply(has_audio_certification)

# %%
df['has_audio_certification'].value_counts()
# Out:
# has_audio_certification
# 0    1142
# 1     126
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 93 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
#  73  display_ppi                  1268 non-null   float64
#  74  color_depth                  1268 non-null   float64
#  75  peak_brightness              1206 non-null   float64
#  76  has_high_contrast            1268 non-null   int64
#  77  height_mm                    1268 non-null   float64
#  78  width_mm                     1268 non-null   float64
#  79  thickness_mm                 1268 non-null   float64
#  80  weight_g                     1268 non-null   float64
#  81  front_potection              1268 non-null   category
#  82  back_material                1268 non-null   category
#  83  frame_material               1268 non-null   category
#  84  durability_cert              1268 non-null   category
#  85  has_3_5mm_jack               1268 non-null   int64
#  86  usb_type                     1268 non-null   category
#  87  usb_version                  1268 non-null   float64
#  88  has_otg                      1268 non-null   int64
#  89  has_ir_blaster               1268 non-null   int64
#  90  water_resistance_level       1268 non-null   category
#  91  has_stereo_speakers          1268 non-null   int64
#  92  has_audio_certification      1268 non-null   int64
# dtypes: category(10), datetime64[ns](1), float64(15), int64(21), object(46)
# memory usage: 837.8+ KB

# %%
df['chipset'].sample(20)
# Out:
# 508               Qualcomm Snapdragon 8s Gen 4 (4 nm), 2127544 Antutu Score
# 351                Qualcomm Snapdragon 8 Gen 5 (3 nm), 2886527 Antutu Score
# 283                     MediaTek Dimensity 7400 (4 nm), 777255 Antutu Score
# 915                     Qualcomm Snapdragon 695 (6 nm), 441369 Antutu Score
# 807                         MediaTek Helio G85 (12 nm), 264823 Antutu Score
# 393                Qualcomm Snapdragon 6s Gen1 (11 nm), 440358 Antutu Score
# 430                                          MediaTek Dimensity 6300 (6 nm)
# 286            MediaTek Dimensity 8350 Extreme (4 nm), 1378568 Antutu Score
# 11                            Apple A16 Bionic (4 nm), 1445704 Antutu Score
# 1009                        Samsung Exynos 1480 (4 nm), 734625 Antutu Score
# 618                      MediaTek Dimensity 810 (6 nm), 421890 Antutu Score
# 1160                Qualcomm Snapdragon 7 Gen 4 (4 nm), 956920 Antutu Score
# 583              MediaTek Dimensity 7300 Energy (4 nm), 750000 Antutu Score
# 762                 Qualcomm Snapdragon 6 Gen 4 (4 nm), 512465 Antutu Score
# 975                     MediaTek Dimensity 6300 (6 nm), 452218 Antutu Score
# 1064    Qualcomm Snapdragon 8 Elite for Galaxy (3 nm), 2795139 Antutu Score
# 61                  MediaTek Dimensity 7300 Pro (4 nm), 688247 Antutu Score
# 314                 MediaTek Dimensity 7200 Pro (4 nm), 708000 Antutu Score
# 627                     Qualcomm Snapdragon 680 (6 nm), 310236 Antutu Score
# 1179                                         MediaTek Dimensity 9500 (3 nm)
# Name: chipset, dtype: object

# %%
df['processor_brand'] = df['chipset'].str.strip().str.lower().str.split(' ').str.get(0).astype('category')

# %%
df['processor_brand'].value_counts(dropna=False)
# Out:
# processor_brand
# mediatek    599
# qualcomm    460
# samsung      74
# unisoc       61
# apple        54
# google       20
# Name: count, dtype: int64

# %%
df['chipset_brand'] = df['chipset'].str.strip().str.lower().str.split('(').str.get(0).str.strip()

# %%
df['chipset_brand'] = df['chipset_brand'].str.replace('apple', '', case=False).str.strip()
df['chipset_brand'] = df['chipset_brand'].str.replace('qualcomm', '', case=False).str.strip()
df['chipset_brand'] = df['chipset_brand'].str.replace('mediatek', '', case=False).str.strip()
df['chipset_brand'] = df['chipset_brand'].str.replace('samsung', '', case=False).str.strip()
df['chipset_brand'] = df['chipset_brand'].str.replace('unisoc', '', case=False).str.strip()
df['chipset_brand'] = df['chipset_brand'].str.replace('google', '', case=False).str.strip()

# %%
df['chipset_brand'] = df['chipset_brand'].str.split(',').str.get(0)

# %%
df[['processor_brand','chipset_brand']].sample(20)
# Out:
#      processor_brand                  chipset_brand
# 584         mediatek          dimensity 7300 energy
# 768         qualcomm            snapdragon 7s gen 3
# 864         mediatek           dimensity 7200 ultra
# 1265        qualcomm             snapdragon 8 elite
# 260         qualcomm                 snapdragon 695
# 887         qualcomm                snapdragon 750g
# 463         mediatek                 dimensity 8350
# 689         qualcomm                 snapdragon 870
# 871         qualcomm            snapdragon 7s gen 3
# 264         qualcomm            snapdragon 8s gen 3
# 953         mediatek                 dimensity 6300
# 71            google                      tensor g3
# 373         qualcomm             snapdragon 7 gen 3
# 1045        qualcomm  snapdragon 8 elite for galaxy
# 685         mediatek             dimensity 8400 max
# 234           unisoc                           t606
# 261         mediatek                 dimensity 7400
# 570         mediatek                 dimensity 7050
# 752         mediatek                 dimensity 7050
# 750         mediatek                 dimensity 6300

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 95 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
#  73  display_ppi                  1268 non-null   float64
#  74  color_depth                  1268 non-null   float64
#  75  peak_brightness              1206 non-null   float64
#  76  has_high_contrast            1268 non-null   int64
#  77  height_mm                    1268 non-null   float64
#  78  width_mm                     1268 non-null   float64
#  79  thickness_mm                 1268 non-null   float64
#  80  weight_g                     1268 non-null   float64
#  81  front_potection              1268 non-null   category
#  82  back_material                1268 non-null   category
#  83  frame_material               1268 non-null   category
#  84  durability_cert              1268 non-null   category
#  85  has_3_5mm_jack               1268 non-null   int64
#  86  usb_type                     1268 non-null   category
#  87  usb_version                  1268 non-null   float64
#  88  has_otg                      1268 non-null   int64
#  89  has_ir_blaster               1268 non-null   int64
#  90  water_resistance_level       1268 non-null   category
#  91  has_stereo_speakers          1268 non-null   int64
#  92  has_audio_certification      1268 non-null   int64
#  93  processor_brand              1268 non-null   category
#  94  chipset_brand                1268 non-null   object
# dtypes: category(11), datetime64[ns](1), float64(15), int64(21), object(47)
# memory usage: 849.2+ KB

# %%
df['chipset_nm'] = df['chipset'].str.split('(').str.get(1).str.split(')').str.get(0).str.split(' ').str.get(0)

# %%
df['chipset_nm'] = pd.to_numeric(df['chipset_nm'])

# %%
df['chipset_nm'].value_counts(dropna=False)
# Out:
# chipset_nm
# 4.0     494
# 6.0     390
# 12.0    167
# 3.0      83
# 5.0      73
# 7.0      34
# 8.0      11
# NaN      10
# 22.0      3
# 28.0      2
# 11.0      1
# Name: count, dtype: int64

# %%
df[df['chipset_nm'] == 11]['chipset']
# Out:
# 393    Qualcomm Snapdragon 6s Gen1 (11 nm), 440358 Antutu Score
# Name: chipset, dtype: object

# %%
df[df['chipset_nm'].isnull()]['chipset']
# Out:
# 137                  Unisoc SC9863A1, 148911 Antutu Score
# 188          MediaTek Dimensity 6300, 452218 Antutu Score
# 189          MediaTek Dimensity 6300, 452218 Antutu Score
# 376    MediaTek Dimensity 8350 Apex, 1403197 Antutu Score
# 377    MediaTek Dimensity 8350 Apex, 1403197 Antutu Score
# 378    MediaTek Dimensity 8350 Apex, 1403197 Antutu Score
# 392      Qualcomm Snapdragon 6s Gen1, 440358 Antutu Score
# 612                                              MediaTek
# 613                                              MediaTek
# 614                           MediaTek Dimensity 6400 Max
# Name: chipset, dtype: object

# %%
df['chipset_brand'].sample(20)
# Out:
# 616           snapdragon 680
# 1163    dimensity 7360 turbo
# 1157      snapdragon 7 gen 3
# 441           dimensity 9500
# 624            dimensity 920
# 1041             exynos 2400
# 795                helio g99
# 988           dimensity 6300
# 369           snapdragon 695
# 288           dimensity 7400
# 50                       a19
# 1031            exynos 2400e
# 294      snapdragon 6s gen 3
# 91        snapdragon 6 gen 1
# 926              exynos 1380
# 1115          dimensity 7400
# 1165    dimensity 7360 turbo
# 478           snapdragon 695
# 1258      snapdragon 8 gen 1
# 401           dimensity 6020
# Name: chipset_brand, dtype: object

# %%
df.loc[[612,613],'chipset_brand'] = np.nan

# %%
df.loc[[612,613]][['chipset','chipset_brand']]
# Out:
#       chipset chipset_brand
# 612  MediaTek           NaN
# 613  MediaTek           NaN

# %%
df['antutu_score'] = df['chipset'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)

# %%
df['antutu_score'] = pd.to_numeric(df['antutu_score'])

# %%
df['antutu_score'].sample(20)
# Out:
# 176      818358.0
# 316     2127544.0
# 709      244837.0
# 1016    1361686.0
# 174     1489956.0
# 114      452218.0
# 575      600033.0
# 1192     150618.0
# 68       910432.0
# 1122     548039.0
# 703      548039.0
# 483      123031.0
# 831      381200.0
# 956      438848.0
# 415      308333.0
# 8       1445704.0
# 428      670521.0
# 270     1299948.0
# 716      578522.0
# 976           NaN
# Name: antutu_score, dtype: float64

# %%
df[df['antutu_score'].isnull()]['chipset']
# Out:
# 67                       Google Tensor (5 nm)
# 406            MediaTek Dimensity 6300 (6 nm)
# 407            MediaTek Dimensity 6300 (6 nm)
# 408            MediaTek Dimensity 6300 (6 nm)
# 430            MediaTek Dimensity 6300 (6 nm)
# 441            MediaTek Dimensity 9500 (3 nm)
# 443            MediaTek Dimensity 9500 (3 nm)
# 606     MediaTek Dimensity 7300 Energy (4 nm)
# 607     MediaTek Dimensity 7300 Energy (4 nm)
# 612                                  MediaTek
# 613                                  MediaTek
# 614               MediaTek Dimensity 6400 Max
# 735        MediaTek Dimensity 6400 Max (6 nm)
# 736        MediaTek Dimensity 6400 Max (6 nm)
# 765            MediaTek Dimensity 6300 (6 nm)
# 766            MediaTek Dimensity 6300 (6 nm)
# 901                 MediaTek Helio G99 (6 nm)
# 945                 MediaTek Helio G99 (6 nm)
# 976                 MediaTek Helio G99 (6 nm)
# 1163     MediaTek Dimensity 7360 Turbo (4 nm)
# 1164     MediaTek Dimensity 7360 Turbo (4 nm)
# 1165     MediaTek Dimensity 7360 Turbo (4 nm)
# 1176           MediaTek Dimensity 9500 (3 nm)
# 1177           MediaTek Dimensity 9500 (3 nm)
# 1178           MediaTek Dimensity 9500 (3 nm)
# 1179           MediaTek Dimensity 9500 (3 nm)
# 1204           MediaTek Dimensity 6300 (6 nm)
# 1205           MediaTek Dimensity 6300 (6 nm)
# 1206           MediaTek Dimensity 6300 (6 nm)
# 1233       Qualcomm Snapdragon 4 Gen 2 (4 nm)
# 1234       Qualcomm Snapdragon 4 Gen 2 (4 nm)
# Name: chipset, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 97 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
#  73  display_ppi                  1268 non-null   float64
#  74  color_depth                  1268 non-null   float64
#  75  peak_brightness              1206 non-null   float64
#  76  has_high_contrast            1268 non-null   int64
#  77  height_mm                    1268 non-null   float64
#  78  width_mm                     1268 non-null   float64
#  79  thickness_mm                 1268 non-null   float64
#  80  weight_g                     1268 non-null   float64
#  81  front_potection              1268 non-null   category
#  82  back_material                1268 non-null   category
#  83  frame_material               1268 non-null   category
#  84  durability_cert              1268 non-null   category
#  85  has_3_5mm_jack               1268 non-null   int64
#  86  usb_type                     1268 non-null   category
#  87  usb_version                  1268 non-null   float64
#  88  has_otg                      1268 non-null   int64
#  89  has_ir_blaster               1268 non-null   int64
#  90  water_resistance_level       1268 non-null   category
#  91  has_stereo_speakers          1268 non-null   int64
#  92  has_audio_certification      1268 non-null   int64
#  93  processor_brand              1268 non-null   category
#  94  chipset_brand                1266 non-null   object
#  95  chipset_nm                   1258 non-null   float64
#  96  antutu_score                 1237 non-null   float64
# dtypes: category(11), datetime64[ns](1), float64(17), int64(21), object(47)
# memory usage: 869.0+ KB

# %%
df['cpu'].sample(20)
# Out:
# 219                                                     Octa-core (4x2.5 GHz Cortex-A78 & 4x2.0 GHz Cortex-A55)
# 1004                         Octa-core (1x2.4 GHz Cortex-A710 & 3x2.36 GHz Cortex-A710 & 4x1.8 GHz Cortex-A510)
# 439                            Octa-core (1x3.63 GHz Cortex-X925 & 3x3.3 GHz Cortex-X4 & 4x2.4 GHz Cortex-A720)
# 872                        Octa-core (1 x Cortex-A720@2.5GHz & 3 x Cortex-A720@2.4GHz & 4 x Cortex-A520@1.8GHz)
# 955                                                     Octa-core (2x2.4 GHz Cortex-A76 & 6x2.0 GHz Cortex-A55)
# 24                                                                          Hexa-core (2x3.78 GHz + 4x2.11 GHz)
# 112                                                     Octa-core (2x1.6 GHz Cortex-A75 & 6x1.6 GHz Cortex-A55)
# 490                                                     Octa-core (4x2.2 GHz Cortex-A53 & 4x1.6 GHz Cortex-A53)
# 644                                                     Octa-core (2x1.8 GHz Cortex-A75 & 6x1.8 GHz Cortex-A55)
# 549                                                     Octa-core (4x2.5 GHz Cortex-A78 & 4x2.0 GHz Cortex-A55)
# 1049                         Octa-core (1x3.19 GHz Cortex-X2 & 3x2.75 GHz Cortex-A710 & 4x1.80 GHz Cortex-A510)
# 1165                                                                      Octa-core (4 × 2.5 GHz + 4 × 2.0 GHz)
# 295                                                     Octa-core (2x2.0 GHz Cortex-A75 & 6x1.8 GHz Cortex-A55)
# 332     Octa-core (1x3.2 GHz Cortex-X3 & 2x2.8 GHz Cortex-A715 & 2x2.8 GHz Cortex-A710 & 3x2.0 GHz Cortex-A510)
# 1075                                            Octa-core (4x2.4 GHz Kryo 265 Gold & 4x1.9 GHz Kryo 265 Silver)
# 106                                                     Octa-core (4x2.3 GHz Cortex-A53 & 4x1.8 GHz Cortex-A53)
# 410                                                     Octa-core (4x2.3 GHz Cortex-A53 & 4x1.8 GHz Cortex-A53)
# 580                                                     Octa-core (2x2.4 GHz Cortex-A76 & 6x2.0 GHz Cortex-A55)
# 265                                                     Octa-core (4x2.5 GHz Cortex-A78 & 4x2.0 GHz Cortex-A55)
# 190                                                 Octa-core (2xCortex‑A76 @ 2.4 GHz + 6xCortex‑A55 @ 2.0 GHz)
# Name: cpu, dtype: object

# %%
df['cpu_core_count'] = df['cpu'].str.strip().str.split(' ').str.get(0)

# %%
df['cpu_core_count'].value_counts(dropna=False)
# Out:
# cpu_core_count
# Octa-core    1193
# Hexa-core      54
# Deca-core      13
# Quad-core       4
# Nona-core       4
# Name: count, dtype: int64

# %%
def extract_core_count(text):

  t = text.lower()

  if 'octa' in t:
    return 8

  if 'hexa' in t:
    return 6

  if 'deca' in t:
    return 10

  if 'quad' in t:
    return 4

  if 'nona' in t:
    return 9

df['cpu_core_count'] = df['cpu_core_count'].apply(extract_core_count)

# %%
df['cpu_core_count'].value_counts(dropna=False)
# Out:
# cpu_core_count
# 8     1193
# 6       54
# 10      13
# 4        4
# 9        4
# Name: count, dtype: int64

# %%
df['cpu_max_ghz'] = df['cpu'].str.extract(r'(\d+\.?\d*)\s*[Gg]*\s*[Gg]Hz', flags=re.IGNORECASE)

# %%
df['cpu_max_ghz'].value_counts(dropna=False)
# Out:
# cpu_max_ghz
# 2.4     235
# 2.2     195
# 2.5     122
# 2.0      83
# 2.6      58
# 1.8      43
# 3.0      38
# 2.8      38
# 2.3      33
# 3.2      32
# 3.1      27
# 3.35     26
# 3.3      25
# 2.63     22
# 2.40     20
# 4.32     19
# 1.6      16
# 3.19     16
# 3.46     14
# 3.00     13
# 2.05     13
# 4.26     12
# 3.25     12
# 3.36     11
# 2.85     11
# 4.04      9
# 2.84      9
# 3.05      8
# 4.21      7
# NaN       7
# 3.78      7
# 4.47      7
# 4.6       6
# 3.23      6
# 4.05      6
# 3.63      6
# 2.35      6
# 2.9       6
# 3.21      6
# 3.39      5
# 3.4       5
# 2.80      4
# 2.7       4
# 2.75      4
# 3.73      4
# 3         3
# 2.99      3
# 2.30      2
# 2.91      2
# 2.1       1
# 3.20      1
# Name: count, dtype: int64

# %%
df['cpu_max_ghz'] = pd.to_numeric(df['cpu_max_ghz'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 99 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
#  73  display_ppi                  1268 non-null   float64
#  74  color_depth                  1268 non-null   float64
#  75  peak_brightness              1206 non-null   float64
#  76  has_high_contrast            1268 non-null   int64
#  77  height_mm                    1268 non-null   float64
#  78  width_mm                     1268 non-null   float64
#  79  thickness_mm                 1268 non-null   float64
#  80  weight_g                     1268 non-null   float64
#  81  front_potection              1268 non-null   category
#  82  back_material                1268 non-null   category
#  83  frame_material               1268 non-null   category
#  84  durability_cert              1268 non-null   category
#  85  has_3_5mm_jack               1268 non-null   int64
#  86  usb_type                     1268 non-null   category
#  87  usb_version                  1268 non-null   float64
#  88  has_otg                      1268 non-null   int64
#  89  has_ir_blaster               1268 non-null   int64
#  90  water_resistance_level       1268 non-null   category
#  91  has_stereo_speakers          1268 non-null   int64
#  92  has_audio_certification      1268 non-null   int64
#  93  processor_brand              1268 non-null   category
#  94  chipset_brand                1266 non-null   object
#  95  chipset_nm                   1258 non-null   float64
#  96  antutu_score                 1237 non-null   float64
#  97  cpu_core_count               1268 non-null   int64
#  98  cpu_max_ghz                  1261 non-null   float64
# dtypes: category(11), datetime64[ns](1), float64(18), int64(22), object(47)
# memory usage: 888.8+ KB

# %%
df['gpu_brand'] = df['gpu'].str.lower().str.strip().str.split(' ').str.get(0)

# %%
df['gpu_brand'] = df['gpu_brand'].str.replace('-',' ')

# %%
df[df['gpu_brand'] == 'unspecified']['gpu']
# Out:
# 137    Unspecified
# Name: gpu, dtype: object

# %%
df.loc[137,'gpu_brand'] = np.nan

# %%
df['gpu_brand'].value_counts(dropna=False)
# Out:
# gpu_brand
# adreno              454
# mali g57            243
# mali g68             95
# arm                  79
# mali g615            57
# apple                54
# mali g52             50
# powervr              42
# mali g610            34
# img                  29
# xclipse              22
# NaN                  19
# mali                 19
# mali g77             12
# immortalis g720      12
# mali g710            10
# immortalis g715       9
# mali g720             7
# immortalis g925       6
# immortalis g715s      6
# mali g715             5
# mali g78              2
# ge8322                2
# Name: count, dtype: int64

# %%
df['gpu_brand'] = df['gpu_brand'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Data columns (total 100 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   model_id                     1268 non-null   int64
#  1   model                        1268 non-null   object
#  2   expert_rating                1268 non-null   int64
#  3   rating                       1268 non-null   float64
#  4   rating_count                 994 non-null    float64
#  5   launch_on                    1268 non-null   datetime64[ns]
#  6   old_price                    844 non-null    float64
#  7   price                        1268 non-null   int64
#  8   launch_price                 1268 non-null   int64
#  9   display_type                 1268 non-null   object
#  10  display_size                 1268 non-null   object
#  11  display_res                  1268 non-null   object
#  12  body_dimension               1268 non-null   object
#  13  weight                       1268 non-null   object
#  14  body_front                   1268 non-null   object
#  15  body_back                    1238 non-null   object
#  16  body_side                    1251 non-null   object
#  17  build_quality                739 non-null    object
#  18  ports                        1268 non-null   object
#  19  ip_rating                    915 non-null    object
#  20  speaker                      1265 non-null   object
#  21  chipset                      1268 non-null   object
#  22  cpu                          1268 non-null   object
#  23  gpu                          1250 non-null   object
#  24  main_cam                     1268 non-null   object
#  25  main_cam2                    1214 non-null   object
#  26  main_cam3                    631 non-null    object
#  27  main_cam_features            1268 non-null   object
#  28  main_video                   1239 non-null   object
#  29  os                           1268 non-null   object
#  30  software_updates             1228 non-null   object
#  31  ai_features                  780 non-null    object
#  32  front_cam                    1268 non-null   object
#  33  front_cam_features           1026 non-null   object
#  34  front_video                  1229 non-null   object
#  35  battery                      1268 non-null   object
#  36  charging                     1268 non-null   object
#  37  storage                      1268 non-null   object
#  38  ram                          1268 non-null   object
#  39  sim                          1264 non-null   object
#  40  tech                         1200 non-null   object
#  41  2g                           1262 non-null   object
#  42  3g                           1264 non-null   object
#  43  4g                           1267 non-null   object
#  44  5g                           1028 non-null   object
#  45  speed                        1264 non-null   object
#  46  wifi                         1268 non-null   object
#  47  bluetooth                    1266 non-null   object
#  48  positioning_system           1268 non-null   object
#  49  nfc                          595 non-null    object
#  50  finger_print                 1192 non-null   object
#  51  sensors                      1268 non-null   object
#  52  add_features                 469 non-null    object
#  53  brand                        1268 non-null   category
#  54  is_available                 1268 non-null   int64
#  55  is_flipkart_available        1268 non-null   int64
#  56  is_amazon_available          1268 non-null   int64
#  57  is_official_available        1268 non-null   int64
#  58  display_panel_type           1268 non-null   object
#  59  display_panel_family         1268 non-null   category
#  60  display_hz                   1268 non-null   int64
#  61  display_dynamic_range        1268 non-null   category
#  62  touch_sampling_rate          852 non-null    float64
#  63  has_ltpo                     1268 non-null   int64
#  64  has_anti_reflection_coating  1268 non-null   int64
#  65  display_inches               1268 non-null   float64
#  66  display_body_ratio           1036 non-null   float64
#  67  has_curved                   1268 non-null   int64
#  68  has_foldable                 1268 non-null   int64
#  69  res_category                 1268 non-null   category
#  70  res_width                    1268 non-null   int64
#  71  res_height                   1268 non-null   int64
#  72  aspect_ration_numeric        1185 non-null   float64
#  73  display_ppi                  1268 non-null   float64
#  74  color_depth                  1268 non-null   float64
#  75  peak_brightness              1206 non-null   float64
#  76  has_high_contrast            1268 non-null   int64
#  77  height_mm                    1268 non-null   float64
#  78  width_mm                     1268 non-null   float64
#  79  thickness_mm                 1268 non-null   float64
#  80  weight_g                     1268 non-null   float64
#  81  front_potection              1268 non-null   category
#  82  back_material                1268 non-null   category
#  83  frame_material               1268 non-null   category
#  84  durability_cert              1268 non-null   category
#  85  has_3_5mm_jack               1268 non-null   int64
#  86  usb_type                     1268 non-null   category
#  87  usb_version                  1268 non-null   float64
#  88  has_otg                      1268 non-null   int64
#  89  has_ir_blaster               1268 non-null   int64
#  90  water_resistance_level       1268 non-null   category
#  91  has_stereo_speakers          1268 non-null   int64
#  92  has_audio_certification      1268 non-null   int64
#  93  processor_brand              1268 non-null   category
#  94  chipset_brand                1266 non-null   object
#  95  chipset_nm                   1258 non-null   float64
#  96  antutu_score                 1237 non-null   float64
#  97  cpu_core_count               1268 non-null   int64
#  98  cpu_max_ghz                  1261 non-null   float64
#  99  gpu_brand                    1249 non-null   category
# dtypes: category(12), datetime64[ns](1), float64(18), int64(22), object(47)
# memory usage: 890.8+ KB

# %%
df['main_cam'].sample(20)
# Out:
# 871                      50 MP, f/1.6, 24mm (Wide-angle), 1 µm, 1/1.55", OIS, PDAF
# 1159               50 MP, f/1.88, 23mm (Wide-angle), 84°, 1 µm, 1/1.56", OIS, PDAF
# 1057          50 MP, f/1.8, 23mm (Wide-angle), 1 µm, 1/1.57", Dual Pixel PDAF, OIS
# 923                              48 MP, f/1.8, 0mm (Wide-angle), 0.8 µm, 1/2", OIS
# 800                                      50 MP, f/1.8, (Wide-angle), 1/1.28", PDAF
# 1138                          50 MP, f/1.9, (Wide-angle), 1 µm, 1/1.56", OIS, PDAF
# 930                     64 MP, f/1.8, 26mm (Wide-angle), 0.8 µm, 1/1.7", OIS, PDAF
# 675                    50 MP, f/1.9, 26mm (Wide-angle), 0.7 µm, 1/1.95", OIS, PDAF
# 167                      48 MP, f/1.8, 25mm (Wide-angle), 0.8 µm, Gimbal OIS, PDAF
# 390                                    50 MP, f/1.8, (Wide-angle), 76°, Auto Focus
# 1219                                              50 MP, f/1.8, (Wide-angle), PDAF
# 674                    50 MP, f/1.9, 26mm (Wide-angle), 0.7 µm, 1/1.95", OIS, PDAF
# 82      48 MP, f/1.7, 25mm (Wide-angle), 82°, 0.8 µm, 1/2.0", Dual Pixel PDAF, OIS
# 228                                      13 MP, f/2.2, (Wide-angle), 1.12 µm, PDAF
# 791                                   13 MP, f/2.2, (Wide-angle), 1 µm, Auto Focus
# 91                                     108 MP, f/1.75, (Wide-angle), 1/1.67", PDAF
# 1222                                              13 MP, f/2.2, (Wide-angle), PDAF
# 403               32 MP, f/1.8, 27mm (Wide-angle), 76°, 0.7 µm, 1/3.1", Auto Focus
# 311                      50 MP, f/1.9, 24mm (Wide-angle), 1 µm, 1/1.56", OIS, PDAF
# 87                          200 MP, f/1.9, 0mm (Wide-angle), 0.56 µm, 1/1.4", PDAF
# Name: main_cam, dtype: object

# %%
df['cam_primary_mp'] = df['main_cam'].str.split(',').str.get(0).str.strip().str.split(' ').str.get(0).astype('int')

# %%
df['cam_primary_mp'].value_counts(dropna=False)
# Out:
# cam_primary_mp
# 50     850
# 64      91
# 48      82
# 108     79
# 13      48
# 8       37
# 200     35
# 32      25
# 12      15
# 16       5
# 100      1
# Name: count, dtype: int64

# %%
df['cam_aperture'] = df['main_cam'].str.split(',').str.get(1).str.split('/').str.get(1).str.strip()

# %%
df['cam_aperture'].value_counts(dropna=False)
# Out:
# cam_aperture
# 1.8        726
# 1.9         80
# 1.88        60
# 1.79        60
# 1.7         53
# 1.6         53
# 1.75        42
# 2.2         42
# 2.0         40
# 1.5         19
# 1.78        18
# 1.68        14
# 1.89        13
# 1.65         9
# 1.85         7
# NaN          6
# 1.57         6
# 1.69         5
# 2.6          4
# 1.4          3
# 1.59         3
# 1.63         2
# 1.4-2.0      1
# 1.6-f        1
# 1.62         1
# Name: count, dtype: int64

# %%
df[df['cam_aperture'] == '1.6-f'][['main_cam','model']]
# Out:
#                                                                                           main_cam  \
# 1262  50 MP, f/1.6-f/4.0, 23mm (Wide-angle), 3.2 µm, 1.0", Auto Focus, Multi-directional PDAF, OIS
#
#                 model
# 1262  Xiaomi 14 Ultra

# %%
df.loc[89,'cam_aperture'] = '1.4'
df.loc[1262,'cam_aperture'] = '1.6'

# %%
df['cam_aperture'].value_counts(dropna=False)
# Out:
# cam_aperture
# 1.8     726
# 1.9      80
# 1.88     60
# 1.79     60
# 1.6      54
# 1.7      53
# 1.75     42
# 2.2      42
# 2.0      40
# 1.5      19
# 1.78     18
# 1.68     14
# 1.89     13
# 1.65      9
# 1.85      7
# 1.57      6
# NaN       6
# 1.69      5
# 1.4       4
# 2.6       4
# 1.59      3
# 1.63      2
# 1.62      1
# Name: count, dtype: int64

# %%
df['cam_aperture'] = pd.to_numeric(df['cam_aperture'])

# %%
df['main_cam'].sample(20)
# Out:
# 296                                        50 MP, f/1.8, (Wide-angle), 0.64 µm, 1/1.28", PDAF
# 42          48 MP, f/1.6, 26mm (Wide-angle), 1 µm, 1/1.56", Dual Pixel PDAF, Sensor-Shift OIS
# 1118                                               50 MP, f/1.8, 0mm (Wide-angle), Auto Focus
# 530                                                                50 MP, f/1.8, (Wide-angle)
# 691                                             64 MP, f/1.79, 25mm (Wide-angle), 80.5°, PDAF
# 799                                     50 MP, f/1.8, 0mm (Wide-angle), 0.7 µm, 1/1.28", PDAF
# 883                                64 MP, f/1.8, 26mm (Wide-angle), 0.8 µm, 1/1.7", OIS, PDAF
# 1119                                               50 MP, f/1.8, 0mm (Wide-angle), Auto Focus
# 276                           50 MP, f/1.8, (Wide-angle), 1 µm, 1/1.56", Dual Pixel PDAF, OIS
# 425                                          50 MP, f/1.8, (Wide-angle), 77°, Auto Focus, EIS
# 438                                           50 MP, f/1.8, 24mm (Wide-angle), 84°, OIS, PDAF
# 705                             50 MP, f/1.8, 26mm (Wide-angle), 0.64 µm, 1/2.76", Auto Focus
# 257                                              50 MP, f/1.8, (Wide-angle), 1.25 µm, 1/2.76"
# 188                                                    50 MP, f/1.8, (Wide-angle), Auto Focus
# 46      48 MP, f/1.78, 24mm (Wide-angle), 1.12 µm, 1/1.28", Dual Pixel PDAF, Sensor-Shift OIS
# 125                                       108 MP, f/1.75, 24mm (Wide-angle), Auto Focus, PDAF
# 121                                               50 MP, f/1.6, (Wide-angle), 0.64 µm, 1/2.8"
# 1065                                                 200 MP, f/1.7, (Wide-angle), 85°, 0.6 µm
# 1193                                               13 MP, f/2.2, 0mm (Wide-angle), Auto Focus
# 84                                                         108 MP, f/1.75, (Wide-angle), PDAF
# Name: main_cam, dtype: object

# %%
def extract_ois(text):

  t = text.lower()

  if 'ois' in t:
    return 1

  return 0

df['cam_has_ois'] = df['main_cam'].apply(extract_ois)

# %%
df['cam_has_ois'].value_counts()
# Out:
# cam_has_ois
# 0    661
# 1    607
# Name: count, dtype: int64
